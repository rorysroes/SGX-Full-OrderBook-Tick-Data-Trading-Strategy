# %%
import time 
def insert(order_book_data,data_to_insert,ob_position):
    top = order_book_data[0:ob_position]
    bottom = order_book_data[ob_position:]
    return pd.concat((top,data_to_insert,bottom)).reset_index(drop = True)

start  =  time.time()

order_book_bid = []
order_book_ask = []
timestamp = data.TimeStamp[0]
temp_ask = 0
temp_bid = 0
bid = []
ask = []
timestamp_ = []
x = data.TimeStamp.unique()
time_contain = []
time_book_sorting = []
timestamp_.append(x[0])
y = data[data['TimeStamp'].str.contains(x[0])]
bid.append(y[(y.BidOrAsk == 'B')][["Price","OrderNumber","QuantityDifference"]]) # bid
ask.append(y[(y.BidOrAsk == 'A')][["Price","OrderNumber","QuantityDifference"]]) # ask
a = bid[0].sort(['Price'],ascending = [False])
b = ask[0].sort(['Price'],ascending = [True])    
order_book_bid.append(a[a.QuantityDifference != 0].reset_index(drop = True))
order_book_ask.append(b[b.QuantityDifference != 0].reset_index(drop = True))

order_book_bid.append(0)
order_book_ask.append(0)
#temp_ask = 0
#temp_bid = 0

for i in range(len(y),100,1):
    print '------------------------------------------------------------------------------'
    print 'data_number = %d'%(i)
    if data.BidOrAsk[i] == 'A':
        print 'BidOrAsk = A'
        print 'temp_ask = %d'%(temp_ask)
        print 'timestamp = '+x[temp_ask]
        print data[i:i+1][['Price',"OrderNumber","QuantityDifference"]]
        print int(data[['QuantityDifference']][i:i+1].values)
        
        if int(data[['QuantityDifference']][i:i+1].values) > 0:
            print 'QuantityDifference = %d > 0 is True'%(int(data[['QuantityDifference']][i:i+1].values))
        else:
            print 'QuantityDifference = %d < 0 is False'%(int(data[['QuantityDifference']][i:i+1].values))
            
        print '/t'
        
        if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            
            print data.TimeStamp[i]
            print x[temp_ask]
            #print data.TimeStamp[i] == x[temp_ask]
            
            if data.TimeStamp[i] == x[temp_ask]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                #print order_book_ask[temp_ask]
                #print int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                #print order_book_ask[temp_ask - 1][(order_book_ask[temp_ask - 1].OrderNumber == data[i:i+1]['OrderNumber'].iloc[0])].index       
                print order_book_ask[temp_ask]
                order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                #print int(data[['OrderBookPosition']][i:i+1].iloc[0])-1
                #order_book_ask[temp_ask - 1].loc[int(data[['OrderBookPosition']][i:i+1].iloc[0])-1] = data[['Price','OrderNumber','QuantityDifference']][i:i+1].iloc[0]       
                #print order_book_ask[temp_ask]
                print order_book_ask[temp_ask]
                
                #print order_book_ask[temp_ask][position_-1:position_+1-1]["Price"].iloc[0]
                #if order_book_ask[temp_ask][position_-1:position_+1-1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                #    print 'Some error %d and %d'%(i,data[['Price']][i:i+1].iloc[0])#+data['OrderNumber'][i:i+1].iloc[0]
                #else:
                #    print 'position and Best Price is True'
                if position_ == 0:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                    else:
                        print 'position and Best Price is True'                     
                   
                elif (0 < position_< (len(order_book_ask[temp_ask])-1)):
                    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                    else:
                        print 'position and Best Price is True'   
                        
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                    else:
                        print 'position and Best Price is True'                
                
                
                
                #order_book_ask[temp_ask - 1] 
                #print order_book_ask[temp_ask]
                
            elif data.TimeStamp[i] != x[temp_ask]:
                if temp_ask == 0:
                    order_book_ask[temp_ask + 1] = order_book_ask[temp_ask]
                    order_book_ask[temp_ask + 1] = insert(order_book_ask[temp_ask + 1],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    if position_ == 0:
                        if order_book_ask[temp_ask + 1][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        else:
                            print 'position and Best Price is True'                     
                   
                    elif 0 < position_< len(order_book_ask[temp_ask + 1])-1:
                    
                        if order_book_ask[temp_ask + 1][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask + 1][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        else:
                            print 'position and Best Price is True'  
                    elif position_ == len(order_book_ask[temp_ask + 1])-1:
                        
                        if order_book_ask[temp_ask + 1][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        else:
                            print 'position and Best Price is True'
                            
                    temp_ask = temp_ask + 1
                    print order_book_ask[temp_ask]                        
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    print position_
                    print order_book_ask[temp_ask]
                    order_book_ask.append(order_book_ask[temp_ask])
                    temp_ask = temp_ask + 1
                    print order_book_ask[temp_ask]
                    #print int(data[['OrderBookPosition']][i:i+1].iloc[0])-1
                    print 'temp_ask1 = %d'%(temp_ask)
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    print order_book_ask[temp_ask]
                    
                    #if order_book_ask[temp_ask][position_-1:position_+1-1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                    #    print 'Some error %d and %d'%(i,data[['Price']][i:i+1].iloc[0])#+data['OrderNumber'][i:i+1].iloc[0]
                    #else:
                    #    print 'position and Best Price is True' 
                        
                    if position_ == 0:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        else:
                            print 'position and Best Price is True'                     
                   
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        else:
                            print 'position and Best Price is True'  
                    elif position_ == len(order_book_ask[temp_ask])-1:
                        
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        else:
                            print 'position and Best Price is True'                        
                           
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    
            #Price_ =  int(data[['Price']][i:i+1].values)
            #Order_Number_ = data[['OrderNumber']][i:i+1].iloc[0] 
            #position_ = int(data[['OrderBookPosition']][i:i+1].values)
            #index_ = order_book_ask[temp_ask - 1][(order_book_ask[temp_ask - 1].Price == Price_)].index + 1
            #print index_
            #print position_
            #print Order_Number_ 
            #print order_book_ask[temp_ask]
            #print data.TimeStamp[i] == x[temp_ask]
            
            if data.TimeStamp[i] == x[temp_ask]: 
                #print order_book_ask[temp_ask - 1]
                #print int(data[['OrderBookPosition']][i:i+1].iloc[0])
                #order_book_ask[temp_ask]  = insert_sum(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0]))     
                ob_position = int(data[['OrderBookPosition']][i:i+1].iloc[0])
                top = order_book_ask[temp_ask - 1][0:(ob_position-1)]
                bottom = order_book_ask[temp_ask - 1][ob_position:]
                QuantityDifference_1 = order_book_ask[temp_ask - 1][(ob_position-1):ob_position].QuantityDifference
                QuantityDifference_2 = data[i:i+1].QuantityDifference
                QuantityDifference_1 = int(QuantityDifference_1.values)
                QuantityDifference_2 = int(QuantityDifference_2.values)
                QuantityDifference_ = QuantityDifference_1 + QuantityDifference_2
                #print QuantityDifference_
                #print type(QuantityDifference_)
                #print order_book_ask[temp_ask - 1][(ob_position-1):ob_position]                
                order_book_ask[temp_ask - 1][(ob_position-1):ob_position][["QuantityDifference"]] = QuantityDifference_
                order_book_ask[temp_ask - 1] = pd.concat((top,order_book_ask[temp_ask - 1][(ob_position-1):ob_position],bottom)).reset_index(drop = True)                
                order_book_ask[temp_ask - 1] = order_book_ask[temp_ask - 1][order_book_ask[temp_ask - 1].QuantityDifference != 0].reset_index(drop = True) 
                #print order_book_ask[temp_ask - 1] 
                
            elif data.TimeStamp[i] != x[temp_ask]:
                order_book_ask.append(order_book_ask[temp_ask - 1])
                #print order_book_ask[temp_ask - 1]
                order_book_ask.append(0)
                temp_ask = temp_ask + 1
                #print order_book_ask[temp_ask - 1]
                #print order_book_ask[temp_ask - 2]
                #order_book_ask[temp_ask]  = insert_sum(order_book_ask[temp_ask - 1],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0]))     
                ob_position = int(data[['OrderBookPosition']][i:i+1].iloc[0])
                top = order_book_ask[temp_ask - 2][0:(ob_position-1)]
                bottom = order_book_ask[temp_ask - 2][ob_position:]
                QuantityDifference_1 = order_book_ask[temp_ask - 2][(ob_position-1):ob_position].QuantityDifference
                QuantityDifference_2 = data[i:i+1].QuantityDifference
                
                QuantityDifference_1 = int(QuantityDifference_1.values)
                QuantityDifference_2 = int(QuantityDifference_2.values)
                QuantityDifference_ = QuantityDifference_1 + QuantityDifference_2
                #print QuantityDifference_
                #print type(QuantityDifference_)
                #print order_book_ask[temp_ask - 2][(ob_position-1):ob_position]
                order_book_ask[temp_ask - 2][(ob_position - 1):ob_position][["QuantityDifference"]] = QuantityDifference_
                order_book_ask[temp_ask - 1] = pd.concat((top,order_book_ask[temp_ask - 2][(ob_position-1):ob_position],bottom)).reset_index(drop = True)                
                order_book_ask[temp_ask - 1] = order_book_ask[temp_ask - 1][order_book_ask[temp_ask - 1].QuantityDifference != 0].reset_index(drop = True) 
                #print order_book_ask[temp_ask - 1] 

end = time.time()            
print "Total time = %f"%(end - start)

# %%
import time 
def insert(order_book_data,data_to_insert,ob_position):
    top = order_book_data[0:ob_position]
    bottom = order_book_data[ob_position:]
    return pd.concat((top,data_to_insert,bottom)).reset_index(drop = True)

start  =  time.time()

order_book_bid = []
order_book_ask = []
timestamp = data.TimeStamp[0]
temp_ask = 0
temp_bid = 0
bid = []
ask = []
timestamp_ = []
x = data.TimeStamp.unique()
time_contain = []
time_book_sorting = []
timestamp_.append(x[0])
y = data[data['TimeStamp'].str.contains(x[0])]
bid.append(y[(y.BidOrAsk == 'B')][["Price","OrderNumber","QuantityDifference"]]) # bid
ask.append(y[(y.BidOrAsk == 'A')][["Price","OrderNumber","QuantityDifference"]]) # ask
a = bid[0].sort(['Price'],ascending = [False])
b = ask[0].sort(['Price'],ascending = [True])    
order_book_bid.append(a[a.QuantityDifference != 0].reset_index(drop = True))
order_book_ask.append(b[b.QuantityDifference != 0].reset_index(drop = True))

order_book_bid.append(0)
order_book_ask.append(0)
#temp_ask = 0
#temp_bid = 0

for i in range(len(y),100,1):
    print '------------------------------------------------------------------------------'
    print 'data_number = %d'%(i)
    if data.BidOrAsk[i] == 'A':
        print 'BidOrAsk = A'
        print 'temp_ask = %d'%(temp_ask)
        print 'timestamp = '+x[temp_ask]
        print data[i:i+1][['Price',"OrderNumber","QuantityDifference"]]
        print int(data[['QuantityDifference']][i:i+1].values)
        
        if int(data[['QuantityDifference']][i:i+1].values) > 0:
            print 'QuantityDifference = %d > 0 is True'%(int(data[['QuantityDifference']][i:i+1].values))
        else:
            print 'QuantityDifference = %d < 0 is False'%(int(data[['QuantityDifference']][i:i+1].values))
            
        print '/t'
        
        if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            
            print data.TimeStamp[i]
            print x[temp_ask]
            #print data.TimeStamp[i] == x[temp_ask]
            
            if data.TimeStamp[i] == x[temp_ask]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                #print order_book_ask[temp_ask]
                #print int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                #print order_book_ask[temp_ask - 1][(order_book_ask[temp_ask - 1].OrderNumber == data[i:i+1]['OrderNumber'].iloc[0])].index       
                print order_book_ask[temp_ask]
                order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                #print int(data[['OrderBookPosition']][i:i+1].iloc[0])-1
                #order_book_ask[temp_ask - 1].loc[int(data[['OrderBookPosition']][i:i+1].iloc[0])-1] = data[['Price','OrderNumber','QuantityDifference']][i:i+1].iloc[0]       
                #print order_book_ask[temp_ask]
                print order_book_ask[temp_ask]
                
                #print order_book_ask[temp_ask][position_-1:position_+1-1]["Price"].iloc[0]
                #if order_book_ask[temp_ask][position_-1:position_+1-1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                #    print 'Some error %d and %d'%(i,data[['Price']][i:i+1].iloc[0])#+data['OrderNumber'][i:i+1].iloc[0]
                #else:
                #    print 'position and Best Price is True'
                if position_ == 0:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        continue
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif (0 < position_< (len(order_book_ask[temp_ask])-1)):
                    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        continue
                    else:
                        print 'position and Best Price is True'   
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        continue
                    else:
                        print 'position and Best Price is True'                
                        continue
                
                
                #order_book_ask[temp_ask - 1] 
                #print order_book_ask[temp_ask]
                
            elif data.TimeStamp[i] != x[temp_ask]:
                if temp_ask == 0:
                    order_book_ask[temp_ask + 1] = order_book_ask[temp_ask]
                    order_book_ask[temp_ask + 1] = insert(order_book_ask[temp_ask + 1],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    if position_ == 0:
                        if order_book_ask[temp_ask + 1][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask + 1])-1:
                    
                        if order_book_ask[temp_ask + 1][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask + 1][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask + 1])-1:
                        
                        if order_book_ask[temp_ask + 1][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'
                            continue
                    temp_ask = temp_ask + 1
                    print order_book_ask[temp_ask]                        
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    print position_
                    print order_book_ask[temp_ask]
                    order_book_ask.append(order_book_ask[temp_ask])
                    temp_ask = temp_ask + 1
                    print order_book_ask[temp_ask]
                    #print int(data[['OrderBookPosition']][i:i+1].iloc[0])-1
                    print 'temp_ask1 = %d'%(temp_ask)
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    print order_book_ask[temp_ask]
                    
                    #if order_book_ask[temp_ask][position_-1:position_+1-1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                    #    print 'Some error %d and %d'%(i,data[['Price']][i:i+1].iloc[0])#+data['OrderNumber'][i:i+1].iloc[0]
                    #else:
                    #    print 'position and Best Price is True' 
                        
                    if position_ == 0:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:
                        
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'                        
                            continue
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    
            #Price_ =  int(data[['Price']][i:i+1].values)
            #Order_Number_ = data[['OrderNumber']][i:i+1].iloc[0] 
            #position_ = int(data[['OrderBookPosition']][i:i+1].values)
            #index_ = order_book_ask[temp_ask - 1][(order_book_ask[temp_ask - 1].Price == Price_)].index + 1
            #print index_
            #print position_
            #print Order_Number_ 
            #print order_book_ask[temp_ask]
            #print data.TimeStamp[i] == x[temp_ask]
            print data.TimeStamp[i]
            print x[temp_ask]
            
            if data.TimeStamp[i] == x[temp_ask]: 
                #print order_book_ask[temp_ask - 1]
                #print int(data[['OrderBookPosition']][i:i+1].iloc[0])
                #order_book_ask[temp_ask]  = insert_sum(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0]))     
                
                ob_position = int(data[['OrderBookPosition']][i:i+1].iloc[0])
                top = order_book_ask[temp_ask - 1][0:(ob_position-1)]
                bottom = order_book_ask[temp_ask - 1][ob_position:]
                QuantityDifference_1 = order_book_ask[temp_ask - 1][(ob_position-1):ob_position].QuantityDifference
                QuantityDifference_2 = data[i:i+1].QuantityDifference
                QuantityDifference_1 = int(QuantityDifference_1.values)
                QuantityDifference_2 = int(QuantityDifference_2.values)
                QuantityDifference_ = QuantityDifference_1 + QuantityDifference_2
                #print QuantityDifference_
                #print type(QuantityDifference_)
                #print order_book_ask[temp_ask - 1][(ob_position-1):ob_position]                
                order_book_ask[temp_ask - 1][(ob_position-1):ob_position][["QuantityDifference"]] = QuantityDifference_
                order_book_ask[temp_ask - 1] = pd.concat((top,order_book_ask[temp_ask - 1][(ob_position-1):ob_position],bottom)).reset_index(drop = True)                
                order_book_ask[temp_ask - 1] = order_book_ask[temp_ask - 1][order_book_ask[temp_ask - 1].QuantityDifference != 0].reset_index(drop = True) 
                #print order_book_ask[temp_ask - 1] 
                
            elif data.TimeStamp[i] != x[temp_ask]:
                print temp_ask
                print order_book_ask[temp_ask]
                order_book_ask.append(order_book_ask[temp_ask])
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]

                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                print order_book_ask[temp_ask]
                if position_ == 0:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        continue
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        continue
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        continue
                    else:
                        print 'position and Best Price is True'                        
                        continue                
                
                
                
                #order_book_ask[temp_ask - 2][(ob_position - 1):ob_position][["QuantityDifference"]] = QuantityDifference_
                #order_book_ask[temp_ask - 1] = pd.concat((top,order_book_ask[temp_ask - 2][(ob_position-1):ob_position],bottom)).reset_index(drop = True)                
                #order_book_ask[temp_ask - 1] = order_book_ask[temp_ask - 1][order_book_ask[temp_ask - 1].QuantityDifference != 0].reset_index(drop = True) 
                #print order_book_ask[temp_ask - 1] 

end = time.time()            
print "Total time = %f"%(end - start)

# %%
import time 
def insert(order_book_data,data_to_insert,ob_position):
    top = order_book_data[0:ob_position]
    bottom = order_book_data[ob_position:]
    return pd.concat((top,data_to_insert,bottom)).reset_index(drop = True)

start  =  time.time()

order_book_bid = []
order_book_ask = []
timestamp = data.TimeStamp[0]
temp_ask = 0
temp_bid = 0
bid = []
ask = []
timestamp_ = []
x = data.TimeStamp.unique()
time_contain = []
time_book_sorting = []
timestamp_.append(x[0])
y = data[data['TimeStamp'].str.contains(x[0])]
bid.append(y[(y.BidOrAsk == 'B')][["Price","OrderNumber","QuantityDifference"]]) # bid
ask.append(y[(y.BidOrAsk == 'A')][["Price","OrderNumber","QuantityDifference"]]) # ask
a = bid[0].sort(['Price'],ascending = [False])
b = ask[0].sort(['Price'],ascending = [True])    
order_book_bid.append(a[a.QuantityDifference != 0].reset_index(drop = True))
order_book_ask.append(b[b.QuantityDifference != 0].reset_index(drop = True))

order_book_bid.append(0)
order_book_ask.append(0)
#temp_ask = 0
#temp_bid = 0

for i in range(len(y),3200,1):
    print '------------------------------------------------------------------------------'
    print 'data_number = %d'%(i)
    if data.BidOrAsk[i] == 'A':
        print 'BidOrAsk = A'
        print 'temp_ask = %d'%(temp_ask)
        print 'timestamp = '+x[temp_ask]
        print data[i:i+1][['Price',"OrderNumber","QuantityDifference"]]
        print int(data[['QuantityDifference']][i:i+1].values)
        
        if int(data[['QuantityDifference']][i:i+1].values) > 0:
            print 'QuantityDifference = %d > 0 is True'%(int(data[['QuantityDifference']][i:i+1].values))
        else:
            print 'QuantityDifference = %d < 0 is False'%(int(data[['QuantityDifference']][i:i+1].values))
            
        print '/t'
        
        if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            
            print data.TimeStamp[i]
            print x[temp_ask]
            #print data.TimeStamp[i] == x[temp_ask]
            
            if data.TimeStamp[i] == x[temp_ask]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                #print order_book_ask[temp_ask]
                #print int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                #print order_book_ask[temp_ask - 1][(order_book_ask[temp_ask - 1].OrderNumber == data[i:i+1]['OrderNumber'].iloc[0])].index       
                print order_book_ask[temp_ask]
                order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                #print int(data[['OrderBookPosition']][i:i+1].iloc[0])-1
                #order_book_ask[temp_ask - 1].loc[int(data[['OrderBookPosition']][i:i+1].iloc[0])-1] = data[['Price','OrderNumber','QuantityDifference']][i:i+1].iloc[0]       
                #print order_book_ask[temp_ask]
                
                
                
                
                print order_book_ask[temp_ask]
                
                #print order_book_ask[temp_ask][position_-1:position_+1-1]["Price"].iloc[0]
                #if order_book_ask[temp_ask][position_-1:position_+1-1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                #    print 'Some error %d and %d'%(i,data[['Price']][i:i+1].iloc[0])#+data['OrderNumber'][i:i+1].iloc[0]
                #else:
                #    print 'position and Best Price is True'
                if position_ == 0:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif (0 < position_< (len(order_book_ask[temp_ask])-1)):
                    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'   
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                
                        continue
                
                
                #order_book_ask[temp_ask - 1] 
                #print order_book_ask[temp_ask]
                
            elif data.TimeStamp[i] != x[temp_ask]:
                if temp_ask == 0:
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = order_book_ask[temp_ask - 1]
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    if position_ == 0:
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask + 1])-1:
                    
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask + 1][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:
                        
                        if order_book_ask[temp_ask][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'
                            continue
                    print order_book_ask[temp_ask]                        
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    print position_
                    print order_book_ask[temp_ask]
                    order_book_ask.append(order_book_ask[temp_ask])
                    temp_ask = temp_ask + 1
                    print order_book_ask[temp_ask]
                    #print int(data[['OrderBookPosition']][i:i+1].iloc[0])-1
                    print 'temp_ask1 = %d'%(temp_ask)
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    print order_book_ask[temp_ask]
                    
                    #if order_book_ask[temp_ask][position_-1:position_+1-1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                    #    print 'Some error %d and %d'%(i,data[['Price']][i:i+1].iloc[0])#+data['OrderNumber'][i:i+1].iloc[0]
                    #else:
                    #    print 'position and Best Price is True' 
                        
                    if position_ == 0:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:
                        
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                        
                            continue
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    
            #Price_ =  int(data[['Price']][i:i+1].values)
            #Order_Number_ = data[['OrderNumber']][i:i+1].iloc[0] 
            #position_ = int(data[['OrderBookPosition']][i:i+1].values)
            #index_ = order_book_ask[temp_ask - 1][(order_book_ask[temp_ask - 1].Price == Price_)].index + 1
            #print index_
            #print position_
            #print Order_Number_ 
            #print order_book_ask[temp_ask]
            #print data.TimeStamp[i] == x[temp_ask]
            print data.TimeStamp[i]
            print x[temp_ask]
            
            if data.TimeStamp[i] == x[temp_ask]: 
                print temp_ask
                print order_book_ask[temp_ask]
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                print order_book_ask[temp_ask]
                
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                print order_book_ask[temp_ask]
                
                if position_ == 0:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                        
                        continue
                #print order_book_ask[temp_ask - 1]
                #print int(data[['OrderBookPosition']][i:i+1].iloc[0])
                #order_book_ask[temp_ask]  = insert_sum(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0]))     
                #position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0])
                #top = order_book_ask[temp_ask - 1][0:(ob_position-1)]
                #bottom = order_book_ask[temp_ask - 1][ob_position:]
                #QuantityDifference_1 = order_book_ask[temp_ask - 1][(ob_position-1):ob_position].QuantityDifference
                #QuantityDifference_2 = data[i:i+1].QuantityDifference
                #QuantityDifference_1 = int(QuantityDifference_1.values)
                #QuantityDifference_2 = int(QuantityDifference_2.values)
                #QuantityDifference_ = QuantityDifference_1 + QuantityDifference_2
                #print QuantityDifference_
                #print type(QuantityDifference_)
                #print order_book_ask[temp_ask - 1][(ob_position-1):ob_position]                
                #order_book_ask[temp_ask - 1][(ob_position-1):ob_position][["QuantityDifference"]] = QuantityDifference_
                #order_book_ask[temp_ask - 1] = pd.concat((top,order_book_ask[temp_ask - 1][(ob_position-1):ob_position],bottom)).reset_index(drop = True)                
                #order_book_ask[temp_ask - 1] = order_book_ask[temp_ask - 1][order_book_ask[temp_ask - 1].QuantityDifference != 0].reset_index(drop = True) 
                #print order_book_ask[temp_ask - 1] 
                
                
                
                
                
                
            elif data.TimeStamp[i] != x[temp_ask]:
                
                print temp_ask
                print order_book_ask[temp_ask]
                order_book_ask.append(order_book_ask[temp_ask])
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_ask = temp_ask + 1
                print 'temp_ask2 = %d'%(temp_ask)
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                print order_book_ask[temp_ask]
                
                if position_ == 0:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                        
                        continue                
                
                
                
                #order_book_ask[temp_ask - 2][(ob_position - 1):ob_position][["QuantityDifference"]] = QuantityDifference_
                #order_book_ask[temp_ask - 1] = pd.concat((top,order_book_ask[temp_ask - 2][(ob_position-1):ob_position],bottom)).reset_index(drop = True)                
                #order_book_ask[temp_ask - 1] = order_book_ask[temp_ask - 1][order_book_ask[temp_ask - 1].QuantityDifference != 0].reset_index(drop = True) 
                #print order_book_ask[temp_ask - 1] 

end = time.time()            
print "Total time = %f"%(end - start)
