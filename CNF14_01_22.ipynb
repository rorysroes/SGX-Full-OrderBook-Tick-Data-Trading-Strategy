# %%
# %pylab inline
# Out:
# /home/rory/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd

# %%
data = []
datapath = '/home/rory/SGX-OrderBook-Tick-Data-Trading-Strategy-/CN_Futures_2014.01.22.csv'
data = pd.read_csv(datapath)

# %%
data_CNF14 = data[data.Series == 'CNF14']

# %%
len(data_CNF14)
# Out:
# 162389

# %%
data = data_CNF14[0:80000]

# %%
len(data)
# Out:
# 80000

# %%
data
# Out:
#       Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 0      CNF14               1  2014-01-22D04:21:22.786910500  E3D584F55D4240C2
# 1      CNF14               2  2014-01-22D04:21:22.786910500  B86D00C4CBBFB0BF
# 2      CNF14               3  2014-01-22D04:21:22.786910500  E1C9F25394A679A6
# 3      CNF14               4  2014-01-22D04:21:22.786910500  470284B16BBE4ABE
# 4      CNF14               5  2014-01-22D04:21:22.786910500  C7118CE560A044E0
# 5      CNF14               6  2014-01-22D04:21:22.786910500  6827C7006AEC4FEC
# 6      CNF14               7  2014-01-22D04:21:22.786910500  AF342B8CD518B4B8
# 7      CNF14               8  2014-01-22D04:21:22.786910500  C15D08A5B29C96DC
# 8      CNF14               9  2014-01-22D04:21:22.786910500  48A74F481D750275
# 9      CNF14              10  2014-01-22D04:21:22.786910500  E19E84B960F74517
# 10     CNF14              11  2014-01-22D04:21:22.786910500  166000C4C677AB77
# 11     CNF14              12  2014-01-22D04:21:22.786910500  6D8780B9C86AAC2A
# 12     CNF14              13  2014-01-22D04:21:22.789910500  4FD78CE15D293CC9
# 13     CNF14              14  2014-01-22D04:21:22.789910500  AF3C2B844DF22D92
# 14     CNF14              15  2014-01-22D04:21:22.789910500  E11624B9A6DB85BB
# 15     CNF14              16  2014-01-22D04:21:22.789910500  4F4B0CB99DFF81BF
# 16     CNF14              17  2014-01-22D04:21:22.789910500  4B4B00B965684508
# 17     CNF14              18  2014-01-22D04:21:22.789910500  479100EDBB3D9F7D
# 18     CNF14              19  2014-01-22D04:21:22.789910500  9672009CE4FAC9FA
# 19     CNF14              20  2014-01-22D04:21:22.789910500  152F8AFD935775B7
# 20     CNF14              21  2014-01-22D04:21:22.789910500  63C12CA1413024D0
# 21     CNF14              22  2014-01-22D04:21:22.789910500  C791DA0F799A5E9A
# 22     CNF14              23  2014-01-22D04:21:22.789910500  6DC928E93E1C21BC
# 23     CNF14              24  2014-01-22D08:45:02.804303200  E0F8E35871055345
# 24     CNF14              25  2014-01-22D08:45:02.942300400  48FC67407C7E5E9E
# 25     CNF14              26  2014-01-22D08:45:05.147274400  E87CEB509D787FB8
# 26     CNF14              27  2014-01-22D08:45:12.388183400  E8FCEB586BB84DF8
# 27     CNF14              28  2014-01-22D08:45:18.698105400  607C6750520D344D
# 28     CNF14              29  2014-01-22D08:45:26.468001400  6074E750B03D927D
# 29     CNF14              30  2014-01-22D08:45:28.659975400  ECFC6B0831EB144B
# ...      ...             ...                            ...               ...
# 79970  CNF14           79971  2014-01-22D10:57:54.268958200  C195ACF1D7E3B723
# 79971  CNF14           79972  2014-01-22D10:57:54.271958200  6F1420F1201CFF5D
# 79972  CNF14           79973  2014-01-22D10:57:54.271958200  484EA171D7A3B843
# ...                  ...     ...                 ...   ...      ...
# 79970                 12  682000                   1              A
# 79971                 13  682000                  25              A
# 79972                113  684000                 -11              A
# 79973                 14  682000                  11              A
# 79974                 15  682000                  20              A
# 79975                 16  682000                  15              A
# 79976                 91  683500                 -11              A
# 79977                 17  682000                  11              A
# 79978                170  687500                   1              A
# 79979                113  684000                 -11              A
# 79980                 18  682000                  11              A
# 79981                202  689500                   1              A
# 79982                187  688500                   1              A
# 79983                 93  683500                 -18              A
# 79984                 72  683000                  18              A
# 79985                 18  682000                 -11              A
# 79986                 17  682000                 -11              A
# 79987                 92  683500                  11              A
# 79988                115  684000                  11              A
# 79989                204  689500                   1              A
# 79990                170  687500                  -1              A
# 79991                186  688500                  -1              A
# 79992                 92  683500                 -11              A
# 79993                 17  682000                  11              A
# 79994                115  684000                 -11              A
# 79995                 18  682000                  11              A
# 79996                201  689500                  -1              A
# 79997                201  689500                  -1              A
# 79998                153  677000                 -18              B
# 79999                163  676500                  18              B
#
#        BestPrice  BestQuantity
# 0         672000            20
# 1         666500            20
# 2         672000            20
# 3         666500            20
# 4         666500            20
# 5         672000            20
# 6         672000            20
# 7         666500            20
# 8         672000            20
# 9         666500            20
# 10        672000            20
# 11        666500            20
# 12        671500            20
# 13        666500            20
# 14        666500            20
# 15        666500            20
# 16        671500            20
# 17        671500            20
# 18        671500            20
# 19        671500            20
# 20        671500            20
# 21        671500            20
# 22        671500            20
# 23        666500            20
# 24        666500            20
# 25        671500            20
# 26        671500            20
# 27        671500            20
# 28        671500            20
# 29        666500            20
# ...          ...           ...
# 79970     682000            78
# 79971     682000           103
# 79972     682000           114
# 79973     682000           114
# 79974     682000           134
# 79975     682000           149
# 79976     682000           160
# 79977     682000           160
# 79978     682000           160
# 79979     682000           171
# 79980     682000           171
# 79981     682000           171
# 79982     682000           171
# 79983     682000           171
# 79984     682000           171
# 79985     682000           160
# 79986     682000           149
# 79987     682000           149
# 79988     682000           149
# 79989     682000           149
# 79990     682000           149
# 79991     682000           149
# 79992     682000           160
# 79993     682000           160
# 79994     682000           171
# 79995     682000           171
# 79996     682000           171
# 79997     682000           171
# 79998     681500           487
# 79999     681500           487
#
# [80000 rows x 11 columns]

# %%
data.TimeStamp.unique(),len(data.TimeStamp.unique())
# Out:
# (array(['2014-01-22D04:21:22.786910500', '2014-01-22D04:21:22.789910500',
#         '2014-01-22D08:45:02.804303200', ...,
#         '2014-01-22D10:57:55.337945200', '2014-01-22D10:57:55.491945200',
#         '2014-01-22D10:57:55.530945200'], dtype=object), 48219)

# %%
a = range(0,len(data.TimeStamp.unique()),1000)

# %%
for i in range(0,len(x),1):
    for j in range(0,len(a),1):
        if i == a[j]:
            print i
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000

# %%
import time 

start = time.time()

order_book_bid = []
order_book_ask = []
bid = []
ask = []
timestamp_ = []
x = data.TimeStamp.unique()
#a = range(0,len(data.TimeStamp.unique()),1000)

for i in range(0,len(x),1):
    timestamp_.append(x[i])
    y = data[data['TimeStamp'].str.contains(x[i])]
    bid.append(y[(y.BidOrAsk == 'B')][["Price","QuantityDifference"]]) # bid
    ask.append(y[(y.BidOrAsk == 'A')][["Price","QuantityDifference"]]) # ask
    if i == 0:
        a = bid[i].groupby(by=['Price'],as_index = False).sum().sort(['Price'],ascending = [False])
        b = ask[i].groupby(by=['Price'],as_index = False).sum().sort(['Price'],ascending = [True])
    elif i > 0:
        a = pd.concat([order_book_bid[i-1],bid[i]]).groupby(by=['Price'],as_index = False).sum().sort(['Price'],ascending = [False])
        b = pd.concat([order_book_ask[i-1],ask[i]]).groupby(by=['Price'],as_index = False).sum().sort(['Price'],ascending = [True])
    order_book_bid.append(a[a.QuantityDifference != 0])
    order_book_ask.append(b[b.QuantityDifference != 0])
    
    if i == 10000:
        print i
    elif i == 20000:
        print i
    elif i == 40000:
        print i
        
end = time.time()  
print "Total time = %f"%(end - start)
# Out:
# /home/rory/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:19: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/rory/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:20: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/rory/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:22: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/rory/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
order_book_bid[1200][0:5]
# Out:
#      Price  QuantityDifference
# 42  667500                  93
# 41  667000                 231
# 40  666500                 290
# 39  666000                 267
# 38  665500                 153

# %%
e = data.TimeStamp.unique()[1200]
data[(data.BidOrAsk == 'B') & (data.TimeStamp == e)]
# Out:
#      Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 1842  CNF14            1843  2014-01-22D09:15:14.009809100  CA0E8D21E015C095
#
#       OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 1842                 74  666000                  10              B     667500
#
#       BestQuantity
# 1842            93

# %%
x = data.TimeStamp.unique()
data[data['TimeStamp'].str.contains(x[0])]
# Out:
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 0   CNF14               1  2014-01-22D04:21:22.786910500  E3D584F55D4240C2
# 1   CNF14               2  2014-01-22D04:21:22.786910500  B86D00C4CBBFB0BF
# 2   CNF14               3  2014-01-22D04:21:22.786910500  E1C9F25394A679A6
# 3   CNF14               4  2014-01-22D04:21:22.786910500  470284B16BBE4ABE
# 4   CNF14               5  2014-01-22D04:21:22.786910500  C7118CE560A044E0
# 5   CNF14               6  2014-01-22D04:21:22.786910500  6827C7006AEC4FEC
# 6   CNF14               7  2014-01-22D04:21:22.786910500  AF342B8CD518B4B8
# 7   CNF14               8  2014-01-22D04:21:22.786910500  C15D08A5B29C96DC
# 8   CNF14               9  2014-01-22D04:21:22.786910500  48A74F481D750275
# 9   CNF14              10  2014-01-22D04:21:22.786910500  E19E84B960F74517
# 10  CNF14              11  2014-01-22D04:21:22.786910500  166000C4C677AB77
# 11  CNF14              12  2014-01-22D04:21:22.786910500  6D8780B9C86AAC2A
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 0                   1  672000                  20              A     672000
# 1                   1  640000                 100              B     666500
# 2                   2  719500                   1              A     672000
# 3                   1  666500                  10              B     666500
# 4                   2  666500                  10              B     666500
# 5                   2  672500                  10              A     672000
# 6                   3  682500                   1              A     672000
# 7                   3  666000                  20              B     666500
# 8                   3  681000                  10              A     672000
# 9                   4  664500                  20              B     666500
# 10                  5  693000                   1              A     672000
# 11                  4  665000                  20              B     666500
#
#     BestQuantity
# 0             20
# 1             20
# 2             20
# 3             20
# 4             20
# 5             20
# 6             20
# 7             20
# 8             20
# 9             20
# 10            20
# 11            20

# %%
len(x)
# Out:
# 1305

# %%
(100226/8244.0) * 150 / 60
# Out:
# 30.393619602134887
