# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = []
datapath = '/home/bigdatas16/SGX-OrderBook-Tick-Data-Trading-Strategy-/stat_order_book/CNF14_01_28_order_book_final.csv'
data1 = pd.read_csv(datapath,sep='\t',encoding = 'utf-8')
data_book_28 = data1[['0','1','2','3']]

# %%
data_book_28_open = data_book_28[213*4-3:67229*4+1]
data_book_28_open = data_book_28_open.reset_index(drop = True)

# %%
import time 
start = time.time()
Bid1 = []
Bid2 = []
Bid3 = []
Bid1_Quantity = []
Bid2_Quantity = []
Bid3_Quantity = []
Ask1 = []
Ask2 = []
Ask3 = []
Ask1_Quantity = []
Ask2_Quantity = []
Ask3_Quantity = []

TimeStamp = []
for i in range(1,len(data_book_28_open),4):
    #print data_book_28_open.iloc[i]['0']
    #print data_book_28_open.iloc[i]['2']
    Bid1.append(float(data_book_28_open.iloc[i]['0'])/100.0)
    Bid1_Quantity.append(float(data_book_28_open.iloc[i]['1']))
    
    Bid2.append(float(data_book_28_open.iloc[i + 1]['0'])/100.0)
    Bid2_Quantity.append(float(data_book_28_open.iloc[i + 1]['1']))  
    
    Bid3.append(float(data_book_28_open.iloc[i + 2]['0'])/100.0)
    Bid3_Quantity.append(float(data_book_28_open.iloc[i + 2]['1']))  
    
    Ask1.append(float(data_book_28_open.iloc[i]['2'])/100.0) 
    Ask1_Quantity.append(float(data_book_28_open.iloc[i]['3']))
    
    Ask2.append(float(data_book_28_open.iloc[i + 1]['2'])/100.0) 
    Ask2_Quantity.append(float(data_book_28_open.iloc[i + 1]['3']))    
    
    Ask3.append(float(data_book_28_open.iloc[i + 2]['2'])/100.0) 
    Ask3_Quantity.append(float(data_book_28_open.iloc[i + 2]['3']))    
    TimeStamp.append(data_book_28_open.iloc[i-1][1])
    
    
end = time.time()  
print "Total time = %f"%(end - start)
# Out:
# Total time = 146.877704

# %%
bid1_ask1_spread = array(Ask1) - array(Bid1)

# %%
data = []
datapath = '/home/bigdatas16/SGX-OrderBook-Tick-Data-Trading-Strategy-/CN_Futures_2014.01.28.csv'
data = pd.read_csv(datapath)
data_CNF14 = data[data.Series == 'CNF14']
data = data_CNF14
market_open_time = data[data['TimeStamp'].str.contains('2014-01-28D09:00')].index.tolist()[0] 
market_close_time = data[data['TimeStamp'].str.contains('2014-01-28D16:00')].index.tolist()[0] 
data_open = data[market_open_time:market_close_time+1]
data_open.loc[data_open.BidOrAsk == 'A',['Trade']] = ' '
data_open['Price'][data_open.Trade == ' '] = 0
data_open = data_open.loc[data_open.groupby('TimeStamp')["Price"].idxmin()]
data_trade = data_open[['TimeStamp','Price','Trade']].reset_index(drop = True)
# Out:
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/pandas/core/generic.py:4428: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2885: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data_trade = data_trade.reset_index(drop = True)
data_trade_time_series_0900_0930 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D09:30')].index.tolist()[0]
data_trade_time_series_0930_1000 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D10:00')].index.tolist()[0]
data_trade_time_series_1000_1030 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D10:30')].index.tolist()[0]
data_trade_time_series_1030_1100 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D11:00')].index.tolist()[0]
data_trade_time_series_1100_1130 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D11:30')].index.tolist()[0]
data_trade_time_series_1130_1200 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D12:00')].index.tolist()[0]
data_trade_time_series_1200_1230 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D12:30')].index.tolist()[0]

data_trade_time_series_1230_1300 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D13:00')].index.tolist()[0]
data_trade_time_series_1300_1330 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D13:30')].index.tolist()[0]
data_trade_time_series_1330_1400 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D14:00')].index.tolist()[0]
data_trade_time_series_1400_1430 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D14:30')].index.tolist()[0]
data_trade_time_series_1430_1500 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D15:00')].index.tolist()[0]
data_trade_time_series_1500_1530 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D15:30')].index.tolist()[0]
data_trade_time_series_1530_1600 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D16:00')].index.tolist()[0]

# %%
import time 
start = time.time()
min_Ask1_time_series = []
min_Ask1_time_series.append(0)
for i in range(1,67017,1):
    min_Ask1_time_series.append(min(Ask1[i:]))
    
max_Bid1_time_series = []
max_Bid1_time_series.append(0)
for i in range(1,67017,1):
    max_Bid1_time_series.append(max(Bid1[i:]))
end = time.time()  
print "Total time = %f"%(end - start)
# Out:
# Total time = 415.062401

# %%
weight1 = 0.50
weight2 = 0.30
weight3 = 0.20

# %%
def diff_weighted_five_category(Bid1_Quantity,Bid2_Quantity,Bid3_Quantity,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity,weight1,weight2,weight3):
    weighted_Bid = array(Bid1_Quantity) * weight1 + array(Bid2_Quantity) * weight2 + array(Bid3_Quantity) * weight3
    weighted_Ask = array(Ask1_Quantity) * weight1 + array(Ask2_Quantity) * weight2 + array(Ask3_Quantity) * weight3
    diff_weighted3 = weighted_Bid - weighted_Ask
    return np.percentile(diff_weighted3,20),np.percentile(diff_weighted3,40),np.percentile(diff_weighted3,60),np.percentile(diff_weighted3,80)

# %%
diff_weighted_five_category(Bid1_Quantity,Bid2_Quantity,Bid3_Quantity,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity,weight1,weight2,weight3)
# Out:
# (-104.80000000000001,
#  -43.39999999999992,
#  8.4000000000000057,
#  72.600000000000023)

# %%
a1 = array(Bid1_Quantity) * weight1 + array(Bid2_Quantity) * weight2 + array(Bid3_Quantity) * weight3

# %%
a2 = array(Ask1_Quantity) * weight1 + array(Ask2_Quantity) * weight2 + array(Ask3_Quantity) * weight3

# %%
max(a1),max(a2)
# Out:
# (574.79999999999995, 976.20000000000005)

# %%
#2014-01-28 close price = 6750
#0.6177
#0.8696
#1.0678
#1.3835

Close_Price = 6750

def bid_stat_time_spread_diff(Bid1,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price):
    
    Bid1_traded_spr5_category_one = 0
    Bid1_traded_expected_spr5_category_one = 0
    Bid1_traded_spr10_category_one = 0
    Bid1_traded_expected_spr10_category_one = 0
    N_spr5_category_one = 0
    N_spr10_category_one = 0

    Bid1_traded_spr5_category_two = 0
    Bid1_traded_expected_spr5_category_two = 0
    Bid1_traded_spr10_category_two = 0
    Bid1_traded_expected_spr10_category_two = 0
    N_spr5_category_two = 0
    N_spr10_category_two = 0

    Bid1_traded_spr5_category_three = 0
    Bid1_traded_expected_spr5_category_three = 0
    Bid1_traded_spr10_category_three = 0
    Bid1_traded_expected_spr10_category_three = 0
    N_spr5_category_three = 0
    N_spr10_category_three = 0

    Bid1_traded_spr5_category_four = 0
    Bid1_traded_expected_spr5_category_four = 0
    Bid1_traded_spr10_category_four = 0
    Bid1_traded_expected_spr10_category_four = 0
    N_spr5_category_four = 0
    N_spr10_category_four = 0

    Bid1_traded_spr5_category_five = 0
    Bid1_traded_expected_spr5_category_five = 0
    Bid1_traded_spr10_category_five = 0
    Bid1_traded_expected_spr10_category_five = 0
    N_spr5_category_five = 0
    N_spr10_category_five = 0

    ###one week
    diff_weighted_five_categories = diff_weighted_five_category(Bid1_Quantity,Bid2_Quantity,Bid3_Quantity,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity,weight1,weight2,weight3)

    print diff_weighted_five_categories

    for i in range(0,data_trade_time_series_1530_1600,1):
        #print i
        #print Bid1[i]
        #print min_Ask1_time_series[i+1]
        weighted_Bid = Bid1_Quantity[i] * weight1 + Bid2_Quantity[i] * weight2 + Bid3_Quantity[i] * weight3
        weighted_Ask = Ask1_Quantity[i] * weight1 + Ask2_Quantity[i] * weight2 + Ask3_Quantity[i] * weight3  
        #print weighted_Bid
        #print weighted_Ask
        #print (weighted_Bid*(1.0) / weighted_Ask)
        #print '\t'
        if (weighted_Bid*(1.0) - weighted_Ask) <= diff_weighted_five_categories[0]:  
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_one = N_spr5_category_one + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_one = Bid1_traded_spr5_category_one + 1
                    Bid1_traded_expected_spr5_category_one = Bid1_traded_expected_spr5_category_one + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_one = Bid1_traded_expected_spr5_category_one + (Ask1[i] - Close_Price)
                    #print Bid1_traded_expected
            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_one = N_spr10_category_one + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr10_category_one = Bid1_traded_spr10_category_one + 1
                    Bid1_traded_expected_spr10_category_one = Bid1_traded_expected_spr10_category_one + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr10_category_one = Bid1_traded_expected_spr10_category_one + (Ask1[i] - Close_Price)
                    #print Bid1_traded_expected
            else:
                pass

        elif diff_weighted_five_categories[0] < (weighted_Bid*(1.0) - weighted_Ask) <= diff_weighted_five_categories[1]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_two = N_spr5_category_two + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_two = Bid1_traded_spr5_category_two + 1
                    Bid1_traded_expected_spr5_category_two = Bid1_traded_expected_spr5_category_two + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_two = Bid1_traded_expected_spr5_category_two + (Ask1[i] - Close_Price)
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_two = N_spr10_category_two + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr10_category_two = Bid1_traded_spr10_category_two + 1
                    Bid1_traded_expected_spr10_category_two = Bid1_traded_expected_spr10_category_two + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr10_category_two = Bid1_traded_expected_spr10_category_two + (Ask1[i] - Close_Price)
                    #print Bid1_traded_expected
            else:
                pass    

        elif diff_weighted_five_categories[1] < (weighted_Bid*(1.0) - weighted_Ask) <= diff_weighted_five_categories[2]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_three = N_spr5_category_three + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_three = Bid1_traded_spr5_category_three + 1
                    Bid1_traded_expected_spr5_category_three = Bid1_traded_expected_spr5_category_three + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_three = Bid1_traded_expected_spr5_category_three + (Ask1[i] - Close_Price)
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_three = N_spr10_category_three + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_three = Bid1_traded_spr10_category_three + 1
                    Bid1_traded_expected_spr10_category_three = Bid1_traded_expected_spr10_category_three + (Ask1[i] - Bid1[i])
                    #print 'a1 = %f'%(Bid1_traded_expected_spr10_category_three)
                else:
                    Bid1_traded_expected_spr10_category_three = Bid1_traded_expected_spr10_category_three + (Ask1[i] - Close_Price)
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_three)
            else:
                pass    

        elif diff_weighted_five_categories[2] < (weighted_Bid*(1.0) - weighted_Ask) <= diff_weighted_five_categories[3]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_four = N_spr5_category_four + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_four = Bid1_traded_spr5_category_four + 1
                    Bid1_traded_expected_spr5_category_four = Bid1_traded_expected_spr5_category_four + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_four = Bid1_traded_expected_spr5_category_four + (Ask1[i] - Close_Price)
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_four = N_spr10_category_four + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_four = Bid1_traded_spr10_category_four + 1
                    Bid1_traded_expected_spr10_category_four = Bid1_traded_expected_spr10_category_four + (Ask1[i] - Bid1[i])
                    #print 'a1 = %f'%(Bid1_traded_expected_spr10_category_four)
                else:
                    Bid1_traded_expected_spr10_category_four = Bid1_traded_expected_spr10_category_four + (Ask1[i] - Close_Price)
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_four)
            else:
                pass    

        elif diff_weighted_five_categories[3] < (weighted_Bid*(1.0) - weighted_Ask): 
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_five = N_spr5_category_five + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_five = Bid1_traded_spr5_category_five + 1
                    Bid1_traded_expected_spr5_category_five = Bid1_traded_expected_spr5_category_five + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_five = Bid1_traded_expected_spr5_category_five + (Ask1[i] - Close_Price)
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_five = N_spr10_category_five + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_five = Bid1_traded_spr10_category_five + 1
                    Bid1_traded_expected_spr10_category_five = Bid1_traded_expected_spr10_category_five + (Ask1[i] - Bid1[i])
                    #print 'a1 = %f'%(Bid1_traded_expected_spr10_category_four)
                else:
                    Bid1_traded_expected_spr10_category_five = Bid1_traded_expected_spr10_category_five + (Ask1[i] - Close_Price)
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_four)
            else:
                pass    


        #print Bid1_traded_expected_spr10_category_three

        if i == data_trade_time_series_0900_0930 - 1:  

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '09:00~09:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '09:00~09:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:00~09:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:00~09:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '09:00~09:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '09:00~09:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:00~09:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:00~09:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '09:00~09:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '09:00~09:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:00~09:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:00~09:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '09:00~09:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '09:00~09:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:00~09:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:00~09:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '09:00~09:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))



            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0        
            print '\t'        
            continue

        elif i == data_trade_time_series_0930_1000 - 1:   

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '09:30~10:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '09:30~10:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '09:30~10:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '09:30~10:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '09:30~10:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0         

            print '\t'        
            continue
        elif i == data_trade_time_series_1000_1030 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '10:00~10:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '10:00~10:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '10:00~10:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '10:00~10:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '10:00~10:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue
        elif i == data_trade_time_series_1030_1100 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '10:30~11:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '10:30~11:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '10:30~11:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:30~11:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~11:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:30~11:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '10:30~11:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '10:30~11:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue

        elif i == data_trade_time_series_1100_1130 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '11:00~11:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '11:00~11:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '11:00~11:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '11:00~11:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '11:00~11:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue

        elif i == data_trade_time_series_1130_1200 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '11:30~12:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '11:30~12:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '11:30~12:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '11:30~12:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '11:30~12:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue
        elif i == data_trade_time_series_1200_1230 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '12:00~12:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '12:00~12:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '12:00~12:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '12:00~12:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '12:00~12:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue
        elif i == data_trade_time_series_1230_1300 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '12:30~13:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '12:30~13:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '12:30~13:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '12:30~13:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '12:30~13:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue
        elif i == data_trade_time_series_1300_1330 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '13:00~13:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '13:00~13:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '13:00~13:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '13:00~13:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '13:00~13:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue
        elif i == data_trade_time_series_1330_1400 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '13:30~14:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '13:30~14:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '13:30~14:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '13:30~14:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '13:30~14:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue        
        elif i == data_trade_time_series_1400_1430 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '14:00~14:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '14:00~14:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '14:00~14:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '14:00~14:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '14:00~14:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue                                          
        elif i == data_trade_time_series_1430_1500 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '14:30~15:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '14:30~15:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '14:30~15:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '14:30~15:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '14:30~15:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue 
        elif i == data_trade_time_series_1500_1530 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '15:00~15:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '15:00~15:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '15:00~15:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '15:00~15:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '15:00~15:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue 
        elif i == data_trade_time_series_1530_1600 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '15:30~16:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '15:30~16:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '15:30~16:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '15:30~16:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '15:30~16:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue

# %%
bid_stat_time_spread_diff(Bid1,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)
# Out:
# (-104.80000000000001, -43.39999999999992, 8.4000000000000057, 72.600000000000023)
# Spread 5 and Category One = 548
# Spread 10 and Category One = 25
# Spread 5 and Category Two= 1249
# Spread 10 and Category Two = 122
# Spread 5 and Category Three = 794
# Spread 10 and Category Three = 786
# Spread 5 and Category Four = 1050
# Spread 10 and Category Four = 203
# Spread 5 and Category Five = 649
# Spread 10 and Category Five = 0
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 5.000000
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 10.000000
# 09:00~09:30 bid1 spread 5 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category two traded expectation = 5.000000
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 10.000000
# 09:00~09:30 bid1 spread 5 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category three traded expectation = 5.000000
# 09:00~09:30 bid1 spread 10 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded expectation = 10.000000
# 09:00~09:30 bid1 spread 5 category four traded probability = 0.939048
# 09:00~09:30 bid1 spread 5 category four traded expectation = 1.038095
# 09:00~09:30 bid1 spread 10 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded expectation = 10.000000
# 09:00~09:30 bid1 spread 5 category five traded probability = 0.893683
# 09:00~09:30 bid1 spread 5 category five traded expectation = -2.442219
# 09:00~09:30 bid1 spread 10 category five traded probability = 0.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 2799
# Spread 10 and Category One = 44
# Spread 5 and Category Two= 2470
# Spread 10 and Category Two = 183
# Spread 5 and Category Three = 1957
# Spread 10 and Category Three = 350
# Spread 5 and Category Four = 2773
# Spread 10 and Category Four = 272
# Spread 5 and Category Five = 2988
# Spread 10 and Category Five = 13
# 09:30~10:00 bid1 spread 5 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category one traded expectation = 5.000000
# 09:30~10:00 bid1 spread 10 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category one traded expectation = 10.000000
# 09:30~10:00 bid1 spread 5 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category two traded expectation = 5.000000
# 09:30~10:00 bid1 spread 10 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category two traded expectation = 10.000000
# 09:30~10:00 bid1 spread 5 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category three traded expectation = 5.000000
# 09:30~10:00 bid1 spread 10 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category three traded expectation = 10.000000
# 09:30~10:00 bid1 spread 5 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category four traded expectation = 5.000000
# 09:30~10:00 bid1 spread 10 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category four traded expectation = 10.000000
# 09:30~10:00 bid1 spread 5 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category five traded expectation = 5.000000
# 09:30~10:00 bid1 spread 10 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category five traded expectation = 9.999999
#
# Spread 5 and Category One = 1746
# Spread 10 and Category One = 87
# Spread 5 and Category Two= 1867
# Spread 10 and Category Two = 86
# Spread 5 and Category Three = 1460
# Spread 10 and Category Three = 242
# Spread 5 and Category Four = 1868
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 2522
# Spread 10 and Category Five = 92
# 10:00~10:30 bid1 spread 5 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category one traded expectation = 5.000000
# 10:00~10:30 bid1 spread 10 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded expectation = 10.000000
# 10:00~10:30 bid1 spread 5 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category two traded expectation = 5.000000
# 10:00~10:30 bid1 spread 10 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category two traded expectation = 10.000000
# 10:00~10:30 bid1 spread 5 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category three traded expectation = 5.000000
# 10:00~10:30 bid1 spread 10 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category three traded expectation = 10.000000
# 10:00~10:30 bid1 spread 5 category four traded probability = 0.987687
# 10:00~10:30 bid1 spread 5 category four traded expectation = 4.199679
# 10:00~10:30 bid1 spread 10 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category four traded expectation = 10.000000
# 10:00~10:30 bid1 spread 5 category five traded probability = 0.983743
# 10:00~10:30 bid1 spread 5 category five traded expectation = 3.943299
# 10:00~10:30 bid1 spread 10 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded expectation = 10.000000
#
# Spread 5 and Category One = 824
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 1059
# Spread 10 and Category Two = 18
# Spread 5 and Category Three = 1665
# Spread 10 and Category Three = 362
# Spread 5 and Category Four = 1583
# Spread 10 and Category Four = 186
# Spread 5 and Category Five = 1622
# Spread 10 and Category Five = 237
# 10:30~11:00 bid1 spread 5 category one traded probability = 0.700243
# 10:30~11:00 bid1 spread 5 category one traded expectation = -12.858010
# 10:30~11:00 bid1 spread 10 category one traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 0.000000
# 10:30~11:00 bid1 spread 5 category two traded probability = 0.514636
# 10:30~11:00 bid1 spread 5 category two traded expectation = -23.781870
# 10:30~11:00 bid1 spread 10 category two traded probability = 0.944444
# 10:30~11:00 bid1 spread 10 category two traded expectation = 6.666666
# 10:30~11:00 bid1 spread 5 category three traded probability = 0.328529
# 10:30~11:00 bid1 spread 5 category three traded expectation = -36.870871
# 11:30~11:00 bid1 spread 10 category three traded probability = 0.709945
# 10:30~11:00 bid1 spread 10 category three traded expectation = -8.674033
# 10:30~11:00 bid1 spread 5 category four traded probability = 0.548958
# 10:30~11:00 bid1 spread 5 category four traded expectation = -23.389135
# 10:30~11:00 bid1 spread 10 category four traded probability = 0.505376
# 10:30~11:00 bid1 spread 10 category four traded expectation = -19.677419
# 10:30~11:00 bid1 spread 5 category five traded probability = 0.544390
# 10:30~11:00 bid1 spread 5 category five traded expectation = -24.870530
# 10:30~11:00 bid1 spread 10 category five traded probability = 0.037975
# 10:30~11:00 bid1 spread 10 category five traded expectation = -56.898734
#
# Spread 5 and Category One = 879
# Spread 10 and Category One = 19
# Spread 5 and Category Two= 864
# Spread 10 and Category Two = 233
# Spread 5 and Category Three = 1095
# Spread 10 and Category Three = 158
# Spread 5 and Category Four = 1215
# Spread 10 and Category Four = 227
# Spread 5 and Category Five = 1111
# Spread 10 and Category Five = 17
# 11:00~11:30 bid1 spread 5 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 5 category one traded expectation = 5.000000
# 11:00~11:30 bid1 spread 10 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = 9.999999
# 11:00~11:30 bid1 spread 5 category two traded probability = 1.000000
# 11:00~11:30 bid1 spread 5 category two traded expectation = 5.000000
# 11:00~11:30 bid1 spread 10 category two traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category two traded expectation = 10.000000
# 11:00~11:30 bid1 spread 5 category three traded probability = 1.000000
# 11:00~11:30 bid1 spread 5 category three traded expectation = 5.000000
# 11:00~11:30 bid1 spread 10 category three traded probability = 0.949367
# 11:00~11:30 bid1 spread 10 category three traded expectation = 7.215190
# 11:00~11:30 bid1 spread 5 category four traded probability = 1.000000
# 11:00~11:30 bid1 spread 5 category four traded expectation = 5.000000
# 11:00~11:30 bid1 spread 10 category four traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category four traded expectation = 10.000000
# 11:00~11:30 bid1 spread 5 category five traded probability = 0.990999
# 11:00~11:30 bid1 spread 5 category five traded expectation = 4.504950
# 11:00~11:30 bid1 spread 10 category five traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category five traded expectation = 9.999999
#
# Spread 5 and Category One = 3
# Spread 10 and Category One = 11
# Spread 5 and Category Two= 168
# Spread 10 and Category Two = 74
# Spread 5 and Category Three = 192
# Spread 10 and Category Three = 9
# Spread 5 and Category Four = 203
# Spread 10 and Category Four = 208
# Spread 5 and Category Five = 72
# Spread 10 and Category Five = 16
# 11:30~12:00 bid1 spread 5 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category one traded expectation = 4.999998
# 11:30~12:00 bid1 spread 10 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = 9.999999
# 11:30~12:00 bid1 spread 5 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = 5.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category two traded expectation = 10.000000
# 11:30~12:00 bid1 spread 5 category three traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category three traded expectation = 5.000000
# 11:30~12:00 bid1 spread 10 category three traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category three traded expectation = 9.999999
# 11:30~12:00 bid1 spread 5 category four traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category four traded expectation = 5.000000
# 11:30~12:00 bid1 spread 10 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = -45.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 0.833333
# 11:30~12:00 bid1 spread 5 category five traded expectation = -4.166667
# 11:30~12:00 bid1 spread 10 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = -44.999997
#
# Spread 5 and Category One = 61
# Spread 10 and Category One = 28
# Spread 5 and Category Two= 22
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 53
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 35
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 5.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded expectation = 10.000000
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 5.000000
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 5.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category four traded expectation = 5.000000
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 123
# Spread 10 and Category One = 27
# Spread 5 and Category Two= 58
# Spread 10 and Category Two = 63
# Spread 5 and Category Three = 0
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 15
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 22
# Spread 10 and Category Five = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 5.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = 10.000000
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 5.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = 10.000000
# 12:30~13:00 bid1 spread 5 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = 5.000000
# 12:30~13:00 bid1 spread 10 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = 5.000000
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 382
# Spread 10 and Category One = 5
# Spread 5 and Category Two= 738
# Spread 10 and Category Two = 4
# Spread 5 and Category Three = 837
# Spread 10 and Category Three = 70
# Spread 5 and Category Four = 916
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 826
# Spread 10 and Category Five = 16
# 13:00~13:30 bid1 spread 5 category one traded probability = 0.602094
# 13:00~13:30 bid1 spread 5 category one traded expectation = -13.664921
# 13:00~13:30 bid1 spread 10 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = 9.999998
# 13:00~13:30 bid1 spread 5 category two traded probability = 0.313008
# 13:00~13:30 bid1 spread 5 category two traded expectation = -27.703252
# 13:00~13:30 bid1 spread 10 category two traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category two traded expectation = 9.999998
# 13:00~13:30 bid1 spread 5 category three traded probability = 0.229391
# 13:00~13:30 bid1 spread 5 category three traded expectation = -32.317802
# 13:00~13:30 bid1 spread 10 category three traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category three traded expectation = 10.000000
# 13:00~13:30 bid1 spread 5 category four traded probability = 0.344978
# 13:00~13:30 bid1 spread 5 category four traded expectation = -28.679039
# 13:00~13:30 bid1 spread 10 category four traded probability = 0.805755
# 13:00~13:30 bid1 spread 10 category four traded expectation = -1.151079
# 13:00~13:30 bid1 spread 5 category five traded probability = 0.341404
# 13:00~13:30 bid1 spread 5 category five traded expectation = -30.048426
# 13:00~13:30 bid1 spread 10 category five traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = -44.687497
#
# Spread 5 and Category One = 1308
# Spread 10 and Category One = 42
# Spread 5 and Category Two= 873
# Spread 10 and Category Two = 83
# Spread 5 and Category Three = 920
# Spread 10 and Category Three = 126
# Spread 5 and Category Four = 701
# Spread 10 and Category Four = 97
# Spread 5 and Category Five = 744
# Spread 10 and Category Five = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 0.218654
# 13:30~14:00 bid1 spread 5 category one traded expectation = -24.671254
# 13:30~14:00 bid1 spread 10 category one traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = -29.999999
# 13:30~14:00 bid1 spread 5 category two traded probability = 0.538373
# 13:30~14:00 bid1 spread 5 category two traded expectation = -14.284078
# 13:30~14:00 bid1 spread 10 category two traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category two traded expectation = -34.096385
# 13:30~14:00 bid1 spread 5 category three traded probability = 0.244565
# 13:30~14:00 bid1 spread 5 category three traded expectation = -28.168478
# 13:30~14:00 bid1 spread 10 category three traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category three traded expectation = -32.857143
# 13:30~14:00 bid1 spread 5 category four traded probability = 0.149786
# 13:30~14:00 bid1 spread 5 category four traded expectation = -31.119829
# 13:30~14:00 bid1 spread 10 category four traded probability = 0.195876
# 13:30~14:00 bid1 spread 10 category four traded expectation = -22.989690
# 13:30~14:00 bid1 spread 5 category five traded probability = 0.178763
# 13:30~14:00 bid1 spread 5 category five traded expectation = -31.720430
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 1724
# Spread 10 and Category One = 268
# Spread 5 and Category Two= 1669
# Spread 10 and Category Two = 111
# Spread 5 and Category Three = 814
# Spread 10 and Category Three = 58
# Spread 5 and Category Four = 472
# Spread 10 and Category Four = 127
# Spread 5 and Category Five = 931
# Spread 10 and Category Five = 15
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.737819
# 14:00~14:30 bid1 spread 5 category one traded expectation = -4.303944
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.055970
# 14:00~14:30 bid1 spread 10 category one traded expectation = -23.190298
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.408029
# 14:00~14:30 bid1 spread 5 category two traded expectation = -15.760935
# 14:00~14:30 bid1 spread 10 category two traded probability = 1.000000
# 14:00~14:30 bid1 spread 10 category two traded expectation = 10.000000
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.636364
# 14:00~14:30 bid1 spread 5 category three traded expectation = -7.856265
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.827586
# 14:00~14:30 bid1 spread 10 category three traded expectation = 3.965517
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.754237
# 14:00~14:30 bid1 spread 5 category four traded expectation = -3.622881
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.881890
# 14:00~14:30 bid1 spread 10 category four traded expectation = 5.866142
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.876477
# 14:00~14:30 bid1 spread 5 category five traded expectation = 0.676692
# 14:00~14:30 bid1 spread 10 category five traded probability = 1.000000
# 14:00~14:30 bid1 spread 10 category five traded expectation = 9.999999
#
# Spread 5 and Category One = 1382
# Spread 10 and Category One = 233
# Spread 5 and Category Two= 839
# Spread 10 and Category Two = 108
# Spread 5 and Category Three = 783
# Spread 10 and Category Three = 230
# Spread 5 and Category Four = 784
# Spread 10 and Category Four = 40
# Spread 5 and Category Five = 1214
# Spread 10 and Category Five = 21
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.717800
# 14:30~15:00 bid1 spread 5 category one traded expectation = -4.370478
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.974249
# 14:30~15:00 bid1 spread 10 category one traded expectation = 9.098712
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.769964
# 14:30~15:00 bid1 spread 5 category two traded expectation = -2.896305
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.064815
# 14:30~15:00 bid1 spread 10 category two traded expectation = -26.250000
# 14:30~15:00 bid1 spread 5 category three traded probability = 0.611750
# 14:30~15:00 bid1 spread 5 category three traded expectation = -8.103448
# 14:30~15:00 bid1 spread 10 category three traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category three traded expectation = -25.347826
# 14:30~15:00 bid1 spread 5 category four traded probability = 0.585459
# 14:30~15:00 bid1 spread 5 category four traded expectation = -8.877551
# 14:30~15:00 bid1 spread 10 category four traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category four traded expectation = -20.374999
# 14:30~15:00 bid1 spread 5 category five traded probability = 0.239703
# 14:30~15:00 bid1 spread 5 category five traded expectation = -20.877265
# 14:30~15:00 bid1 spread 10 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = -19.999999
#
# Spread 5 and Category One = 338
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 263
# Spread 10 and Category Two = 61
# Spread 5 and Category Three = 309
# Spread 10 and Category Three = 113
# Spread 5 and Category Four = 138
# Spread 10 and Category Four = 3
# Spread 5 and Category Five = 273
# Spread 10 and Category Five = 0
# 15:00~15:30 bid1 spread 5 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category one traded expectation = -21.523669
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded expectation = -23.155893
# 15:00~15:30 bid1 spread 10 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = -20.000000
# 15:00~15:30 bid1 spread 5 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category three traded expectation = -22.055016
# 15:00~15:30 bid1 spread 10 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category three traded expectation = -20.000000
# 15:00~15:30 bid1 spread 5 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded expectation = -24.963768
# 15:00~15:30 bid1 spread 10 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = -19.999993
# 15:00~15:30 bid1 spread 5 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded expectation = -25.000000
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 478
# Spread 10 and Category One = 10
# Spread 5 and Category Two= 100
# Spread 10 and Category Two = 1
# Spread 5 and Category Three = 23
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 5
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 0.838912
# 15:30~16:00 bid1 spread 5 category one traded expectation = 0.972803
# 15:30~16:00 bid1 spread 10 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = -14.999999
# 15:30~16:00 bid1 spread 5 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = -20.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded expectation = -14.999985
# 15:30~16:00 bid1 spread 5 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = -19.999999
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded expectation = -19.999996
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000

# %%
bid_stat_time_spread_diff(Bid2,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)
# Out:
# (-104.80000000000001, -43.39999999999992, 8.4000000000000057, 72.600000000000023)
# Spread 5 and Category One = 548
# Spread 10 and Category One = 25
# Spread 5 and Category Two= 1249
# Spread 10 and Category Two = 122
# Spread 5 and Category Three = 794
# Spread 10 and Category Three = 786
# Spread 5 and Category Four = 1050
# Spread 10 and Category Four = 203
# Spread 5 and Category Five = 649
# Spread 10 and Category Five = 0
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 10.000000
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 14.999999
# 09:00~09:30 bid1 spread 5 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category two traded expectation = 10.000000
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 15.000000
# 09:00~09:30 bid1 spread 5 category three traded probability = 0.981108
# 09:00~09:30 bid1 spread 5 category three traded expectation = 8.772040
# 09:00~09:30 bid1 spread 10 category three traded probability = 0.996183
# 09:00~09:30 bid1 spread 10 category three traded expectation = 14.751908
# 09:00~09:30 bid1 spread 5 category four traded probability = 0.898095
# 09:00~09:30 bid1 spread 5 category four traded expectation = 3.071429
# 09:00~09:30 bid1 spread 10 category four traded probability = 0.645320
# 09:00~09:30 bid1 spread 10 category four traded expectation = -8.054187
# 09:00~09:30 bid1 spread 5 category five traded probability = 0.893683
# 09:00~09:30 bid1 spread 5 category five traded expectation = 2.026194
# 09:00~09:30 bid1 spread 10 category five traded probability = 0.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 2799
# Spread 10 and Category One = 44
# Spread 5 and Category Two= 2470
# Spread 10 and Category Two = 183
# Spread 5 and Category Three = 1957
# Spread 10 and Category Three = 350
# Spread 5 and Category Four = 2773
# Spread 10 and Category Four = 272
# Spread 5 and Category Five = 2988
# Spread 10 and Category Five = 13
# 09:30~10:00 bid1 spread 5 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category one traded expectation = 10.000000
# 09:30~10:00 bid1 spread 10 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category one traded expectation = 15.000000
# 09:30~10:00 bid1 spread 5 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category two traded expectation = 10.000000
# 09:30~10:00 bid1 spread 10 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category two traded expectation = 15.000000
# 09:30~10:00 bid1 spread 5 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category three traded expectation = 10.000000
# 09:30~10:00 bid1 spread 10 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category three traded expectation = 15.000000
# 09:30~10:00 bid1 spread 5 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category four traded expectation = 10.000000
# 09:30~10:00 bid1 spread 10 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category four traded expectation = 15.000000
# 09:30~10:00 bid1 spread 5 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category five traded expectation = 10.000000
# 09:30~10:00 bid1 spread 10 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category five traded expectation = 14.999999
#
# Spread 5 and Category One = 1746
# Spread 10 and Category One = 87
# Spread 5 and Category Two= 1867
# Spread 10 and Category Two = 86
# Spread 5 and Category Three = 1460
# Spread 10 and Category Three = 242
# Spread 5 and Category Four = 1868
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 2522
# Spread 10 and Category Five = 92
# 10:00~10:30 bid1 spread 5 category one traded probability = 0.997136
# 10:00~10:30 bid1 spread 5 category one traded expectation = 9.813860
# 10:00~10:30 bid1 spread 10 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded expectation = 15.000000
# 10:00~10:30 bid1 spread 5 category two traded probability = 0.997322
# 10:00~10:30 bid1 spread 5 category two traded expectation = 9.825924
# 10:00~10:30 bid1 spread 10 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category two traded expectation = 15.000000
# 10:00~10:30 bid1 spread 5 category three traded probability = 0.997260
# 10:00~10:30 bid1 spread 5 category three traded expectation = 9.821918
# 10:00~10:30 bid1 spread 10 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category three traded expectation = 15.000000
# 10:00~10:30 bid1 spread 5 category four traded probability = 0.974304
# 10:00~10:30 bid1 spread 5 category four traded expectation = 8.268201
# 10:00~10:30 bid1 spread 10 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category four traded expectation = 15.000000
# 10:00~10:30 bid1 spread 5 category five traded probability = 0.973037
# 10:00~10:30 bid1 spread 5 category five traded expectation = 8.166138
# 10:00~10:30 bid1 spread 10 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded expectation = 15.000000
#
# Spread 5 and Category One = 824
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 1059
# Spread 10 and Category Two = 18
# Spread 5 and Category Three = 1665
# Spread 10 and Category Three = 362
# Spread 5 and Category Four = 1583
# Spread 10 and Category Four = 186
# Spread 5 and Category Five = 1622
# Spread 10 and Category Five = 237
# 10:30~11:00 bid1 spread 5 category one traded probability = 0.646845
# 10:30~11:00 bid1 spread 5 category one traded expectation = -12.293689
# 10:30~11:00 bid1 spread 10 category one traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 0.000000
# 10:30~11:00 bid1 spread 5 category two traded probability = 0.470255
# 10:30~11:00 bid1 spread 5 category two traded expectation = -23.895184
# 10:30~11:00 bid1 spread 10 category two traded probability = 0.944444
# 10:30~11:00 bid1 spread 10 category two traded expectation = 11.388888
# 10:30~11:00 bid1 spread 5 category three traded probability = 0.231231
# 10:30~11:00 bid1 spread 5 category three traded expectation = -41.354354
# 11:30~11:00 bid1 spread 10 category three traded probability = 0.709945
# 10:30~11:00 bid1 spread 10 category three traded expectation = -5.124309
# 10:30~11:00 bid1 spread 5 category four traded probability = 0.265319
# 10:30~11:00 bid1 spread 5 category four traded expectation = -38.373342
# 10:30~11:00 bid1 spread 10 category four traded probability = 0.053763
# 10:30~11:00 bid1 spread 10 category four traded expectation = -41.989247
# 10:30~11:00 bid1 spread 5 category five traded probability = 0.347719
# 10:30~11:00 bid1 spread 5 category five traded expectation = -33.508015
# 10:30~11:00 bid1 spread 10 category five traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category five traded expectation = -58.797468
#
# Spread 5 and Category One = 879
# Spread 10 and Category One = 19
# Spread 5 and Category Two= 864
# Spread 10 and Category Two = 233
# Spread 5 and Category Three = 1095
# Spread 10 and Category Three = 158
# Spread 5 and Category Four = 1215
# Spread 10 and Category Four = 227
# Spread 5 and Category Five = 1111
# Spread 10 and Category Five = 17
# 11:00~11:30 bid1 spread 5 category one traded probability = 0.946530
# 11:00~11:30 bid1 spread 5 category one traded expectation = 7.059158
# 11:00~11:30 bid1 spread 10 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = 14.999999
# 11:00~11:30 bid1 spread 5 category two traded probability = 0.861111
# 11:00~11:30 bid1 spread 5 category two traded expectation = 2.361111
# 11:00~11:30 bid1 spread 10 category two traded probability = 0.304721
# 11:00~11:30 bid1 spread 10 category two traded expectation = -23.240343
# 11:00~11:30 bid1 spread 5 category three traded probability = 0.892237
# 11:00~11:30 bid1 spread 5 category three traded expectation = 4.073059
# 11:00~11:30 bid1 spread 10 category three traded probability = 0.930380
# 11:00~11:30 bid1 spread 10 category three traded expectation = 10.917721
# 11:00~11:30 bid1 spread 5 category four traded probability = 0.942387
# 11:00~11:30 bid1 spread 5 category four traded expectation = 6.831276
# 11:00~11:30 bid1 spread 10 category four traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category four traded expectation = 15.000000
# 11:00~11:30 bid1 spread 5 category five traded probability = 0.969397
# 11:00~11:30 bid1 spread 5 category five traded expectation = 8.271827
# 11:00~11:30 bid1 spread 10 category five traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category five traded expectation = 14.999999
#
# Spread 5 and Category One = 3
# Spread 10 and Category One = 11
# Spread 5 and Category Two= 168
# Spread 10 and Category Two = 74
# Spread 5 and Category Three = 192
# Spread 10 and Category Three = 9
# Spread 5 and Category Four = 203
# Spread 10 and Category Four = 208
# Spread 5 and Category Five = 72
# Spread 10 and Category Five = 16
# 11:30~12:00 bid1 spread 5 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category one traded expectation = 9.999997
# 11:30~12:00 bid1 spread 10 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = 14.999999
# 11:30~12:00 bid1 spread 5 category two traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = -45.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 0.135135
# 11:30~12:00 bid1 spread 10 category two traded expectation = -32.567567
# 11:30~12:00 bid1 spread 5 category three traded probability = 0.463542
# 11:30~12:00 bid1 spread 5 category three traded expectation = -19.505208
# 11:30~12:00 bid1 spread 10 category three traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category three traded expectation = 14.999998
# 11:30~12:00 bid1 spread 5 category four traded probability = 0.413793
# 11:30~12:00 bid1 spread 5 category four traded expectation = -22.241379
# 11:30~12:00 bid1 spread 10 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = -45.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 0.125000
# 11:30~12:00 bid1 spread 5 category five traded expectation = -38.958333
# 11:30~12:00 bid1 spread 10 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = -44.999997
#
# Spread 5 and Category One = 61
# Spread 10 and Category One = 28
# Spread 5 and Category Two= 22
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 53
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 35
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 10.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded expectation = 14.999999
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 10.000000
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 10.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category four traded expectation = 10.000000
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 123
# Spread 10 and Category One = 27
# Spread 5 and Category Two= 58
# Spread 10 and Category Two = 63
# Spread 5 and Category Three = 0
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 15
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 22
# Spread 10 and Category Five = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 10.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = 14.999999
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 10.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = 15.000000
# 12:30~13:00 bid1 spread 5 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = 9.999999
# 12:30~13:00 bid1 spread 10 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = 10.000000
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 382
# Spread 10 and Category One = 5
# Spread 5 and Category Two= 738
# Spread 10 and Category Two = 4
# Spread 5 and Category Three = 837
# Spread 10 and Category Three = 70
# Spread 5 and Category Four = 916
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 826
# Spread 10 and Category Five = 16
# 13:00~13:30 bid1 spread 5 category one traded probability = 0.602094
# 13:00~13:30 bid1 spread 5 category one traded expectation = -10.654450
# 13:00~13:30 bid1 spread 10 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = 14.999997
# 13:00~13:30 bid1 spread 5 category two traded probability = 0.257453
# 13:00~13:30 bid1 spread 5 category two traded expectation = -28.692412
# 13:00~13:30 bid1 spread 10 category two traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category two traded expectation = 14.999996
# 13:00~13:30 bid1 spread 5 category three traded probability = 0.151732
# 13:00~13:30 bid1 spread 5 category three traded expectation = -35.119474
# 13:00~13:30 bid1 spread 10 category three traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category three traded expectation = 15.000000
# 13:00~13:30 bid1 spread 5 category four traded probability = 0.274017
# 13:00~13:30 bid1 spread 5 category four traded expectation = -30.856987
# 13:00~13:30 bid1 spread 10 category four traded probability = 0.676259
# 13:00~13:30 bid1 spread 10 category four traded expectation = -4.244604
# 13:00~13:30 bid1 spread 5 category five traded probability = 0.308717
# 13:00~13:30 bid1 spread 5 category five traded expectation = -30.139225
# 13:00~13:30 bid1 spread 10 category five traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = -44.687497
#
# Spread 5 and Category One = 1308
# Spread 10 and Category One = 42
# Spread 5 and Category Two= 873
# Spread 10 and Category Two = 83
# Spread 5 and Category Three = 920
# Spread 10 and Category Three = 126
# Spread 5 and Category Four = 701
# Spread 10 and Category Four = 97
# Spread 5 and Category Five = 744
# Spread 10 and Category Five = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 0.007645
# 13:30~14:00 bid1 spread 5 category one traded expectation = -31.345566
# 13:30~14:00 bid1 spread 10 category one traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = -29.999999
# 13:30~14:00 bid1 spread 5 category two traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category two traded expectation = -34.742268
# 13:30~14:00 bid1 spread 10 category two traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category two traded expectation = -34.096385
# 13:30~14:00 bid1 spread 5 category three traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category three traded expectation = -37.070652
# 13:30~14:00 bid1 spread 10 category three traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category three traded expectation = -32.857143
# 13:30~14:00 bid1 spread 5 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category four traded expectation = -36.483595
# 13:30~14:00 bid1 spread 10 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category four traded expectation = -30.824742
# 13:30~14:00 bid1 spread 5 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded expectation = -38.615591
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 1724
# Spread 10 and Category One = 268
# Spread 5 and Category Two= 1669
# Spread 10 and Category Two = 111
# Spread 5 and Category Three = 814
# Spread 10 and Category Three = 58
# Spread 5 and Category Four = 472
# Spread 10 and Category Four = 127
# Spread 5 and Category Five = 931
# Spread 10 and Category Five = 15
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.346288
# 14:00~14:30 bid1 spread 5 category one traded expectation = -14.318445
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.011194
# 14:00~14:30 bid1 spread 10 category one traded expectation = -24.477612
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.349910
# 14:00~14:30 bid1 spread 5 category two traded expectation = -15.754943
# 14:00~14:30 bid1 spread 10 category two traded probability = 0.612613
# 14:00~14:30 bid1 spread 10 category two traded expectation = 1.441441
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.585995
# 14:00~14:30 bid1 spread 5 category three traded expectation = -6.437346
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.827586
# 14:00~14:30 bid1 spread 10 category three traded expectation = 8.103448
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.692797
# 14:00~14:30 bid1 spread 5 category four traded expectation = -2.002119
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.881890
# 14:00~14:30 bid1 spread 10 category four traded expectation = 10.275590
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.860365
# 14:00~14:30 bid1 spread 5 category five traded expectation = 4.495166
# 14:00~14:30 bid1 spread 10 category five traded probability = 1.000000
# 14:00~14:30 bid1 spread 10 category five traded expectation = 14.999999
#
# Spread 5 and Category One = 1382
# Spread 10 and Category One = 233
# Spread 5 and Category Two= 839
# Spread 10 and Category Two = 108
# Spread 5 and Category Three = 783
# Spread 10 and Category Three = 230
# Spread 5 and Category Four = 784
# Spread 10 and Category Four = 40
# Spread 5 and Category Five = 1214
# Spread 10 and Category Five = 21
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.468162
# 14:30~15:00 bid1 spread 5 category one traded expectation = -8.983357
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.489270
# 14:30~15:00 bid1 spread 10 category one traded expectation = -3.004292
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.264601
# 14:30~15:00 bid1 spread 5 category two traded expectation = -15.703218
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.046296
# 14:30~15:00 bid1 spread 10 category two traded expectation = -26.574074
# 14:30~15:00 bid1 spread 5 category three traded probability = 0.114943
# 14:30~15:00 bid1 spread 5 category three traded expectation = -21.270753
# 14:30~15:00 bid1 spread 10 category three traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category three traded expectation = -25.347826
# 14:30~15:00 bid1 spread 5 category four traded probability = 0.247449
# 14:30~15:00 bid1 spread 5 category four traded expectation = -17.091837
# 14:30~15:00 bid1 spread 10 category four traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category four traded expectation = -20.374999
# 14:30~15:00 bid1 spread 5 category five traded probability = 0.057661
# 14:30~15:00 bid1 spread 5 category five traded expectation = -25.704283
# 14:30~15:00 bid1 spread 10 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = -19.999999
#
# Spread 5 and Category One = 338
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 263
# Spread 10 and Category Two = 61
# Spread 5 and Category Three = 309
# Spread 10 and Category Three = 113
# Spread 5 and Category Four = 138
# Spread 10 and Category Four = 3
# Spread 5 and Category Five = 273
# Spread 10 and Category Five = 0
# 15:00~15:30 bid1 spread 5 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category one traded expectation = -21.523669
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded expectation = -23.155893
# 15:00~15:30 bid1 spread 10 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = -20.000000
# 15:00~15:30 bid1 spread 5 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category three traded expectation = -22.055016
# 15:00~15:30 bid1 spread 10 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category three traded expectation = -20.000000
# 15:00~15:30 bid1 spread 5 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded expectation = -24.963768
# 15:00~15:30 bid1 spread 10 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = -19.999993
# 15:00~15:30 bid1 spread 5 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded expectation = -25.000000
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 478
# Spread 10 and Category One = 10
# Spread 5 and Category Two= 100
# Spread 10 and Category Two = 1
# Spread 5 and Category Three = 23
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 5
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category one traded expectation = -15.805439
# 15:30~16:00 bid1 spread 10 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = -14.999999
# 15:30~16:00 bid1 spread 5 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = -20.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded expectation = -14.999985
# 15:30~16:00 bid1 spread 5 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = -19.999999
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded expectation = -19.999996
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000

# %%
bid_stat_time_spread_diff(Bid3,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)
# Out:
# (-104.80000000000001, -43.39999999999992, 8.4000000000000057, 72.600000000000023)
# Spread 5 and Category One = 548
# Spread 10 and Category One = 25
# Spread 5 and Category Two= 1249
# Spread 10 and Category Two = 122
# Spread 5 and Category Three = 794
# Spread 10 and Category Three = 786
# Spread 5 and Category Four = 1050
# Spread 10 and Category Four = 203
# Spread 5 and Category Five = 649
# Spread 10 and Category Five = 0
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 15.000000
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 19.999999
# 09:00~09:30 bid1 spread 5 category two traded probability = 0.998399
# 09:00~09:30 bid1 spread 5 category two traded expectation = 14.895917
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 20.000000
# 09:00~09:30 bid1 spread 5 category three traded probability = 0.895466
# 09:00~09:30 bid1 spread 5 category three traded expectation = 8.110831
# 09:00~09:30 bid1 spread 10 category three traded probability = 0.996183
# 09:00~09:30 bid1 spread 10 category three traded expectation = 19.732824
# 09:00~09:30 bid1 spread 5 category four traded probability = 0.865714
# 09:00~09:30 bid1 spread 5 category four traded expectation = 5.457143
# 09:00~09:30 bid1 spread 10 category four traded probability = 0.443350
# 09:00~09:30 bid1 spread 10 category four traded expectation = -17.955665
# 09:00~09:30 bid1 spread 5 category five traded probability = 0.893683
# 09:00~09:30 bid1 spread 5 category five traded expectation = 6.494607
# 09:00~09:30 bid1 spread 10 category five traded probability = 0.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 2799
# Spread 10 and Category One = 44
# Spread 5 and Category Two= 2470
# Spread 10 and Category Two = 183
# Spread 5 and Category Three = 1957
# Spread 10 and Category Three = 350
# Spread 5 and Category Four = 2773
# Spread 10 and Category Four = 272
# Spread 5 and Category Five = 2988
# Spread 10 and Category Five = 13
# 09:30~10:00 bid1 spread 5 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category one traded expectation = 15.000000
# 09:30~10:00 bid1 spread 10 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category one traded expectation = 20.000000
# 09:30~10:00 bid1 spread 5 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category two traded expectation = 15.000000
# 09:30~10:00 bid1 spread 10 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category two traded expectation = 20.000000
# 09:30~10:00 bid1 spread 5 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category three traded expectation = 15.000000
# 09:30~10:00 bid1 spread 10 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category three traded expectation = 20.000000
# 09:30~10:00 bid1 spread 5 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category four traded expectation = 15.000000
# 09:30~10:00 bid1 spread 10 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category four traded expectation = 20.000000
# 09:30~10:00 bid1 spread 5 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category five traded expectation = 15.000000
# 09:30~10:00 bid1 spread 10 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category five traded expectation = 19.999998
#
# Spread 5 and Category One = 1746
# Spread 10 and Category One = 87
# Spread 5 and Category Two= 1867
# Spread 10 and Category Two = 86
# Spread 5 and Category Three = 1460
# Spread 10 and Category Three = 242
# Spread 5 and Category Four = 1868
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 2522
# Spread 10 and Category Five = 92
# 10:00~10:30 bid1 spread 5 category one traded probability = 0.996564
# 10:00~10:30 bid1 spread 5 category one traded expectation = 14.762314
# 10:00~10:30 bid1 spread 10 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded expectation = 20.000000
# 10:00~10:30 bid1 spread 5 category two traded probability = 0.994108
# 10:00~10:30 bid1 spread 5 category two traded expectation = 14.603642
# 10:00~10:30 bid1 spread 10 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category two traded expectation = 20.000000
# 10:00~10:30 bid1 spread 5 category three traded probability = 0.971233
# 10:00~10:30 bid1 spread 5 category three traded expectation = 13.116438
# 10:00~10:30 bid1 spread 10 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category three traded expectation = 20.000000
# 10:00~10:30 bid1 spread 5 category four traded probability = 0.906852
# 10:00~10:30 bid1 spread 5 category four traded expectation = 8.755353
# 10:00~10:30 bid1 spread 10 category four traded probability = 0.884892
# 10:00~10:30 bid1 spread 10 category four traded expectation = 12.517986
# 10:00~10:30 bid1 spread 5 category five traded probability = 0.885408
# 10:00~10:30 bid1 spread 5 category five traded expectation = 7.335448
# 10:00~10:30 bid1 spread 10 category five traded probability = 0.782609
# 10:00~10:30 bid1 spread 10 category five traded expectation = 5.869565
#
# Spread 5 and Category One = 824
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 1059
# Spread 10 and Category Two = 18
# Spread 5 and Category Three = 1665
# Spread 10 and Category Three = 362
# Spread 5 and Category Four = 1583
# Spread 10 and Category Four = 186
# Spread 5 and Category Five = 1622
# Spread 10 and Category Five = 237
# 10:30~11:00 bid1 spread 5 category one traded probability = 0.503641
# 10:30~11:00 bid1 spread 5 category one traded expectation = -16.935680
# 10:30~11:00 bid1 spread 10 category one traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 0.000000
# 10:30~11:00 bid1 spread 5 category two traded probability = 0.315392
# 10:30~11:00 bid1 spread 5 category two traded expectation = -30.061379
# 10:30~11:00 bid1 spread 10 category two traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category two traded expectation = -35.833331
# 10:30~11:00 bid1 spread 5 category three traded probability = 0.187988
# 10:30~11:00 bid1 spread 5 category three traded expectation = -42.576577
# 11:30~11:00 bid1 spread 10 category three traded probability = 0.287293
# 10:30~11:00 bid1 spread 10 category three traded expectation = -24.820442
# 10:30~11:00 bid1 spread 5 category four traded probability = 0.147189
# 10:30~11:00 bid1 spread 5 category four traded expectation = -43.543904
# 10:30~11:00 bid1 spread 10 category four traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category four traded expectation = -44.677419
# 10:30~11:00 bid1 spread 5 category five traded probability = 0.162762
# 10:30~11:00 bid1 spread 5 category five traded expectation = -41.942047
# 10:30~11:00 bid1 spread 10 category five traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category five traded expectation = -58.797468
#
# Spread 5 and Category One = 879
# Spread 10 and Category One = 19
# Spread 5 and Category Two= 864
# Spread 10 and Category Two = 233
# Spread 5 and Category Three = 1095
# Spread 10 and Category Three = 158
# Spread 5 and Category Four = 1215
# Spread 10 and Category Four = 227
# Spread 5 and Category Five = 1111
# Spread 10 and Category Five = 17
# 11:00~11:30 bid1 spread 5 category one traded probability = 0.808874
# 11:00~11:30 bid1 spread 5 category one traded expectation = 4.220705
# 11:00~11:30 bid1 spread 10 category one traded probability = 0.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = -34.999998
# 11:00~11:30 bid1 spread 5 category two traded probability = 0.659722
# 11:00~11:30 bid1 spread 5 category two traded expectation = -4.409722
# 11:00~11:30 bid1 spread 10 category two traded probability = 0.128755
# 11:00~11:30 bid1 spread 10 category two traded expectation = -31.394850
# 11:00~11:30 bid1 spread 5 category three traded probability = 0.764384
# 11:00~11:30 bid1 spread 5 category three traded expectation = 1.502283
# 11:00~11:30 bid1 spread 10 category three traded probability = 0.708861
# 11:00~11:30 bid1 spread 10 category three traded expectation = 3.386076
# 11:00~11:30 bid1 spread 5 category four traded probability = 0.765432
# 11:00~11:30 bid1 spread 5 category four traded expectation = 1.810700
# 11:00~11:30 bid1 spread 10 category four traded probability = 0.458150
# 11:00~11:30 bid1 spread 10 category four traded expectation = -9.801762
# 11:00~11:30 bid1 spread 5 category five traded probability = 0.726373
# 11:00~11:30 bid1 spread 5 category five traded expectation = -0.247525
# 11:00~11:30 bid1 spread 10 category five traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category five traded expectation = 19.999999
#
# Spread 5 and Category One = 3
# Spread 10 and Category One = 11
# Spread 5 and Category Two= 168
# Spread 10 and Category Two = 74
# Spread 5 and Category Three = 192
# Spread 10 and Category Three = 9
# Spread 5 and Category Four = 203
# Spread 10 and Category Four = 208
# Spread 5 and Category Five = 72
# Spread 10 and Category Five = 16
# 11:30~12:00 bid1 spread 5 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category one traded expectation = 14.999995
# 11:30~12:00 bid1 spread 10 category one traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = -34.999997
# 11:30~12:00 bid1 spread 5 category two traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = -45.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category two traded expectation = -39.324324
# 11:30~12:00 bid1 spread 5 category three traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category three traded expectation = -42.682291
# 11:30~12:00 bid1 spread 10 category three traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category three traded expectation = -34.999996
# 11:30~12:00 bid1 spread 5 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded expectation = -42.931034
# 11:30~12:00 bid1 spread 10 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = -45.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded expectation = -45.208333
# 11:30~12:00 bid1 spread 10 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = -44.999997
#
# Spread 5 and Category One = 61
# Spread 10 and Category One = 28
# Spread 5 and Category Two= 22
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 53
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 35
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 15.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 0.821429
# 12:00~12:30 bid1 spread 10 category one traded expectation = 10.178571
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 14.999999
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 15.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 0.028571
# 12:00~12:30 bid1 spread 5 category four traded expectation = -38.428570
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 123
# Spread 10 and Category One = 27
# Spread 5 and Category Two= 58
# Spread 10 and Category Two = 63
# Spread 5 and Category Three = 0
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 15
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 22
# Spread 10 and Category Five = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 15.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = -34.999999
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 15.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = -34.999999
# 12:30~13:00 bid1 spread 5 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = -39.999997
# 12:30~13:00 bid1 spread 10 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = -39.999998
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 382
# Spread 10 and Category One = 5
# Spread 5 and Category Two= 738
# Spread 10 and Category Two = 4
# Spread 5 and Category Three = 837
# Spread 10 and Category Three = 70
# Spread 5 and Category Four = 916
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 826
# Spread 10 and Category Five = 16
# 13:00~13:30 bid1 spread 5 category one traded probability = 0.602094
# 13:00~13:30 bid1 spread 5 category one traded expectation = -7.643979
# 13:00~13:30 bid1 spread 10 category one traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = -34.999993
# 13:00~13:30 bid1 spread 5 category two traded probability = 0.177507
# 13:00~13:30 bid1 spread 5 category two traded expectation = -31.802168
# 13:00~13:30 bid1 spread 10 category two traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category two traded expectation = -34.999991
# 13:00~13:30 bid1 spread 5 category three traded probability = 0.087216
# 13:00~13:30 bid1 spread 5 category three traded expectation = -37.909199
# 13:00~13:30 bid1 spread 10 category three traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category three traded expectation = -35.000000
# 13:00~13:30 bid1 spread 5 category four traded probability = 0.064410
# 13:00~13:30 bid1 spread 5 category four traded expectation = -41.015284
# 13:00~13:30 bid1 spread 10 category four traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category four traded expectation = -38.057554
# 13:00~13:30 bid1 spread 5 category five traded probability = 0.012107
# 13:00~13:30 bid1 spread 5 category five traded expectation = -44.909201
# 13:00~13:30 bid1 spread 10 category five traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = -44.687497
#
# Spread 5 and Category One = 1308
# Spread 10 and Category One = 42
# Spread 5 and Category Two= 873
# Spread 10 and Category Two = 83
# Spread 5 and Category Three = 920
# Spread 10 and Category Three = 126
# Spread 5 and Category Four = 701
# Spread 10 and Category Four = 97
# Spread 5 and Category Five = 744
# Spread 10 and Category Five = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category one traded expectation = -31.651376
# 13:30~14:00 bid1 spread 10 category one traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = -29.999999
# 13:30~14:00 bid1 spread 5 category two traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category two traded expectation = -34.742268
# 13:30~14:00 bid1 spread 10 category two traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category two traded expectation = -34.096385
# 13:30~14:00 bid1 spread 5 category three traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category three traded expectation = -37.070652
# 13:30~14:00 bid1 spread 10 category three traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category three traded expectation = -32.857143
# 13:30~14:00 bid1 spread 5 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category four traded expectation = -36.483595
# 13:30~14:00 bid1 spread 10 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category four traded expectation = -30.824742
# 13:30~14:00 bid1 spread 5 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded expectation = -38.615591
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 1724
# Spread 10 and Category One = 268
# Spread 5 and Category Two= 1669
# Spread 10 and Category Two = 111
# Spread 5 and Category Three = 814
# Spread 10 and Category Three = 58
# Spread 5 and Category Four = 472
# Spread 10 and Category Four = 127
# Spread 5 and Category Five = 931
# Spread 10 and Category Five = 15
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.258701
# 14:00~14:30 bid1 spread 5 category one traded expectation = -15.652552
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.003731
# 14:00~14:30 bid1 spread 10 category one traded expectation = -24.682836
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.210306
# 14:00~14:30 bid1 spread 5 category two traded expectation = -18.891552
# 14:00~14:30 bid1 spread 10 category two traded probability = 0.135135
# 14:00~14:30 bid1 spread 10 category two traded expectation = -12.207207
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.303440
# 14:00~14:30 bid1 spread 5 category three traded expectation = -13.396806
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.241379
# 14:00~14:30 bid1 spread 10 category three traded expectation = -8.275862
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.226695
# 14:00~14:30 bid1 spread 5 category four traded expectation = -14.851695
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.346457
# 14:00~14:30 bid1 spread 10 category four traded expectation = -4.055118
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.206230
# 14:00~14:30 bid1 spread 5 category five traded expectation = -14.097744
# 14:00~14:30 bid1 spread 10 category five traded probability = 0.933333
# 14:00~14:30 bid1 spread 10 category five traded expectation = 17.666665
#
# Spread 5 and Category One = 1382
# Spread 10 and Category One = 233
# Spread 5 and Category Two= 839
# Spread 10 and Category Two = 108
# Spread 5 and Category Three = 783
# Spread 10 and Category Three = 230
# Spread 5 and Category Four = 784
# Spread 10 and Category Four = 40
# Spread 5 and Category Five = 1214
# Spread 10 and Category Five = 21
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.259045
# 14:30~15:00 bid1 spread 5 category one traded expectation = -13.961650
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category one traded expectation = -17.682403
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.032181
# 14:30~15:00 bid1 spread 5 category two traded expectation = -22.514899
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category two traded expectation = -27.962963
# 14:30~15:00 bid1 spread 5 category three traded probability = 0.000000
# 14:30~15:00 bid1 spread 5 category three traded expectation = -24.719029
# 14:30~15:00 bid1 spread 10 category three traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category three traded expectation = -25.347826
# 14:30~15:00 bid1 spread 5 category four traded probability = 0.000000
# 14:30~15:00 bid1 spread 5 category four traded expectation = -24.515306
# 14:30~15:00 bid1 spread 10 category four traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category four traded expectation = -20.374999
# 14:30~15:00 bid1 spread 5 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 5 category five traded expectation = -27.434102
# 14:30~15:00 bid1 spread 10 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = -19.999999
#
# Spread 5 and Category One = 338
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 263
# Spread 10 and Category Two = 61
# Spread 5 and Category Three = 309
# Spread 10 and Category Three = 113
# Spread 5 and Category Four = 138
# Spread 10 and Category Four = 3
# Spread 5 and Category Five = 273
# Spread 10 and Category Five = 0
# 15:00~15:30 bid1 spread 5 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category one traded expectation = -21.523669
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded expectation = -23.155893
# 15:00~15:30 bid1 spread 10 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = -20.000000
# 15:00~15:30 bid1 spread 5 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category three traded expectation = -22.055016
# 15:00~15:30 bid1 spread 10 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category three traded expectation = -20.000000
# 15:00~15:30 bid1 spread 5 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded expectation = -24.963768
# 15:00~15:30 bid1 spread 10 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = -19.999993
# 15:00~15:30 bid1 spread 5 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded expectation = -25.000000
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 478
# Spread 10 and Category One = 10
# Spread 5 and Category Two= 100
# Spread 10 and Category Two = 1
# Spread 5 and Category Three = 23
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 5
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category one traded expectation = -15.805439
# 15:30~16:00 bid1 spread 10 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = -14.999999
# 15:30~16:00 bid1 spread 5 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = -20.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded expectation = -14.999985
# 15:30~16:00 bid1 spread 5 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = -19.999999
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded expectation = -19.999996
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000

# %%
#2014-01-28 close price = 6750
#0.6177
#0.8696
#1.0678
#1.3835

Close_Price = 6750

def ask_stat_time_spread_divid(Ask1,Bid1,max_Bid1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price):
    
    Bid1_traded_spr5_category_one = 0
    Bid1_traded_expected_spr5_category_one = 0
    Bid1_traded_spr10_category_one = 0
    Bid1_traded_expected_spr10_category_one = 0
    N_spr5_category_one = 0
    N_spr10_category_one = 0

    Bid1_traded_spr5_category_two = 0
    Bid1_traded_expected_spr5_category_two = 0
    Bid1_traded_spr10_category_two = 0
    Bid1_traded_expected_spr10_category_two = 0
    N_spr5_category_two = 0
    N_spr10_category_two = 0

    Bid1_traded_spr5_category_three = 0
    Bid1_traded_expected_spr5_category_three = 0
    Bid1_traded_spr10_category_three = 0
    Bid1_traded_expected_spr10_category_three = 0
    N_spr5_category_three = 0
    N_spr10_category_three = 0

    Bid1_traded_spr5_category_four = 0
    Bid1_traded_expected_spr5_category_four = 0
    Bid1_traded_spr10_category_four = 0
    Bid1_traded_expected_spr10_category_four = 0
    N_spr5_category_four = 0
    N_spr10_category_four = 0

    Bid1_traded_spr5_category_five = 0
    Bid1_traded_expected_spr5_category_five = 0
    Bid1_traded_spr10_category_five = 0
    Bid1_traded_expected_spr10_category_five = 0
    N_spr5_category_five = 0
    N_spr10_category_five = 0

    ###one week
    diff_weighted_five_categories = diff_weighted_five_category(Bid1_Quantity,Bid2_Quantity,Bid3_Quantity,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity,weight1,weight2,weight3)

    print diff_weighted_five_categories

    for i in range(0,data_trade_time_series_1530_1600,1):
        #print i
        #print Bid1[i]
        #print min_Ask1_time_series[i+1]
        weighted_Bid = Bid1_Quantity[i] * weight1 + Bid2_Quantity[i] * weight2 + Bid3_Quantity[i] * weight3
        weighted_Ask = Ask1_Quantity[i] * weight1 + Ask2_Quantity[i] * weight2 + Ask3_Quantity[i] * weight3  
        #print weighted_Bid
        #print weighted_Ask
        #print (weighted_Bid*(1.0) / weighted_Ask)
        #print '\t'
        if (weighted_Bid*(1.0) - weighted_Ask) <= diff_weighted_five_categories[0]:  
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_one = N_spr5_category_one + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_one = Bid1_traded_spr5_category_one + 1
                    Bid1_traded_expected_spr5_category_one = Bid1_traded_expected_spr5_category_one + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_one = Bid1_traded_expected_spr5_category_one + (Close_Price - Bid1[i])
                    #print Bid1_traded_expected
            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_one = N_spr10_category_one + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr10_category_one = Bid1_traded_spr10_category_one + 1
                    Bid1_traded_expected_spr10_category_one = Bid1_traded_expected_spr10_category_one + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr10_category_one = Bid1_traded_expected_spr10_category_one + (Close_Price -  Bid1[i])
                    #print Bid1_traded_expected
            else:
                pass

        elif diff_weighted_five_categories[0] < (weighted_Bid*(1.0) - weighted_Ask) <= diff_weighted_five_categories[1]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_two = N_spr5_category_two + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_two = Bid1_traded_spr5_category_two + 1
                    Bid1_traded_expected_spr5_category_two = Bid1_traded_expected_spr5_category_two + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_two = Bid1_traded_expected_spr5_category_two + (Close_Price - Bid1[i])
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_two = N_spr10_category_two + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr10_category_two = Bid1_traded_spr10_category_two + 1
                    Bid1_traded_expected_spr10_category_two = Bid1_traded_expected_spr10_category_two + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr10_category_two = Bid1_traded_expected_spr10_category_two + (Close_Price - Bid1[i])
                    #print Bid1_traded_expected
            else:
                pass    

        elif diff_weighted_five_categories[1] < (weighted_Bid*(1.0) - weighted_Ask) <= diff_weighted_five_categories[2]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_three = N_spr5_category_three + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_three = Bid1_traded_spr5_category_three + 1
                    Bid1_traded_expected_spr5_category_three = Bid1_traded_expected_spr5_category_three + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_three = Bid1_traded_expected_spr5_category_three + (Close_Price - Bid1[i])
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_three = N_spr10_category_three + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_three = Bid1_traded_spr10_category_three + 1
                    Bid1_traded_expected_spr10_category_three = Bid1_traded_expected_spr10_category_three + (Ask1[i] - Bid1[i])
                    #print 'a1 = %f'%(Bid1_traded_expected_spr10_category_three)
                else:
                    Bid1_traded_expected_spr10_category_three = Bid1_traded_expected_spr10_category_three + (Close_Price - Bid1[i])
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_three)
            else:
                pass    

        elif diff_weighted_five_categories[2] < (weighted_Bid*(1.0) - weighted_Ask) <= diff_weighted_five_categories[3]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_four = N_spr5_category_four + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_four = Bid1_traded_spr5_category_four + 1
                    Bid1_traded_expected_spr5_category_four = Bid1_traded_expected_spr5_category_four + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_four = Bid1_traded_expected_spr5_category_four + (Close_Price - Bid1[i])
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_four = N_spr10_category_four + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_four = Bid1_traded_spr10_category_four + 1
                    Bid1_traded_expected_spr10_category_four = Bid1_traded_expected_spr10_category_four + (Ask1[i] - Bid1[i])
                    #print 'a1 = %f'%(Bid1_traded_expected_spr10_category_four)
                else:
                    Bid1_traded_expected_spr10_category_four = Bid1_traded_expected_spr10_category_four + (Close_Price - Bid1[i])
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_four)
            else:
                pass    

        elif diff_weighted_five_categories[3] < (weighted_Bid*(1.0) - weighted_Ask): 
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_five = N_spr5_category_five + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_five = Bid1_traded_spr5_category_five + 1
                    Bid1_traded_expected_spr5_category_five = Bid1_traded_expected_spr5_category_five + (Ask1[i] - Bid1[i])
                else:
                    Bid1_traded_expected_spr5_category_five = Bid1_traded_expected_spr5_category_five + (Close_Price - Bid1[i])
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_five = N_spr10_category_five + 1
                if Ask1[i] < max_Bid1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_five = Bid1_traded_spr10_category_five + 1
                    Bid1_traded_expected_spr10_category_five = Bid1_traded_expected_spr10_category_five + (Ask1[i] - Bid1[i])
                    #print 'a1 = %f'%(Bid1_traded_expected_spr10_category_four)
                else:
                    Bid1_traded_expected_spr10_category_five = Bid1_traded_expected_spr10_category_five + (Close_Price - Bid1[i])
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_four)
            else:
                pass    


        #print Bid1_traded_expected_spr10_category_three

        if i == data_trade_time_series_0900_0930 - 1:  

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '09:00~09:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '09:00~09:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:00~09:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:00~09:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '09:00~09:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '09:00~09:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:00~09:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:00~09:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '09:00~09:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '09:00~09:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:00~09:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:00~09:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '09:00~09:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '09:00~09:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:00~09:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:00~09:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '09:00~09:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))



            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0        
            print '\t'        
            continue

        elif i == data_trade_time_series_0930_1000 - 1:   

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '09:30~10:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '09:30~10:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '09:30~10:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '09:30~10:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '09:30~10:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0         

            print '\t'        
            continue
        elif i == data_trade_time_series_1000_1030 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '10:00~10:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '10:00~10:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '10:00~10:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '10:00~10:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '10:00~10:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue
        elif i == data_trade_time_series_1030_1100 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '10:30~11:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '10:30~11:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '10:30~11:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:30~11:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~11:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:30~11:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '10:30~11:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '10:30~11:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue

        elif i == data_trade_time_series_1100_1130 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '11:00~11:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '11:00~11:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '11:00~11:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '11:00~11:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '11:00~11:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue

        elif i == data_trade_time_series_1130_1200 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '11:30~12:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '11:30~12:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '11:30~12:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '11:30~12:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '11:30~12:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue
        elif i == data_trade_time_series_1200_1230 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '12:00~12:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '12:00~12:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '12:00~12:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '12:00~12:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '12:00~12:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue
        elif i == data_trade_time_series_1230_1300 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '12:30~13:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '12:30~13:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '12:30~13:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '12:30~13:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '12:30~13:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue
        elif i == data_trade_time_series_1300_1330 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '13:00~13:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '13:00~13:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '13:00~13:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '13:00~13:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '13:00~13:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue
        elif i == data_trade_time_series_1330_1400 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '13:30~14:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '13:30~14:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '13:30~14:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '13:30~14:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '13:30~14:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 
            print '\t'
            continue        
        elif i == data_trade_time_series_1400_1430 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '14:00~14:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '14:00~14:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '14:00~14:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '14:00~14:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '14:00~14:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue                                          
        elif i == data_trade_time_series_1430_1500 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '14:30~15:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '14:30~15:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '14:30~15:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '14:30~15:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '14:30~15:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue 
        elif i == data_trade_time_series_1500_1530 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '15:00~15:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '15:00~15:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '15:00~15:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '15:00~15:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '15:00~15:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue 
        elif i == data_trade_time_series_1530_1600 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '15:30~16:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))

            print '15:30~16:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))

            print '15:30~16:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))

            print '15:30~16:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))

            print '15:30~16:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))

            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0        
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0        
            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0        
            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0 

            print '\t'
            continue

# %%
ask_stat_time_spread_divid(Ask1,Bid1,max_Bid1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)
# Out:
# (-104.80000000000001, -43.39999999999992, 8.4000000000000057, 72.600000000000023)
# Spread 5 and Category One = 548
# Spread 10 and Category One = 25
# Spread 5 and Category Two= 1249
# Spread 10 and Category Two = 122
# Spread 5 and Category Three = 794
# Spread 10 and Category Three = 786
# Spread 5 and Category Four = 1050
# Spread 10 and Category Four = 203
# Spread 5 and Category Five = 649
# Spread 10 and Category Five = 0
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 5.000000
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 10.000000
# 09:00~09:30 bid1 spread 5 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category two traded expectation = 5.000000
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 10.000000
# 09:00~09:30 bid1 spread 5 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category three traded expectation = 5.000000
# 09:00~09:30 bid1 spread 10 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded expectation = 10.000000
# 09:00~09:30 bid1 spread 5 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category four traded expectation = 5.000000
# 09:00~09:30 bid1 spread 10 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded expectation = 10.000000
# 09:00~09:30 bid1 spread 5 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category five traded expectation = 5.000000
# 09:00~09:30 bid1 spread 10 category five traded probability = 0.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 2799
# Spread 10 and Category One = 44
# Spread 5 and Category Two= 2470
# Spread 10 and Category Two = 183
# Spread 5 and Category Three = 1957
# Spread 10 and Category Three = 350
# Spread 5 and Category Four = 2773
# Spread 10 and Category Four = 272
# Spread 5 and Category Five = 2988
# Spread 10 and Category Five = 13
# 09:30~10:00 bid1 spread 5 category one traded probability = 0.395498
# 09:30~10:00 bid1 spread 5 category one traded expectation = 0.550196
# 09:30~10:00 bid1 spread 10 category one traded probability = 0.159091
# 09:30~10:00 bid1 spread 10 category one traded expectation = -7.613636
# 09:30~10:00 bid1 spread 5 category two traded probability = 0.440486
# 09:30~10:00 bid1 spread 5 category two traded expectation = 2.455466
# 09:30~10:00 bid1 spread 10 category two traded probability = 0.404372
# 09:30~10:00 bid1 spread 10 category two traded expectation = 6.693989
# 09:30~10:00 bid1 spread 5 category three traded probability = 0.451712
# 09:30~10:00 bid1 spread 5 category three traded expectation = 4.307614
# 09:30~10:00 bid1 spread 10 category three traded probability = 0.100000
# 09:30~10:00 bid1 spread 10 category three traded expectation = 8.171429
# 09:30~10:00 bid1 spread 5 category four traded probability = 0.591057
# 09:30~10:00 bid1 spread 5 category four traded expectation = 5.623873
# 09:30~10:00 bid1 spread 10 category four traded probability = 0.257353
# 09:30~10:00 bid1 spread 10 category four traded expectation = 11.838235
# 09:30~10:00 bid1 spread 5 category five traded probability = 0.611446
# 09:30~10:00 bid1 spread 5 category five traded expectation = 6.300201
# 09:30~10:00 bid1 spread 10 category five traded probability = 0.615385
# 09:30~10:00 bid1 spread 10 category five traded expectation = 15.769230
#
# Spread 5 and Category One = 1746
# Spread 10 and Category One = 87
# Spread 5 and Category Two= 1867
# Spread 10 and Category Two = 86
# Spread 5 and Category Three = 1460
# Spread 10 and Category Three = 242
# Spread 5 and Category Four = 1868
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 2522
# Spread 10 and Category Five = 92
# 10:00~10:30 bid1 spread 5 category one traded probability = 0.795533
# 10:00~10:30 bid1 spread 5 category one traded expectation = 8.067010
# 10:00~10:30 bid1 spread 10 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded expectation = 10.000000
# 10:00~10:30 bid1 spread 5 category two traded probability = 0.894483
# 10:00~10:30 bid1 spread 5 category two traded expectation = 6.582753
# 10:00~10:30 bid1 spread 10 category two traded probability = 0.918605
# 10:00~10:30 bid1 spread 10 category two traded expectation = 11.220930
# 10:00~10:30 bid1 spread 5 category three traded probability = 0.839041
# 10:00~10:30 bid1 spread 5 category three traded expectation = 7.414384
# 10:00~10:30 bid1 spread 10 category three traded probability = 0.545455
# 10:00~10:30 bid1 spread 10 category three traded expectation = 16.818182
# 10:00~10:30 bid1 spread 5 category four traded probability = 0.975910
# 10:00~10:30 bid1 spread 5 category four traded expectation = 5.361349
# 10:00~10:30 bid1 spread 10 category four traded probability = 0.906475
# 10:00~10:30 bid1 spread 10 category four traded expectation = 11.402878
# 10:00~10:30 bid1 spread 5 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category five traded expectation = 5.000000
# 10:00~10:30 bid1 spread 10 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded expectation = 10.000000
#
# Spread 5 and Category One = 824
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 1059
# Spread 10 and Category Two = 18
# Spread 5 and Category Three = 1665
# Spread 10 and Category Three = 362
# Spread 5 and Category Four = 1583
# Spread 10 and Category Four = 186
# Spread 5 and Category Five = 1622
# Spread 10 and Category Five = 237
# 10:30~11:00 bid1 spread 5 category one traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category one traded expectation = 5.000000
# 10:30~11:00 bid1 spread 10 category one traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 0.000000
# 10:30~11:00 bid1 spread 5 category two traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category two traded expectation = 5.000000
# 10:30~11:00 bid1 spread 10 category two traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category two traded expectation = 9.999999
# 10:30~11:00 bid1 spread 5 category three traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category three traded expectation = 5.000000
# 11:30~11:00 bid1 spread 10 category three traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category three traded expectation = 10.000000
# 10:30~11:00 bid1 spread 5 category four traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category four traded expectation = 5.000000
# 10:30~11:00 bid1 spread 10 category four traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category four traded expectation = 10.000000
# 10:30~11:00 bid1 spread 5 category five traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category five traded expectation = 5.000000
# 10:30~11:00 bid1 spread 10 category five traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category five traded expectation = 10.000000
#
# Spread 5 and Category One = 879
# Spread 10 and Category One = 19
# Spread 5 and Category Two= 864
# Spread 10 and Category Two = 233
# Spread 5 and Category Three = 1095
# Spread 10 and Category Three = 158
# Spread 5 and Category Four = 1215
# Spread 10 and Category Four = 227
# Spread 5 and Category Five = 1111
# Spread 10 and Category Five = 17
# 11:00~11:30 bid1 spread 5 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 5 category one traded expectation = 5.000000
# 11:00~11:30 bid1 spread 10 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = 9.999999
# 11:00~11:30 bid1 spread 5 category two traded probability = 1.000000
# 11:00~11:30 bid1 spread 5 category two traded expectation = 5.000000
# 11:00~11:30 bid1 spread 10 category two traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category two traded expectation = 10.000000
# 11:00~11:30 bid1 spread 5 category three traded probability = 1.000000
# 11:00~11:30 bid1 spread 5 category three traded expectation = 5.000000
# 11:00~11:30 bid1 spread 10 category three traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category three traded expectation = 10.000000
# 11:00~11:30 bid1 spread 5 category four traded probability = 1.000000
# 11:00~11:30 bid1 spread 5 category four traded expectation = 5.000000
# 11:00~11:30 bid1 spread 10 category four traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category four traded expectation = 10.000000
# 11:00~11:30 bid1 spread 5 category five traded probability = 1.000000
# 11:00~11:30 bid1 spread 5 category five traded expectation = 5.000000
# 11:00~11:30 bid1 spread 10 category five traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category five traded expectation = 9.999999
#
# Spread 5 and Category One = 3
# Spread 10 and Category One = 11
# Spread 5 and Category Two= 168
# Spread 10 and Category Two = 74
# Spread 5 and Category Three = 192
# Spread 10 and Category Three = 9
# Spread 5 and Category Four = 203
# Spread 10 and Category Four = 208
# Spread 5 and Category Five = 72
# Spread 10 and Category Five = 16
# 11:30~12:00 bid1 spread 5 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category one traded expectation = 4.999998
# 11:30~12:00 bid1 spread 10 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = 9.999999
# 11:30~12:00 bid1 spread 5 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = 5.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category two traded expectation = 10.000000
# 11:30~12:00 bid1 spread 5 category three traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category three traded expectation = 5.000000
# 11:30~12:00 bid1 spread 10 category three traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category three traded expectation = 9.999999
# 11:30~12:00 bid1 spread 5 category four traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category four traded expectation = 5.000000
# 11:30~12:00 bid1 spread 10 category four traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = 10.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category five traded expectation = 5.000000
# 11:30~12:00 bid1 spread 10 category five traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = 9.999999
#
# Spread 5 and Category One = 61
# Spread 10 and Category One = 28
# Spread 5 and Category Two= 22
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 53
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 35
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 5.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded expectation = 10.000000
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 5.000000
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 5.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category four traded expectation = 5.000000
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 123
# Spread 10 and Category One = 27
# Spread 5 and Category Two= 58
# Spread 10 and Category Two = 63
# Spread 5 and Category Three = 0
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 15
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 22
# Spread 10 and Category Five = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 5.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = 10.000000
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 5.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = 10.000000
# 12:30~13:00 bid1 spread 5 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = 5.000000
# 12:30~13:00 bid1 spread 10 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = 5.000000
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 382
# Spread 10 and Category One = 5
# Spread 5 and Category Two= 738
# Spread 10 and Category Two = 4
# Spread 5 and Category Three = 837
# Spread 10 and Category Three = 70
# Spread 5 and Category Four = 916
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 826
# Spread 10 and Category Five = 16
# 13:00~13:30 bid1 spread 5 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category one traded expectation = 5.000000
# 13:00~13:30 bid1 spread 10 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = 9.999998
# 13:00~13:30 bid1 spread 5 category two traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category two traded expectation = 5.000000
# 13:00~13:30 bid1 spread 10 category two traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category two traded expectation = 9.999998
# 13:00~13:30 bid1 spread 5 category three traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category three traded expectation = 5.000000
# 13:00~13:30 bid1 spread 10 category three traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category three traded expectation = 10.000000
# 13:00~13:30 bid1 spread 5 category four traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category four traded expectation = 5.000000
# 13:00~13:30 bid1 spread 10 category four traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category four traded expectation = 10.000000
# 13:00~13:30 bid1 spread 5 category five traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category five traded expectation = 5.000000
# 13:00~13:30 bid1 spread 10 category five traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = 9.999999
#
# Spread 5 and Category One = 1308
# Spread 10 and Category One = 42
# Spread 5 and Category Two= 873
# Spread 10 and Category Two = 83
# Spread 5 and Category Three = 920
# Spread 10 and Category Three = 126
# Spread 5 and Category Four = 701
# Spread 10 and Category Four = 97
# Spread 5 and Category Five = 744
# Spread 10 and Category Five = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category one traded expectation = 5.000000
# 13:30~14:00 bid1 spread 10 category one traded probability = 1.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = 10.000000
# 13:30~14:00 bid1 spread 5 category two traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category two traded expectation = 5.000000
# 13:30~14:00 bid1 spread 10 category two traded probability = 1.000000
# 13:30~14:00 bid1 spread 10 category two traded expectation = 10.000000
# 13:30~14:00 bid1 spread 5 category three traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category three traded expectation = 5.000000
# 13:30~14:00 bid1 spread 10 category three traded probability = 1.000000
# 13:30~14:00 bid1 spread 10 category three traded expectation = 10.000000
# 13:30~14:00 bid1 spread 5 category four traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category four traded expectation = 5.000000
# 13:30~14:00 bid1 spread 10 category four traded probability = 1.000000
# 13:30~14:00 bid1 spread 10 category four traded expectation = 10.000000
# 13:30~14:00 bid1 spread 5 category five traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category five traded expectation = 5.000000
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 1724
# Spread 10 and Category One = 268
# Spread 5 and Category Two= 1669
# Spread 10 and Category Two = 111
# Spread 5 and Category Three = 814
# Spread 10 and Category Three = 58
# Spread 5 and Category Four = 472
# Spread 10 and Category Four = 127
# Spread 5 and Category Five = 931
# Spread 10 and Category Five = 15
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.741299
# 14:00~14:30 bid1 spread 5 category one traded expectation = 8.648492
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.988806
# 14:00~14:30 bid1 spread 10 category one traded expectation = 10.149254
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.789694
# 14:00~14:30 bid1 spread 5 category two traded expectation = 7.884961
# 14:00~14:30 bid1 spread 10 category two traded probability = 0.387387
# 14:00~14:30 bid1 spread 10 category two traded expectation = 18.513513
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.696560
# 14:00~14:30 bid1 spread 5 category three traded expectation = 9.312039
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.172414
# 14:00~14:30 bid1 spread 10 category three traded expectation = 21.206896
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.773305
# 14:00~14:30 bid1 spread 5 category four traded expectation = 8.347458
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.118110
# 14:00~14:30 bid1 spread 10 category four traded expectation = 21.496063
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.793770
# 14:00~14:30 bid1 spread 5 category five traded expectation = 8.093448
# 14:00~14:30 bid1 spread 10 category five traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category five traded expectation = 20.333332
#
# Spread 5 and Category One = 1382
# Spread 10 and Category One = 233
# Spread 5 and Category Two= 839
# Spread 10 and Category Two = 108
# Spread 5 and Category Three = 783
# Spread 10 and Category Three = 230
# Spread 5 and Category Four = 784
# Spread 10 and Category Four = 40
# Spread 5 and Category Five = 1214
# Spread 10 and Category Five = 21
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.740955
# 14:30~15:00 bid1 spread 5 category one traded expectation = 8.885673
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.510730
# 14:30~15:00 bid1 spread 10 category one traded expectation = 17.339056
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.967819
# 14:30~15:00 bid1 spread 5 category two traded expectation = 5.482718
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.953704
# 14:30~15:00 bid1 spread 10 category two traded expectation = 10.694444
# 14:30~15:00 bid1 spread 5 category three traded probability = 1.000000
# 14:30~15:00 bid1 spread 5 category three traded expectation = 5.000000
# 14:30~15:00 bid1 spread 10 category three traded probability = 1.000000
# 14:30~15:00 bid1 spread 10 category three traded expectation = 10.000000
# 14:30~15:00 bid1 spread 5 category four traded probability = 1.000000
# 14:30~15:00 bid1 spread 5 category four traded expectation = 5.000000
# 14:30~15:00 bid1 spread 10 category four traded probability = 1.000000
# 14:30~15:00 bid1 spread 10 category four traded expectation = 10.000000
# 14:30~15:00 bid1 spread 5 category five traded probability = 1.000000
# 14:30~15:00 bid1 spread 5 category five traded expectation = 5.000000
# 14:30~15:00 bid1 spread 10 category five traded probability = 1.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = 10.000000
#
# Spread 5 and Category One = 338
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 263
# Spread 10 and Category Two = 61
# Spread 5 and Category Three = 309
# Spread 10 and Category Three = 113
# Spread 5 and Category Four = 138
# Spread 10 and Category Four = 3
# Spread 5 and Category Five = 273
# Spread 10 and Category Five = 0
# 15:00~15:30 bid1 spread 5 category one traded probability = 1.000000
# 15:00~15:30 bid1 spread 5 category one traded expectation = 5.000000
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 1.000000
# 15:00~15:30 bid1 spread 5 category two traded expectation = 5.000000
# 15:00~15:30 bid1 spread 10 category two traded probability = 1.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = 10.000000
# 15:00~15:30 bid1 spread 5 category three traded probability = 1.000000
# 15:00~15:30 bid1 spread 5 category three traded expectation = 5.000000
# 15:00~15:30 bid1 spread 10 category three traded probability = 1.000000
# 15:00~15:30 bid1 spread 10 category three traded expectation = 10.000000
# 15:00~15:30 bid1 spread 5 category four traded probability = 1.000000
# 15:00~15:30 bid1 spread 5 category four traded expectation = 5.000000
# 15:00~15:30 bid1 spread 10 category four traded probability = 1.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = 9.999997
# 15:00~15:30 bid1 spread 5 category five traded probability = 1.000000
# 15:00~15:30 bid1 spread 5 category five traded expectation = 5.000000
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 478
# Spread 10 and Category One = 10
# Spread 5 and Category Two= 100
# Spread 10 and Category Two = 1
# Spread 5 and Category Three = 23
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 5
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 0.161088
# 15:30~16:00 bid1 spread 5 category one traded expectation = 17.583682
# 15:30~16:00 bid1 spread 10 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = 24.999998
# 15:30~16:00 bid1 spread 5 category two traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = 5.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded expectation = 24.999975
# 15:30~16:00 bid1 spread 5 category three traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = 5.000000
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category four traded expectation = 4.999999
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000

# %%
ask_stat_time_spread_divid(Ask2,Bid1,max_Bid1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)
# Out:
# (-104.80000000000001, -43.39999999999992, 8.4000000000000057, 72.600000000000023)
# Spread 5 and Category One = 548
# Spread 10 and Category One = 25
# Spread 5 and Category Two= 1249
# Spread 10 and Category Two = 122
# Spread 5 and Category Three = 794
# Spread 10 and Category Three = 786
# Spread 5 and Category Four = 1050
# Spread 10 and Category Four = 203
# Spread 5 and Category Five = 649
# Spread 10 and Category Five = 0
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 10.000000
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 14.999999
# 09:00~09:30 bid1 spread 5 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category two traded expectation = 10.000000
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 15.000000
# 09:00~09:30 bid1 spread 5 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category three traded expectation = 10.000000
# 09:00~09:30 bid1 spread 10 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded expectation = 15.000000
# 09:00~09:30 bid1 spread 5 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category four traded expectation = 10.000000
# 09:00~09:30 bid1 spread 10 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded expectation = 15.000000
# 09:00~09:30 bid1 spread 5 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category five traded expectation = 10.015408
# 09:00~09:30 bid1 spread 10 category five traded probability = 0.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 2799
# Spread 10 and Category One = 44
# Spread 5 and Category Two= 2470
# Spread 10 and Category Two = 183
# Spread 5 and Category Three = 1957
# Spread 10 and Category Three = 350
# Spread 5 and Category Four = 2773
# Spread 10 and Category Four = 272
# Spread 5 and Category Five = 2988
# Spread 10 and Category Five = 13
# 09:30~10:00 bid1 spread 5 category one traded probability = 0.280457
# 09:30~10:00 bid1 spread 5 category one traded expectation = 1.375491
# 09:30~10:00 bid1 spread 10 category one traded probability = 0.159091
# 09:30~10:00 bid1 spread 10 category one traded expectation = -6.818182
# 09:30~10:00 bid1 spread 5 category two traded probability = 0.280972
# 09:30~10:00 bid1 spread 5 category two traded expectation = 4.230769
# 09:30~10:00 bid1 spread 10 category two traded probability = 0.306011
# 09:30~10:00 bid1 spread 10 category two traded expectation = 10.191257
# 09:30~10:00 bid1 spread 5 category three traded probability = 0.327542
# 09:30~10:00 bid1 spread 5 category three traded expectation = 5.725600
# 09:30~10:00 bid1 spread 10 category three traded probability = 0.091429
# 09:30~10:00 bid1 spread 10 category three traded expectation = 8.500000
# 09:30~10:00 bid1 spread 5 category four traded probability = 0.368915
# 09:30~10:00 bid1 spread 5 category four traded expectation = 6.750811
# 09:30~10:00 bid1 spread 10 category four traded probability = 0.238971
# 09:30~10:00 bid1 spread 10 category four traded expectation = 12.849265
# 09:30~10:00 bid1 spread 5 category five traded probability = 0.323628
# 09:30~10:00 bid1 spread 5 category five traded expectation = 7.814592
# 09:30~10:00 bid1 spread 10 category five traded probability = 0.615385
# 09:30~10:00 bid1 spread 10 category five traded expectation = 18.846152
#
# Spread 5 and Category One = 1746
# Spread 10 and Category One = 87
# Spread 5 and Category Two= 1867
# Spread 10 and Category Two = 86
# Spread 5 and Category Three = 1460
# Spread 10 and Category Three = 242
# Spread 5 and Category Four = 1868
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 2522
# Spread 10 and Category Five = 92
# 10:00~10:30 bid1 spread 5 category one traded probability = 0.694731
# 10:00~10:30 bid1 spread 5 category one traded expectation = 13.556701
# 10:00~10:30 bid1 spread 10 category one traded probability = 0.655172
# 10:00~10:30 bid1 spread 10 category one traded expectation = 20.172414
# 10:00~10:30 bid1 spread 5 category two traded probability = 0.794858
# 10:00~10:30 bid1 spread 5 category two traded expectation = 12.549545
# 10:00~10:30 bid1 spread 10 category two traded probability = 0.802326
# 10:00~10:30 bid1 spread 10 category two traded expectation = 17.558139
# 10:00~10:30 bid1 spread 5 category three traded probability = 0.752740
# 10:00~10:30 bid1 spread 5 category three traded expectation = 12.904110
# 10:00~10:30 bid1 spread 10 category three traded probability = 0.400826
# 10:00~10:30 bid1 spread 10 category three traded expectation = 21.714876
# 10:00~10:30 bid1 spread 5 category four traded probability = 0.820128
# 10:00~10:30 bid1 spread 5 category four traded expectation = 12.577623
# 10:00~10:30 bid1 spread 10 category four traded probability = 0.906475
# 10:00~10:30 bid1 spread 10 category four traded expectation = 15.935252
# 10:00~10:30 bid1 spread 5 category five traded probability = 0.947264
# 10:00~10:30 bid1 spread 5 category five traded expectation = 10.791039
# 10:00~10:30 bid1 spread 10 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded expectation = 15.000000
#
# Spread 5 and Category One = 824
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 1059
# Spread 10 and Category Two = 18
# Spread 5 and Category Three = 1665
# Spread 10 and Category Three = 362
# Spread 5 and Category Four = 1583
# Spread 10 and Category Four = 186
# Spread 5 and Category Five = 1622
# Spread 10 and Category Five = 237
# 10:30~11:00 bid1 spread 5 category one traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category one traded expectation = 10.000000
# 10:30~11:00 bid1 spread 10 category one traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 0.000000
# 10:30~11:00 bid1 spread 5 category two traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category two traded expectation = 10.000000
# 10:30~11:00 bid1 spread 10 category two traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category two traded expectation = 14.999999
# 10:30~11:00 bid1 spread 5 category three traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category three traded expectation = 10.000000
# 11:30~11:00 bid1 spread 10 category three traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category three traded expectation = 15.000000
# 10:30~11:00 bid1 spread 5 category four traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category four traded expectation = 10.000000
# 10:30~11:00 bid1 spread 10 category four traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category four traded expectation = 15.000000
# 10:30~11:00 bid1 spread 5 category five traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category five traded expectation = 10.000000
# 10:30~11:00 bid1 spread 10 category five traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category five traded expectation = 15.000000
#
# Spread 5 and Category One = 879
# Spread 10 and Category One = 19
# Spread 5 and Category Two= 864
# Spread 10 and Category Two = 233
# Spread 5 and Category Three = 1095
# Spread 10 and Category Three = 158
# Spread 5 and Category Four = 1215
# Spread 10 and Category Four = 227
# Spread 5 and Category Five = 1111
# Spread 10 and Category Five = 17
# 11:00~11:30 bid1 spread 5 category one traded probability = 0.946530
# 11:00~11:30 bid1 spread 5 category one traded expectation = 10.802048
# 11:00~11:30 bid1 spread 10 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = 14.999999
# 11:00~11:30 bid1 spread 5 category two traded probability = 0.908565
# 11:00~11:30 bid1 spread 5 category two traded expectation = 11.371528
# 11:00~11:30 bid1 spread 10 category two traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category two traded expectation = 15.000000
# 11:00~11:30 bid1 spread 5 category three traded probability = 0.861187
# 11:00~11:30 bid1 spread 5 category three traded expectation = 12.082192
# 11:00~11:30 bid1 spread 10 category three traded probability = 0.689873
# 11:00~11:30 bid1 spread 10 category three traded expectation = 19.651899
# 11:00~11:30 bid1 spread 5 category four traded probability = 0.903704
# 11:00~11:30 bid1 spread 5 category four traded expectation = 11.444444
# 11:00~11:30 bid1 spread 10 category four traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category four traded expectation = 15.000000
# 11:00~11:30 bid1 spread 5 category five traded probability = 0.974797
# 11:00~11:30 bid1 spread 5 category five traded expectation = 10.378038
# 11:00~11:30 bid1 spread 10 category five traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category five traded expectation = 14.999999
#
# Spread 5 and Category One = 3
# Spread 10 and Category One = 11
# Spread 5 and Category Two= 168
# Spread 10 and Category Two = 74
# Spread 5 and Category Three = 192
# Spread 10 and Category Three = 9
# Spread 5 and Category Four = 203
# Spread 10 and Category Four = 208
# Spread 5 and Category Five = 72
# Spread 10 and Category Five = 16
# 11:30~12:00 bid1 spread 5 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category one traded expectation = 9.999997
# 11:30~12:00 bid1 spread 10 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = 14.999999
# 11:30~12:00 bid1 spread 5 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = 10.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category two traded expectation = 15.000000
# 11:30~12:00 bid1 spread 5 category three traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category three traded expectation = 10.000000
# 11:30~12:00 bid1 spread 10 category three traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category three traded expectation = 14.999998
# 11:30~12:00 bid1 spread 5 category four traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category four traded expectation = 10.000000
# 11:30~12:00 bid1 spread 10 category four traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = 15.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category five traded expectation = 10.000000
# 11:30~12:00 bid1 spread 10 category five traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = 14.999999
#
# Spread 5 and Category One = 61
# Spread 10 and Category One = 28
# Spread 5 and Category Two= 22
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 53
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 35
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 10.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded expectation = 14.999999
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 10.000000
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 10.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category four traded expectation = 10.000000
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 123
# Spread 10 and Category One = 27
# Spread 5 and Category Two= 58
# Spread 10 and Category Two = 63
# Spread 5 and Category Three = 0
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 15
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 22
# Spread 10 and Category Five = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 10.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = 14.999999
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 10.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = 15.000000
# 12:30~13:00 bid1 spread 5 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = 9.999999
# 12:30~13:00 bid1 spread 10 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = 10.000000
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 382
# Spread 10 and Category One = 5
# Spread 5 and Category Two= 738
# Spread 10 and Category Two = 4
# Spread 5 and Category Three = 837
# Spread 10 and Category Three = 70
# Spread 5 and Category Four = 916
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 826
# Spread 10 and Category Five = 16
# 13:00~13:30 bid1 spread 5 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category one traded expectation = 10.000000
# 13:00~13:30 bid1 spread 10 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = 14.999997
# 13:00~13:30 bid1 spread 5 category two traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category two traded expectation = 10.000000
# 13:00~13:30 bid1 spread 10 category two traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category two traded expectation = 14.999996
# 13:00~13:30 bid1 spread 5 category three traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category three traded expectation = 10.000000
# 13:00~13:30 bid1 spread 10 category three traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category three traded expectation = 15.000000
# 13:00~13:30 bid1 spread 5 category four traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category four traded expectation = 10.000000
# 13:00~13:30 bid1 spread 10 category four traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category four traded expectation = 15.000000
# 13:00~13:30 bid1 spread 5 category five traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category five traded expectation = 10.000000
# 13:00~13:30 bid1 spread 10 category five traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = 14.999999
#
# Spread 5 and Category One = 1308
# Spread 10 and Category One = 42
# Spread 5 and Category Two= 873
# Spread 10 and Category Two = 83
# Spread 5 and Category Three = 920
# Spread 10 and Category Three = 126
# Spread 5 and Category Four = 701
# Spread 10 and Category Four = 97
# Spread 5 and Category Five = 744
# Spread 10 and Category Five = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category one traded expectation = 10.000000
# 13:30~14:00 bid1 spread 10 category one traded probability = 1.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = 15.000000
# 13:30~14:00 bid1 spread 5 category two traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category two traded expectation = 10.000000
# 13:30~14:00 bid1 spread 10 category two traded probability = 1.000000
# 13:30~14:00 bid1 spread 10 category two traded expectation = 15.000000
# 13:30~14:00 bid1 spread 5 category three traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category three traded expectation = 10.000000
# 13:30~14:00 bid1 spread 10 category three traded probability = 1.000000
# 13:30~14:00 bid1 spread 10 category three traded expectation = 15.000000
# 13:30~14:00 bid1 spread 5 category four traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category four traded expectation = 10.000000
# 13:30~14:00 bid1 spread 10 category four traded probability = 1.000000
# 13:30~14:00 bid1 spread 10 category four traded expectation = 15.000000
# 13:30~14:00 bid1 spread 5 category five traded probability = 1.000000
# 13:30~14:00 bid1 spread 5 category five traded expectation = 10.000000
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 1724
# Spread 10 and Category One = 268
# Spread 5 and Category Two= 1669
# Spread 10 and Category Two = 111
# Spread 5 and Category Three = 814
# Spread 10 and Category Three = 58
# Spread 5 and Category Four = 472
# Spread 10 and Category Four = 127
# Spread 5 and Category Five = 931
# Spread 10 and Category Five = 15
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.653712
# 14:00~14:30 bid1 spread 5 category one traded expectation = 13.668793
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.944030
# 14:00~14:30 bid1 spread 10 category one traded expectation = 15.764925
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.650090
# 14:00~14:30 bid1 spread 5 category two traded expectation = 13.927501
# 14:00~14:30 bid1 spread 10 category two traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category two traded expectation = 26.261261
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.414005
# 14:00~14:30 bid1 spread 5 category three traded expectation = 17.033170
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.172414
# 14:00~14:30 bid1 spread 10 category three traded expectation = 22.068965
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.307203
# 14:00~14:30 bid1 spread 5 category four traded expectation = 19.205508
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.118110
# 14:00~14:30 bid1 spread 10 category four traded expectation = 22.086614
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.139635
# 14:00~14:30 bid1 spread 5 category five traded expectation = 21.874329
# 14:00~14:30 bid1 spread 10 category five traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category five traded expectation = 20.333332
#
# Spread 5 and Category One = 1382
# Spread 10 and Category One = 233
# Spread 5 and Category Two= 839
# Spread 10 and Category Two = 108
# Spread 5 and Category Three = 783
# Spread 10 and Category Three = 230
# Spread 5 and Category Four = 784
# Spread 10 and Category Four = 40
# Spread 5 and Category Five = 1214
# Spread 10 and Category Five = 21
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.405210
# 14:30~15:00 bid1 spread 5 category one traded expectation = 17.626628
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.025751
# 14:30~15:00 bid1 spread 10 category one traded expectation = 27.167382
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.529201
# 14:30~15:00 bid1 spread 5 category two traded expectation = 16.901073
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.935185
# 14:30~15:00 bid1 spread 10 category two traded expectation = 15.740741
# 14:30~15:00 bid1 spread 5 category three traded probability = 0.652618
# 14:30~15:00 bid1 spread 5 category three traded expectation = 15.210728
# 14:30~15:00 bid1 spread 10 category three traded probability = 0.621739
# 14:30~15:00 bid1 spread 10 category three traded expectation = 20.673913
# 14:30~15:00 bid1 spread 5 category four traded probability = 0.614796
# 14:30~15:00 bid1 spread 5 category four traded expectation = 15.778061
# 14:30~15:00 bid1 spread 10 category four traded probability = 0.075000
# 14:30~15:00 bid1 spread 10 category four traded expectation = 28.874999
# 14:30~15:00 bid1 spread 5 category five traded probability = 0.873147
# 14:30~15:00 bid1 spread 5 category five traded expectation = 11.902801
# 14:30~15:00 bid1 spread 10 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = 29.999999
#
# Spread 5 and Category One = 338
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 263
# Spread 10 and Category Two = 61
# Spread 5 and Category Three = 309
# Spread 10 and Category Three = 113
# Spread 5 and Category Four = 138
# Spread 10 and Category Four = 3
# Spread 5 and Category Five = 273
# Spread 10 and Category Five = 0
# 15:00~15:30 bid1 spread 5 category one traded probability = 0.304734
# 15:00~15:30 bid1 spread 5 category one traded expectation = 20.428994
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 0.631179
# 15:00~15:30 bid1 spread 5 category two traded expectation = 15.532319
# 15:00~15:30 bid1 spread 10 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = 30.000000
# 15:00~15:30 bid1 spread 5 category three traded probability = 0.411003
# 15:00~15:30 bid1 spread 5 category three traded expectation = 18.834951
# 15:00~15:30 bid1 spread 10 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category three traded expectation = 30.000000
# 15:00~15:30 bid1 spread 5 category four traded probability = 0.992754
# 15:00~15:30 bid1 spread 5 category four traded expectation = 10.108696
# 15:00~15:30 bid1 spread 10 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = 29.999990
# 15:00~15:30 bid1 spread 5 category five traded probability = 1.000000
# 15:00~15:30 bid1 spread 5 category five traded expectation = 10.000000
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 478
# Spread 10 and Category One = 10
# Spread 5 and Category Two= 100
# Spread 10 and Category Two = 1
# Spread 5 and Category Three = 23
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 5
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category one traded expectation = 20.805439
# 15:30~16:00 bid1 spread 10 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = 24.999998
# 15:30~16:00 bid1 spread 5 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = 25.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded expectation = 24.999975
# 15:30~16:00 bid1 spread 5 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = 24.999999
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded expectation = 24.999995
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000

# %%
ask_stat_time_spread_divid(Ask3,Bid1,max_Bid1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)
# Out:
# (-104.80000000000001, -43.39999999999992, 8.4000000000000057, 72.600000000000023)
# Spread 5 and Category One = 548
# Spread 10 and Category One = 25
# Spread 5 and Category Two= 1249
# Spread 10 and Category Two = 122
# Spread 5 and Category Three = 794
# Spread 10 and Category Three = 786
# Spread 5 and Category Four = 1050
# Spread 10 and Category Four = 203
# Spread 5 and Category Five = 649
# Spread 10 and Category Five = 0
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 15.000000
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 19.999999
# 09:00~09:30 bid1 spread 5 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category two traded expectation = 15.000000
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 20.000000
# 09:00~09:30 bid1 spread 5 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category three traded expectation = 15.000000
# 09:00~09:30 bid1 spread 10 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded expectation = 20.000000
# 09:00~09:30 bid1 spread 5 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category four traded expectation = 15.000000
# 09:00~09:30 bid1 spread 10 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded expectation = 20.000000
# 09:00~09:30 bid1 spread 5 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category five traded expectation = 15.015408
# 09:00~09:30 bid1 spread 10 category five traded probability = 0.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 2799
# Spread 10 and Category One = 44
# Spread 5 and Category Two= 2470
# Spread 10 and Category Two = 183
# Spread 5 and Category Three = 1957
# Spread 10 and Category Three = 350
# Spread 5 and Category Four = 2773
# Spread 10 and Category Four = 272
# Spread 5 and Category Five = 2988
# Spread 10 and Category Five = 13
# 09:30~10:00 bid1 spread 5 category one traded probability = 0.197928
# 09:30~10:00 bid1 spread 5 category one traded expectation = 1.473741
# 09:30~10:00 bid1 spread 10 category one traded probability = 0.159091
# 09:30~10:00 bid1 spread 10 category one traded expectation = -6.022727
# 09:30~10:00 bid1 spread 5 category two traded probability = 0.229960
# 09:30~10:00 bid1 spread 5 category two traded expectation = 4.759109
# 09:30~10:00 bid1 spread 10 category two traded probability = 0.207650
# 09:30~10:00 bid1 spread 10 category two traded expectation = 10.245902
# 09:30~10:00 bid1 spread 5 category three traded probability = 0.259581
# 09:30~10:00 bid1 spread 5 category three traded expectation = 6.269801
# 09:30~10:00 bid1 spread 10 category three traded probability = 0.077143
# 09:30~10:00 bid1 spread 10 category three traded expectation = 8.728571
# 09:30~10:00 bid1 spread 5 category four traded probability = 0.341147
# 09:30~10:00 bid1 spread 5 category four traded expectation = 8.548503
# 09:30~10:00 bid1 spread 10 category four traded probability = 0.205882
# 09:30~10:00 bid1 spread 10 category four traded expectation = 13.382353
# 09:30~10:00 bid1 spread 5 category five traded probability = 0.283133
# 09:30~10:00 bid1 spread 5 category five traded expectation = 9.667001
# 09:30~10:00 bid1 spread 10 category five traded probability = 0.615385
# 09:30~10:00 bid1 spread 10 category five traded expectation = 21.923075
#
# Spread 5 and Category One = 1746
# Spread 10 and Category One = 87
# Spread 5 and Category Two= 1867
# Spread 10 and Category Two = 86
# Spread 5 and Category Three = 1460
# Spread 10 and Category Three = 242
# Spread 5 and Category Four = 1868
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 2522
# Spread 10 and Category Five = 92
# 10:00~10:30 bid1 spread 5 category one traded probability = 0.477663
# 10:00~10:30 bid1 spread 5 category one traded expectation = 20.286369
# 10:00~10:30 bid1 spread 10 category one traded probability = 0.655172
# 10:00~10:30 bid1 spread 10 category one traded expectation = 23.448276
# 10:00~10:30 bid1 spread 5 category two traded probability = 0.500268
# 10:00~10:30 bid1 spread 5 category two traded expectation = 20.942689
# 10:00~10:30 bid1 spread 10 category two traded probability = 0.197674
# 10:00~10:30 bid1 spread 10 category two traded expectation = 30.639535
# 10:00~10:30 bid1 spread 5 category three traded probability = 0.571233
# 10:00~10:30 bid1 spread 5 category three traded expectation = 19.390411
# 10:00~10:30 bid1 spread 10 category three traded probability = 0.152893
# 10:00~10:30 bid1 spread 10 category three traded expectation = 27.438016
# 10:00~10:30 bid1 spread 5 category four traded probability = 0.774090
# 10:00~10:30 bid1 spread 5 category four traded expectation = 17.368844
# 10:00~10:30 bid1 spread 10 category four traded probability = 0.733813
# 10:00~10:30 bid1 spread 10 category four traded expectation = 23.057554
# 10:00~10:30 bid1 spread 5 category five traded probability = 0.897700
# 10:00~10:30 bid1 spread 5 category five traded expectation = 16.270817
# 10:00~10:30 bid1 spread 10 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded expectation = 20.000000
#
# Spread 5 and Category One = 824
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 1059
# Spread 10 and Category Two = 18
# Spread 5 and Category Three = 1665
# Spread 10 and Category Three = 362
# Spread 5 and Category Four = 1583
# Spread 10 and Category Four = 186
# Spread 5 and Category Five = 1622
# Spread 10 and Category Five = 237
# 10:30~11:00 bid1 spread 5 category one traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category one traded expectation = 15.000000
# 10:30~11:00 bid1 spread 10 category one traded probability = 0.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 0.000000
# 10:30~11:00 bid1 spread 5 category two traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category two traded expectation = 15.000000
# 10:30~11:00 bid1 spread 10 category two traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category two traded expectation = 19.999999
# 10:30~11:00 bid1 spread 5 category three traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category three traded expectation = 15.000000
# 11:30~11:00 bid1 spread 10 category three traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category three traded expectation = 20.000000
# 10:30~11:00 bid1 spread 5 category four traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category four traded expectation = 15.000000
# 10:30~11:00 bid1 spread 10 category four traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category four traded expectation = 20.000000
# 10:30~11:00 bid1 spread 5 category five traded probability = 1.000000
# 10:30~11:00 bid1 spread 5 category five traded expectation = 15.000000
# 10:30~11:00 bid1 spread 10 category five traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category five traded expectation = 20.000000
#
# Spread 5 and Category One = 879
# Spread 10 and Category One = 19
# Spread 5 and Category Two= 864
# Spread 10 and Category Two = 233
# Spread 5 and Category Three = 1095
# Spread 10 and Category Three = 158
# Spread 5 and Category Four = 1215
# Spread 10 and Category Four = 227
# Spread 5 and Category Five = 1111
# Spread 10 and Category Five = 17
# 11:00~11:30 bid1 spread 5 category one traded probability = 0.777019
# 11:00~11:30 bid1 spread 5 category one traded expectation = 18.077361
# 11:00~11:30 bid1 spread 10 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = 19.999999
# 11:00~11:30 bid1 spread 5 category two traded probability = 0.631944
# 11:00~11:30 bid1 spread 5 category two traded expectation = 20.063657
# 11:00~11:30 bid1 spread 10 category two traded probability = 0.978541
# 11:00~11:30 bid1 spread 10 category two traded expectation = 20.321888
# 11:00~11:30 bid1 spread 5 category three traded probability = 0.617352
# 11:00~11:30 bid1 spread 5 category three traded expectation = 20.045662
# 11:00~11:30 bid1 spread 10 category three traded probability = 0.291139
# 11:00~11:30 bid1 spread 10 category three traded expectation = 29.082278
# 11:00~11:30 bid1 spread 5 category four traded probability = 0.711934
# 11:00~11:30 bid1 spread 5 category four traded expectation = 18.839506
# 11:00~11:30 bid1 spread 10 category four traded probability = 0.665198
# 11:00~11:30 bid1 spread 10 category four traded expectation = 25.022026
# 11:00~11:30 bid1 spread 5 category five traded probability = 0.849685
# 11:00~11:30 bid1 spread 5 category five traded expectation = 17.128713
# 11:00~11:30 bid1 spread 10 category five traded probability = 0.058824
# 11:00~11:30 bid1 spread 10 category five traded expectation = 34.117645
#
# Spread 5 and Category One = 3
# Spread 10 and Category One = 11
# Spread 5 and Category Two= 168
# Spread 10 and Category Two = 74
# Spread 5 and Category Three = 192
# Spread 10 and Category Three = 9
# Spread 5 and Category Four = 203
# Spread 10 and Category Four = 208
# Spread 5 and Category Five = 72
# Spread 10 and Category Five = 16
# 11:30~12:00 bid1 spread 5 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category one traded expectation = 14.999995
# 11:30~12:00 bid1 spread 10 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = 19.999998
# 11:30~12:00 bid1 spread 5 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = 15.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category two traded expectation = 20.000000
# 11:30~12:00 bid1 spread 5 category three traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category three traded expectation = 15.000000
# 11:30~12:00 bid1 spread 10 category three traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category three traded expectation = 19.999998
# 11:30~12:00 bid1 spread 5 category four traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category four traded expectation = 15.000000
# 11:30~12:00 bid1 spread 10 category four traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = 20.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category five traded expectation = 15.000000
# 11:30~12:00 bid1 spread 10 category five traded probability = 1.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = 19.999999
#
# Spread 5 and Category One = 61
# Spread 10 and Category One = 28
# Spread 5 and Category Two= 22
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 53
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 35
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 15.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded expectation = 19.999999
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 14.999999
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 15.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category four traded expectation = 15.000000
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 123
# Spread 10 and Category One = 27
# Spread 5 and Category Two= 58
# Spread 10 and Category Two = 63
# Spread 5 and Category Three = 0
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 15
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 22
# Spread 10 and Category Five = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 15.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = 19.999999
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 15.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = 20.000000
# 12:30~13:00 bid1 spread 5 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = 14.999999
# 12:30~13:00 bid1 spread 10 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = 14.999999
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 382
# Spread 10 and Category One = 5
# Spread 5 and Category Two= 738
# Spread 10 and Category Two = 4
# Spread 5 and Category Three = 837
# Spread 10 and Category Three = 70
# Spread 5 and Category Four = 916
# Spread 10 and Category Four = 139
# Spread 5 and Category Five = 826
# Spread 10 and Category Five = 16
# 13:00~13:30 bid1 spread 5 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category one traded expectation = 15.000000
# 13:00~13:30 bid1 spread 10 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = 19.999996
# 13:00~13:30 bid1 spread 5 category two traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category two traded expectation = 15.000000
# 13:00~13:30 bid1 spread 10 category two traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category two traded expectation = 19.999995
# 13:00~13:30 bid1 spread 5 category three traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category three traded expectation = 15.000000
# 13:00~13:30 bid1 spread 10 category three traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category three traded expectation = 20.000000
# 13:00~13:30 bid1 spread 5 category four traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category four traded expectation = 15.000000
# 13:00~13:30 bid1 spread 10 category four traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category four traded expectation = 20.000000
# 13:00~13:30 bid1 spread 5 category five traded probability = 1.000000
# 13:00~13:30 bid1 spread 5 category five traded expectation = 15.000000
# 13:00~13:30 bid1 spread 10 category five traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = 19.999999
#
# Spread 5 and Category One = 1308
# Spread 10 and Category One = 42
# Spread 5 and Category Two= 873
# Spread 10 and Category Two = 83
# Spread 5 and Category Three = 920
# Spread 10 and Category Three = 126
# Spread 5 and Category Four = 701
# Spread 10 and Category Four = 97
# Spread 5 and Category Five = 744
# Spread 10 and Category Five = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 0.827217
# 13:30~14:00 bid1 spread 5 category one traded expectation = 17.591743
# 13:30~14:00 bid1 spread 10 category one traded probability = 1.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = 20.000000
# 13:30~14:00 bid1 spread 5 category two traded probability = 0.892325
# 13:30~14:00 bid1 spread 5 category two traded expectation = 16.615120
# 13:30~14:00 bid1 spread 10 category two traded probability = 0.987952
# 13:30~14:00 bid1 spread 10 category two traded expectation = 20.180723
# 13:30~14:00 bid1 spread 5 category three traded probability = 0.911957
# 13:30~14:00 bid1 spread 5 category three traded expectation = 16.320652
# 13:30~14:00 bid1 spread 10 category three traded probability = 0.809524
# 13:30~14:00 bid1 spread 10 category three traded expectation = 22.857143
# 13:30~14:00 bid1 spread 5 category four traded probability = 0.937233
# 13:30~14:00 bid1 spread 5 category four traded expectation = 15.941512
# 13:30~14:00 bid1 spread 10 category four traded probability = 0.845361
# 13:30~14:00 bid1 spread 10 category four traded expectation = 22.319587
# 13:30~14:00 bid1 spread 5 category five traded probability = 0.974462
# 13:30~14:00 bid1 spread 5 category five traded expectation = 15.383064
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 1724
# Spread 10 and Category One = 268
# Spread 5 and Category Two= 1669
# Spread 10 and Category Two = 111
# Spread 5 and Category Three = 814
# Spread 10 and Category Three = 58
# Spread 5 and Category Four = 472
# Spread 10 and Category Four = 127
# Spread 5 and Category Five = 931
# Spread 10 and Category Five = 15
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.262181
# 14:00~14:30 bid1 spread 5 category one traded expectation = 22.810325
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.029851
# 14:00~14:30 bid1 spread 10 category one traded expectation = 34.197761
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.591971
# 14:00~14:30 bid1 spread 5 category two traded expectation = 18.049730
# 14:00~14:30 bid1 spread 10 category two traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category two traded expectation = 26.261261
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.363636
# 14:00~14:30 bid1 spread 5 category three traded expectation = 19.858722
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category three traded expectation = 25.517241
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.245763
# 14:00~14:30 bid1 spread 5 category four traded expectation = 21.663136
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category four traded expectation = 24.448819
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.123523
# 14:00~14:30 bid1 spread 5 category five traded expectation = 22.814178
# 14:00~14:30 bid1 spread 10 category five traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category five traded expectation = 20.333332
#
# Spread 5 and Category One = 1382
# Spread 10 and Category One = 233
# Spread 5 and Category Two= 839
# Spread 10 and Category Two = 108
# Spread 5 and Category Three = 783
# Spread 10 and Category Three = 230
# Spread 5 and Category Four = 784
# Spread 10 and Category Four = 40
# Spread 5 and Category Five = 1214
# Spread 10 and Category Five = 21
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.200434
# 14:30~15:00 bid1 spread 5 category one traded expectation = 22.724313
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category one traded expectation = 27.682403
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.199046
# 14:30~15:00 bid1 spread 5 category two traded expectation = 24.499404
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.703704
# 14:30~15:00 bid1 spread 10 category two traded expectation = 23.888889
# 14:30~15:00 bid1 spread 5 category three traded probability = 0.278416
# 14:30~15:00 bid1 spread 5 category three traded expectation = 24.086845
# 14:30~15:00 bid1 spread 10 category three traded probability = 0.447826
# 14:30~15:00 bid1 spread 10 category three traded expectation = 26.391304
# 14:30~15:00 bid1 spread 5 category four traded probability = 0.253827
# 14:30~15:00 bid1 spread 5 category four traded expectation = 24.266582
# 14:30~15:00 bid1 spread 10 category four traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category four traded expectation = 30.374999
# 14:30~15:00 bid1 spread 5 category five traded probability = 0.450577
# 14:30~15:00 bid1 spread 5 category five traded expectation = 22.607084
# 14:30~15:00 bid1 spread 10 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = 29.999999
#
# Spread 5 and Category One = 338
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 263
# Spread 10 and Category Two = 61
# Spread 5 and Category Three = 309
# Spread 10 and Category Three = 113
# Spread 5 and Category Four = 138
# Spread 10 and Category Four = 3
# Spread 5 and Category Five = 273
# Spread 10 and Category Five = 0
# 15:00~15:30 bid1 spread 5 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category one traded expectation = 26.523669
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded expectation = 28.155893
# 15:00~15:30 bid1 spread 10 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = 30.000000
# 15:00~15:30 bid1 spread 5 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category three traded expectation = 27.055016
# 15:00~15:30 bid1 spread 10 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category three traded expectation = 30.000000
# 15:00~15:30 bid1 spread 5 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded expectation = 29.963768
# 15:00~15:30 bid1 spread 10 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = 29.999990
# 15:00~15:30 bid1 spread 5 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded expectation = 30.000000
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 0.000000
#
# Spread 5 and Category One = 478
# Spread 10 and Category One = 10
# Spread 5 and Category Two= 100
# Spread 10 and Category Two = 1
# Spread 5 and Category Three = 23
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 5
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category one traded expectation = 20.805439
# 15:30~16:00 bid1 spread 10 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = 24.999998
# 15:30~16:00 bid1 spread 5 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = 25.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded expectation = 24.999975
# 15:30~16:00 bid1 spread 5 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = 24.999999
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded expectation = 24.999995
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000
