# %%
# %pylab inline
import numpy as np
import pandas as pd
import dateutil.parser

data = []
datapath = '/home/bigdatas16/SGX-OrderBook-Tick-Data-Trading-Strategy-/CN_Futures_2014.01.28.csv'
data = pd.read_csv(datapath)
data_CNF14 = data[data.Series == 'CNF14']
data = data_CNF14
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
market_open_time = data[data['TimeStamp'].str.contains('2014-01-28D09:00')].index.tolist()[0] 
market_close_time = data[data['TimeStamp'].str.contains('2014-01-28D16:00')].index.tolist()[0] 
data_open = data[market_open_time:market_close_time+1]
data_open.loc[data_open.BidOrAsk == 'A',['Trade']] = ' '
data_open['Price'][data_open.Trade == ' '] = 1000000
data_open = data_open.loc[data_open.groupby('TimeStamp')["Price"].idxmin()]
data_trade = data_open[['TimeStamp','Price','Trade']]
# Out:
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
len(data_trade)
# Out:
# 67017

# %%
data1 = []
datapath = '/home/bigdatas16/SGX-OrderBook-Tick-Data-Trading-Strategy-/stat_order_book_/CNF14_01_28_order_book_final.csv'
data1 = pd.read_csv(datapath,sep='\t',encoding = 'utf-8')
data_book_28 = data1[['0','1','2','3']]

# %%
len(data_book_28)
# Out:
# 277373

# %%
277373/3
# Out:
# 92457

# %%
len(data.TimeStamp.unique())
# Out:
# 69350

# %%
data.TimeStamp.unique()[213]#.head(246)
# Out:
# '2014-01-28D08:59:58.780335000'

# %%
data.TimeStamp.unique()[67229]
# Out:
# '2014-01-28D15:59:55.969361700'

# %%
data_TimeUnique = pd.DataFrame({'TimeStamp':data[market_open_time:market_close_time][['TimeStamp']].TimeStamp.unique()})
#data[data['TimeStamp'].str.contains('2014-01-28D09:29')].index.tolist()[0]

# %%
len(data_TimeUnique)#TimeStamp
# Out:
# 67016

# %%
data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D09:30')].index.tolist()[0]-1
# Out:
# 5426

# %%
data_trade[5426:5428]
# Out:
#                            TimeStamp    Price Trade
# 10734  2014-01-28D09:29:59.919771000  1000000
# 10735  2014-01-28D09:30:00.024771000  1000000

# %%
data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D10:00')].index.tolist()[0]-1
# Out:
# 19275

# %%
data_trade[19275:19277]
# Out:
#                            TimeStamp    Price Trade
# 36710  2014-01-28D09:59:59.852206200  1000000
# 36711  2014-01-28D10:00:00.169206200  1000000

# %%
data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D10:30')].index.tolist()[0]-1
# Out:
# 29384

# %%
data_trade[29384:29386]
# Out:
#                            TimeStamp    Price Trade
# 55691  2014-01-28D10:29:59.812653800  1000000
# 55692  2014-01-28D10:30:00.171653800  1000000

# %%
data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D11:00')].index.tolist()[0]-1
# Out:
# 36940

# %%
data_trade[36940:36942]
# Out:
#                            TimeStamp    Price Trade
# 69061  2014-01-28D10:59:59.790856400  1000000
# 69062  2014-01-28D11:00:00.095843400  1000000

# %%
data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D11:30')].index.tolist()[0]-1
# Out:
# 42758

# %%
data_trade[42758:42758+2]
# Out:
#                            TimeStamp    Price Trade
# 79404  2014-01-28D11:29:59.435523700  1000000
# 79406  2014-01-28D11:30:00.007511700  1000000

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D11:30')].index.tolist()[0]-1
data_trade[index:index+2]
# Out:
#                            TimeStamp    Price Trade
# 79404  2014-01-28D11:29:59.435523700  1000000
# 79406  2014-01-28D11:30:00.007511700  1000000

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D12:00')].index.tolist()[0]-1
data_trade[index:index+2]
# Out:
#                            TimeStamp    Price Trade
# 81034  2014-01-28D11:59:49.895079300  1000000
# 81035  2014-01-28D12:00:00.505947300  1000000

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D12:30')].index.tolist()[0]-1
data_trade[index:index+2]
# Out:
#                            TimeStamp    Price Trade
# 81388  2014-01-28D12:29:59.066892900  1000000
# 81392  2014-01-28D12:30:35.947418100  1000000

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D12:30')].index.tolist()[0]-1
data_trade[index:index+2]

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D13:00')].index.tolist()[0]-1
data_trade[index:index+2]
# Out:
#                            TimeStamp    Price Trade
# 82034  2014-01-28D12:59:59.813531100  1000000
# 82036  2014-01-28D13:00:00.398531100  1000000

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D13:30')].index.tolist()[0]-1
data_trade[index:index+2]
# Out:
#                            TimeStamp    Price Trade
# 89728  2014-01-28D13:29:59.785182700  1000000
# 89729  2014-01-28D13:30:01.163158600  1000000

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D14:00')].index.tolist()[0]-1
data_trade[index:index+2]
# Out:
#                            TimeStamp    Price Trade
# 99018  2014-01-28D13:59:59.368834300  1000000
# 99019  2014-01-28D14:00:00.962808300  1000000

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D14:30')].index.tolist()[0]-1
data_trade[index:index+2]
# Out:
#                             TimeStamp    Price Trade
# 111474  2014-01-28D14:29:59.889028900  1000000
# 111476  2014-01-28D14:30:00.344028900  1000000

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D15:00')].index.tolist()[0]-1
data_trade[index:index+2]
# Out:
#                             TimeStamp    Price Trade
# 121886  2014-01-28D14:59:59.755171500  1000000
# 121888  2014-01-28D15:00:01.502145500  1000000

# %%
index = data_TimeUnique[data_TimeUnique['TimeStamp'].str.contains('2014-01-28D15:30')].index.tolist()[0]-1
data_trade[index:index+2]
# Out:
#                             TimeStamp    Price Trade
# 124397  2014-01-28D15:29:59.056878100  1000000
# 124399  2014-01-28D15:30:00.135866100  1000000

# %%
data_book_28_open = data_book_28[213*4-3:67229*4+1]

# %%
data_book_28_open = data_book_28_open.reset_index(drop = True)

# %%
((67229*4+2)-(213*4-3))/4 ,len(data_trade),len(data_open.TimeStamp.unique())
# Out:
# (67017, 67017, 67017)

# %%
data_trade[5427:]
# Out:
#                             TimeStamp    Price Trade
# 10735   2014-01-28D09:30:00.024771000  1000000
# 10737   2014-01-28D09:30:00.027771000  1000000
# 10738   2014-01-28D09:30:00.061771000  1000000
# 10739   2014-01-28D09:30:00.076771000   673000     T
# 10744   2014-01-28D09:30:00.078771000  1000000
# 10745   2014-01-28D09:30:00.079771000  1000000
# 10746   2014-01-28D09:30:00.082771000  1000000
# 10749   2014-01-28D09:30:00.084771000  1000000
# 10751   2014-01-28D09:30:00.086771000  1000000
# 10752   2014-01-28D09:30:00.087771000  1000000
# 10754   2014-01-28D09:30:00.088771000  1000000
# 10756   2014-01-28D09:30:00.089771000  1000000
# 10758   2014-01-28D09:30:00.090771000  1000000
# 10760   2014-01-28D09:30:00.091771000  1000000
# 10761   2014-01-28D09:30:00.093771000  1000000
# 10762   2014-01-28D09:30:00.094771000  1000000
# 10765   2014-01-28D09:30:00.096771000  1000000
# 10767   2014-01-28D09:30:00.198765200  1000000
# 10769   2014-01-28D09:30:00.249760100  1000000
# ...

# %%
len(data_trade[(data_trade.Trade == 'T')])
# Out:
# 1200

# %%
data_book_28_open['0'][]
# Out:
# 1    668500
# 2    668000
# Name: 0, dtype: object

# %%
float(data_book_28_open.iloc[1]['0'])/100.0
# Out:
# 6685.0

# %%
#data_book_28_open#['0'][3]

# %%
len(data_book_28_open)
# Out:
# 268068

# %%
import time 
start = time.time()
Bid1 = []
Bid2 = []
Bid3 = []
Bid1_Quantity = []
Bid2_Quantity = []
Bid3_Quantity = []
Ask1 = []
Ask2 = []
Ask3 = []
Ask1_Quantity = []
Ask2_Quantity = []
Ask3_Quantity = []

TimeStamp = []
for i in range(1,len(data_book_28_open),4):
    #print data_book_28_open.iloc[i]['0']
    #print data_book_28_open.iloc[i]['2']
    Bid1.append(float(data_book_28_open.iloc[i]['0'])/100.0)
    Bid1_Quantity.append(float(data_book_28_open.iloc[i]['1']))
    
    Bid2.append(float(data_book_28_open.iloc[i + 1]['0'])/100.0)
    Bid2_Quantity.append(float(data_book_28_open.iloc[i + 1]['1']))  
    
    Bid3.append(float(data_book_28_open.iloc[i + 2]['0'])/100.0)
    Bid3_Quantity.append(float(data_book_28_open.iloc[i + 2]['1']))  
    
    Ask1.append(float(data_book_28_open.iloc[i]['2'])/100.0) 
    Ask1_Quantity.append(float(data_book_28_open.iloc[i]['3']))
    
    Ask2.append(float(data_book_28_open.iloc[i + 1]['2'])/100.0) 
    Ask2_Quantity.append(float(data_book_28_open.iloc[i + 1]['3']))    
    
    Ask3.append(float(data_book_28_open.iloc[i + 2]['2'])/100.0) 
    Ask3_Quantity.append(float(data_book_28_open.iloc[i + 2]['3']))    
    TimeStamp.append(data_book_28_open.iloc[i-1][1])
    
    
end = time.time()  
print "Total time = %f"%(end - start)
# Out:
# Total time = 125.322113

# %%
len(Bid1),len(Bid2),len(Bid3),len(Bid1_Quantity),len(Bid2_Quantity),len(Bid3_Quantity),len(Ask1_Quantity),len(Ask2_Quantity),len(Ask3_Quantity)
# Out:
# (67017, 67017, 67017, 67017, 67017, 67017, 67017, 67017, 67017)

# %%
len(data_trade)
# Out:
# 67017

# %%
bid1_ask1_spread = array(Ask1) - array(Bid1)

# %%
bid1_ask1_spread
# Out:
# array([ 0.,  5.,  5., ...,  0.,  0.,  0.])

# %%
#data_book_28_open['3']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (17,9))
plt.grid()
plot(Ask1[0:67016],label = 'Ask1')
plot(Ask2[0:67016],label = 'Ask2')
plot(Ask3[0:67016],label = 'Ask3')

plot(Bid1[0:67016],label = 'Bid1')
plot(Bid2[0:67016],label = 'Bid2')
plot(Bid3[0:67016],label = 'Bid3')

plt.legend(loc = 4)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (17,5))
plt.grid()
plot(bid1_ask1_spread[0:67016])
plt.ylim(4,11)
# Out:
# (4, 11)

# %%
min(bid1_ask1_spread[1000:10000]),max(bid1_ask1_spread[1000:10000])
# Out:
# (5.0, 10.0)

# %%
hist(bid1_ask1_spread)
# Out:
# (array([  3.00000000e+01,   0.00000000e+00,   0.00000000e+00,
#           6.04680000e+04,   0.00000000e+00,   0.00000000e+00,
#           6.51800000e+03,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00]),
#  array([  0. ,   1.5,   3. ,   4.5,   6. ,   7.5,   9. ,  10.5,  12. ,
#          13.5,  15. ]),
#  <a list of 10 Patch objects>)

# %%
data_trade = data_trade.reset_index(drop = True)
#data_trade

# %%
data_trade = data_trade.reset_index(drop = True)
data_trade_time_series_0900_0930 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D09:30')].index.tolist()[0]
data_trade_time_series_0930_1000 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D10:00')].index.tolist()[0]
data_trade_time_series_1000_1030 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D10:30')].index.tolist()[0]
data_trade_time_series_1030_1100 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D11:00')].index.tolist()[0]
data_trade_time_series_1100_1130 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D11:30')].index.tolist()[0]
data_trade_time_series_1130_1200 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D12:00')].index.tolist()[0]
data_trade_time_series_1200_1230 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D12:30')].index.tolist()[0]

data_trade_time_series_1230_1300 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D13:00')].index.tolist()[0]
data_trade_time_series_1300_1330 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D13:30')].index.tolist()[0]
data_trade_time_series_1330_1400 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D14:00')].index.tolist()[0]
data_trade_time_series_1400_1430 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D14:30')].index.tolist()[0]
data_trade_time_series_1430_1500 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D15:00')].index.tolist()[0]
data_trade_time_series_1500_1530 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D15:30')].index.tolist()[0]
data_trade_time_series_1530_1600 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D16:00')].index.tolist()[0]

# %%
data_trade_time_series_0900_0930,data_trade_time_series_0930_1000,data_trade_time_series_1000_1030,data_trade_time_series_1030_1100,data_trade_time_series_1100_1130,data_trade_time_series_1130_1200,data_trade_time_series_1200_1230
# Out:
# (5427, 19276, 29385, 36941, 42759, 43716, 43915)

# %%
data_trade_time_series_1300_1330,data_trade_time_series_1330_1400,data_trade_time_series_1400_1430,data_trade_time_series_1430_1500,data_trade_time_series_1500_1530,data_trade_time_series_1530_1600
# Out:
# (48156, 53050, 59239, 64873, 66371, 67016)

# %%
data_trade[:data_trade_time_series_0900_0930]
data_trade[data_trade_time_series_0900_0930:data_trade_time_series_0930_1000]
data_trade[data_trade_time_series_0930_1000:data_trade_time_series_1000_1030]
data_trade[data_trade_time_series_1000_1030:data_trade_time_series_1030_1100]
data_trade[data_trade_time_series_1030_1100:data_trade_time_series_1100_1130]
data_trade[data_trade_time_series_1100_1130:data_trade_time_series_1130_1200]
data_trade[data_trade_time_series_1130_1200:data_trade_time_series_1200_1230]
data_trade[data_trade_time_series_1200_1230:data_trade_time_series_1230_1300]
data_trade[data_trade_time_series_1230_1300:data_trade_time_series_1300_1330]
data_trade[data_trade_time_series_1300_1330:data_trade_time_series_1330_1400]
data_trade[data_trade_time_series_1330_1400:data_trade_time_series_1400_1430]
data_trade[data_trade_time_series_1400_1430:data_trade_time_series_1430_1500]
data_trade[data_trade_time_series_1430_1500:data_trade_time_series_1500_1530]
data_trade[data_trade_time_series_1500_1530:data_trade_time_series_1530_1600]
# Out:
#                            TimeStamp    Price Trade
# 66371  2014-01-28D15:30:00.135866100  1000000
# 66372  2014-01-28D15:30:20.730615200  1000000
# 66373  2014-01-28D15:30:20.740614200  1000000
# 66374  2014-01-28D15:30:21.588614100  1000000
# 66375  2014-01-28D15:30:40.652386100  1000000
# 66376  2014-01-28D15:30:41.913362100  1000000
# 66377  2014-01-28D15:30:51.893242100  1000000
# 66378  2014-01-28D15:31:13.842978500  1000000
# 66379  2014-01-28D15:31:15.099966100  1000000
# 66380  2014-01-28D15:31:18.872918100  1000000
# 66381  2014-01-28D15:31:36.602714100   672500     T
# 66382  2014-01-28D15:31:37.698702100  1000000
# 66383  2014-01-28D15:31:40.274666100  1000000
# 66384  2014-01-28D15:31:40.275666100  1000000
# 66385  2014-01-28D15:31:40.314666100  1000000
# 66386  2014-01-28D15:31:40.424666100  1000000
# 66387  2014-01-28D15:31:40.429666100  1000000
# 66388  2014-01-28D15:31:40.465666100  1000000
# 66389  2014-01-28D15:31:40.628666100  1000000
# ...

# %%
data_trade[data_trade['TimeStamp'].str.contains('2014-01-28D10:00')]#.index.tolist()[0]
# Out:
#                            TimeStamp    Price Trade
# 19276  2014-01-28D10:00:00.169206200  1000000
# 19277  2014-01-28D10:00:00.196206200  1000000
# 19278  2014-01-28D10:00:00.199206200  1000000
# 19279  2014-01-28D10:00:00.690206200  1000000
# 19280  2014-01-28D10:00:00.918194200  1000000
# 19281  2014-01-28D10:00:01.106194200  1000000
# 19282  2014-01-28D10:00:01.232194200  1000000
# 19283  2014-01-28D10:00:01.239194200  1000000
# 19284  2014-01-28D10:00:01.270194200  1000000
# 19285  2014-01-28D10:00:01.359194200  1000000
# 19286  2014-01-28D10:00:01.370194200  1000000
# 19287  2014-01-28D10:00:01.371194200  1000000
# 19288  2014-01-28D10:00:01.390194200  1000000
# 19289  2014-01-28D10:00:01.410194200  1000000
# 19290  2014-01-28D10:00:01.472194200  1000000
# 19291  2014-01-28D10:00:01.486194200  1000000
# 19292  2014-01-28D10:00:01.526194200  1000000
# 19293  2014-01-28D10:00:01.565194200  1000000
# 19294  2014-01-28D10:00:01.566194200  1000000
# ...

# %%
data_trade[:19276]
# Out:
#                            TimeStamp    Price Trade
# 0      2014-01-28D09:00:00.053323000   668500     T
# 1      2014-01-28D09:00:00.054323000   668500     T
# 2      2014-01-28D09:00:00.122323000  1000000
# 3      2014-01-28D09:00:00.123323000  1000000
# 4      2014-01-28D09:00:00.124323000  1000000
# 5      2014-01-28D09:00:00.126323000  1000000
# 6      2014-01-28D09:00:00.128323000  1000000
# 7      2014-01-28D09:00:00.129323000  1000000
# 8      2014-01-28D09:00:00.131323000  1000000
# 9      2014-01-28D09:00:00.132323000  1000000
# 10     2014-01-28D09:00:00.136323000  1000000
# 11     2014-01-28D09:00:00.264323000  1000000
# 12     2014-01-28D09:00:00.692311000  1000000
# 13     2014-01-28D09:00:01.781299000  1000000
# 14     2014-01-28D09:00:01.959299000  1000000
# 15     2014-01-28D09:00:01.970299000  1000000
# 16     2014-01-28D09:00:02.455299000  1000000
# 17     2014-01-28D09:00:02.464299000  1000000
# 18     2014-01-28D09:00:02.580293900  1000000
# ...

# %%
data_trade_time_series = data_trade[['Price']]

# %%
len(data_trade_time_series),len(Bid1),len(Bid2),len(Bid3),len(Ask1),len(Ask2),len(Ask3)
# Out:
# (67017, 67017, 67017, 67017, 67017, 67017, 67017)

# %%
min_data_trade_time_series_index = data_trade_time_series[(data_trade_time_series.Price == 668500)].index.tolist()[len(data_trade_time_series[(data_trade_time_series.Price == 668500)]) - 1]

# %%
min_data_trade_time_series_index
# Out:
# 31491

# %%
data_trade_time_series.Price.unique()
# Out:
# array([ 668500, 1000000,  669500,  670000,  670500,  671500,  672500,
#         672000,  673000,  673500,  674500,  675500,  675000,  676000,
#         676500,  677000,  674000,  671000,  669000])

# %%
data_trade_time_series_array = array(data_trade_time_series)

# %%
Bid1
# Out:
# [6685.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6680.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
# ...

# %%
Bid1[1] < min(Ask1[2:])
# Out:
# True

# %%
min_Ask1_time_series = []
min_Ask1_time_series.append(0)
for i in range(1,67017,1):
    min_Ask1_time_series.append(min(Ask1[i:]))

# %%
min_Bid_Trade_time_series = []
min_Bid_Trade_time_series.append(0)
for i in range(1,67017,1):
    min_Bid_Trade_time_series.append(min(data_trade_time_series_array[i:]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-59a2a94ae435> in <module>()
#       2 min_Bid_Trade_time_series.append(0)
#       3 for i in range(1,67017,1):
# ----> 4     min_Bid_Trade_time_series.append(min(data_trade_time_series_array[i:]))
#
# KeyboardInterrupt:

# %%
len(min_Bid_Trade_time_series)
# Out:
# 18414

# %%
min(data_trade_time_series_array/100.0) == 6685.0
# Out:
# array([ True], dtype=bool)

# %%
data_trade_time_series_0900_0930,data_trade_time_series_0930_1000,data_trade_time_series_1000_1030
# Out:
# (5427, 19276, 29385)

# %%
data_trade_time_series_1030_1100,data_trade_time_series_1100_1130,data_trade_time_series_1130_1200
# Out:
# (36941, 42759, 43716)

# %%
min(min_Ask1_time_series[50000:])
# Out:
# 6705.0

# %%
min_Ask1_time_series[40000+1]
# Out:
# 6695.0

# %%
#2014-01-28 close price = 6750
import time 
start = time.time()
Bid1_traded = 0
Bid1_traded_expected = 0
Close_Price = 6750
for i in range(0,data_trade_time_series_1530_1600,1):#data_trade_time_series_1300_1330 ,1):
    #print i
    #print Bid1[i]
    #print min_Ask1_time_series[i+1]
    if Bid1[i] > min_Ask1_time_series[i+1]: #or Bid1[i] < min_Bid_Trade_time_series[(i+1):]:
        #print 'trade = %d'%(i)
        #print Bid1_traded
        Bid1_traded = Bid1_traded + 1
        Bid1_traded_expected = Bid1_traded_expected + (Ask1[i] - Bid1[i])
    else:
        Bid1_traded_expected = Bid1_traded_expected + (Ask1[i] - Close_Price)
        #print Bid1_traded_expected
        
    if i == data_trade_time_series_0900_0930 - 1:    
        print '09:00~09:30 bid1 traded probability = %f'%(Bid1_traded*(1.0)/data_trade_time_series_0900_0930)
        print '09:00~09:30 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/data_trade_time_series_0900_0930*(1.0))
        Bid1_traded = 0
        Bid1_traded_expected = 0
        print '\t'        
        continue
    elif i == data_trade_time_series_0930_1000 - 1:    
        print '09:30~10:00 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_0930_1000 - data_trade_time_series_0900_0930)*(1.0))
        print '09:30~10:00 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_0930_1000 - data_trade_time_series_0900_0930)*(1.0))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'        
        continue
    elif i == data_trade_time_series_1000_1030 - 1:
        print '10:00~10:30 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1000_1030 - data_trade_time_series_0930_1000))
        print '10:00~10:30 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1000_1030 - data_trade_time_series_0930_1000))
        Bid1_traded = 0
        Bid1_traded_expected = 0  
        print '\t'
        continue
    elif i == data_trade_time_series_1030_1100 - 1:
        print '10:30~11:00 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1030_1100 - data_trade_time_series_1000_1030))
        print '10:30~11:00 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1030_1100 - data_trade_time_series_1000_1030))
        Bid1_traded = 0
        Bid1_traded_expected = 0  
        print '\t'
        continue
    elif i == data_trade_time_series_1100_1130 - 1:
        print '11:00~11:30 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1100_1130 - data_trade_time_series_1030_1100))
        print '11:00~11:30 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1100_1130 - data_trade_time_series_1030_1100))
        Bid1_traded = 0
        Bid1_traded_expected = 0   
        print '\t'
        continue
    elif i == data_trade_time_series_1130_1200 - 1:
        print '11:30~12:00 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1130_1200 - data_trade_time_series_1100_1130))
        print '11:30~12:00 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1130_1200 - data_trade_time_series_1100_1130))
        Bid1_traded = 0
        Bid1_traded_expected = 0  
        print '\t'
        continue
    elif i == data_trade_time_series_1200_1230 - 1:
        print '12:00~12:30 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1200_1230 - data_trade_time_series_1130_1200))
        print '12:00~12:30 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1200_1230 - data_trade_time_series_1130_1200))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'
        continue
    elif i == data_trade_time_series_1230_1300 - 1:
        print '12:30~13:00 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1230_1300 - data_trade_time_series_1200_1230))
        print '12:30~13:00 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1230_1300 - data_trade_time_series_1200_1230))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'
        continue
    elif i == data_trade_time_series_1300_1330 - 1:
        print '13:00~13:30 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1300_1330 - data_trade_time_series_1230_1300))
        print '13:00~13:30 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1300_1330 - data_trade_time_series_1230_1300))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'
        continue
    elif i == data_trade_time_series_1330_1400 - 1:
        print '13:30_14:00 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1330_1400 - data_trade_time_series_1300_1330))
        print '13:30_14:00 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1330_1400 - data_trade_time_series_1300_1330))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'
        continue        
    elif i == data_trade_time_series_1400_1430 - 1:
        print '14:00_14:30 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        print '14:00_14:30 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'
        continue        
    elif i == data_trade_time_series_1400_1430 - 1:
        print '14:00_14:30 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        print '14:00_14:30 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'
        continue         
    elif i == data_trade_time_series_1430_1500 - 1:
        print '14:30_15:00 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1430_1500 - data_trade_time_series_1400_1430))
        print '14:30_15:00 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1430_1500 - data_trade_time_series_1400_1430))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'
        continue 
    elif i == data_trade_time_series_1500_1530 - 1:
        print '15:00_15:30 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1500_1530 - data_trade_time_series_1430_1500))
        print '15:00_15:30 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1500_1530 - data_trade_time_series_1430_1500))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'
        continue 
    elif i == data_trade_time_series_1530_1600 - 1:
        print '15:30_16:00 bid1 traded probability = %f'%(Bid1_traded*(1.0)/(data_trade_time_series_1530_1600 - data_trade_time_series_1500_1530))
        print '15:30_16:00 bid1 traded expectation = %f'%(Bid1_traded_expected*(1.0)/(data_trade_time_series_1530_1600 - data_trade_time_series_1500_1530))
        Bid1_traded = 0
        Bid1_traded_expected = 0 
        print '\t'
        continue
        
end = time.time()
print "Total time = %f"%(end - start)
# Out:
# 09:00~09:30 bid1 traded probability = 0.975309
# 09:00~09:30 bid1 traded expectation = 4.377188
#
# 09:30~10:00 bid1 traded probability = 1.000000
# 09:30~10:00 bid1 traded expectation = 5.311214
#
# 10:00~10:30 bid1 traded probability = 0.993669
# 10:00~10:30 bid1 traded expectation = 4.908003
#
# 10:30~11:00 bid1 traded probability = 0.502647
# 10:30~11:00 bid1 traded expectation = -25.767602
#
# 11:00~11:30 bid1 traded probability = 0.996906
# 11:00~11:30 bid1 traded expectation = 5.391887
#
# 11:30~12:00 bid1 traded probability = 0.753396
# 11:30~12:00 bid1 traded expectation = -6.891327
#
# 12:00~12:30 bid1 traded probability = 1.000000
# 12:00~12:30 bid1 traded expectation = 5.703518
#
# 12:30~13:00 bid1 traded probability = 1.000000
# 12:30~13:00 bid1 traded expectation = 6.461039
#
# 13:00~13:30 bid1 traded probability = 0.366641
# 13:00~13:30 bid1 traded expectation = -26.414950
#
# 13:30_14:00 bid1 traded probability = 0.252963
# ...

# %%
Bid1_traded/data_trade_time_series_0900_0930
# Out:
# 1

# %%
Bid1_traded_expected/data_trade_time_series_0900_0930
# Out:
# 6.045697438732264

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (17,9))
plt.grid()
plot(Ask1[0:67017],label = 'Ask1')
#plot(Ask2[0:data_trade_time_series_0900_0930],label = 'Ask2')
#plot(Ask3[0:data_trade_time_series_0900_0930],label = 'Ask3')
plot(min_Ask1_time_series[0:data_trade_time_series_1530_1600],label = 'min Ask1')
plot(Bid1[0:data_trade_time_series_1530_1600],label = 'Bid1')
#plot(Bid2[0:data_trade_time_series_0900_0930],label = 'Bid2')
#plot(Bid3[0:data_trade_time_series_0900_0930],label = 'Bid3')
plt.ylim(6670,6780)
plt.legend(loc = 4)

# %%
min_Ask1_time_series
# Out:
# [0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
#  6685.0,
# ...

# %%
plot(bid1_ask1_spread),len(bid1_ask1_spread)
# Out:
# ([<matplotlib.lines.Line2D at 0x7ffe5d8b6c10>], 67017)

# %%
#2014-01-28 close price = 6750
import time 
start = time.time()
Bid2_traded = 0
Bid2_traded_expected = 0
Close_Price = 6750
for i in range(0,data_trade_time_series_1530_1600,1):#data_trade_time_series_1300_1330 ,1):
    #print i
    #print Bid1[i]
    #print min_Ask1_time_series[i+1]
    if Bid2[i] > min_Ask1_time_series[i+1]: #or Bid1[i] < min_Bid_Trade_time_series[(i+1):]:
        #print 'trade = %d'%(i)
        #print Bid1_traded
        Bid2_traded = Bid2_traded + 1
        Bid2_traded_expected = Bid2_traded_expected + (Ask1[i] - Bid2[i])
    else:
        Bid2_traded_expected = Bid2_traded_expected + (Ask1[i] - Close_Price)
        #print Bid1_traded_expected
        
    if i == data_trade_time_series_0900_0930 - 1:    
        print '09:00~09:30 bid2 traded probability = %f'%(Bid2_traded*(1.0)/data_trade_time_series_0900_0930)
        print '09:00~09:30 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/data_trade_time_series_0900_0930*(1.0))
        Bid2_traded = 0
        Bid2_traded_expected = 0
        print '\t'        
        continue
    elif i == data_trade_time_series_0930_1000 - 1:    
        print '09:30~10:00 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_0930_1000 - data_trade_time_series_0900_0930)*(1.0))
        print '09:30~10:00 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_0930_1000 - data_trade_time_series_0900_0930)*(1.0))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'        
        continue
    elif i == data_trade_time_series_1000_1030 - 1:
        print '10:00~10:30 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1000_1030 - data_trade_time_series_0930_1000))
        print '10:00~10:30 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1000_1030 - data_trade_time_series_0930_1000))
        Bid2_traded = 0
        Bid2_traded_expected = 0  
        print '\t'
        continue
    elif i == data_trade_time_series_1030_1100 - 1:
        print '10:30~11:00 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1030_1100 - data_trade_time_series_1000_1030))
        print '10:30~11:00 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1030_1100 - data_trade_time_series_1000_1030))
        Bid2_traded = 0
        Bid2_traded_expected = 0  
        print '\t'
        continue
    elif i == data_trade_time_series_1100_1130 - 1:
        print '11:00~11:30 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1100_1130 - data_trade_time_series_1030_1100))
        print '11:00~11:30 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1100_1130 - data_trade_time_series_1030_1100))
        Bid1_traded = 0
        Bid1_traded_expected = 0   
        print '\t'
        continue
    elif i == data_trade_time_series_1130_1200 - 1:
        print '11:30~12:00 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1130_1200 - data_trade_time_series_1100_1130))
        print '11:30~12:00 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1130_1200 - data_trade_time_series_1100_1130))
        Bid2_traded = 0
        Bid2_traded_expected = 0  
        print '\t'
        continue
    elif i == data_trade_time_series_1200_1230 - 1:
        print '12:00~12:30 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1200_1230 - data_trade_time_series_1130_1200))
        print '12:00~12:30 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1200_1230 - data_trade_time_series_1130_1200))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'
        continue
    elif i == data_trade_time_series_1230_1300 - 1:
        print '12:30~13:00 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1230_1300 - data_trade_time_series_1200_1230))
        print '12:30~13:00 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1230_1300 - data_trade_time_series_1200_1230))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'
        continue
    elif i == data_trade_time_series_1300_1330 - 1:
        print '13:00~13:30 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1300_1330 - data_trade_time_series_1230_1300))
        print '13:00~13:30 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1300_1330 - data_trade_time_series_1230_1300))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'
        continue
    elif i == data_trade_time_series_1330_1400 - 1:
        print '13:30_14:00 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1330_1400 - data_trade_time_series_1300_1330))
        print '13:30_14:00 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1330_1400 - data_trade_time_series_1300_1330))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'
        continue        
    elif i == data_trade_time_series_1400_1430 - 1:
        print '14:00_14:30 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        print '14:00_14:30 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'
        continue        
    elif i == data_trade_time_series_1400_1430 - 1:
        print '14:00_14:30 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        print '14:00_14:30 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'
        continue         
    elif i == data_trade_time_series_1430_1500 - 1:
        print '14:30_15:00 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1430_1500 - data_trade_time_series_1400_1430))
        print '14:30_15:00 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1430_1500 - data_trade_time_series_1400_1430))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'
        continue 
    elif i == data_trade_time_series_1500_1530 - 1:
        print '15:00_15:30 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1500_1530 - data_trade_time_series_1430_1500))
        print '15:00_15:30 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1500_1530 - data_trade_time_series_1430_1500))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'
        continue 
    elif i == data_trade_time_series_1530_1600 - 1:
        print '15:30_16:00 bid2 traded probability = %f'%(Bid2_traded*(1.0)/(data_trade_time_series_1530_1600 - data_trade_time_series_1500_1530))
        print '15:30_16:00 bid2 traded expectation = %f'%(Bid2_traded_expected*(1.0)/(data_trade_time_series_1530_1600 - data_trade_time_series_1500_1530))
        Bid2_traded = 0
        Bid2_traded_expected = 0 
        print '\t'
        continue
        
end = time.time()
print "Total time = %f"%(end - start)
# Out:
# 09:00~09:30 bid2 traded probability = 0.950802
# 09:00~09:30 bid2 traded expectation = 7.660770
#
# 09:30~10:00 bid2 traded probability = 1.000000
# 09:30~10:00 bid2 traded expectation = 10.311214
#
# 10:00~10:30 bid2 traded probability = 0.987140
# 10:00~10:30 bid2 traded expectation = 9.451973
#
# 10:30~11:00 bid2 traded probability = 0.355214
# 10:30~11:00 bid2 traded expectation = -32.130757
#
# 11:00~11:30 bid2 traded probability = 0.903403
# 11:00~11:30 bid2 traded expectation = 5.233757
#
# 11:30~12:00 bid2 traded probability = 5.716823
# 11:30~12:00 bid2 traded expectation = -0.386625
#
# 12:00~12:30 bid2 traded probability = 1.000000
# 12:00~12:30 bid2 traded expectation = 10.703518
#
# 12:30~13:00 bid2 traded probability = 1.000000
# 12:30~13:00 bid2 traded expectation = 11.461039
#
# 13:00~13:30 bid2 traded probability = 0.311721
# 13:00~13:30 bid2 traded expectation = -27.439614
#
# 13:30_14:00 bid2 traded probability = 0.002043
# ...

# %%
#2014-01-28 close price = 6750
import time 
start = time.time()
Bid3_traded = 0
Bid3_traded_expected = 0
Close_Price = 6750
for i in range(0,data_trade_time_series_1530_1600,1):#data_trade_time_series_1300_1330 ,1):
    #print i
    #print Bid1[i]
    #print min_Ask1_time_series[i+1]
    if Bid3[i] > min_Ask1_time_series[i+1]: #or Bid1[i] < min_Bid_Trade_time_series[(i+1):]:
        #print 'trade = %d'%(i)
        #print Bid1_traded
        Bid3_traded = Bid3_traded + 1
        Bid3_traded_expected = Bid3_traded_expected + (Ask1[i] - Bid3[i])
    else:
        Bid3_traded_expected = Bid3_traded_expected + (Ask1[i] - Close_Price)
        #print Bid1_traded_expected
        
    if i == data_trade_time_series_0900_0930 - 1:    
        print '09:00~09:30 bid3 traded probability = %f'%(Bid3_traded*(1.0)/data_trade_time_series_0900_0930)
        print '09:00~09:30 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/data_trade_time_series_0900_0930*(1.0))
        Bid3_traded = 0
        Bid3_traded_expected = 0
        print '\t'        
        continue
    elif i == data_trade_time_series_0930_1000 - 1:    
        print '09:30~10:00 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_0930_1000 - data_trade_time_series_0900_0930)*(1.0))
        print '09:30~10:00 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_0930_1000 - data_trade_time_series_0900_0930)*(1.0))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'        
        continue
    elif i == data_trade_time_series_1000_1030 - 1:
        print '10:00~10:30 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1000_1030 - data_trade_time_series_0930_1000))
        print '10:00~10:30 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1000_1030 - data_trade_time_series_0930_1000))
        Bid3_traded = 0
        Bid3_traded_expected = 0  
        print '\t'
        continue
    elif i == data_trade_time_series_1030_1100 - 1:
        print '10:30~11:00 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1030_1100 - data_trade_time_series_1000_1030))
        print '10:30~11:00 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1030_1100 - data_trade_time_series_1000_1030))
        Bid3_traded = 0
        Bid3_traded_expected = 0  
        print '\t'
        continue
    elif i == data_trade_time_series_1100_1130 - 1:
        print '11:00~11:30 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1100_1130 - data_trade_time_series_1030_1100))
        print '11:00~11:30 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1100_1130 - data_trade_time_series_1030_1100))
        Bid3_traded = 0
        Bid3_traded_expected = 0   
        print '\t'
        continue
    elif i == data_trade_time_series_1130_1200 - 1:
        print '11:30~12:00 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1130_1200 - data_trade_time_series_1100_1130))
        print '11:30~12:00 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1130_1200 - data_trade_time_series_1100_1130))
        Bid3_traded = 0
        Bid3_traded_expected = 0  
        print '\t'
        continue
    elif i == data_trade_time_series_1200_1230 - 1:
        print '12:00~12:30 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1200_1230 - data_trade_time_series_1130_1200))
        print '12:00~12:30 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1200_1230 - data_trade_time_series_1130_1200))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'
        continue
    elif i == data_trade_time_series_1230_1300 - 1:
        print '12:30~13:00 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1230_1300 - data_trade_time_series_1200_1230))
        print '12:30~13:00 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1230_1300 - data_trade_time_series_1200_1230))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'
        continue
    elif i == data_trade_time_series_1300_1330 - 1:
        print '13:00~13:30 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1300_1330 - data_trade_time_series_1230_1300))
        print '13:00~13:30 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1300_1330 - data_trade_time_series_1230_1300))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'
        continue
    elif i == data_trade_time_series_1330_1400 - 1:
        print '13:30_14:00 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1330_1400 - data_trade_time_series_1300_1330))
        print '13:30_14:00 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1330_1400 - data_trade_time_series_1300_1330))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'
        continue        
    elif i == data_trade_time_series_1400_1430 - 1:
        print '14:00_14:30 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        print '14:00_14:30 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'
        continue        
    elif i == data_trade_time_series_1400_1430 - 1:
        print '14:00_14:30 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        print '14:00_14:30 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1400_1430 - data_trade_time_series_1330_1400))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'
        continue         
    elif i == data_trade_time_series_1430_1500 - 1:
        print '14:30_15:00 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1430_1500 - data_trade_time_series_1400_1430))
        print '14:30_15:00 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1430_1500 - data_trade_time_series_1400_1430))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'
        continue 
    elif i == data_trade_time_series_1500_1530 - 1:
        print '15:00_15:30 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1500_1530 - data_trade_time_series_1430_1500))
        print '15:00_15:30 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1500_1530 - data_trade_time_series_1430_1500))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'
        continue 
    elif i == data_trade_time_series_1530_1600 - 1:
        print '15:30_16:00 bid3 traded probability = %f'%(Bid3_traded*(1.0)/(data_trade_time_series_1530_1600 - data_trade_time_series_1500_1530))
        print '15:30_16:00 bid3 traded expectation = %f'%(Bid3_traded_expected*(1.0)/(data_trade_time_series_1530_1600 - data_trade_time_series_1500_1530))
        Bid3_traded = 0
        Bid3_traded_expected = 0 
        print '\t'
        continue
        
end = time.time()
print "Total time = %f"%(end - start)
# Out:
# 09:00~09:30 bid3 traded probability = 0.924083
# 09:00~09:30 bid3 traded expectation = 10.678091
#
# 09:30~10:00 bid3 traded probability = 1.000000
# 09:30~10:00 bid3 traded expectation = 15.311214
#
# 10:00~10:30 bid3 traded probability = 0.944802
# 10:00~10:30 bid3 traded expectation = 11.635671
#
# 10:30~11:00 bid3 traded probability = 0.220090
# 10:30~11:00 bid3 traded expectation = -37.786527
#
# 11:00~11:30 bid3 traded probability = 0.707803
# 11:00~11:30 bid3 traded expectation = -1.007219
#
# 11:30~12:00 bid3 traded probability = 0.003135
# 11:30~12:00 bid3 traded expectation = -43.265413
#
# 12:00~12:30 bid3 traded probability = 0.804020
# 12:00~12:30 bid3 traded expectation = 4.924623
#
# 12:30~13:00 bid3 traded probability = 0.587662
# 12:30~13:00 bid3 traded expectation = -6.217532
#
# 13:00~13:30 bid3 traded probability = 0.127892
# 13:00~13:30 bid3 traded expectation = -35.991609
#
# 13:30_14:00 bid3 traded probability = 0.000000
# ...
