# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data1 = []
datapath = '/home/bigdatas16/SGX-OrderBook-Tick-Data-Trading-Strategy-/stat_order_book/CNF14_01_02_order_book_final.csv'
data1 = pd.read_csv(datapath,sep='\t',encoding = 'utf-8')
data_book_02 = data1[['0','1','2','3']]

# %%
data_book_02
# Out:
#                 0                   1         2      3
# 0       TimeStamp  04:19:51.857166800       NaN    NaN
# 1          700500                   2  715500.0    2.0
# 2          699000                   2  717500.0    1.0
# 3          697500                   1  719500.0    1.0
# 4       TimeStamp  08:45:00.130582600       NaN    NaN
# 5          700500                   2       0.0  210.0
# 6          699000                   2  715500.0    2.0
# 7          697500                   1  717500.0    1.0
# 8       TimeStamp  08:45:00.131582600       NaN    NaN
# 9        682000.0               111.0  682000.0  210.0
# 10            NaN                 NaN  715500.0    2.0
# 11            NaN                 NaN  717500.0    1.0
# 12      TimeStamp  08:45:00.296582600       NaN    NaN
# 13         708000                 210  708000.0  210.0
# 14         700500                   2  715500.0    2.0
# 15         699000                   2  717500.0    1.0
# 16      TimeStamp  08:45:00.398582300       NaN    NaN
# 17         708000                 210  708000.0  210.0
# 18         700500                   2  715500.0    2.0
# 19         699000                   2  717500.0    1.0
# 20      TimeStamp  08:45:13.857414600       NaN    NaN
# 21         708000                 210  708000.0  210.0
# 22         700500                   2  715500.0    2.0
# 23         699000                   2  717500.0    1.0
# 24      TimeStamp  08:45:14.337414600       NaN    NaN
# 25         708000                 210  708000.0  210.0
# 26         700500                   2  715500.0    2.0
# 27         699000                   2  717500.0    1.0
# 28      TimeStamp  08:45:14.977402600       NaN    NaN
# 29         708000                 210  708000.0  210.0
# ...           ...                 ...       ...    ...
# 234806     703000                  27  704500.0   18.0
# 234807     702500                 125  705000.0  167.0
# 234808  TimeStamp  15:58:21.926767700       NaN    NaN
# 234809     704000                  12  704000.0  155.0
# 234810     703000                  27  704500.0   18.0
# 234811     702500                 125  705000.0  167.0
# 234812  TimeStamp  15:59:19.574026400       NaN    NaN
# 234813     704000                  12  704000.0  155.0
# 234814     703000                  27  704500.0   18.0
# 234815     702500                 125  705000.0  167.0
# 234816  TimeStamp  15:59:26.977922700       NaN    NaN
# 234817     704000                  12  704000.0  155.0
# 234818     703000                  27  704500.0   18.0
# 234819     702500                 125  705000.0  167.0
# 234820  TimeStamp  15:59:43.337714700       NaN    NaN
# 234821     704000                  12  704000.0  155.0
# 234822     703500                 150  704500.0   18.0
# 234823     703000                  27  705000.0  167.0
# 234824  TimeStamp  15:59:54.093571700       NaN    NaN
# 234825     704000                  12  704000.0  155.0
# 234826     703500                 150  704500.0   18.0
# 234827     703000                  27  705000.0  167.0
# 234828  TimeStamp  15:59:55.429558700       NaN    NaN
# 234829     704000                 132  704000.0  155.0
# 234830     703500                 150  704500.0   18.0
# 234831     703000                  27  705000.0  167.0
# 234832  TimeStamp  16:00:00.024493700       NaN    NaN
# 234833     703500                 150  704000.0   23.0
# 234834     703000                  27  704500.0   18.0
# 234835     702500                 125  705000.0  167.0
#
# [234836 rows x 4 columns]

# %%
data_book_02_open = data_book_02[292*4:67229*4+1]
data_book_02_open = data_book_02_open.reset_index(drop = True)

# %%
data_book_02_open
# Out:
#                 0                   1         2      3
# 0       TimeStamp  08:59:59.945064600       NaN    NaN
# 1          710500                 212  710500.0  212.0
# 2          710000                   2  711000.0  107.0
# 3          709500                  21  711500.0    6.0
# 4       TimeStamp  09:00:00.049064600       NaN    NaN
# 5          710000                   2  711000.0  107.0
# 6          709500                  21  711500.0    6.0
# 7          709000                   6  712000.0   10.0
# 8       TimeStamp  09:00:00.103064600       NaN    NaN
# 9          710000                   2  711000.0  117.0
# 10         709500                  21  711500.0    6.0
# 11         709000                  16  712000.0   10.0
# 12      TimeStamp  09:00:00.104064600       NaN    NaN
# 13         710000                   2  711000.0  117.0
# 14         709500                  21  711500.0   26.0
# 15         709000                  16  712000.0   10.0
# 16      TimeStamp  09:00:00.105064600       NaN    NaN
# 17         710000                   2  711000.0  117.0
# 18         709500                  21  711500.0   26.0
# 19         709000                  16  712000.0   10.0
# 20      TimeStamp  09:00:00.111064600       NaN    NaN
# 21         710000                   2  711000.0  117.0
# 22         709500                  21  711500.0   26.0
# 23         709000                  16  712000.0   10.0
# 24      TimeStamp  09:00:00.128064600       NaN    NaN
# 25         710000                   2  711000.0  117.0
# 26         709500                  21  711500.0   26.0
# 27         709000                  16  712000.0   10.0
# 28      TimeStamp  09:00:00.170064600       NaN    NaN
# 29         710000                   2  711000.0  117.0
# ...           ...                 ...       ...    ...
# 233638     703000                  27  704500.0   18.0
# 233639     702500                 125  705000.0  167.0
# 233640  TimeStamp  15:58:21.926767700       NaN    NaN
# 233641     704000                  12  704000.0  155.0
# 233642     703000                  27  704500.0   18.0
# 233643     702500                 125  705000.0  167.0
# 233644  TimeStamp  15:59:19.574026400       NaN    NaN
# 233645     704000                  12  704000.0  155.0
# 233646     703000                  27  704500.0   18.0
# 233647     702500                 125  705000.0  167.0
# 233648  TimeStamp  15:59:26.977922700       NaN    NaN
# 233649     704000                  12  704000.0  155.0
# 233650     703000                  27  704500.0   18.0
# 233651     702500                 125  705000.0  167.0
# 233652  TimeStamp  15:59:43.337714700       NaN    NaN
# 233653     704000                  12  704000.0  155.0
# 233654     703500                 150  704500.0   18.0
# 233655     703000                  27  705000.0  167.0
# 233656  TimeStamp  15:59:54.093571700       NaN    NaN
# 233657     704000                  12  704000.0  155.0
# 233658     703500                 150  704500.0   18.0
# 233659     703000                  27  705000.0  167.0
# 233660  TimeStamp  15:59:55.429558700       NaN    NaN
# 233661     704000                 132  704000.0  155.0
# 233662     703500                 150  704500.0   18.0
# 233663     703000                  27  705000.0  167.0
# 233664  TimeStamp  16:00:00.024493700       NaN    NaN
# 233665     703500                 150  704000.0   23.0
# 233666     703000                  27  704500.0   18.0
# 233667     702500                 125  705000.0  167.0
#
# [233668 rows x 4 columns]

# %%
data = []
datapath = '/home/bigdatas16/SGX-OrderBook-Tick-Data-Trading-Strategy-/CN_Futures_2014.01.02.csv'
data = pd.read_csv(datapath)
data_CNF14 = data[data.Series == 'CNF14']
data = data_CNF14
market_open_time = data[data['TimeStamp'].str.contains('2014-01-02D09:00')].index.tolist()[0] 
market_close_time = data[data['TimeStamp'].str.contains('2014-01-02D16:00')].index.tolist()[0] 
data_open = data[market_open_time:market_close_time+1]
data_open.loc[data_open.BidOrAsk == 'A',['Trade']] = ' '
data_open['Price'][data_open.Trade == ' '] = 0
data_open = data_open.loc[data_open.groupby('TimeStamp')["Price"].idxmin()]
data_trade = data_open[['TimeStamp','Price','Trade']].reset_index(drop = True)
# Out:
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/pandas/core/generic.py:4428: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2885: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
def BidQ123_AskQ123(data_book_28_open):
    Bid1 = []
    Bid2 = []
    Bid3 = []
    Bid1_Quantity = []
    Bid2_Quantity = []
    Bid3_Quantity = []
    Ask1 = []
    Ask2 = []
    Ask3 = []
    Ask1_Quantity = []
    Ask2_Quantity = []
    Ask3_Quantity = []

    TimeStamp = []
    for i in range(1,len(data_book_28_open),4):
        #print data_book_28_open.iloc[i]['0']
        #print data_book_28_open.iloc[i]['2']
        Bid1.append(float(data_book_28_open.iloc[i]['0'])/100.0)
        Bid1_Quantity.append(float(data_book_28_open.iloc[i]['1']))

        Bid2.append(float(data_book_28_open.iloc[i + 1]['0'])/100.0)
        Bid2_Quantity.append(float(data_book_28_open.iloc[i + 1]['1']))  

        Bid3.append(float(data_book_28_open.iloc[i + 2]['0'])/100.0)
        Bid3_Quantity.append(float(data_book_28_open.iloc[i + 2]['1']))  

        Ask1.append(float(data_book_28_open.iloc[i]['2'])/100.0) 
        Ask1_Quantity.append(float(data_book_28_open.iloc[i]['3']))

        Ask2.append(float(data_book_28_open.iloc[i + 1]['2'])/100.0) 
        Ask2_Quantity.append(float(data_book_28_open.iloc[i + 1]['3']))    

        Ask3.append(float(data_book_28_open.iloc[i + 2]['2'])/100.0) 
        Ask3_Quantity.append(float(data_book_28_open.iloc[i + 2]['3']))    
        TimeStamp.append(data_book_28_open.iloc[i-1][1])
    return Bid1,Bid2,Bid3,Ask1,Ask2,Ask3,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity
# Out:
# Total time = 0.000708

# %%
import time 
start = time.time()
Bid1,Bid2,Bid3,Ask1,Ask2,Ask3,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity = BidQ123_AskQ123(data_book_02_open)
end = time.time()  
print "Total time = %f"%(end - start)
# Out:
# Total time = 94.698805

# %%
def data_time_split(data_trade,day):
    data_trade = data_trade.reset_index(drop = True)
    #print data_trade
    #print '2014-01-'+day+'D09:30'
    data_trade_time_series_0900_0930 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D09:30')].index.tolist()[0]
    data_trade_time_series_0930_1000 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D10:00')].index.tolist()[0]
    data_trade_time_series_1000_1030 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D10:30')].index.tolist()[0]
    data_trade_time_series_1030_1100 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D11:00')].index.tolist()[0]
    data_trade_time_series_1100_1130 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D11:30')].index.tolist()[0]
    data_trade_time_series_1130_1200 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D12:00')].index.tolist()[0]
    data_trade_time_series_1200_1230 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D12:30')].index.tolist()[0]
    data_trade_time_series_1230_1300 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D13:00')].index.tolist()[0]
    data_trade_time_series_1300_1330 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D13:30')].index.tolist()[0]
    data_trade_time_series_1330_1400 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D14:00')].index.tolist()[0]
    data_trade_time_series_1400_1430 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D14:30')].index.tolist()[0]
    data_trade_time_series_1430_1500 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D15:00')].index.tolist()[0]
    data_trade_time_series_1500_1530 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D15:30')].index.tolist()[0]
    data_trade_time_series_1530_1600 = data_trade[data_trade['TimeStamp'].str.contains('2014-01-'+day+'D16:00')].index.tolist()[0]
    return data_trade_time_series_0900_0930,data_trade_time_series_0930_1000,data_trade_time_series_1000_1030,data_trade_time_series_1030_1100,\
           data_trade_time_series_1100_1130,data_trade_time_series_1130_1200,data_trade_time_series_1200_1230,data_trade_time_series_1230_1300,\
           data_trade_time_series_1300_1330,data_trade_time_series_1330_1400,data_trade_time_series_1400_1430,data_trade_time_series_1430_1500,\
           data_trade_time_series_1500_1530,data_trade_time_series_1530_1600

# %%
day = '02'
data_trade_time_series_0900_0930,data_trade_time_series_0930_1000,data_trade_time_series_1000_1030,data_trade_time_series_1030_1100,\
data_trade_time_series_1100_1130,data_trade_time_series_1130_1200,data_trade_time_series_1200_1230,data_trade_time_series_1230_1300,\
data_trade_time_series_1300_1330,data_trade_time_series_1330_1400,data_trade_time_series_1400_1430,data_trade_time_series_1430_1500,\
data_trade_time_series_1500_1530,data_trade_time_series_1530_1600 = data_time_split(data_trade,day)

# %%
import time 
start = time.time()
min_Ask1_time_series = []
min_Ask1_time_series.append(0)
for i in range(1,len(Ask1),1):
    min_Ask1_time_series.append(min(Ask1[i:]))
    
max_Bid1_time_series = []
max_Bid1_time_series.append(0)
for i in range(1,len(Bid1),1):
    max_Bid1_time_series.append(max(Bid1[i:]))
end = time.time()  
print "Total time = %f"%(end - start)
# Out:
# Total time = 240.622551

# %%
data_trade_timestamp = data_trade.TimeStamp
bid1_ask1_spread = array(Ask1) - array(Bid1)
Close_Price = 7030

# %%
len(data_trade_timestamp)
# Out:
# 58416

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (17,9))
plt.grid()
plot(Ask1[0:data_trade_time_series_1530_1600],label = 'Ask1')
#plot(Ask2[0:data_trade_time_series_1530_1600],label = 'Ask2')
#plot(Ask3[0:data_trade_time_series_1530_1600],label = 'Ask3')
plot(min_Ask1_time_series[0:data_trade_time_series_1530_1600],label = 'min Ask1')
plot(max_Bid1_time_series[0:data_trade_time_series_1530_1600],label = 'max Bid1')

plot(Bid1[0:data_trade_time_series_1530_1600],label = 'Bid1')
#plot(Bid2[0:data_trade_time_series_1530_1600],label = 'Bid2')
#plot(Bid3[0:data_trade_time_series_1530_1600],label = 'Bid3')
plt.ylim(6980,7140)
plt.legend(loc = 4)

# %%
weight1 = 0.50
weight2 = 0.30
weight3 = 0.20
def divid_weighted_five_category(Bid1_Quantity,Bid2_Quantity,Bid3_Quantity,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity,weight1,weight2,weight3):
    weighted_Bid = array(Bid1_Quantity) * weight1 + array(Bid2_Quantity) * weight2 + array(Bid3_Quantity) * weight3
    weighted_Ask = array(Ask1_Quantity) * weight1 + array(Ask2_Quantity) * weight2 + array(Ask3_Quantity) * weight3
    divid_weighted3 = weighted_Bid / weighted_Ask
    return np.percentile(divid_weighted3,20),np.percentile(divid_weighted3,40),np.percentile(divid_weighted3,60),np.percentile(divid_weighted3,80)

# %%
#2014-01-02 close price = 7030
#0.6177
#0.8696
#1.0678
#1.3835
def bid_stat_time_spread_divid(Bid1,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price):
    
    Bid1_traded_spr5_category_one = 0
    Bid1_traded_expected_spr5_category_one = 0
    Bid1_traded_spr10_category_one = 0
    Bid1_traded_expected_spr10_category_one = 0
    N_spr5_category_one = 0
    N_spr10_category_one = 0
    MDD_traded_spr5_category_one = 0
    MDD_traded_spr10_category_one = 0
    traded_time_spr5_category_one = 0
    traded_time_spr10_category_one = 0
    
    Bid1_traded_spr5_category_two = 0
    Bid1_traded_expected_spr5_category_two = 0
    Bid1_traded_spr10_category_two = 0
    Bid1_traded_expected_spr10_category_two = 0
    N_spr5_category_two = 0
    N_spr10_category_two = 0
    MDD_traded_spr5_category_two = 0
    MDD_traded_spr10_category_two = 0
    traded_time_spr5_category_two = 0
    traded_time_spr10_category_two = 0
    
    Bid1_traded_spr5_category_three = 0
    Bid1_traded_expected_spr5_category_three = 0
    Bid1_traded_spr10_category_three = 0
    Bid1_traded_expected_spr10_category_three = 0
    N_spr5_category_three = 0
    N_spr10_category_three = 0
    MDD_traded_spr5_category_three = 0
    MDD_traded_spr10_category_three = 0
    traded_time_spr5_category_three = 0
    traded_time_spr10_category_three = 0
    
    Bid1_traded_spr5_category_four = 0
    Bid1_traded_expected_spr5_category_four = 0
    Bid1_traded_spr10_category_four = 0
    Bid1_traded_expected_spr10_category_four = 0
    N_spr5_category_four = 0
    N_spr10_category_four = 0
    MDD_traded_spr5_category_four = 0
    MDD_traded_spr10_category_four = 0
    traded_time_spr5_category_four = 0
    traded_time_spr10_category_four = 0
    
    Bid1_traded_spr5_category_five = 0
    Bid1_traded_expected_spr5_category_five = 0
    Bid1_traded_spr10_category_five = 0
    Bid1_traded_expected_spr10_category_five = 0
    N_spr5_category_five = 0
    N_spr10_category_five = 0
    MDD_traded_spr5_category_five = 0
    MDD_traded_spr10_category_five = 0    
    traded_time_spr5_category_five = 0
    traded_time_spr10_category_five = 0    
    
    ###one week
    divid_weighted_five_categories = divid_weighted_five_category(Bid1_Quantity,Bid2_Quantity,Bid3_Quantity,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity,weight1,weight2,weight3)

    print divid_weighted_five_categories

    for i in range(0,data_trade_time_series_1530_1600,1):
        #print i
        #print Bid1[i]
        #print min_Ask1_time_series[i+1]
        weighted_Bid = Bid1_Quantity[i] * weight1 + Bid2_Quantity[i] * weight2 + Bid3_Quantity[i] * weight3
        weighted_Ask = Ask1_Quantity[i] * weight1 + Ask2_Quantity[i] * weight2 + Ask3_Quantity[i] * weight3  
        #print weighted_Bid
        #print weighted_Ask
        #print (weighted_Bid*(1.0) / weighted_Ask)
        #print '\t'
        if (weighted_Bid*(1.0) / weighted_Ask) <= divid_weighted_five_categories[0]:  
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_one = N_spr5_category_one + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_one = Bid1_traded_spr5_category_one + 1
                    Bid1_traded_expected_spr5_category_one = Bid1_traded_expected_spr5_category_one + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_one = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_one 
                    #print MDD_traded_spr5_category_one
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_one = traded_time_spr5_category_one + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_one
                    
                else:
                    Bid1_traded_expected_spr5_category_one = Bid1_traded_expected_spr5_category_one + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_one = N_spr10_category_one + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr10_category_one = Bid1_traded_spr10_category_one + 1
                    Bid1_traded_expected_spr10_category_one = Bid1_traded_expected_spr10_category_one + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_one = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_one
                    #print MDD_traded_spr10_category_one
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_one = traded_time_spr10_category_one + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_one
                else:
                    Bid1_traded_expected_spr10_category_one = Bid1_traded_expected_spr10_category_one + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
            else:
                pass

        elif divid_weighted_five_categories[0] < (weighted_Bid*(1.0) / weighted_Ask) <= divid_weighted_five_categories[1]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_two = N_spr5_category_two + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_two = Bid1_traded_spr5_category_two + 1
                    Bid1_traded_expected_spr5_category_two = Bid1_traded_expected_spr5_category_two + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_two = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_two 
                    #print MDD_traded_spr5_category_two              
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_two = traded_time_spr5_category_two + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_two
                    
                else:
                    Bid1_traded_expected_spr5_category_two = Bid1_traded_expected_spr5_category_two + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_two = N_spr10_category_two + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr10_category_two = Bid1_traded_spr10_category_two + 1
                    Bid1_traded_expected_spr10_category_two = Bid1_traded_expected_spr10_category_two + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_two = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_two 
                    #print MDD_traded_spr10_category_two                 
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_two = traded_time_spr10_category_two + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_two
                else:
                    Bid1_traded_expected_spr10_category_two = Bid1_traded_expected_spr10_category_two + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
            else:
                pass    

        elif divid_weighted_five_categories[1] < (weighted_Bid*(1.0) / weighted_Ask) <= divid_weighted_five_categories[2]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_three = N_spr5_category_three + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_three = Bid1_traded_spr5_category_three + 1
                    Bid1_traded_expected_spr5_category_three = Bid1_traded_expected_spr5_category_three + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_three = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_three 
                    #print MDD_traded_spr5_category_three    
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_three = traded_time_spr5_category_three + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_three
                    
                else:
                    Bid1_traded_expected_spr5_category_three = Bid1_traded_expected_spr5_category_three + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_three = N_spr10_category_three + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_three = Bid1_traded_spr10_category_three + 1
                    Bid1_traded_expected_spr10_category_three = Bid1_traded_expected_spr10_category_three + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_three = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_three 
                    #print MDD_traded_spr10_category_three               
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_three = traded_time_spr10_category_three + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_three
                else:
                    Bid1_traded_expected_spr10_category_three = Bid1_traded_expected_spr10_category_three + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_three)
            else:
                pass    

        elif divid_weighted_five_categories[2] < (weighted_Bid*(1.0) / weighted_Ask) <= divid_weighted_five_categories[3]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_four = N_spr5_category_four + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_four = Bid1_traded_spr5_category_four + 1
                    Bid1_traded_expected_spr5_category_four = Bid1_traded_expected_spr5_category_four + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_four = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_four 
                    #print MDD_traded_spr5_category_four
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_four = traded_time_spr5_category_four + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_four
                else:
                    Bid1_traded_expected_spr5_category_four = Bid1_traded_expected_spr5_category_four + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_four = N_spr10_category_four + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_four = Bid1_traded_spr10_category_four + 1
                    Bid1_traded_expected_spr10_category_four = Bid1_traded_expected_spr10_category_four + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_four = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_four 
                    #print MDD_traded_spr10_category_four 
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_four = traded_time_spr10_category_four + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_four
                else:
                    Bid1_traded_expected_spr10_category_four = Bid1_traded_expected_spr10_category_four + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_four)
            else:
                pass    

        elif divid_weighted_five_categories[3] < (weighted_Bid*(1.0) / weighted_Ask): 
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_five = N_spr5_category_five + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_five = Bid1_traded_spr5_category_five + 1
                    Bid1_traded_expected_spr5_category_five = Bid1_traded_expected_spr5_category_five + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_five = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_five 
                    #print MDD_traded_spr5_category_five
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_five = traded_time_spr5_category_five + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_five
                else:
                    Bid1_traded_expected_spr5_category_five = Bid1_traded_expected_spr5_category_five + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_five = N_spr10_category_five + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_five = Bid1_traded_spr10_category_five + 1
                    Bid1_traded_expected_spr10_category_five = Bid1_traded_expected_spr10_category_five + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    #print 'a1 = %f'%(Bid1_traded_expected_spr10_category_four)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_five = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_five 
                    #print MDD_traded_spr10_category_five 
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_five = traded_time_spr10_category_five + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_five
                else:
                    Bid1_traded_expected_spr10_category_five = Bid1_traded_expected_spr10_category_five + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_four)
            else:
                pass    


        #print Bid1_traded_expected_spr10_category_three

        if i == data_trade_time_series_0900_0930 - 1:  

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '09:00~09:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:00~09:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '09:00~09:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '09:00~09:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/N_spr5_category_two)
            print '09:00~09:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/N_spr5_category_two)
            print '09:00~09:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/N_spr10_category_two)
            print '09:00~09:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/N_spr10_category_two)
            print '09:00~09:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '09:00~09:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '09:00~09:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '09:00~09:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '09:00~09:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/N_spr5_category_three)
            print '09:00~09:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/N_spr5_category_three)
            print '09:00~09:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/N_spr10_category_three)
            print '09:00~09:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/N_spr10_category_three)
            print '09:00~09:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '09:00~09:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '09:00~09:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '09:00~09:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
           
            print '09:00~09:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/N_spr5_category_four)
            print '09:00~09:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/N_spr5_category_four)
            print '09:00~09:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/N_spr10_category_four)
            print '09:00~09:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/N_spr10_category_four)
            print '09:00~09:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '09:00~09:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '09:00~09:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '09:00~09:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '09:00~09:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/N_spr5_category_five)
            print '09:00~09:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/N_spr5_category_five)
            print '09:00~09:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/N_spr10_category_five)
            print '09:00~09:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/N_spr10_category_five)
            print '09:00~09:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '09:00~09:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '09:00~09:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '09:00~09:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
           
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0           
            print '\t'        
            continue

        elif i == data_trade_time_series_0930_1000 - 1:   

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '09:30~10:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:30~10:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '09:30~10:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '09:30~10:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '09:30~10:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '09:30~10:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '09:30~10:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '09:30~10:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '09:30~10:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
          
            print '09:30~10:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '09:30~10:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '09:30~10:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '09:30~10:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '09:30~10:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '09:30~10:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
           
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0        

            print '\t'        
            continue
        elif i == data_trade_time_series_1000_1030 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '10:00~10:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:00~10:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '10:00~10:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '10:00~10:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:00~10:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '10:00~10:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '10:00~10:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:00~10:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '10:00~10:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
                      
            print '10:00~10:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:00~10:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '10:00~10:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '10:00~10:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:00~10:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '10:00~10:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
           
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0        
            print '\t'
            continue
        elif i == data_trade_time_series_1030_1100 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '10:30~11:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:30~11:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '10:30~11:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '10:30~11:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:30~11:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '10:30~11:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '10:30~11:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:30~11:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~11:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:30~11:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:30~11:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '10:30~11:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '10:30~11:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '10:30~11:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
               
            print '10:30~11:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:30~11:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '10:30~11:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '10:30~11:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:30~11:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '10:30~11:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
           
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0  
            print '\t'
            continue

        elif i == data_trade_time_series_1100_1130 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '11:00~11:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:00~11:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '11:00~11:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '11:00~11:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:00~11:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '11:00~11:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '11:00~11:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:00~11:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '11:00~11:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
               
            print '11:00~11:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:00~11:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '11:00~11:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '11:00~11:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:00~11:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '11:00~11:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
           
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0          

            print '\t'
            continue

        elif i == data_trade_time_series_1130_1200 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '11:30~12:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:30~12:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '11:30~12:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '11:30~12:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:30~12:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '11:30~12:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '11:30~12:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:30~12:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '11:30~12:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
          
            print '11:30~12:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:30~12:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '11:30~12:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '11:30~12:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:30~12:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '11:30~12:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
           
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0         

            print '\t'
            continue
        elif i == data_trade_time_series_1200_1230 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '12:00~12:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:00~12:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '12:00~12:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '12:00~12:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:00~12:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '12:00~12:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '12:00~12:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:00~12:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '12:00~12:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
          
            print '12:00~12:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:00~12:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '12:00~12:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '12:00~12:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:00~12:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '12:00~12:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
                       
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0  
            print '\t'
            continue
        elif i == data_trade_time_series_1230_1300 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '12:30~13:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:30~13:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '12:30~13:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '12:30~13:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:30~13:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '12:30~13:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '12:30~13:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:30~13:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '12:30~13:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
          
            print '12:30~13:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:30~13:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '12:30~13:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '12:30~13:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:30~13:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '12:00~13:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '12:00~13:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
                       
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0         

            print '\t'
            continue
        elif i == data_trade_time_series_1300_1330 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '13:00~13:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:00~13:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '13:00~13:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '13:00~13:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:00~13:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '13:30~13:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '13:30~13:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '13:00~13:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:00~13:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '13:00~13:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
          
            print '13:00~13:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:00~13:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '13:00~13:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '13:00~13:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:00~13:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '13:00~13:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
                       
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0  

            print '\t'
            continue
        elif i == data_trade_time_series_1330_1400 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '13:30~14:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:30~14:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '13:30~14:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '13:30~14:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:30~14:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '13:30~14:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '13:30~14:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:30~14:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '13:30~14:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
          
            print '13:30~14:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:30~14:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '13:30~14:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '13:30~14:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:30~14:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '13:30~14:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
                       
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0     

            print '\t'
            continue        
        elif i == data_trade_time_series_1400_1430 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '14:00~14:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:00~14:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '14:00~14:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '14:00~14:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:00~14:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '14:00~14:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '14:00~14:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:00~14:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '14:00~14:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
               
            print '14:00~14:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:00~14:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '14:00~14:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '14:00~14:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:00~14:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '14:00~14:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
                       
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0  
            print '\t'
            continue                                          
        elif i == data_trade_time_series_1430_1500 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '14:30~15:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:30~15:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '14:30~15:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '14:30~15:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:30~15:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '14:30~15:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '14:30~15:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:30~15:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '14:30~15:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
          
            print '14:30~15:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:30~15:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '14:00~15:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '14:00~15:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '14:30~15:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:30~15:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '14:30~15:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
                       
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0  
            print '\t'
            continue 
        elif i == data_trade_time_series_1500_1530 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '15:00~15:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:00~15:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '15:00~15:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '15:00~15:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:00~15:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '15:00~15:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '15:00~15:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:00~15:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '15:00~15:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
          
            print '15:00~15:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:00~15:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '15:00~15:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '15:00~15:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:00~15:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '15:00~15:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
           
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0  
            print '\t'
            continue 
        elif i == data_trade_time_series_1530_1600 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)

            print '15:30~16:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:30~16:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '15:30~16:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            
            print '15:30~16:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:30~16:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '15:30~16:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            
            print '15:30~16:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:30~16:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '15:30~16:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '15:30~16:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
          
            print '15:30~16:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:30~16:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '15:30~16:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '15:30~16:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:30~16:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '15:30~16:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
                     
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0  

            print '\t'
            continue

# %%
bid_stat_time_spread_divid(Bid1,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)
# Out:
# (0.69994295493439806, 0.89640600166502682, 1.0786112641952614, 1.3621418506341008)
# Spread 5 and Category One = 849
# Spread 10 and Category One = 284
# Spread 5 and Category Two= 682
# Spread 10 and Category Two = 406
# Spread 5 and Category Three = 509
# Spread 10 and Category Three = 224
# Spread 5 and Category Four = 674
# Spread 10 and Category Four = 306
# Spread 5 and Category Five = 1079
# Spread 10 and Category Five = 285
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category one MDD = 2.738516
# 09:00~09:30 bid1 spread 10 category one MDD = 4.000000
# 09:00~09:30 bid1 spread 5 category one traded time = 459.421672
# 09:00~09:30 bid1 spread 10 category one traded time = 744.999997
# 09:00~09:30 bid1 spread 5 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category two traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category two MDD = 3.221408
# 09:00~09:30 bid1 spread 10 category two MDD = 3.581281
# 09:00~09:30 bid1 spread 5 category two traded time = 573.884163
# 09:00~09:30 bid1 spread 10 category two traded time = 641.399013
# 09:00~09:30 bid1 spread 5 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category three traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category three MDD = 3.263261
# 09:00~09:30 bid1 spread 10 category three MDD = 4.392857
# 09:00~09:30 bid1 spread 5 category three traded time = 600.929272
# 09:00~09:30 bid1 spread 10 category three traded time = 867.834818
# 09:00~09:30 bid1 spread 5 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category four traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category four MDD = 3.409496
# 09:00~09:30 bid1 spread 10 category four MDD = 5.529412
# 09:00~09:30 bid1 spread 5 category four traded time = 646.722551
# 09:00~09:30 bid1 spread 10 category four traded time = 1184.552284
# 09:00~09:30 bid1 spread 5 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category five traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category five MDD = 3.518072
# 09:00~09:30 bid1 spread 10 category five MDD = 3.715789
# 09:00~09:30 bid1 spread 5 category five traded time = 668.245597
# 09:00~09:30 bid1 spread 10 category five traded time = 652.294735
#
# Spread 5 and Category One = 1170
# Spread 10 and Category One = 91
# Spread 5 and Category Two= 1361
# Spread 10 and Category Two = 345
# Spread 5 and Category Three = 1386
# Spread 10 and Category Three = 248
# Spread 5 and Category Four = 1214
# Spread 10 and Category Four = 229
# Spread 5 and Category Five = 1825
# Spread 10 and Category Five = 75
# 09:30~10:00 bid1 spread 5 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category one traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category one traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category one MDD = 1.470085
# 09:30~10:00 bid1 spread 10 category one MDD = 2.395604
# 09:30~10:00 bid1 spread 5 category one traded time = 179.951282
# 09:30~10:00 bid1 spread 10 category one traded time = 305.593403
# 09:30~10:00 bid1 spread 5 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category two traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category two traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category two MDD = 1.731080
# 09:30~10:00 bid1 spread 10 category two MDD = 2.652174
# 09:30~10:00 bid1 spread 5 category two traded time = 256.989713
# 09:30~10:00 bid1 spread 10 category two traded time = 523.886955
# 09:30~10:00 bid1 spread 5 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category three traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category three traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category three MDD = 1.888889
# 09:30~10:00 bid1 spread 10 category three MDD = 2.318548
# 09:30~10:00 bid1 spread 5 category three traded time = 255.678210
# 09:30~10:00 bid1 spread 10 category three traded time = 297.931450
# 09:30~10:00 bid1 spread 5 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category four traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category four traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category four MDD = 1.976936
# 09:30~10:00 bid1 spread 10 category four MDD = 2.323144
# 09:30~10:00 bid1 spread 5 category four traded time = 281.155683
# 09:30~10:00 bid1 spread 10 category four traded time = 207.689955
# 09:30~10:00 bid1 spread 5 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category five traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category five traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category five MDD = 2.240548
# 09:30~10:00 bid1 spread 10 category five MDD = 2.146667
# 09:30~10:00 bid1 spread 5 category five traded time = 320.886575
# 09:30~10:00 bid1 spread 10 category five traded time = 122.293332
#
# Spread 5 and Category One = 1289
# Spread 10 and Category One = 20
# Spread 5 and Category Two= 1076
# Spread 10 and Category Two = 116
# Spread 5 and Category Three = 1243
# Spread 10 and Category Three = 300
# Spread 5 and Category Four = 1136
# Spread 10 and Category Four = 411
# Spread 5 and Category Five = 2061
# Spread 10 and Category Five = 58
# 10:00~10:30 bid1 spread 5 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category one traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category one MDD = 2.595811
# 10:00~10:30 bid1 spread 10 category one MDD = 3.050000
# 10:00~10:30 bid1 spread 5 category one traded time = 611.067494
# 10:00~10:30 bid1 spread 10 category one traded time = 737.199963
# 10:00~10:30 bid1 spread 5 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category two traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category two traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category two MDD = 2.822491
# 10:00~10:30 bid1 spread 10 category two MDD = 3.568965
# 10:00~10:30 bid1 spread 5 category two traded time = 657.276022
# 10:00~10:30 bid1 spread 10 category two traded time = 766.922407
# 10:00~10:30 bid1 spread 5 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category three traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category three traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category three MDD = 2.751408
# 10:00~10:30 bid1 spread 10 category three MDD = 4.386667
# 10:00~10:30 bid1 spread 5 category three traded time = 576.491552
# 10:00~10:30 bid1 spread 10 category three traded time = 1197.129996
# 10:00~10:30 bid1 spread 5 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category four traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category four traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category four MDD = 3.256162
# 10:00~10:30 bid1 spread 10 category four MDD = 3.703163
# 10:00~10:30 bid1 spread 5 category four traded time = 734.426056
# 10:00~10:30 bid1 spread 10 category four traded time = 907.447686
# 10:00~10:30 bid1 spread 5 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category five traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category five MDD = 3.507521
# 10:00~10:30 bid1 spread 10 category five MDD = 2.724138
# 10:00~10:30 bid1 spread 5 category five traded time = 778.329451
# 10:00~10:30 bid1 spread 10 category five traded time = 446.758613
#
# Spread 5 and Category One = 1505
# Spread 10 and Category One = 90
# Spread 5 and Category Two= 1458
# Spread 10 and Category Two = 156
# Spread 5 and Category Three = 1503
# Spread 10 and Category Three = 132
# Spread 5 and Category Four = 1600
# Spread 10 and Category Four = 243
# Spread 5 and Category Five = 1521
# Spread 10 and Category Five = 162
# 10:30~11:00 bid1 spread 5 category one traded probability = 0.894352
# 10:30~11:00 bid1 spread 5 category one traded expectation = 0.424585
# 10:30~11:00 bid1 spread 10 category one traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 2.000000
# 10:30~11:00 bid1 spread 5 category one MDD = 3.219269
# 10:30~11:00 bid1 spread 10 category one MDD = 4.500000
# 10:30~11:00 bid1 spread 5 category one traded time = 1615.021926
# 10:30~11:00 bid1 spread 10 category one traded time = 1311.711097
# 10:30~11:00 bid1 spread 5 category two traded probability = 0.889575
# 10:30~11:00 bid1 spread 5 category two traded expectation = 0.373114
# 10:30~11:00 bid1 spread 10 category two traded probability = 0.705128
# 10:30~11:00 bid1 spread 10 category two traded expectation = 0.282051
# 10:30~11:00 bid1 spread 5 category two MDD = 2.571331
# 10:30~11:00 bid1 spread 10 category two MDD = 2.371795
# 10:30~11:00 bid1 spread 5 category two traded time = 1034.596707
# 10:30~11:00 bid1 spread 10 category two traded time = 480.923074
# 10:30~11:00 bid1 spread 5 category three traded probability = 0.924817
# 10:30~11:00 bid1 spread 5 category three traded expectation = 0.562209
# 11:30~11:00 bid1 spread 10 category three traded probability = 0.787879
# 10:30~11:00 bid1 spread 10 category three traded expectation = 0.750000
# 10:30~11:00 bid1 spread 5 category three MDD = 2.858949
# 10:30~11:00 bid1 spread 10 category three MDD = 1.863636
# 10:30~11:00 bid1 spread 5 category three traded time = 1492.892880
# 10:30~11:00 bid1 spread 10 category three traded time = 135.333332
# 10:30~11:00 bid1 spread 5 category four traded probability = 0.916875
# 10:30~11:00 bid1 spread 5 category four traded expectation = 0.548750
# 10:30~11:00 bid1 spread 10 category four traded probability = 0.563786
# 10:30~11:00 bid1 spread 10 category four traded expectation = 0.230453
# 10:30~11:00 bid1 spread 5 category four MDD = 2.134375
# 10:30~11:00 bid1 spread 10 category four MDD = 1.691358
# 10:30~11:00 bid1 spread 5 category four traded time = 473.195625
# 10:30~11:00 bid1 spread 10 category four traded time = 188.427983
# 10:30~11:00 bid1 spread 5 category five traded probability = 0.729126
# 10:30~11:00 bid1 spread 5 category five traded expectation = -0.574622
# 10:30~11:00 bid1 spread 10 category five traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category five traded expectation = 2.000000
# 10:30~11:00 bid1 spread 5 category five MDD = 1.680473
# 10:30~11:00 bid1 spread 10 category five MDD = 2.086420
# 10:30~11:00 bid1 spread 5 category five traded time = 180.182774
# 10:30~11:00 bid1 spread 10 category five traded time = 145.716048
#
# Spread 5 and Category One = 1963
# Spread 10 and Category One = 50
# Spread 5 and Category Two= 1897
# Spread 10 and Category Two = 162
# Spread 5 and Category Three = 1667
# Spread 10 and Category Three = 56
# Spread 5 and Category Four = 1768
# Spread 10 and Category Four = 147
# Spread 5 and Category Five = 900
# Spread 10 and Category Five = 14
# 11:00~11:30 bid1 spread 5 category one traded probability = 0.996434
# 11:00~11:30 bid1 spread 5 category one traded expectation = 0.985736
# 11:00~11:30 bid1 spread 10 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = 2.000000
# 11:00~11:30 bid1 spread 5 category one MDD = 1.848701
# 11:00~11:30 bid1 spread 10 category one MDD = 3.220000
# 11:00~11:30 bid1 spread 5 category one traded time = 692.915945
# 11:00~11:30 bid1 spread 10 category one traded time = 472.739991
# 11:00~11:30 bid1 spread 5 category two traded probability = 0.874539
# 11:00~11:30 bid1 spread 5 category two traded expectation = 0.498155
# 11:00~11:30 bid1 spread 10 category two traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category two traded expectation = 2.000000
# 11:00~11:30 bid1 spread 5 category two MDD = 1.721139
# 11:00~11:30 bid1 spread 10 category two MDD = 3.030864
# 11:00~11:30 bid1 spread 5 category two traded time = 515.772272
# 11:00~11:30 bid1 spread 10 category two traded time = 619.524688
# 11:00~11:30 bid1 spread 5 category three traded probability = 0.898620
# 11:00~11:30 bid1 spread 5 category three traded expectation = 0.594481
# 11:00~11:30 bid1 spread 10 category three traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category three traded expectation = 2.000000
# 11:00~11:30 bid1 spread 5 category three MDD = 2.184763
# 11:00~11:30 bid1 spread 10 category three MDD = 2.660714
# 11:00~11:30 bid1 spread 5 category three traded time = 2388.355727
# 11:00~11:30 bid1 spread 10 category three traded time = 669.982131
# 11:00~11:30 bid1 spread 5 category four traded probability = 0.953620
# 11:00~11:30 bid1 spread 5 category four traded expectation = 0.814480
# 11:00~11:30 bid1 spread 10 category four traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category four traded expectation = 2.000000
# 11:00~11:30 bid1 spread 5 category four MDD = 2.257919
# 11:00~11:30 bid1 spread 10 category four MDD = 2.142857
# 11:00~11:30 bid1 spread 5 category four traded time = 2376.721718
# 11:00~11:30 bid1 spread 10 category four traded time = 469.734691
# 11:00~11:30 bid1 spread 5 category five traded probability = 0.916667
# 11:00~11:30 bid1 spread 5 category five traded expectation = 0.666667
# 11:00~11:30 bid1 spread 10 category five traded probability = 0.142857
# 11:00~11:30 bid1 spread 10 category five traded expectation = -1.428571
# 11:00~11:30 bid1 spread 5 category five MDD = 2.056667
# 11:00~11:30 bid1 spread 10 category five MDD = 0.285714
# 11:00~11:30 bid1 spread 5 category five traded time = 909.498888
# 11:00~11:30 bid1 spread 10 category five traded time = 15.142856
#
# Spread 5 and Category One = 243
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 90
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 53
# Spread 10 and Category Three = 101
# Spread 5 and Category Four = 111
# Spread 10 and Category Four = 47
# Spread 5 and Category Five = 122
# Spread 10 and Category Five = 5
# 11:30~12:00 bid1 spread 5 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category one traded expectation = 1.000000
# 11:30~12:00 bid1 spread 10 category one traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = 0.000000
# 11:30~12:00 bid1 spread 5 category one MDD = 2.666667
# 11:30~12:00 bid1 spread 10 category one MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category one traded time = 5363.534957
# 11:30~12:00 bid1 spread 10 category one traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = 1.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category two traded expectation = 0.000000
# 11:30~12:00 bid1 spread 5 category two MDD = 3.000000
# 11:30~12:00 bid1 spread 10 category two MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded time = 6385.188818
# 11:30~12:00 bid1 spread 10 category two traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category three traded probability = 0.471698
# 11:30~12:00 bid1 spread 5 category three traded expectation = -1.113208
# 11:30~12:00 bid1 spread 10 category three traded probability = 0.099010
# 11:30~12:00 bid1 spread 10 category three traded expectation = -1.603960
# 11:30~12:00 bid1 spread 5 category three MDD = 1.415094
# 11:30~12:00 bid1 spread 10 category three MDD = 0.297030
# 11:30~12:00 bid1 spread 5 category three traded time = 2908.471643
# 11:30~12:00 bid1 spread 10 category three traded time = 478.346530
# 11:30~12:00 bid1 spread 5 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded expectation = -3.000000
# 11:30~12:00 bid1 spread 10 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = -2.000000
# 11:30~12:00 bid1 spread 5 category four MDD = 0.000000
# 11:30~12:00 bid1 spread 10 category four MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded time = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 0.049180
# 11:30~12:00 bid1 spread 5 category five traded expectation = -2.803279
# 11:30~12:00 bid1 spread 10 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = -2.000000
# 11:30~12:00 bid1 spread 5 category five MDD = 0.147541
# 11:30~12:00 bid1 spread 10 category five MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded time = 237.737703
# 11:30~12:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 154
# Spread 10 and Category One = 83
# Spread 5 and Category Two= 78
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 15
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 42
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded expectation = 2.000000
# 12:00~12:30 bid1 spread 5 category one MDD = 1.181818
# 12:00~12:30 bid1 spread 10 category one MDD = 2.000000
# 12:00~12:30 bid1 spread 5 category one traded time = 1778.487001
# 12:00~12:30 bid1 spread 10 category one traded time = 3977.915615
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 1.000000
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category two MDD = 2.000000
# 12:00~12:30 bid1 spread 10 category two MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category two traded time = 3150.140985
# 12:00~12:30 bid1 spread 10 category two traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 1.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three MDD = 2.000000
# 12:00~12:30 bid1 spread 10 category three MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded time = 3586.133094
# 12:00~12:30 bid1 spread 10 category three traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category four traded expectation = 1.000000
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four MDD = 2.000000
# 12:00~12:30 bid1 spread 10 category four MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded time = 3821.333242
# 12:00~12:30 bid1 spread 10 category four traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five MDD = 0.000000
# 12:00~12:30 bid1 spread 10 category five MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded time = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 152
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 28
# Spread 10 and Category Two = 5
# Spread 5 and Category Three = 2
# Spread 10 and Category Three = 7
# Spread 5 and Category Four = 0
# Spread 10 and Category Four = 71
# Spread 5 and Category Five = 228
# Spread 10 and Category Five = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 1.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category one MDD = 2.000000
# 12:30~13:00 bid1 spread 10 category one MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category one traded time = 1969.447355
# 12:30~13:00 bid1 spread 10 category one traded time = 0.000000
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 1.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = 2.000000
# 12:30~13:00 bid1 spread 5 category two MDD = 2.000000
# 12:30~13:00 bid1 spread 10 category two MDD = 2.999999
# 12:30~13:00 bid1 spread 5 category two traded time = 2054.678498
# 12:30~13:00 bid1 spread 10 category two traded time = 1914.399617
# 12:30~13:00 bid1 spread 5 category three traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 1.000000
# 12:30~13:00 bid1 spread 10 category three traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = 2.000000
# 12:30~13:00 bid1 spread 5 category three MDD = 1.999999
# 12:30~13:00 bid1 spread 10 category three MDD = 3.000000
# 12:30~13:00 bid1 spread 5 category three traded time = 1827.499086
# 12:30~13:00 bid1 spread 10 category three traded time = 1411.428370
# 12:30~13:00 bid1 spread 5 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = 2.000000
# 12:30~13:00 bid1 spread 5 category four MDD = 0.000000
# 12:30~13:00 bid1 spread 10 category four MDD = 3.000000
# 12:30~13:00 bid1 spread 5 category four traded time = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded time = 2129.605604
# 12:30~13:00 bid1 spread 5 category five traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = 1.000000
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five MDD = 3.000000
# 12:30~13:00 bid1 spread 10 category five MDD = 0.000000
# 12:00~13:00 bid1 spread 5 category five traded time = 1349.087713
# 12:00~13:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 991
# Spread 10 and Category One = 6
# Spread 5 and Category Two= 855
# Spread 10 and Category Two = 99
# Spread 5 and Category Three = 423
# Spread 10 and Category Three = 99
# Spread 5 and Category Four = 680
# Spread 10 and Category Four = 151
# Spread 5 and Category Five = 502
# Spread 10 and Category Five = 9
# 13:00~13:30 bid1 spread 5 category one traded probability = 0.914228
# 13:00~13:30 bid1 spread 5 category one traded expectation = 0.656912
# 13:00~13:30 bid1 spread 10 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = 2.000000
# 13:00~13:30 bid1 spread 5 category one MDD = 1.208880
# 13:00~13:30 bid1 spread 10 category one MDD = 2.000000
# 13:00~13:30 bid1 spread 5 category one traded time = 411.325933
# 13:00~13:30 bid1 spread 10 category one traded time = 499.833250
# 13:00~13:30 bid1 spread 5 category two traded probability = 0.915789
# 13:00~13:30 bid1 spread 5 category two traded expectation = 0.663158
# 13:00~13:30 bid1 spread 10 category two traded probability = 0.595960
# 13:00~13:30 bid1 spread 10 category two traded expectation = 0.383838
# 13:00~13:30 bid1 spread 5 category two MDD = 1.383626
# 13:00~13:30 bid1 spread 10 category two MDD = 1.181818
# 13:30~13:30 bid1 spread 5 category two traded time = 480.754385
# 13:30~13:30 bid1 spread 10 category two traded time = 414.292925
# 13:00~13:30 bid1 spread 5 category three traded probability = 0.895981
# 13:00~13:30 bid1 spread 5 category three traded expectation = 0.583924
# 13:00~13:30 bid1 spread 10 category three traded probability = 0.717172
# 13:00~13:30 bid1 spread 10 category three traded expectation = 0.868687
# 13:00~13:30 bid1 spread 5 category three MDD = 1.503546
# 13:00~13:30 bid1 spread 10 category three MDD = 1.434343
# 13:00~13:30 bid1 spread 5 category three traded time = 517.314420
# 13:00~13:30 bid1 spread 10 category three traded time = 545.171712
# 13:00~13:30 bid1 spread 5 category four traded probability = 0.727941
# 13:00~13:30 bid1 spread 5 category four traded expectation = -0.167647
# 13:00~13:30 bid1 spread 10 category four traded probability = 0.966887
# 13:00~13:30 bid1 spread 10 category four traded expectation = 1.867550
# 13:00~13:30 bid1 spread 5 category four MDD = 1.235294
# 13:00~13:30 bid1 spread 10 category four MDD = 1.933775
# 13:00~13:30 bid1 spread 5 category four traded time = 449.461764
# 13:00~13:30 bid1 spread 10 category four traded time = 823.715226
# 13:00~13:30 bid1 spread 5 category five traded probability = 0.607570
# 13:00~13:30 bid1 spread 5 category five traded expectation = -0.583665
# 13:00~13:30 bid1 spread 10 category five traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = 2.000000
# 13:00~13:30 bid1 spread 5 category five MDD = 1.195219
# 13:00~13:30 bid1 spread 10 category five MDD = 3.000000
# 13:00~13:30 bid1 spread 5 category five traded time = 419.621513
# 13:00~13:30 bid1 spread 10 category five traded time = 1113.666543
#
# Spread 5 and Category One = 773
# Spread 10 and Category One = 43
# Spread 5 and Category Two= 861
# Spread 10 and Category Two = 117
# Spread 5 and Category Three = 1040
# Spread 10 and Category Three = 215
# Spread 5 and Category Four = 890
# Spread 10 and Category Four = 44
# Spread 5 and Category Five = 788
# Spread 10 and Category Five = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 0.410091
# 13:30~14:00 bid1 spread 5 category one traded expectation = -0.600259
# 13:30~14:00 bid1 spread 10 category one traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = -1.000000
# 13:30~14:00 bid1 spread 5 category one MDD = 0.411384
# 13:30~14:00 bid1 spread 10 category one MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category one traded time = 66.243208
# 13:30~14:00 bid1 spread 10 category one traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category two traded probability = 0.249710
# 13:30~14:00 bid1 spread 5 category two traded expectation = -1.472706
# 13:30~14:00 bid1 spread 10 category two traded probability = 0.179487
# 13:30~14:00 bid1 spread 10 category two traded expectation = -0.435897
# 13:30~14:00 bid1 spread 5 category two MDD = 0.295006
# 13:30~14:00 bid1 spread 10 category two MDD = 0.350427
# 13:30~14:00 bid1 spread 5 category two traded time = 49.084785
# 13:30~14:00 bid1 spread 10 category two traded time = 45.316239
# 13:30~14:00 bid1 spread 5 category three traded probability = 0.140385
# 13:30~14:00 bid1 spread 5 category three traded expectation = -1.984615
# 13:30~14:00 bid1 spread 10 category three traded probability = 0.046512
# 13:30~14:00 bid1 spread 10 category three traded expectation = -1.530233
# 13:30~14:00 bid1 spread 5 category three MDD = 0.143269
# 13:30~14:00 bid1 spread 10 category three MDD = 0.093023
# 13:30~14:00 bid1 spread 5 category three traded time = 30.335577
# 13:30~14:00 bid1 spread 10 category three traded time = 13.265116
# 13:30~14:00 bid1 spread 5 category four traded probability = 0.139326
# 13:30~14:00 bid1 spread 5 category four traded expectation = -1.721348
# 13:30~14:00 bid1 spread 10 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category four traded expectation = -1.954545
# 13:30~14:00 bid1 spread 5 category four MDD = 0.142697
# 13:30~14:00 bid1 spread 10 category four MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category four traded time = 27.638202
# 13:30~14:00 bid1 spread 10 category four traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded probability = 0.050761
# 13:30~14:00 bid1 spread 5 category five traded expectation = -2.373096
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
# 13:30~14:00 bid1 spread 5 category five MDD = 0.090102
# 13:30~14:00 bid1 spread 10 category five MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded time = 12.951777
# 13:30~14:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 843
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 608
# Spread 10 and Category Two = 109
# Spread 5 and Category Three = 727
# Spread 10 and Category Three = 227
# Spread 5 and Category Four = 847
# Spread 10 and Category Four = 62
# Spread 5 and Category Five = 1114
# Spread 10 and Category Five = 0
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.855279
# 14:00~14:30 bid1 spread 5 category one traded expectation = 0.855279
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category one traded expectation = 0.000000
# 14:00~14:30 bid1 spread 5 category one MDD = 1.077106
# 14:00~14:30 bid1 spread 10 category one MDD = 0.000000
# 14:00~14:30 bid1 spread 5 category one traded time = 783.521945
# 14:00~14:30 bid1 spread 10 category one traded time = 0.000000
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.703947
# 14:00~14:30 bid1 spread 5 category two traded expectation = 0.703947
# 14:00~14:30 bid1 spread 10 category two traded probability = 0.899083
# 14:00~14:30 bid1 spread 10 category two traded expectation = 1.899083
# 14:00~14:30 bid1 spread 5 category two MDD = 1.092105
# 14:00~14:30 bid1 spread 10 category two MDD = 1.844037
# 14:00~14:30 bid1 spread 5 category two traded time = 799.236841
# 14:00~14:30 bid1 spread 10 category two traded time = 730.293571
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.541953
# 14:00~14:30 bid1 spread 5 category three traded expectation = 0.524072
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.731278
# 14:00~14:30 bid1 spread 10 category three traded expectation = 1.555066
# 14:00~14:30 bid1 spread 5 category three MDD = 1.122421
# 14:00~14:30 bid1 spread 10 category three MDD = 1.471366
# 14:00~14:30 bid1 spread 5 category three traded time = 634.312241
# 14:00~14:30 bid1 spread 10 category three traded time = 716.792948
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.492326
# 14:00~14:30 bid1 spread 5 category four traded expectation = 0.329398
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.064516
# 14:00~14:30 bid1 spread 10 category four traded expectation = 0.435484
# 14:00~14:30 bid1 spread 5 category four MDD = 0.991736
# 14:00~14:30 bid1 spread 10 category four MDD = 0.129032
# 14:00~14:30 bid1 spread 5 category four traded time = 512.072018
# 14:00~14:30 bid1 spread 10 category four traded time = 63.225805
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.505386
# 14:00~14:30 bid1 spread 5 category five traded expectation = 0.295332
# 14:00~14:30 bid1 spread 10 category five traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category five traded expectation = 0.000000
# 14:00~14:30 bid1 spread 5 category five MDD = 1.019749
# 14:00~14:30 bid1 spread 10 category five MDD = 0.000000
# 14:00~14:30 bid1 spread 5 category five traded time = 484.713644
# 14:00~14:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 804
# Spread 10 and Category One = 14
# Spread 5 and Category Two= 630
# Spread 10 and Category Two = 64
# Spread 5 and Category Three = 934
# Spread 10 and Category Three = 103
# Spread 5 and Category Four = 561
# Spread 10 and Category Four = 51
# Spread 5 and Category Five = 606
# Spread 10 and Category Five = 0
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.952736
# 14:30~15:00 bid1 spread 5 category one traded expectation = 0.952736
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category one traded expectation = 1.000000
# 14:30~15:00 bid1 spread 5 category one MDD = 1.106965
# 14:30~15:00 bid1 spread 10 category one MDD = 0.000000
# 14:30~15:00 bid1 spread 5 category one traded time = 970.708954
# 14:30~15:00 bid1 spread 10 category one traded time = 0.000000
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.833333
# 14:30~15:00 bid1 spread 5 category two traded expectation = 0.833333
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.703125
# 14:30~15:00 bid1 spread 10 category two traded expectation = 1.703125
# 14:30~15:00 bid1 spread 5 category two MDD = 0.922222
# 14:30~15:00 bid1 spread 10 category two MDD = 1.406250
# 14:30~15:00 bid1 spread 5 category two traded time = 693.560316
# 14:30~15:00 bid1 spread 10 category two traded time = 2415.546837
# 14:30~15:00 bid1 spread 5 category three traded probability = 0.667024
# 14:30~15:00 bid1 spread 5 category three traded expectation = 0.662741
# 14:30~15:00 bid1 spread 10 category three traded probability = 0.514563
# 14:30~15:00 bid1 spread 10 category three traded expectation = 1.407767
# 14:30~15:00 bid1 spread 5 category three MDD = 0.738758
# 14:30~15:00 bid1 spread 10 category three MDD = 1.019417
# 14:30~15:00 bid1 spread 5 category three traded time = 525.182012
# 14:30~15:00 bid1 spread 10 category three traded time = 753.485430
# 14:30~15:00 bid1 spread 5 category four traded probability = 0.524064
# 14:30~15:00 bid1 spread 5 category four traded expectation = 0.468806
# 14:30~15:00 bid1 spread 10 category four traded probability = 0.686274
# 14:30~15:00 bid1 spread 10 category four traded expectation = 1.392157
# 14:30~15:00 bid1 spread 5 category four MDD = 0.716578
# 14:30~15:00 bid1 spread 10 category four MDD = 1.372549
# 14:00~15:00 bid1 spread 5 category four traded time = 854.515150
# 14:00~15:00 bid1 spread 10 category four traded time = 2130.137213
# 14:30~15:00 bid1 spread 5 category five traded probability = 0.759076
# 14:30~15:00 bid1 spread 5 category five traded expectation = 0.589109
# 14:30~15:00 bid1 spread 10 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = 0.000000
# 14:30~15:00 bid1 spread 5 category five MDD = 1.452145
# 14:30~15:00 bid1 spread 10 category five MDD = 0.000000
# 14:30~15:00 bid1 spread 5 category five traded time = 2287.820128
# 14:30~15:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 90
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 378
# Spread 10 and Category Two = 19
# Spread 5 and Category Three = 366
# Spread 10 and Category Three = 55
# Spread 5 and Category Four = 271
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 241
# Spread 10 and Category Five = 7
# 15:00~15:30 bid1 spread 5 category one traded probability = 0.933333
# 15:00~15:30 bid1 spread 5 category one traded expectation = 0.933333
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category one MDD = 1.100000
# 15:00~15:30 bid1 spread 10 category one MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category one traded time = 739.288881
# 15:00~15:30 bid1 spread 10 category one traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 0.365079
# 15:00~15:30 bid1 spread 5 category two traded expectation = 0.365079
# 15:00~15:30 bid1 spread 10 category two traded probability = 1.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = 2.000000
# 15:00~15:30 bid1 spread 5 category two MDD = 0.436508
# 15:00~15:30 bid1 spread 10 category two MDD = 2.000000
# 15:00~15:30 bid1 spread 5 category two traded time = 276.748677
# 15:00~15:30 bid1 spread 10 category two traded time = 2961.999844
# 15:00~15:30 bid1 spread 5 category three traded probability = 0.669399
# 15:00~15:30 bid1 spread 5 category three traded expectation = 0.669399
# 15:00~15:30 bid1 spread 10 category three traded probability = 0.363636
# 15:00~15:30 bid1 spread 10 category three traded expectation = 1.363636
# 15:00~15:30 bid1 spread 5 category three MDD = 1.158470
# 15:00~15:30 bid1 spread 10 category three MDD = 0.727273
# 15:00~15:30 bid1 spread 5 category three traded time = 1425.166663
# 15:00~15:30 bid1 spread 10 category three traded time = 1089.981798
# 15:00~15:30 bid1 spread 5 category four traded probability = 0.756458
# 15:00~15:30 bid1 spread 5 category four traded expectation = 0.756458
# 15:00~15:30 bid1 spread 10 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category four MDD = 1.453875
# 15:00~15:30 bid1 spread 10 category four MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded time = 2050.464937
# 15:00~15:30 bid1 spread 10 category four traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded probability = 0.763485
# 15:00~15:30 bid1 spread 5 category five traded expectation = 0.763485
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 1.000000
# 15:00~15:30 bid1 spread 5 category five MDD = 1.497925
# 15:00~15:30 bid1 spread 10 category five MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded time = 2175.373435
# 15:00~15:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 105
# Spread 10 and Category One = 31
# Spread 5 and Category Two= 10
# Spread 10 and Category Two = 51
# Spread 5 and Category Three = 13
# Spread 10 and Category Three = 19
# Spread 5 and Category Four = 15
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 66
# Spread 10 and Category Five = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category one traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category one traded probability = 1.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = 2.000000
# 15:30~16:00 bid1 spread 5 category one MDD = 1.609524
# 15:30~16:00 bid1 spread 10 category one MDD = 1.903226
# 15:30~16:00 bid1 spread 5 category one traded time = 640.314280
# 15:30~16:00 bid1 spread 10 category one traded time = 34.483870
# 15:30~16:00 bid1 spread 5 category two traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.117647
# 15:30~16:00 bid1 spread 10 category two traded expectation = 1.117647
# 15:30~16:00 bid1 spread 5 category two MDD = 2.000000
# 15:30~16:00 bid1 spread 10 category two MDD = 0.235294
# 15:30~16:00 bid1 spread 5 category two traded time = 489.899951
# 15:30~16:00 bid1 spread 10 category two traded time = 44.470587
# 15:30~16:00 bid1 spread 5 category three traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 1.000000
# 15:30~16:00 bid1 spread 5 category three MDD = 2.000000
# 15:30~16:00 bid1 spread 10 category three MDD = 0.000000
# 15:30~16:30 bid1 spread 5 category three traded time = 488.999962
# 15:30~16:30 bid1 spread 10 category three traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 0.800000
# 15:30~16:00 bid1 spread 5 category four traded expectation = 0.800000
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four MDD = 1.600000
# 15:30~16:00 bid1 spread 10 category four MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded time = 300.333313
# 15:30~16:00 bid1 spread 10 category four traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.151515
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.151515
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five MDD = 0.303030
# 15:30~16:00 bid1 spread 10 category five MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded time = 44.227272
# 15:30~16:00 bid1 spread 10 category five traded time = 0.000000

# %%
bid_stat_time_spread_divid(Bid2,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)
# Out:
# (0.69994295493439806, 0.89640600166502682, 1.0786112641952614, 1.3621418506341008)
# Spread 5 and Category One = 849
# Spread 10 and Category One = 284
# Spread 5 and Category Two= 682
# Spread 10 and Category Two = 406
# Spread 5 and Category Three = 509
# Spread 10 and Category Three = 224
# Spread 5 and Category Four = 674
# Spread 10 and Category Four = 306
# Spread 5 and Category Five = 1079
# Spread 10 and Category Five = 285
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 2.017668
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category one MDD = 4.149588
# 09:00~09:30 bid1 spread 10 category one MDD = 5.119718
# 09:00~09:30 bid1 spread 5 category one traded time = 728.386336
# 09:00~09:30 bid1 spread 10 category one traded time = 852.616194
# 09:00~09:30 bid1 spread 5 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category two traded expectation = 2.007331
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category two MDD = 4.521994
# 09:00~09:30 bid1 spread 10 category two MDD = 5.017241
# 09:00~09:30 bid1 spread 5 category two traded time = 802.853371
# 09:00~09:30 bid1 spread 10 category two traded time = 945.379308
# 09:00~09:30 bid1 spread 5 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category three traded expectation = 2.000000
# 09:00~09:30 bid1 spread 10 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category three MDD = 4.607073
# 09:00~09:30 bid1 spread 10 category three MDD = 5.665179
# 09:00~09:30 bid1 spread 5 category three traded time = 837.320234
# 09:00~09:30 bid1 spread 10 category three traded time = 1125.821424
# 09:00~09:30 bid1 spread 5 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category four traded expectation = 2.000000
# 09:00~09:30 bid1 spread 10 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category four MDD = 4.833828
# 09:00~09:30 bid1 spread 10 category four MDD = 6.529412
# 09:00~09:30 bid1 spread 5 category four traded time = 926.296735
# 09:00~09:30 bid1 spread 10 category four traded time = 1379.709146
# 09:00~09:30 bid1 spread 5 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category five traded expectation = 2.002780
# 09:00~09:30 bid1 spread 10 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category five MDD = 4.710843
# 09:00~09:30 bid1 spread 10 category five MDD = 4.715789
# 09:00~09:30 bid1 spread 5 category five traded time = 885.874883
# 09:00~09:30 bid1 spread 10 category five traded time = 757.456138
#
# Spread 5 and Category One = 1170
# Spread 10 and Category One = 91
# Spread 5 and Category Two= 1361
# Spread 10 and Category Two = 345
# Spread 5 and Category Three = 1386
# Spread 10 and Category Three = 248
# Spread 5 and Category Four = 1214
# Spread 10 and Category Four = 229
# Spread 5 and Category Five = 1825
# Spread 10 and Category Five = 75
# 09:30~10:00 bid1 spread 5 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category one traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category one traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category one MDD = 2.627350
# 09:30~10:00 bid1 spread 10 category one MDD = 3.395604
# 09:30~10:00 bid1 spread 5 category one traded time = 366.024786
# 09:30~10:00 bid1 spread 10 category one traded time = 446.142852
# 09:30~10:00 bid1 spread 5 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category two traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category two traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category two MDD = 2.874357
# 09:30~10:00 bid1 spread 10 category two MDD = 3.655072
# 09:30~10:00 bid1 spread 5 category two traded time = 415.890521
# 09:30~10:00 bid1 spread 10 category two traded time = 651.901447
# 09:30~10:00 bid1 spread 5 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category three traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category three traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category three MDD = 2.944444
# 09:30~10:00 bid1 spread 10 category three MDD = 3.318548
# 09:30~10:00 bid1 spread 5 category three traded time = 357.459596
# 09:30~10:00 bid1 spread 10 category three traded time = 475.221772
# 09:30~10:00 bid1 spread 5 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category four traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category four traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category four MDD = 3.016474
# 09:30~10:00 bid1 spread 10 category four MDD = 3.327511
# 09:30~10:00 bid1 spread 5 category four traded time = 411.626029
# 09:30~10:00 bid1 spread 10 category four traded time = 343.650654
# 09:30~10:00 bid1 spread 5 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category five traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category five traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category five MDD = 3.275068
# 09:30~10:00 bid1 spread 10 category five MDD = 3.146667
# 09:30~10:00 bid1 spread 5 category five traded time = 490.483835
# 09:30~10:00 bid1 spread 10 category five traded time = 298.346663
#
# Spread 5 and Category One = 1289
# Spread 10 and Category One = 20
# Spread 5 and Category Two= 1076
# Spread 10 and Category Two = 116
# Spread 5 and Category Three = 1243
# Spread 10 and Category Three = 300
# Spread 5 and Category Four = 1136
# Spread 10 and Category Four = 411
# Spread 5 and Category Five = 2061
# Spread 10 and Category Five = 58
# 10:00~10:30 bid1 spread 5 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category one traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category one MDD = 4.391777
# 10:00~10:30 bid1 spread 10 category one MDD = 5.350000
# 10:00~10:30 bid1 spread 5 category one traded time = 1187.686578
# 10:00~10:30 bid1 spread 10 category one traded time = 1744.999913
# 10:00~10:30 bid1 spread 5 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category two traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category two traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category two MDD = 4.373606
# 10:00~10:30 bid1 spread 10 category two MDD = 5.267241
# 10:00~10:30 bid1 spread 5 category two traded time = 1084.427508
# 10:00~10:30 bid1 spread 10 category two traded time = 1368.836195
# 10:00~10:30 bid1 spread 5 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category three traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category three traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category three MDD = 4.000000
# 10:00~10:30 bid1 spread 10 category three MDD = 5.470000
# 10:00~10:30 bid1 spread 5 category three traded time = 811.972646
# 10:00~10:30 bid1 spread 10 category three traded time = 1471.606662
# 10:00~10:30 bid1 spread 5 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category four traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category four traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category four MDD = 4.315141
# 10:00~10:30 bid1 spread 10 category four MDD = 4.703163
# 10:00~10:30 bid1 spread 5 category four traded time = 903.037851
# 10:00~10:30 bid1 spread 10 category four traded time = 1029.671530
# 10:00~10:30 bid1 spread 5 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category five traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category five MDD = 4.555556
# 10:00~10:30 bid1 spread 10 category five MDD = 3.724138
# 10:00~10:30 bid1 spread 5 category five traded time = 946.905385
# 10:00~10:30 bid1 spread 10 category five traded time = 514.827577
#
# Spread 5 and Category One = 1505
# Spread 10 and Category One = 90
# Spread 5 and Category Two= 1458
# Spread 10 and Category Two = 156
# Spread 5 and Category Three = 1503
# Spread 10 and Category Three = 132
# Spread 5 and Category Four = 1600
# Spread 10 and Category Four = 243
# Spread 5 and Category Five = 1521
# Spread 10 and Category Five = 162
# 10:30~11:00 bid1 spread 5 category one traded probability = 0.770100
# 10:30~11:00 bid1 spread 5 category one traded expectation = 0.809967
# 10:30~11:00 bid1 spread 10 category one traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 3.000000
# 10:30~11:00 bid1 spread 5 category one MDD = 3.312292
# 10:30~11:00 bid1 spread 10 category one MDD = 5.500000
# 10:30~11:00 bid1 spread 5 category one traded time = 1211.424584
# 10:30~11:00 bid1 spread 10 category one traded time = 1626.877760
# 10:30~11:00 bid1 spread 5 category two traded probability = 0.751715
# 10:30~11:00 bid1 spread 5 category two traded expectation = 0.586420
# 10:30~11:00 bid1 spread 10 category two traded probability = 0.705128
# 10:30~11:00 bid1 spread 10 category two traded expectation = 0.987179
# 10:30~11:00 bid1 spread 5 category two MDD = 2.746914
# 10:30~11:00 bid1 spread 10 category two MDD = 3.076923
# 10:30~11:00 bid1 spread 5 category two traded time = 608.293552
# 10:30~11:00 bid1 spread 10 category two traded time = 673.358970
# 10:30~11:00 bid1 spread 5 category three traded probability = 0.702595
# 10:30~11:00 bid1 spread 5 category three traded expectation = 0.401198
# 11:30~11:00 bid1 spread 10 category three traded probability = 0.681818
# 10:30~11:00 bid1 spread 10 category three traded expectation = 0.901515
# 10:30~11:00 bid1 spread 5 category three MDD = 2.618097
# 10:30~11:00 bid1 spread 10 category three MDD = 2.750000
# 10:30~11:00 bid1 spread 5 category three traded time = 519.783100
# 10:30~11:00 bid1 spread 10 category three traded time = 243.507574
# 10:30~11:00 bid1 spread 5 category four traded probability = 0.833125
# 10:30~11:00 bid1 spread 5 category four traded expectation = 0.983125
# 10:30~11:00 bid1 spread 10 category four traded probability = 0.555556
# 10:30~11:00 bid1 spread 10 category four traded expectation = 0.744856
# 10:30~11:00 bid1 spread 5 category four MDD = 2.834375
# 10:30~11:00 bid1 spread 10 category four MDD = 2.411523
# 10:30~11:00 bid1 spread 5 category four traded time = 789.413125
# 10:30~11:00 bid1 spread 10 category four traded time = 416.172838
# 10:30~11:00 bid1 spread 5 category five traded probability = 0.641683
# 10:30~11:00 bid1 spread 5 category five traded expectation = -0.368836
# 10:30~11:00 bid1 spread 10 category five traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category five traded expectation = 3.000000
# 10:30~11:00 bid1 spread 5 category five MDD = 2.131492
# 10:30~11:00 bid1 spread 10 category five MDD = 3.086420
# 10:30~11:00 bid1 spread 5 category five traded time = 223.655490
# 10:30~11:00 bid1 spread 10 category five traded time = 158.049382
#
# Spread 5 and Category One = 1963
# Spread 10 and Category One = 50
# Spread 5 and Category Two= 1897
# Spread 10 and Category Two = 162
# Spread 5 and Category Three = 1667
# Spread 10 and Category Three = 56
# Spread 5 and Category Four = 1768
# Spread 10 and Category Four = 147
# Spread 5 and Category Five = 900
# Spread 10 and Category Five = 14
# 11:00~11:30 bid1 spread 5 category one traded probability = 0.934794
# 11:00~11:30 bid1 spread 5 category one traded expectation = 1.735609
# 11:00~11:30 bid1 spread 10 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = 3.000000
# 11:00~11:30 bid1 spread 5 category one MDD = 2.694345
# 11:00~11:30 bid1 spread 10 category one MDD = 4.220000
# 11:00~11:30 bid1 spread 5 category one traded time = 749.927661
# 11:00~11:30 bid1 spread 10 category one traded time = 690.279986
# 11:00~11:30 bid1 spread 5 category two traded probability = 0.833421
# 11:00~11:30 bid1 spread 5 category two traded expectation = 1.208224
# 11:00~11:30 bid1 spread 10 category two traded probability = 0.969136
# 11:00~11:30 bid1 spread 10 category two traded expectation = 2.876543
# 11:00~11:30 bid1 spread 5 category two MDD = 2.528730
# 11:00~11:30 bid1 spread 10 category two MDD = 3.913580
# 11:00~11:30 bid1 spread 5 category two traded time = 776.745914
# 11:00~11:30 bid1 spread 10 category two traded time = 1376.703695
# 11:00~11:30 bid1 spread 5 category three traded probability = 0.565687
# 11:00~11:30 bid1 spread 5 category three traded expectation = 0.161368
# 11:00~11:30 bid1 spread 10 category three traded probability = 0.928571
# 11:00~11:30 bid1 spread 10 category three traded expectation = 2.714286
# 11:00~11:30 bid1 spread 5 category three MDD = 1.813437
# 11:00~11:30 bid1 spread 10 category three MDD = 3.375000
# 11:00~11:30 bid1 spread 5 category three traded time = 660.825435
# 11:00~11:30 bid1 spread 10 category three traded time = 769.214272
# 11:00~11:30 bid1 spread 5 category four traded probability = 0.619344
# 11:00~11:30 bid1 spread 5 category four traded expectation = 0.430995
# 11:00~11:30 bid1 spread 10 category four traded probability = 0.952381
# 11:00~11:30 bid1 spread 10 category four traded expectation = 2.809524
# 11:00~11:30 bid1 spread 5 category four MDD = 1.914593
# 11:00~11:30 bid1 spread 10 category four MDD = 2.952381
# 11:00~11:30 bid1 spread 5 category four traded time = 481.932126
# 11:00~11:30 bid1 spread 10 category four traded time = 2692.081614
# 11:00~11:30 bid1 spread 5 category five traded probability = 0.808889
# 11:00~11:30 bid1 spread 5 category five traded expectation = 1.152222
# 11:00~11:30 bid1 spread 10 category five traded probability = 0.142857
# 11:00~11:30 bid1 spread 10 category five traded expectation = -1.285714
# 11:00~11:30 bid1 spread 5 category five MDD = 2.642222
# 11:00~11:30 bid1 spread 10 category five MDD = 0.428571
# 11:00~11:30 bid1 spread 5 category five traded time = 1502.556665
# 11:00~11:30 bid1 spread 10 category five traded time = 507.499964
#
# Spread 5 and Category One = 243
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 90
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 53
# Spread 10 and Category Three = 101
# Spread 5 and Category Four = 111
# Spread 10 and Category Four = 47
# Spread 5 and Category Five = 122
# Spread 10 and Category Five = 5
# 11:30~12:00 bid1 spread 5 category one traded probability = 0.230453
# 11:30~12:00 bid1 spread 5 category one traded expectation = -1.078189
# 11:30~12:00 bid1 spread 10 category one traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = 0.000000
# 11:30~12:00 bid1 spread 5 category one MDD = 0.588477
# 11:30~12:00 bid1 spread 10 category one MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category one traded time = 1076.584358
# 11:30~12:00 bid1 spread 10 category one traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = -2.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category two traded expectation = 0.000000
# 11:30~12:00 bid1 spread 5 category two MDD = 0.000000
# 11:30~12:00 bid1 spread 10 category two MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded time = 0.000000
# 11:30~12:00 bid1 spread 10 category two traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category three traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category three traded expectation = -2.528302
# 11:30~12:00 bid1 spread 10 category three traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category three traded expectation = -1.900990
# 11:30~12:00 bid1 spread 5 category three MDD = 0.000000
# 11:30~12:00 bid1 spread 10 category three MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category three traded time = 0.000000
# 11:30~12:00 bid1 spread 10 category three traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded expectation = -3.000000
# 11:30~12:00 bid1 spread 10 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = -2.000000
# 11:30~12:00 bid1 spread 5 category four MDD = 0.000000
# 11:30~12:00 bid1 spread 10 category four MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded time = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded expectation = -2.950820
# 11:30~12:00 bid1 spread 10 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = -2.000000
# 11:30~12:00 bid1 spread 5 category five MDD = 0.000000
# 11:30~12:00 bid1 spread 10 category five MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded time = 0.000000
# 11:30~12:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 154
# Spread 10 and Category One = 83
# Spread 5 and Category Two= 78
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 15
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 42
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 2.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded expectation = 3.000000
# 12:00~12:30 bid1 spread 5 category one MDD = 2.181818
# 12:00~12:30 bid1 spread 10 category one MDD = 3.000000
# 12:00~12:30 bid1 spread 5 category one traded time = 3949.668806
# 12:00~12:30 bid1 spread 10 category one traded time = 4241.915612
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 2.000000
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category two MDD = 3.000000
# 12:00~12:30 bid1 spread 10 category two MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category two traded time = 3414.140982
# 12:00~12:30 bid1 spread 10 category two traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 2.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three MDD = 3.000000
# 12:00~12:30 bid1 spread 10 category three MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded time = 3850.133077
# 12:00~12:30 bid1 spread 10 category three traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category four traded expectation = 2.000000
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four MDD = 3.000000
# 12:00~12:30 bid1 spread 10 category four MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded time = 4085.333236
# 12:00~12:30 bid1 spread 10 category four traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five MDD = 0.000000
# 12:00~12:30 bid1 spread 10 category five MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded time = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 152
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 28
# Spread 10 and Category Two = 5
# Spread 5 and Category Three = 2
# Spread 10 and Category Three = 7
# Spread 5 and Category Four = 0
# Spread 10 and Category Four = 71
# Spread 5 and Category Five = 228
# Spread 10 and Category Five = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 2.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category one MDD = 3.000000
# 12:30~13:00 bid1 spread 10 category one MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category one traded time = 2233.447354
# 12:30~13:00 bid1 spread 10 category one traded time = 0.000000
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 2.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = -1.000000
# 12:30~13:00 bid1 spread 5 category two MDD = 3.000000
# 12:30~13:00 bid1 spread 10 category two MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category two traded time = 2318.678489
# 12:30~13:00 bid1 spread 10 category two traded time = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 1.999999
# 12:30~13:00 bid1 spread 10 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = -1.000000
# 12:30~13:00 bid1 spread 5 category three MDD = 2.999999
# 12:30~13:00 bid1 spread 10 category three MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded time = 2091.498954
# 12:30~13:00 bid1 spread 10 category three traded time = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = -1.000000
# 12:30~13:00 bid1 spread 5 category four MDD = 0.000000
# 12:30~13:00 bid1 spread 10 category four MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded time = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded time = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = -2.000000
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five MDD = 0.000000
# 12:30~13:00 bid1 spread 10 category five MDD = 0.000000
# 12:00~13:00 bid1 spread 5 category five traded time = 0.000000
# 12:00~13:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 991
# Spread 10 and Category One = 6
# Spread 5 and Category Two= 855
# Spread 10 and Category Two = 99
# Spread 5 and Category Three = 423
# Spread 10 and Category Three = 99
# Spread 5 and Category Four = 680
# Spread 10 and Category Four = 151
# Spread 5 and Category Five = 502
# Spread 10 and Category Five = 9
# 13:00~13:30 bid1 spread 5 category one traded probability = 0.476287
# 13:00~13:30 bid1 spread 5 category one traded expectation = -0.180626
# 13:00~13:30 bid1 spread 10 category one traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = -1.000000
# 13:00~13:30 bid1 spread 5 category one MDD = 0.952573
# 13:00~13:30 bid1 spread 10 category one MDD = 0.000000
# 13:00~13:30 bid1 spread 5 category one traded time = 350.327951
# 13:00~13:30 bid1 spread 10 category one traded time = 0.000000
# 13:00~13:30 bid1 spread 5 category two traded probability = 0.223392
# 13:00~13:30 bid1 spread 5 category two traded expectation = -1.190643
# 13:00~13:30 bid1 spread 10 category two traded probability = 0.313131
# 13:00~13:30 bid1 spread 10 category two traded expectation = -0.151515
# 13:00~13:30 bid1 spread 5 category two MDD = 0.472515
# 13:00~13:30 bid1 spread 10 category two MDD = 0.929293
# 13:30~13:30 bid1 spread 5 category two traded time = 203.762573
# 13:30~13:30 bid1 spread 10 category two traded time = 332.666663
# 13:00~13:30 bid1 spread 5 category three traded probability = 0.089835
# 13:00~13:30 bid1 spread 5 category three traded expectation = -1.744681
# 13:00~13:30 bid1 spread 10 category three traded probability = 0.040404
# 13:00~13:30 bid1 spread 10 category three traded expectation = -1.121212
# 13:00~13:30 bid1 spread 5 category three MDD = 0.196217
# 13:00~13:30 bid1 spread 10 category three MDD = 0.121212
# 13:00~13:30 bid1 spread 5 category three traded time = 79.576832
# 13:00~13:30 bid1 spread 10 category three traded time = 43.393939
# 13:00~13:30 bid1 spread 5 category four traded probability = 0.138235
# 13:00~13:30 bid1 spread 5 category four traded expectation = -1.798529
# 13:00~13:30 bid1 spread 10 category four traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category four traded expectation = -1.033113
# 13:00~13:30 bid1 spread 5 category four MDD = 0.342647
# 13:00~13:30 bid1 spread 10 category four MDD = 0.000000
# 13:00~13:30 bid1 spread 5 category four traded time = 136.360294
# 13:00~13:30 bid1 spread 10 category four traded time = 0.000000
# 13:00~13:30 bid1 spread 5 category five traded probability = 0.093625
# 13:00~13:30 bid1 spread 5 category five traded expectation = -2.031873
# 13:00~13:30 bid1 spread 10 category five traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = -1.000000
# 13:00~13:30 bid1 spread 5 category five MDD = 0.278884
# 13:00~13:30 bid1 spread 10 category five MDD = 0.000000
# 13:00~13:30 bid1 spread 5 category five traded time = 101.081673
# 13:00~13:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 773
# Spread 10 and Category One = 43
# Spread 5 and Category Two= 861
# Spread 10 and Category Two = 117
# Spread 5 and Category Three = 1040
# Spread 10 and Category Three = 215
# Spread 5 and Category Four = 890
# Spread 10 and Category Four = 44
# Spread 5 and Category Five = 788
# Spread 10 and Category Five = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 0.161708
# 13:30~14:00 bid1 spread 5 category one traded expectation = -0.956016
# 13:30~14:00 bid1 spread 10 category one traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = -1.000000
# 13:30~14:00 bid1 spread 5 category one MDD = 0.323415
# 13:30~14:00 bid1 spread 10 category one MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category one traded time = 44.375162
# 13:30~14:00 bid1 spread 10 category one traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category two traded probability = 0.069686
# 13:30~14:00 bid1 spread 5 category two traded expectation = -1.867596
# 13:30~14:00 bid1 spread 10 category two traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category two traded expectation = -0.974359
# 13:30~14:00 bid1 spread 5 category two MDD = 0.139373
# 13:30~14:00 bid1 spread 10 category two MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category two traded time = 17.557491
# 13:30~14:00 bid1 spread 10 category two traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category three traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category three traded expectation = -2.300000
# 13:30~14:00 bid1 spread 10 category three traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category three traded expectation = -1.669767
# 13:30~14:00 bid1 spread 5 category three MDD = 0.000000
# 13:30~14:00 bid1 spread 10 category three MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category three traded time = 0.000000
# 13:30~14:00 bid1 spread 10 category three traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category four traded expectation = -2.022472
# 13:30~14:00 bid1 spread 10 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category four traded expectation = -1.954545
# 13:30~14:00 bid1 spread 5 category four MDD = 0.000000
# 13:30~14:00 bid1 spread 10 category four MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category four traded time = 0.000000
# 13:30~14:00 bid1 spread 10 category four traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded expectation = -2.513959
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
# 13:30~14:00 bid1 spread 5 category five MDD = 0.000000
# 13:30~14:00 bid1 spread 10 category five MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded time = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 843
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 608
# Spread 10 and Category Two = 109
# Spread 5 and Category Three = 727
# Spread 10 and Category Three = 227
# Spread 5 and Category Four = 847
# Spread 10 and Category Four = 62
# Spread 5 and Category Five = 1114
# Spread 10 and Category Five = 0
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.798339
# 14:00~14:30 bid1 spread 5 category one traded expectation = 1.653618
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category one traded expectation = 0.000000
# 14:00~14:30 bid1 spread 5 category one MDD = 1.704626
# 14:00~14:30 bid1 spread 10 category one MDD = 0.000000
# 14:00~14:30 bid1 spread 5 category one traded time = 745.128113
# 14:00~14:30 bid1 spread 10 category one traded time = 0.000000
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.652961
# 14:00~14:30 bid1 spread 5 category two traded expectation = 1.356908
# 14:00~14:30 bid1 spread 10 category two traded probability = 0.853211
# 14:00~14:30 bid1 spread 10 category two traded expectation = 2.752294
# 14:00~14:30 bid1 spread 5 category two MDD = 1.592105
# 14:00~14:30 bid1 spread 10 category two MDD = 2.559633
# 14:00~14:30 bid1 spread 5 category two traded time = 768.953946
# 14:00~14:30 bid1 spread 10 category two traded time = 728.165131
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.462173
# 14:00~14:30 bid1 spread 5 category three traded expectation = 0.986245
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.722467
# 14:00~14:30 bid1 spread 10 category three traded expectation = 2.277533
# 14:00~14:30 bid1 spread 5 category three MDD = 1.345254
# 14:00~14:30 bid1 spread 10 category three MDD = 2.167401
# 14:00~14:30 bid1 spread 5 category three traded time = 535.352131
# 14:00~14:30 bid1 spread 10 category three traded time = 760.740085
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.485242
# 14:00~14:30 bid1 spread 5 category four traded expectation = 0.814640
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.064516
# 14:00~14:30 bid1 spread 10 category four traded expectation = 0.500000
# 14:00~14:30 bid1 spread 5 category four MDD = 1.455726
# 14:00~14:30 bid1 spread 10 category four MDD = 0.193548
# 14:00~14:30 bid1 spread 5 category four traded time = 538.879574
# 14:00~14:30 bid1 spread 10 category four traded time = 68.322580
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.496409
# 14:00~14:30 bid1 spread 5 category five traded expectation = 0.791741
# 14:00~14:30 bid1 spread 10 category five traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category five traded expectation = 0.000000
# 14:00~14:30 bid1 spread 5 category five MDD = 1.489228
# 14:00~14:30 bid1 spread 10 category five MDD = 0.000000
# 14:00~14:30 bid1 spread 5 category five traded time = 509.465888
# 14:00~14:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 804
# Spread 10 and Category One = 14
# Spread 5 and Category Two= 630
# Spread 10 and Category Two = 64
# Spread 5 and Category Three = 934
# Spread 10 and Category Three = 103
# Spread 5 and Category Four = 561
# Spread 10 and Category Four = 51
# Spread 5 and Category Five = 606
# Spread 10 and Category Five = 0
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.669154
# 14:30~15:00 bid1 spread 5 category one traded expectation = 1.621891
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category one traded expectation = 1.000000
# 14:30~15:00 bid1 spread 5 category one MDD = 1.337065
# 14:30~15:00 bid1 spread 10 category one MDD = 0.000000
# 14:30~15:00 bid1 spread 5 category one traded time = 2335.299748
# 14:30~15:00 bid1 spread 10 category one traded time = 0.000000
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.592063
# 14:30~15:00 bid1 spread 5 category two traded expectation = 1.425397
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.062500
# 14:30~15:00 bid1 spread 10 category two traded expectation = 1.765625
# 14:30~15:00 bid1 spread 5 category two MDD = 1.184127
# 14:30~15:00 bid1 spread 10 category two MDD = 0.187500
# 14:30~15:00 bid1 spread 5 category two traded time = 1789.082537
# 14:30~15:00 bid1 spread 10 category two traded time = 29.500000
# 14:30~15:00 bid1 spread 5 category three traded probability = 0.490364
# 14:30~15:00 bid1 spread 5 category three traded expectation = 1.153105
# 14:30~15:00 bid1 spread 10 category three traded probability = 0.330097
# 14:30~15:00 bid1 spread 10 category three traded expectation = 1.737864
# 14:30~15:00 bid1 spread 5 category three MDD = 0.980728
# 14:30~15:00 bid1 spread 10 category three MDD = 0.980583
# 14:30~15:00 bid1 spread 5 category three traded time = 1025.938971
# 14:30~15:00 bid1 spread 10 category three traded time = 141.203882
# 14:30~15:00 bid1 spread 5 category four traded probability = 0.210339
# 14:30~15:00 bid1 spread 5 category four traded expectation = 0.679144
# 14:30~15:00 bid1 spread 10 category four traded probability = 0.156863
# 14:30~15:00 bid1 spread 10 category four traded expectation = 1.549020
# 14:30~15:00 bid1 spread 5 category four MDD = 0.420677
# 14:30~15:00 bid1 spread 10 category four MDD = 0.470588
# 14:00~15:00 bid1 spread 5 category four traded time = 486.169340
# 14:00~15:00 bid1 spread 10 category four traded time = 67.058822
# 14:30~15:00 bid1 spread 5 category five traded probability = 0.108911
# 14:30~15:00 bid1 spread 5 category five traded expectation = 0.698020
# 14:30~15:00 bid1 spread 10 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = 0.000000
# 14:30~15:00 bid1 spread 5 category five MDD = 0.298680
# 14:30~15:00 bid1 spread 10 category five MDD = 0.000000
# 14:30~15:00 bid1 spread 5 category five traded time = 88.252475
# 14:30~15:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 90
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 378
# Spread 10 and Category Two = 19
# Spread 5 and Category Three = 366
# Spread 10 and Category Three = 55
# Spread 5 and Category Four = 271
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 241
# Spread 10 and Category Five = 7
# 15:00~15:30 bid1 spread 5 category one traded probability = 0.755556
# 15:00~15:30 bid1 spread 5 category one traded expectation = 1.688889
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category one MDD = 1.511111
# 15:00~15:30 bid1 spread 10 category one MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category one traded time = 2405.877751
# 15:00~15:30 bid1 spread 10 category one traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 0.293651
# 15:00~15:30 bid1 spread 5 category two traded expectation = 0.658730
# 15:00~15:30 bid1 spread 10 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = 2.000000
# 15:00~15:30 bid1 spread 5 category two MDD = 0.587302
# 15:00~15:30 bid1 spread 10 category two MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded time = 936.269839
# 15:00~15:30 bid1 spread 10 category two traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category three traded probability = 0.180328
# 15:00~15:30 bid1 spread 5 category three traded expectation = 0.849727
# 15:00~15:30 bid1 spread 10 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category three traded expectation = 1.363636
# 15:00~15:30 bid1 spread 5 category three MDD = 0.360656
# 15:00~15:30 bid1 spread 10 category three MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category three traded time = 574.401638
# 15:00~15:30 bid1 spread 10 category three traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded probability = 0.059041
# 15:00~15:30 bid1 spread 5 category four traded expectation = 0.815498
# 15:00~15:30 bid1 spread 10 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category four MDD = 0.118081
# 15:00~15:30 bid1 spread 10 category four MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded time = 185.309962
# 15:00~15:30 bid1 spread 10 category four traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded probability = 0.029046
# 15:00~15:30 bid1 spread 5 category five traded expectation = 0.792531
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 1.000000
# 15:00~15:30 bid1 spread 5 category five MDD = 0.058091
# 15:00~15:30 bid1 spread 10 category five MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded time = 90.946058
# 15:00~15:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 105
# Spread 10 and Category One = 31
# Spread 5 and Category Two= 10
# Spread 10 and Category Two = 51
# Spread 5 and Category Three = 13
# Spread 10 and Category Three = 19
# Spread 5 and Category Four = 15
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 66
# Spread 10 and Category Five = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 0.390476
# 15:30~16:00 bid1 spread 5 category one traded expectation = 1.390476
# 15:30~16:00 bid1 spread 10 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = 2.000000
# 15:30~16:00 bid1 spread 5 category one MDD = 0.780952
# 15:30~16:00 bid1 spread 10 category one MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category one traded time = 120.361904
# 15:30~16:00 bid1 spread 10 category one traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded expectation = 1.117647
# 15:30~16:00 bid1 spread 5 category two MDD = 0.000000
# 15:30~16:00 bid1 spread 10 category two MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded time = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 1.000000
# 15:30~16:00 bid1 spread 5 category three MDD = 0.000000
# 15:30~16:00 bid1 spread 10 category three MDD = 0.000000
# 15:30~16:30 bid1 spread 5 category three traded time = 0.000000
# 15:30~16:30 bid1 spread 10 category three traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded expectation = 0.800000
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four MDD = 0.000000
# 15:30~16:00 bid1 spread 10 category four MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded time = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.151515
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five MDD = 0.000000
# 15:30~16:00 bid1 spread 10 category five MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded time = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded time = 0.000000

# %%
bid_stat_time_spread_divid(Bid2,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)
# Out:
# (0.69994295493439806, 0.89640600166502682, 1.0786112641952614, 1.3621418506341008)
# Spread 5 and Category One = 849
# Spread 10 and Category One = 284
# Spread 5 and Category Two= 682
# Spread 10 and Category Two = 406
# Spread 5 and Category Three = 509
# Spread 10 and Category Three = 224
# Spread 5 and Category Four = 674
# Spread 10 and Category Four = 306
# Spread 5 and Category Five = 1079
# Spread 10 and Category Five = 285
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 2.017668
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category one MDD = 4.149588
# 09:00~09:30 bid1 spread 10 category one MDD = 5.119718
# 09:00~09:30 bid1 spread 5 category one traded time = 728.386336
# 09:00~09:30 bid1 spread 10 category one traded time = 852.616194
# 09:00~09:30 bid1 spread 5 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category two traded expectation = 2.007331
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category two MDD = 4.521994
# 09:00~09:30 bid1 spread 10 category two MDD = 5.017241
# 09:00~09:30 bid1 spread 5 category two traded time = 802.853371
# 09:00~09:30 bid1 spread 10 category two traded time = 945.379308
# 09:00~09:30 bid1 spread 5 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category three traded expectation = 2.000000
# 09:00~09:30 bid1 spread 10 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category three MDD = 4.607073
# 09:00~09:30 bid1 spread 10 category three MDD = 5.665179
# 09:00~09:30 bid1 spread 5 category three traded time = 837.320234
# 09:00~09:30 bid1 spread 10 category three traded time = 1125.821424
# 09:00~09:30 bid1 spread 5 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category four traded expectation = 2.000000
# 09:00~09:30 bid1 spread 10 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category four MDD = 4.833828
# 09:00~09:30 bid1 spread 10 category four MDD = 6.529412
# 09:00~09:30 bid1 spread 5 category four traded time = 926.296735
# 09:00~09:30 bid1 spread 10 category four traded time = 1379.709146
# 09:00~09:30 bid1 spread 5 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category five traded expectation = 2.002780
# 09:00~09:30 bid1 spread 10 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 3.000000
# 09:00~09:30 bid1 spread 5 category five MDD = 4.710843
# 09:00~09:30 bid1 spread 10 category five MDD = 4.715789
# 09:00~09:30 bid1 spread 5 category five traded time = 885.874883
# 09:00~09:30 bid1 spread 10 category five traded time = 757.456138
#
# Spread 5 and Category One = 1170
# Spread 10 and Category One = 91
# Spread 5 and Category Two= 1361
# Spread 10 and Category Two = 345
# Spread 5 and Category Three = 1386
# Spread 10 and Category Three = 248
# Spread 5 and Category Four = 1214
# Spread 10 and Category Four = 229
# Spread 5 and Category Five = 1825
# Spread 10 and Category Five = 75
# 09:30~10:00 bid1 spread 5 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category one traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category one traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category one MDD = 2.627350
# 09:30~10:00 bid1 spread 10 category one MDD = 3.395604
# 09:30~10:00 bid1 spread 5 category one traded time = 366.024786
# 09:30~10:00 bid1 spread 10 category one traded time = 446.142852
# 09:30~10:00 bid1 spread 5 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category two traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category two traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category two MDD = 2.874357
# 09:30~10:00 bid1 spread 10 category two MDD = 3.655072
# 09:30~10:00 bid1 spread 5 category two traded time = 415.890521
# 09:30~10:00 bid1 spread 10 category two traded time = 651.901447
# 09:30~10:00 bid1 spread 5 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category three traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category three traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category three MDD = 2.944444
# 09:30~10:00 bid1 spread 10 category three MDD = 3.318548
# 09:30~10:00 bid1 spread 5 category three traded time = 357.459596
# 09:30~10:00 bid1 spread 10 category three traded time = 475.221772
# 09:30~10:00 bid1 spread 5 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category four traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category four traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category four MDD = 3.016474
# 09:30~10:00 bid1 spread 10 category four MDD = 3.327511
# 09:30~10:00 bid1 spread 5 category four traded time = 411.626029
# 09:30~10:00 bid1 spread 10 category four traded time = 343.650654
# 09:30~10:00 bid1 spread 5 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category five traded expectation = 2.000000
# 09:30~10:00 bid1 spread 10 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category five traded expectation = 3.000000
# 09:30~10:00 bid1 spread 5 category five MDD = 3.275068
# 09:30~10:00 bid1 spread 10 category five MDD = 3.146667
# 09:30~10:00 bid1 spread 5 category five traded time = 490.483835
# 09:30~10:00 bid1 spread 10 category five traded time = 298.346663
#
# Spread 5 and Category One = 1289
# Spread 10 and Category One = 20
# Spread 5 and Category Two= 1076
# Spread 10 and Category Two = 116
# Spread 5 and Category Three = 1243
# Spread 10 and Category Three = 300
# Spread 5 and Category Four = 1136
# Spread 10 and Category Four = 411
# Spread 5 and Category Five = 2061
# Spread 10 and Category Five = 58
# 10:00~10:30 bid1 spread 5 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category one traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category one MDD = 4.391777
# 10:00~10:30 bid1 spread 10 category one MDD = 5.350000
# 10:00~10:30 bid1 spread 5 category one traded time = 1187.686578
# 10:00~10:30 bid1 spread 10 category one traded time = 1744.999913
# 10:00~10:30 bid1 spread 5 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category two traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category two traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category two MDD = 4.373606
# 10:00~10:30 bid1 spread 10 category two MDD = 5.267241
# 10:00~10:30 bid1 spread 5 category two traded time = 1084.427508
# 10:00~10:30 bid1 spread 10 category two traded time = 1368.836195
# 10:00~10:30 bid1 spread 5 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category three traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category three traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category three MDD = 4.000000
# 10:00~10:30 bid1 spread 10 category three MDD = 5.470000
# 10:00~10:30 bid1 spread 5 category three traded time = 811.972646
# 10:00~10:30 bid1 spread 10 category three traded time = 1471.606662
# 10:00~10:30 bid1 spread 5 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category four traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category four traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category four MDD = 4.315141
# 10:00~10:30 bid1 spread 10 category four MDD = 4.703163
# 10:00~10:30 bid1 spread 5 category four traded time = 903.037851
# 10:00~10:30 bid1 spread 10 category four traded time = 1029.671530
# 10:00~10:30 bid1 spread 5 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category five traded expectation = 2.000000
# 10:00~10:30 bid1 spread 10 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded expectation = 3.000000
# 10:00~10:30 bid1 spread 5 category five MDD = 4.555556
# 10:00~10:30 bid1 spread 10 category five MDD = 3.724138
# 10:00~10:30 bid1 spread 5 category five traded time = 946.905385
# 10:00~10:30 bid1 spread 10 category five traded time = 514.827577
#
# Spread 5 and Category One = 1505
# Spread 10 and Category One = 90
# Spread 5 and Category Two= 1458
# Spread 10 and Category Two = 156
# Spread 5 and Category Three = 1503
# Spread 10 and Category Three = 132
# Spread 5 and Category Four = 1600
# Spread 10 and Category Four = 243
# Spread 5 and Category Five = 1521
# Spread 10 and Category Five = 162
# 10:30~11:00 bid1 spread 5 category one traded probability = 0.770100
# 10:30~11:00 bid1 spread 5 category one traded expectation = 0.809967
# 10:30~11:00 bid1 spread 10 category one traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 3.000000
# 10:30~11:00 bid1 spread 5 category one MDD = 3.312292
# 10:30~11:00 bid1 spread 10 category one MDD = 5.500000
# 10:30~11:00 bid1 spread 5 category one traded time = 1211.424584
# 10:30~11:00 bid1 spread 10 category one traded time = 1626.877760
# 10:30~11:00 bid1 spread 5 category two traded probability = 0.751715
# 10:30~11:00 bid1 spread 5 category two traded expectation = 0.586420
# 10:30~11:00 bid1 spread 10 category two traded probability = 0.705128
# 10:30~11:00 bid1 spread 10 category two traded expectation = 0.987179
# 10:30~11:00 bid1 spread 5 category two MDD = 2.746914
# 10:30~11:00 bid1 spread 10 category two MDD = 3.076923
# 10:30~11:00 bid1 spread 5 category two traded time = 608.293552
# 10:30~11:00 bid1 spread 10 category two traded time = 673.358970
# 10:30~11:00 bid1 spread 5 category three traded probability = 0.702595
# 10:30~11:00 bid1 spread 5 category three traded expectation = 0.401198
# 11:30~11:00 bid1 spread 10 category three traded probability = 0.681818
# 10:30~11:00 bid1 spread 10 category three traded expectation = 0.901515
# 10:30~11:00 bid1 spread 5 category three MDD = 2.618097
# 10:30~11:00 bid1 spread 10 category three MDD = 2.750000
# 10:30~11:00 bid1 spread 5 category three traded time = 519.783100
# 10:30~11:00 bid1 spread 10 category three traded time = 243.507574
# 10:30~11:00 bid1 spread 5 category four traded probability = 0.833125
# 10:30~11:00 bid1 spread 5 category four traded expectation = 0.983125
# 10:30~11:00 bid1 spread 10 category four traded probability = 0.555556
# 10:30~11:00 bid1 spread 10 category four traded expectation = 0.744856
# 10:30~11:00 bid1 spread 5 category four MDD = 2.834375
# 10:30~11:00 bid1 spread 10 category four MDD = 2.411523
# 10:30~11:00 bid1 spread 5 category four traded time = 789.413125
# 10:30~11:00 bid1 spread 10 category four traded time = 416.172838
# 10:30~11:00 bid1 spread 5 category five traded probability = 0.641683
# 10:30~11:00 bid1 spread 5 category five traded expectation = -0.368836
# 10:30~11:00 bid1 spread 10 category five traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category five traded expectation = 3.000000
# 10:30~11:00 bid1 spread 5 category five MDD = 2.131492
# 10:30~11:00 bid1 spread 10 category five MDD = 3.086420
# 10:30~11:00 bid1 spread 5 category five traded time = 223.655490
# 10:30~11:00 bid1 spread 10 category five traded time = 158.049382
#
# Spread 5 and Category One = 1963
# Spread 10 and Category One = 50
# Spread 5 and Category Two= 1897
# Spread 10 and Category Two = 162
# Spread 5 and Category Three = 1667
# Spread 10 and Category Three = 56
# Spread 5 and Category Four = 1768
# Spread 10 and Category Four = 147
# Spread 5 and Category Five = 900
# Spread 10 and Category Five = 14
# 11:00~11:30 bid1 spread 5 category one traded probability = 0.934794
# 11:00~11:30 bid1 spread 5 category one traded expectation = 1.735609
# 11:00~11:30 bid1 spread 10 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = 3.000000
# 11:00~11:30 bid1 spread 5 category one MDD = 2.694345
# 11:00~11:30 bid1 spread 10 category one MDD = 4.220000
# 11:00~11:30 bid1 spread 5 category one traded time = 749.927661
# 11:00~11:30 bid1 spread 10 category one traded time = 690.279986
# 11:00~11:30 bid1 spread 5 category two traded probability = 0.833421
# 11:00~11:30 bid1 spread 5 category two traded expectation = 1.208224
# 11:00~11:30 bid1 spread 10 category two traded probability = 0.969136
# 11:00~11:30 bid1 spread 10 category two traded expectation = 2.876543
# 11:00~11:30 bid1 spread 5 category two MDD = 2.528730
# 11:00~11:30 bid1 spread 10 category two MDD = 3.913580
# 11:00~11:30 bid1 spread 5 category two traded time = 776.745914
# 11:00~11:30 bid1 spread 10 category two traded time = 1376.703695
# 11:00~11:30 bid1 spread 5 category three traded probability = 0.565687
# 11:00~11:30 bid1 spread 5 category three traded expectation = 0.161368
# 11:00~11:30 bid1 spread 10 category three traded probability = 0.928571
# 11:00~11:30 bid1 spread 10 category three traded expectation = 2.714286
# 11:00~11:30 bid1 spread 5 category three MDD = 1.813437
# 11:00~11:30 bid1 spread 10 category three MDD = 3.375000
# 11:00~11:30 bid1 spread 5 category three traded time = 660.825435
# 11:00~11:30 bid1 spread 10 category three traded time = 769.214272
# 11:00~11:30 bid1 spread 5 category four traded probability = 0.619344
# 11:00~11:30 bid1 spread 5 category four traded expectation = 0.430995
# 11:00~11:30 bid1 spread 10 category four traded probability = 0.952381
# 11:00~11:30 bid1 spread 10 category four traded expectation = 2.809524
# 11:00~11:30 bid1 spread 5 category four MDD = 1.914593
# 11:00~11:30 bid1 spread 10 category four MDD = 2.952381
# 11:00~11:30 bid1 spread 5 category four traded time = 481.932126
# 11:00~11:30 bid1 spread 10 category four traded time = 2692.081614
# 11:00~11:30 bid1 spread 5 category five traded probability = 0.808889
# 11:00~11:30 bid1 spread 5 category five traded expectation = 1.152222
# 11:00~11:30 bid1 spread 10 category five traded probability = 0.142857
# 11:00~11:30 bid1 spread 10 category five traded expectation = -1.285714
# 11:00~11:30 bid1 spread 5 category five MDD = 2.642222
# 11:00~11:30 bid1 spread 10 category five MDD = 0.428571
# 11:00~11:30 bid1 spread 5 category five traded time = 1502.556665
# 11:00~11:30 bid1 spread 10 category five traded time = 507.499964
#
# Spread 5 and Category One = 243
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 90
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 53
# Spread 10 and Category Three = 101
# Spread 5 and Category Four = 111
# Spread 10 and Category Four = 47
# Spread 5 and Category Five = 122
# Spread 10 and Category Five = 5
# 11:30~12:00 bid1 spread 5 category one traded probability = 0.230453
# 11:30~12:00 bid1 spread 5 category one traded expectation = -1.078189
# 11:30~12:00 bid1 spread 10 category one traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = 0.000000
# 11:30~12:00 bid1 spread 5 category one MDD = 0.588477
# 11:30~12:00 bid1 spread 10 category one MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category one traded time = 1076.584358
# 11:30~12:00 bid1 spread 10 category one traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = -2.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category two traded expectation = 0.000000
# 11:30~12:00 bid1 spread 5 category two MDD = 0.000000
# 11:30~12:00 bid1 spread 10 category two MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded time = 0.000000
# 11:30~12:00 bid1 spread 10 category two traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category three traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category three traded expectation = -2.528302
# 11:30~12:00 bid1 spread 10 category three traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category three traded expectation = -1.900990
# 11:30~12:00 bid1 spread 5 category three MDD = 0.000000
# 11:30~12:00 bid1 spread 10 category three MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category three traded time = 0.000000
# 11:30~12:00 bid1 spread 10 category three traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded expectation = -3.000000
# 11:30~12:00 bid1 spread 10 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = -2.000000
# 11:30~12:00 bid1 spread 5 category four MDD = 0.000000
# 11:30~12:00 bid1 spread 10 category four MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded time = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded time = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded expectation = -2.950820
# 11:30~12:00 bid1 spread 10 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = -2.000000
# 11:30~12:00 bid1 spread 5 category five MDD = 0.000000
# 11:30~12:00 bid1 spread 10 category five MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded time = 0.000000
# 11:30~12:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 154
# Spread 10 and Category One = 83
# Spread 5 and Category Two= 78
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 15
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 42
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 2.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded expectation = 3.000000
# 12:00~12:30 bid1 spread 5 category one MDD = 2.181818
# 12:00~12:30 bid1 spread 10 category one MDD = 3.000000
# 12:00~12:30 bid1 spread 5 category one traded time = 3949.668806
# 12:00~12:30 bid1 spread 10 category one traded time = 4241.915612
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 2.000000
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category two MDD = 3.000000
# 12:00~12:30 bid1 spread 10 category two MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category two traded time = 3414.140982
# 12:00~12:30 bid1 spread 10 category two traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 2.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three MDD = 3.000000
# 12:00~12:30 bid1 spread 10 category three MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded time = 3850.133077
# 12:00~12:30 bid1 spread 10 category three traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category four traded expectation = 2.000000
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four MDD = 3.000000
# 12:00~12:30 bid1 spread 10 category four MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded time = 4085.333236
# 12:00~12:30 bid1 spread 10 category four traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five MDD = 0.000000
# 12:00~12:30 bid1 spread 10 category five MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded time = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 152
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 28
# Spread 10 and Category Two = 5
# Spread 5 and Category Three = 2
# Spread 10 and Category Three = 7
# Spread 5 and Category Four = 0
# Spread 10 and Category Four = 71
# Spread 5 and Category Five = 228
# Spread 10 and Category Five = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 2.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category one MDD = 3.000000
# 12:30~13:00 bid1 spread 10 category one MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category one traded time = 2233.447354
# 12:30~13:00 bid1 spread 10 category one traded time = 0.000000
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 2.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = -1.000000
# 12:30~13:00 bid1 spread 5 category two MDD = 3.000000
# 12:30~13:00 bid1 spread 10 category two MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category two traded time = 2318.678489
# 12:30~13:00 bid1 spread 10 category two traded time = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 1.999999
# 12:30~13:00 bid1 spread 10 category three traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = -1.000000
# 12:30~13:00 bid1 spread 5 category three MDD = 2.999999
# 12:30~13:00 bid1 spread 10 category three MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category three traded time = 2091.498954
# 12:30~13:00 bid1 spread 10 category three traded time = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = -1.000000
# 12:30~13:00 bid1 spread 5 category four MDD = 0.000000
# 12:30~13:00 bid1 spread 10 category four MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded time = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded time = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = -2.000000
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five MDD = 0.000000
# 12:30~13:00 bid1 spread 10 category five MDD = 0.000000
# 12:00~13:00 bid1 spread 5 category five traded time = 0.000000
# 12:00~13:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 991
# Spread 10 and Category One = 6
# Spread 5 and Category Two= 855
# Spread 10 and Category Two = 99
# Spread 5 and Category Three = 423
# Spread 10 and Category Three = 99
# Spread 5 and Category Four = 680
# Spread 10 and Category Four = 151
# Spread 5 and Category Five = 502
# Spread 10 and Category Five = 9
# 13:00~13:30 bid1 spread 5 category one traded probability = 0.476287
# 13:00~13:30 bid1 spread 5 category one traded expectation = -0.180626
# 13:00~13:30 bid1 spread 10 category one traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = -1.000000
# 13:00~13:30 bid1 spread 5 category one MDD = 0.952573
# 13:00~13:30 bid1 spread 10 category one MDD = 0.000000
# 13:00~13:30 bid1 spread 5 category one traded time = 350.327951
# 13:00~13:30 bid1 spread 10 category one traded time = 0.000000
# 13:00~13:30 bid1 spread 5 category two traded probability = 0.223392
# 13:00~13:30 bid1 spread 5 category two traded expectation = -1.190643
# 13:00~13:30 bid1 spread 10 category two traded probability = 0.313131
# 13:00~13:30 bid1 spread 10 category two traded expectation = -0.151515
# 13:00~13:30 bid1 spread 5 category two MDD = 0.472515
# 13:00~13:30 bid1 spread 10 category two MDD = 0.929293
# 13:30~13:30 bid1 spread 5 category two traded time = 203.762573
# 13:30~13:30 bid1 spread 10 category two traded time = 332.666663
# 13:00~13:30 bid1 spread 5 category three traded probability = 0.089835
# 13:00~13:30 bid1 spread 5 category three traded expectation = -1.744681
# 13:00~13:30 bid1 spread 10 category three traded probability = 0.040404
# 13:00~13:30 bid1 spread 10 category three traded expectation = -1.121212
# 13:00~13:30 bid1 spread 5 category three MDD = 0.196217
# 13:00~13:30 bid1 spread 10 category three MDD = 0.121212
# 13:00~13:30 bid1 spread 5 category three traded time = 79.576832
# 13:00~13:30 bid1 spread 10 category three traded time = 43.393939
# 13:00~13:30 bid1 spread 5 category four traded probability = 0.138235
# 13:00~13:30 bid1 spread 5 category four traded expectation = -1.798529
# 13:00~13:30 bid1 spread 10 category four traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category four traded expectation = -1.033113
# 13:00~13:30 bid1 spread 5 category four MDD = 0.342647
# 13:00~13:30 bid1 spread 10 category four MDD = 0.000000
# 13:00~13:30 bid1 spread 5 category four traded time = 136.360294
# 13:00~13:30 bid1 spread 10 category four traded time = 0.000000
# 13:00~13:30 bid1 spread 5 category five traded probability = 0.093625
# 13:00~13:30 bid1 spread 5 category five traded expectation = -2.031873
# 13:00~13:30 bid1 spread 10 category five traded probability = 0.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = -1.000000
# 13:00~13:30 bid1 spread 5 category five MDD = 0.278884
# 13:00~13:30 bid1 spread 10 category five MDD = 0.000000
# 13:00~13:30 bid1 spread 5 category five traded time = 101.081673
# 13:00~13:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 773
# Spread 10 and Category One = 43
# Spread 5 and Category Two= 861
# Spread 10 and Category Two = 117
# Spread 5 and Category Three = 1040
# Spread 10 and Category Three = 215
# Spread 5 and Category Four = 890
# Spread 10 and Category Four = 44
# Spread 5 and Category Five = 788
# Spread 10 and Category Five = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 0.161708
# 13:30~14:00 bid1 spread 5 category one traded expectation = -0.956016
# 13:30~14:00 bid1 spread 10 category one traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = -1.000000
# 13:30~14:00 bid1 spread 5 category one MDD = 0.323415
# 13:30~14:00 bid1 spread 10 category one MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category one traded time = 44.375162
# 13:30~14:00 bid1 spread 10 category one traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category two traded probability = 0.069686
# 13:30~14:00 bid1 spread 5 category two traded expectation = -1.867596
# 13:30~14:00 bid1 spread 10 category two traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category two traded expectation = -0.974359
# 13:30~14:00 bid1 spread 5 category two MDD = 0.139373
# 13:30~14:00 bid1 spread 10 category two MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category two traded time = 17.557491
# 13:30~14:00 bid1 spread 10 category two traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category three traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category three traded expectation = -2.300000
# 13:30~14:00 bid1 spread 10 category three traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category three traded expectation = -1.669767
# 13:30~14:00 bid1 spread 5 category three MDD = 0.000000
# 13:30~14:00 bid1 spread 10 category three MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category three traded time = 0.000000
# 13:30~14:00 bid1 spread 10 category three traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category four traded expectation = -2.022472
# 13:30~14:00 bid1 spread 10 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category four traded expectation = -1.954545
# 13:30~14:00 bid1 spread 5 category four MDD = 0.000000
# 13:30~14:00 bid1 spread 10 category four MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category four traded time = 0.000000
# 13:30~14:00 bid1 spread 10 category four traded time = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded expectation = -2.513959
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
# 13:30~14:00 bid1 spread 5 category five MDD = 0.000000
# 13:30~14:00 bid1 spread 10 category five MDD = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded time = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 843
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 608
# Spread 10 and Category Two = 109
# Spread 5 and Category Three = 727
# Spread 10 and Category Three = 227
# Spread 5 and Category Four = 847
# Spread 10 and Category Four = 62
# Spread 5 and Category Five = 1114
# Spread 10 and Category Five = 0
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.798339
# 14:00~14:30 bid1 spread 5 category one traded expectation = 1.653618
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category one traded expectation = 0.000000
# 14:00~14:30 bid1 spread 5 category one MDD = 1.704626
# 14:00~14:30 bid1 spread 10 category one MDD = 0.000000
# 14:00~14:30 bid1 spread 5 category one traded time = 745.128113
# 14:00~14:30 bid1 spread 10 category one traded time = 0.000000
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.652961
# 14:00~14:30 bid1 spread 5 category two traded expectation = 1.356908
# 14:00~14:30 bid1 spread 10 category two traded probability = 0.853211
# 14:00~14:30 bid1 spread 10 category two traded expectation = 2.752294
# 14:00~14:30 bid1 spread 5 category two MDD = 1.592105
# 14:00~14:30 bid1 spread 10 category two MDD = 2.559633
# 14:00~14:30 bid1 spread 5 category two traded time = 768.953946
# 14:00~14:30 bid1 spread 10 category two traded time = 728.165131
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.462173
# 14:00~14:30 bid1 spread 5 category three traded expectation = 0.986245
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.722467
# 14:00~14:30 bid1 spread 10 category three traded expectation = 2.277533
# 14:00~14:30 bid1 spread 5 category three MDD = 1.345254
# 14:00~14:30 bid1 spread 10 category three MDD = 2.167401
# 14:00~14:30 bid1 spread 5 category three traded time = 535.352131
# 14:00~14:30 bid1 spread 10 category three traded time = 760.740085
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.485242
# 14:00~14:30 bid1 spread 5 category four traded expectation = 0.814640
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.064516
# 14:00~14:30 bid1 spread 10 category four traded expectation = 0.500000
# 14:00~14:30 bid1 spread 5 category four MDD = 1.455726
# 14:00~14:30 bid1 spread 10 category four MDD = 0.193548
# 14:00~14:30 bid1 spread 5 category four traded time = 538.879574
# 14:00~14:30 bid1 spread 10 category four traded time = 68.322580
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.496409
# 14:00~14:30 bid1 spread 5 category five traded expectation = 0.791741
# 14:00~14:30 bid1 spread 10 category five traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category five traded expectation = 0.000000
# 14:00~14:30 bid1 spread 5 category five MDD = 1.489228
# 14:00~14:30 bid1 spread 10 category five MDD = 0.000000
# 14:00~14:30 bid1 spread 5 category five traded time = 509.465888
# 14:00~14:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 804
# Spread 10 and Category One = 14
# Spread 5 and Category Two= 630
# Spread 10 and Category Two = 64
# Spread 5 and Category Three = 934
# Spread 10 and Category Three = 103
# Spread 5 and Category Four = 561
# Spread 10 and Category Four = 51
# Spread 5 and Category Five = 606
# Spread 10 and Category Five = 0
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.669154
# 14:30~15:00 bid1 spread 5 category one traded expectation = 1.621891
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category one traded expectation = 1.000000
# 14:30~15:00 bid1 spread 5 category one MDD = 1.337065
# 14:30~15:00 bid1 spread 10 category one MDD = 0.000000
# 14:30~15:00 bid1 spread 5 category one traded time = 2335.299748
# 14:30~15:00 bid1 spread 10 category one traded time = 0.000000
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.592063
# 14:30~15:00 bid1 spread 5 category two traded expectation = 1.425397
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.062500
# 14:30~15:00 bid1 spread 10 category two traded expectation = 1.765625
# 14:30~15:00 bid1 spread 5 category two MDD = 1.184127
# 14:30~15:00 bid1 spread 10 category two MDD = 0.187500
# 14:30~15:00 bid1 spread 5 category two traded time = 1789.082537
# 14:30~15:00 bid1 spread 10 category two traded time = 29.500000
# 14:30~15:00 bid1 spread 5 category three traded probability = 0.490364
# 14:30~15:00 bid1 spread 5 category three traded expectation = 1.153105
# 14:30~15:00 bid1 spread 10 category three traded probability = 0.330097
# 14:30~15:00 bid1 spread 10 category three traded expectation = 1.737864
# 14:30~15:00 bid1 spread 5 category three MDD = 0.980728
# 14:30~15:00 bid1 spread 10 category three MDD = 0.980583
# 14:30~15:00 bid1 spread 5 category three traded time = 1025.938971
# 14:30~15:00 bid1 spread 10 category three traded time = 141.203882
# 14:30~15:00 bid1 spread 5 category four traded probability = 0.210339
# 14:30~15:00 bid1 spread 5 category four traded expectation = 0.679144
# 14:30~15:00 bid1 spread 10 category four traded probability = 0.156863
# 14:30~15:00 bid1 spread 10 category four traded expectation = 1.549020
# 14:30~15:00 bid1 spread 5 category four MDD = 0.420677
# 14:30~15:00 bid1 spread 10 category four MDD = 0.470588
# 14:00~15:00 bid1 spread 5 category four traded time = 486.169340
# 14:00~15:00 bid1 spread 10 category four traded time = 67.058822
# 14:30~15:00 bid1 spread 5 category five traded probability = 0.108911
# 14:30~15:00 bid1 spread 5 category five traded expectation = 0.698020
# 14:30~15:00 bid1 spread 10 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = 0.000000
# 14:30~15:00 bid1 spread 5 category five MDD = 0.298680
# 14:30~15:00 bid1 spread 10 category five MDD = 0.000000
# 14:30~15:00 bid1 spread 5 category five traded time = 88.252475
# 14:30~15:00 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 90
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 378
# Spread 10 and Category Two = 19
# Spread 5 and Category Three = 366
# Spread 10 and Category Three = 55
# Spread 5 and Category Four = 271
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 241
# Spread 10 and Category Five = 7
# 15:00~15:30 bid1 spread 5 category one traded probability = 0.755556
# 15:00~15:30 bid1 spread 5 category one traded expectation = 1.688889
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category one MDD = 1.511111
# 15:00~15:30 bid1 spread 10 category one MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category one traded time = 2405.877751
# 15:00~15:30 bid1 spread 10 category one traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 0.293651
# 15:00~15:30 bid1 spread 5 category two traded expectation = 0.658730
# 15:00~15:30 bid1 spread 10 category two traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = 2.000000
# 15:00~15:30 bid1 spread 5 category two MDD = 0.587302
# 15:00~15:30 bid1 spread 10 category two MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded time = 936.269839
# 15:00~15:30 bid1 spread 10 category two traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category three traded probability = 0.180328
# 15:00~15:30 bid1 spread 5 category three traded expectation = 0.849727
# 15:00~15:30 bid1 spread 10 category three traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category three traded expectation = 1.363636
# 15:00~15:30 bid1 spread 5 category three MDD = 0.360656
# 15:00~15:30 bid1 spread 10 category three MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category three traded time = 574.401638
# 15:00~15:30 bid1 spread 10 category three traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded probability = 0.059041
# 15:00~15:30 bid1 spread 5 category four traded expectation = 0.815498
# 15:00~15:30 bid1 spread 10 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category four MDD = 0.118081
# 15:00~15:30 bid1 spread 10 category four MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded time = 185.309962
# 15:00~15:30 bid1 spread 10 category four traded time = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded probability = 0.029046
# 15:00~15:30 bid1 spread 5 category five traded expectation = 0.792531
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 1.000000
# 15:00~15:30 bid1 spread 5 category five MDD = 0.058091
# 15:00~15:30 bid1 spread 10 category five MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded time = 90.946058
# 15:00~15:30 bid1 spread 10 category five traded time = 0.000000
#
# Spread 5 and Category One = 105
# Spread 10 and Category One = 31
# Spread 5 and Category Two= 10
# Spread 10 and Category Two = 51
# Spread 5 and Category Three = 13
# Spread 10 and Category Three = 19
# Spread 5 and Category Four = 15
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 66
# Spread 10 and Category Five = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 0.390476
# 15:30~16:00 bid1 spread 5 category one traded expectation = 1.390476
# 15:30~16:00 bid1 spread 10 category one traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = 2.000000
# 15:30~16:00 bid1 spread 5 category one MDD = 0.780952
# 15:30~16:00 bid1 spread 10 category one MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category one traded time = 120.361904
# 15:30~16:00 bid1 spread 10 category one traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded expectation = 1.117647
# 15:30~16:00 bid1 spread 5 category two MDD = 0.000000
# 15:30~16:00 bid1 spread 10 category two MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category two traded time = 0.000000
# 15:30~16:00 bid1 spread 10 category two traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 1.000000
# 15:30~16:00 bid1 spread 5 category three MDD = 0.000000
# 15:30~16:00 bid1 spread 10 category three MDD = 0.000000
# 15:30~16:30 bid1 spread 5 category three traded time = 0.000000
# 15:30~16:30 bid1 spread 10 category three traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded expectation = 0.800000
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four MDD = 0.000000
# 15:30~16:00 bid1 spread 10 category four MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded time = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded time = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.151515
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five MDD = 0.000000
# 15:30~16:00 bid1 spread 10 category five MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded time = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded time = 0.000000

# %%
data_trade_timestamp[len(data_trade_timestamp)-1]
# Out:
# '2014-01-02D16:00:00.024493700'

# %%
#2014-01-02 close price = 7030
#0.6177
#0.8696
#1.0678
#1.3835
#category = 0.7 0.9 1.1 1.3
def bid_stat_time_spread_divid_category(Bid1,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price,data_trade_timestamp):
    
    Bid1_traded_spr5_category_one = 0
    Bid1_traded_expected_spr5_category_one = 0
    Bid1_traded_spr10_category_one = 0
    Bid1_traded_expected_spr10_category_one = 0
    N_spr5_category_one = 0
    N_spr10_category_one = 0
    MDD_traded_spr5_category_one = 0
    MDD_traded_spr10_category_one = 0
    traded_time_spr5_category_one = 0
    traded_time_spr10_category_one = 0
    N_spr5_category_one_traded = 0
    N_spr10_category_one_traded = 0
    traded_time_spr5_category_one_traded = 0
    traded_time_spr10_category_one_traded = 0
    
    Bid1_traded_spr5_category_two = 0
    Bid1_traded_expected_spr5_category_two = 0
    Bid1_traded_spr10_category_two = 0
    Bid1_traded_expected_spr10_category_two = 0
    N_spr5_category_two = 0
    N_spr10_category_two = 0
    MDD_traded_spr5_category_two = 0
    MDD_traded_spr10_category_two = 0
    traded_time_spr5_category_two = 0
    traded_time_spr10_category_two = 0
    N_spr5_category_two_traded = 0
    N_spr10_category_two_traded = 0
    traded_time_spr5_category_two_traded = 0
    traded_time_spr10_category_two_traded = 0
    
    Bid1_traded_spr5_category_three = 0
    Bid1_traded_expected_spr5_category_three = 0
    Bid1_traded_spr10_category_three = 0
    Bid1_traded_expected_spr10_category_three = 0
    N_spr5_category_three = 0
    N_spr10_category_three = 0
    MDD_traded_spr5_category_three = 0
    MDD_traded_spr10_category_three = 0
    traded_time_spr5_category_three = 0
    traded_time_spr10_category_three = 0
    N_spr5_category_three_traded = 0
    N_spr10_category_three_traded = 0
    traded_time_spr5_category_three_traded = 0
    traded_time_spr10_category_three_traded = 0
    
    Bid1_traded_spr5_category_four = 0
    Bid1_traded_expected_spr5_category_four = 0
    Bid1_traded_spr10_category_four = 0
    Bid1_traded_expected_spr10_category_four = 0
    N_spr5_category_four = 0
    N_spr10_category_four = 0
    MDD_traded_spr5_category_four = 0
    MDD_traded_spr10_category_four = 0
    traded_time_spr5_category_four = 0
    traded_time_spr10_category_four = 0
    N_spr5_category_four_traded = 0
    N_spr10_category_four_traded = 0
    traded_time_spr5_category_four_traded = 0
    traded_time_spr10_category_four_traded = 0
  
    Bid1_traded_spr5_category_five = 0
    Bid1_traded_expected_spr5_category_five = 0
    Bid1_traded_spr10_category_five = 0
    Bid1_traded_expected_spr10_category_five = 0
    N_spr5_category_five = 0
    N_spr10_category_five = 0
    MDD_traded_spr5_category_five = 0
    MDD_traded_spr10_category_five = 0    
    traded_time_spr5_category_five = 0
    traded_time_spr10_category_five = 0    
    N_spr5_category_five_traded = 0
    N_spr10_category_five_traded = 0
    traded_time_spr5_category_five_traded = 0
    traded_time_spr10_category_five_traded = 0
  
    ###one week
    #divid_weighted_five_categories = divid_weighted_five_category(Bid1_Quantity,Bid2_Quantity,Bid3_Quantity,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity,weight1,weight2,weight3)

    #print divid_weighted_five_categories

    for i in range(0,data_trade_time_series_1530_1600,1):
        #print i
        #print Bid1[i]
        #print min_Ask1_time_series[i+1]
        weighted_Bid = Bid1_Quantity[i] * weight1 + Bid2_Quantity[i] * weight2 + Bid3_Quantity[i] * weight3
        weighted_Ask = Ask1_Quantity[i] * weight1 + Ask2_Quantity[i] * weight2 + Ask3_Quantity[i] * weight3  
        #print weighted_Bid
        #print weighted_Ask
        #print (weighted_Bid*(1.0) / weighted_Ask)
        #print '\t'
        if (weighted_Bid*(1.0) / weighted_Ask) <= 0.7:#divid_weighted_five_categories[0]:  
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_one = N_spr5_category_one + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_one = Bid1_traded_spr5_category_one + 1
                    Bid1_traded_expected_spr5_category_one = Bid1_traded_expected_spr5_category_one + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_one = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_one 
                    #print MDD_traded_spr5_category_one
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_one = traded_time_spr5_category_one + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_one
                    
                    N_spr5_category_one_traded = N_spr5_category_one_traded + 1
                    #print N_spr5_category_one_traded
                    traded_time_spr5_category_one_traded = traded_time_spr5_category_one_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_one_traded
                else:
                    Bid1_traded_expected_spr5_category_one = Bid1_traded_expected_spr5_category_one + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
                    MDD_traded_spr5_category_one = MDD_traded_spr5_category_one + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    #print MDD_traded_spr5_category_one
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr5_category_one = traded_time_spr5_category_one + (time_traded_second - time_start_second)

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_one = N_spr10_category_one + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr10_category_one = Bid1_traded_spr10_category_one + 1
                    Bid1_traded_expected_spr10_category_one = Bid1_traded_expected_spr10_category_one + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_one = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_one
                    #print MDD_traded_spr10_category_one
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_one = traded_time_spr10_category_one + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_one
                    
                    N_spr10_category_one_traded = N_spr10_category_one_traded + 1
                    #print N_spr10_category_one_traded
                    traded_time_spr10_category_one_traded = traded_time_spr10_category_one_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_one_traded
                else:
                    Bid1_traded_expected_spr10_category_one = Bid1_traded_expected_spr10_category_one + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
                    MDD_traded_spr10_category_one = MDD_traded_spr10_category_one + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    #print MDD_traded_spr10_category_one
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr10_category_one = traded_time_spr10_category_one + (time_traded_second - time_start_second)

            else:
                pass

        elif 0.7 < (weighted_Bid*(1.0) / weighted_Ask) <= 0.9:#divid_weighted_five_categories[1]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_two = N_spr5_category_two + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_two = Bid1_traded_spr5_category_two + 1
                    Bid1_traded_expected_spr5_category_two = Bid1_traded_expected_spr5_category_two + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_two = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_two 
                    #print MDD_traded_spr5_category_two              
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_two = traded_time_spr5_category_two + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_two
                    
                    N_spr5_category_two_traded = N_spr5_category_two_traded + 1
                    #print N_spr5_category_two_traded
                    traded_time_spr5_category_two_traded = traded_time_spr5_category_two_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_two_traded
                else:
                    Bid1_traded_expected_spr5_category_two = Bid1_traded_expected_spr5_category_two + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
                    MDD_traded_spr5_category_two = MDD_traded_spr5_category_two + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    #print MDD_traded_spr5_category_two  
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr5_category_two = traded_time_spr5_category_two + (time_traded_second - time_start_second)

                    
            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_two = N_spr10_category_two + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr10_category_two = Bid1_traded_spr10_category_two + 1
                    Bid1_traded_expected_spr10_category_two = Bid1_traded_expected_spr10_category_two + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_two = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_two 
                    #print MDD_traded_spr10_category_two                 
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_two = traded_time_spr10_category_two + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_two
                    
                    N_spr10_category_two_traded = N_spr10_category_two_traded + 1
                    #print N_spr10_category_two_traded
                    traded_time_spr10_category_two_traded = traded_time_spr10_category_two_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_two_traded
                else:
                    Bid1_traded_expected_spr10_category_two = Bid1_traded_expected_spr10_category_two + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
                    MDD_traded_spr10_category_two = MDD_traded_spr10_category_two + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr10_category_two = traded_time_spr10_category_two + (time_traded_second - time_start_second)
            else:
                pass    

        elif 0.9 < (weighted_Bid*(1.0) / weighted_Ask) <= 1.1:#divid_weighted_five_categories[2]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_three = N_spr5_category_three + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_three = Bid1_traded_spr5_category_three + 1
                    Bid1_traded_expected_spr5_category_three = Bid1_traded_expected_spr5_category_three + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_three = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_three 
                    #print MDD_traded_spr5_category_three    
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_three = traded_time_spr5_category_three + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_three
                    
                    N_spr5_category_three_traded = N_spr5_category_three_traded + 1
                    #print N_spr5_category_three_traded
                    traded_time_spr5_category_three_traded = traded_time_spr5_category_three_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_three_traded
                    
                else:
                    Bid1_traded_expected_spr5_category_three = Bid1_traded_expected_spr5_category_three + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
                    MDD_traded_spr5_category_three = MDD_traded_spr5_category_three + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr5_category_three = traded_time_spr5_category_three + (time_traded_second - time_start_second)

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_three = N_spr10_category_three + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_three = Bid1_traded_spr10_category_three + 1
                    Bid1_traded_expected_spr10_category_three = Bid1_traded_expected_spr10_category_three + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_three = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_three 
                    #print MDD_traded_spr10_category_three               
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_three = traded_time_spr10_category_three + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_three
                    
                    N_spr10_category_three_traded = N_spr10_category_three_traded + 1
                    #print N_spr10_category_three_traded
                    traded_time_spr10_category_three_traded = traded_time_spr10_category_three_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_three_traded
                    
                    
                else:
                    Bid1_traded_expected_spr10_category_three = Bid1_traded_expected_spr10_category_three + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_three)
                    MDD_traded_spr10_category_three = MDD_traded_spr10_category_three + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr10_category_three = traded_time_spr10_category_three + (time_traded_second - time_start_second)
            else:
                pass    

        elif 1.1 < (weighted_Bid*(1.0) / weighted_Ask) <= 1.3:#divid_weighted_five_categories[3]:
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_four = N_spr5_category_four + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_four = Bid1_traded_spr5_category_four + 1
                    Bid1_traded_expected_spr5_category_four = Bid1_traded_expected_spr5_category_four + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_four = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_four 
                    #print MDD_traded_spr5_category_four
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_four = traded_time_spr5_category_four + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_four
                    
                    N_spr5_category_four_traded = N_spr5_category_four_traded + 1
                    #print N_spr5_category_three_traded
                    traded_time_spr5_category_four_traded = traded_time_spr5_category_four_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_three_traded
                    
                else:
                    Bid1_traded_expected_spr5_category_four = Bid1_traded_expected_spr5_category_four + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
                    MDD_traded_spr5_category_four = MDD_traded_spr5_category_four + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr5_category_four = traded_time_spr5_category_four + (time_traded_second - time_start_second)

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_four = N_spr10_category_four + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_four = Bid1_traded_spr10_category_four + 1
                    Bid1_traded_expected_spr10_category_four = Bid1_traded_expected_spr10_category_four + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_four = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_four 
                    #print MDD_traded_spr10_category_four 
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_four = traded_time_spr10_category_four + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_four
                    
                    N_spr10_category_four_traded = N_spr10_category_four_traded + 1
                    #print N_spr5_category_three_traded
                    traded_time_spr10_category_four_traded = traded_time_spr10_category_four_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_three_traded
                    
                else:
                    Bid1_traded_expected_spr10_category_four = Bid1_traded_expected_spr10_category_four + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_four)
                    MDD_traded_spr10_category_four = MDD_traded_spr10_category_four + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr10_category_four = traded_time_spr10_category_four + (time_traded_second - time_start_second)
            else:
                pass    

        elif 1.30 < (weighted_Bid*(1.0) / weighted_Ask): 
            if bid1_ask1_spread[i] == 5:
                N_spr5_category_five = N_spr5_category_five + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1_traded
                    Bid1_traded_spr5_category_five = Bid1_traded_spr5_category_five + 1
                    Bid1_traded_expected_spr5_category_five = Bid1_traded_expected_spr5_category_five + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr5_category_five = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr5_category_five 
                    #print MDD_traded_spr5_category_five
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr5_category_five = traded_time_spr5_category_five + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_five
                    
                    N_spr5_category_five_traded = N_spr5_category_five_traded + 1
                    #print N_spr5_category_five_traded
                    traded_time_spr5_category_five_traded = traded_time_spr5_category_five_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr5_category_five_traded
                    
                else:
                    Bid1_traded_expected_spr5_category_five = Bid1_traded_expected_spr5_category_five + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print Bid1_traded_expected
                    MDD_traded_spr5_category_five = MDD_traded_spr5_category_five + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr5_category_five = traded_time_spr5_category_five + (time_traded_second - time_start_second)

            elif bid1_ask1_spread[i] == 10:
                N_spr10_category_five = N_spr10_category_five + 1
                if Bid1[i] > min_Ask1_time_series[i+1]: 
                    #print 'trade = %d'%(i)
                    #print Bid1[i]
                    #print Ask1[i]
                    Bid1_traded_spr10_category_five = Bid1_traded_spr10_category_five + 1
                    Bid1_traded_expected_spr10_category_five = Bid1_traded_expected_spr10_category_five + (Ask1[i] - Bid1[i])*(1.0)/(5.0)
                    #print 'a1 = %f'%(Bid1_traded_expected_spr10_category_four)
                    first_min_index = np.where(np.array(Ask1[(i+1):]) < Bid1[i])[0][1]
                    #print first_min_index
                    MDD_traded_spr10_category_five = (max(Ask1[(i+1):(i+1+first_min_index)]) - Bid1[i])*(1.0)/(5.0) + MDD_traded_spr10_category_five 
                    #print MDD_traded_spr10_category_five 
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[i + first_min_index]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    #print time_start
                    #print time_traded
                    #print time_start_second
                    #print time_traded_second
                    traded_time_spr10_category_five = traded_time_spr10_category_five + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_five
                    
                    N_spr10_category_five_traded = N_spr10_category_five_traded + 1
                    #print N_spr5_category_five_traded
                    traded_time_spr10_category_five_traded = traded_time_spr10_category_five_traded + (time_traded_second - time_start_second)
                    #print traded_time_spr10_category_five_traded
                else:
                    Bid1_traded_expected_spr10_category_five = Bid1_traded_expected_spr10_category_five + (Ask1[i] - Close_Price)*(1.0)/(5.0)
                    #print 'a2 = %f'%(Bid1_traded_expected_spr10_category_four)
                    MDD_traded_spr10_category_five = MDD_traded_spr10_category_five + (max(Ask1[(i+1):]) - Bid1[i])*(1.0)/(5.0)
                    time_start = data_trade_timestamp[i]
                    time_traded = data_trade_timestamp[len(data_trade_timestamp)-1]
                    time_traded_second = float(time_traded[11])*36000 + float(time_traded[12])*3600 \
                                       + float(time_traded[14])*600 + float(time_traded[15])*60\
                                       + float(time_traded[17])*10 + float(time_traded[18])
                    time_start_second = float(time_start[11])*36000 + float(time_start[12])*3600 \
                                      + float(time_start[14])*600 + float(time_start[15])*60\
                                      + float(time_start[17])*10 + float(time_start[18])
                    traded_time_spr10_category_five = traded_time_spr10_category_five + (time_traded_second - time_start_second)
            else:
                pass    


        #print Bid1_traded_expected_spr10_category_three

        if i == data_trade_time_series_0900_0930 - 1:  

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
                 
            print '09:00~09:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:00~09:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '09:00~09:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '09:00~09:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '09:00~09:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/N_spr5_category_two)
            print '09:00~09:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/N_spr5_category_two)
            print '09:00~09:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/N_spr10_category_two)
            print '09:00~09:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/N_spr10_category_two)
            print '09:00~09:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '09:00~09:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '09:00~09:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '09:00~09:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '09:00~09:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/N_spr5_category_three)
            print '09:00~09:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/N_spr5_category_three)
            print '09:00~09:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/N_spr10_category_three)
            print '09:00~09:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/N_spr10_category_three)
            print '09:00~09:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '09:00~09:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '09:00~09:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '09:00~09:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
    
            print '09:00~09:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/N_spr5_category_four)
            print '09:00~09:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/N_spr5_category_four)
            print '09:00~09:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/N_spr10_category_four)
            print '09:00~09:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/N_spr10_category_four)
            print '09:00~09:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '09:00~09:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '09:00~09:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '09:00~09:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '09:00~09:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/N_spr5_category_five)
            print '09:00~09:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/N_spr5_category_five)
            print '09:00~09:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/N_spr10_category_five)
            print '09:00~09:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/N_spr10_category_five)
            print '09:00~09:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '09:00~09:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '09:00~09:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '09:00~09:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
    
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0        
            print '\t'        
            continue

        elif i == data_trade_time_series_0930_1000 - 1:   

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '09:30~10:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '09:30~10:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '09:30~10:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '09:30~10:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '09:30~10:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '09:30~10:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '09:30~10:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '09:30~10:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '09:30~10:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '09:30~10:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '09:30~10:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '09:30~10:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
    
            print '09:30~10:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '09:30~10:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '09:30~10:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '09:30~10:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '09:30~10:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '09:30~10:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '09:30~10:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '09:30~10:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
    
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0

            print '\t'        
            continue
        elif i == data_trade_time_series_1000_1030 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '10:00~10:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:00~10:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '10:00~10:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '10:00~10:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '10:00~10:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:00~10:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '10:00~10:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '10:00~10:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '10:00~10:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:00~10:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '10:00~10:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '10:00~10:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '10:00~10:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:00~10:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '10:00~10:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '10:00~10:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '10:00~10:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:00~10:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '10:00~10:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '10:00~10:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
    
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0  
            print '\t'
            continue
        elif i == data_trade_time_series_1030_1100 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '10:30~11:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '10:30~11:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '10:30~11:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '10:30~11:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '10:30~11:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '10:30~11:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '10:30~11:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '10:30~11:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '10:30~11:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:30~11:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '10:30~11:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:30~11:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '10:30~11:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '10:30~11:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '10:30~11:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '10:30~11:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '10:30~11:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '10:30~11:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '10:30~11:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '10:30~11:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '10:30~11:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '10:30~11:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '10:30~11:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '10:30~11:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
    
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0
            print '\t'
            continue

        elif i == data_trade_time_series_1100_1130 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '11:00~11:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:00~11:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '11:00~11:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '11:00~11:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '11:00~11:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:00~11:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '11:00~11:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '11:00~11:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '11:00~11:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:00~11:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '11:00~11:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '11:00~11:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '11:00~11:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:00~11:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '11:00~11:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '11:00~11:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '11:00~11:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:00~11:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '11:00~11:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '11:00~11:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
    
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0    

            print '\t'
            continue

        elif i == data_trade_time_series_1130_1200 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '11:30~12:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '11:30~12:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '11:30~12:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '11:30~12:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '11:30~12:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '11:30~12:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '11:30~12:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '11:30~12:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '11:30~12:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '11:30~12:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '11:30~12:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '11:30~12:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '11:30~12:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '11:30~12:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '11:30~12:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '11:30~12:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '11:30~12:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '11:30~12:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '11:30~12:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '11:30~12:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
    
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0    

            print '\t'
            continue
        elif i == data_trade_time_series_1200_1230 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '12:00~12:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:00~12:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '12:00~12:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '12:00~12:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '12:00~12:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:00~12:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '12:00~12:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '12:00~12:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '12:00~12:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:00~12:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '12:00~12:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '12:00~12:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '12:00~12:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:00~12:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '12:00~12:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '12:00~12:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
           
            print '12:00~12:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:00~12:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '12:00~12:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '12:00~12:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
         
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0
            print '\t'
            continue
        elif i == data_trade_time_series_1230_1300 - 1:

            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '12:30~13:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '12:30~13:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '12:30~13:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '12:30~13:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '12:30~13:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '12:30~13:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '12:30~13:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '12:30~13:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '12:30~13:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '12:30~13:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '12:30~13:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '12:30~13:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '12:30~13:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '12:30~13:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '12:30~13:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '12:30~13:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '12:30~13:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '12:30~13:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '12:30~13:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '12:00~13:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '12:00~13:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
           
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0
            print '\t'
            continue
        elif i == data_trade_time_series_1300_1330 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '13:00~13:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:00~13:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '13:00~13:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '13:00~13:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '13:00~13:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:00~13:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '13:00~13:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '13:30~13:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '13:30~13:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '13:00~13:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:00~13:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '13:00~13:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '13:00~13:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '13:00~13:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:00~13:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '13:00~13:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '13:00~13:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '13:00~13:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:00~13:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '13:00~13:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '13:00~13:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
    
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0
            print '\t'
            continue
        elif i == data_trade_time_series_1330_1400 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '13:30~14:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '13:30~14:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '13:30~14:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '13:30~14:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '13:30~14:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '13:30~14:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '13:30~14:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '13:30~14:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '13:30~14:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '13:30~14:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '13:30~14:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '13:30~14:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '13:30~14:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '13:30~14:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '13:30~14:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '13:30~14:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '13:30~14:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '13:30~14:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '13:30~14:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '13:30~14:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
    
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0
            print '\t'
            continue        
        elif i == data_trade_time_series_1400_1430 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '14:00~14:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:00~14:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '14:00~14:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '14:00~14:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '14:00~14:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:00~14:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '14:00~14:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '14:00~14:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '14:00~14:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:00~14:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '14:00~14:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '14:00~14:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '14:00~14:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:00~14:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '14:00~14:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '14:00~14:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '14:00~14:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:00~14:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '14:00~14:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '14:00~14:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
             
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0 
            print '\t'
            continue                                          
        elif i == data_trade_time_series_1430_1500 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '14:30~15:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '14:30~15:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '14:30~15:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '14:30~15:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '14:30~15:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '14:30~15:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '14:30~15:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '14:30~15:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '14:30~15:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '14:30~15:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '14:30~15:00 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '14:30~15:00 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '14:30~15:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '14:30~15:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '14:30~15:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '14:00~15:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '14:00~15:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '14:30~15:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '14:30~15:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '14:30~15:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '14:30~15:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
           
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0
            print '\t'
            continue 
        elif i == data_trade_time_series_1500_1530 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '15:00~15:30 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:00~15:30 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '15:00~15:30 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '15:00~15:30 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '15:00~15:30 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:00~15:30 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '15:00~15:30 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '15:00~15:30 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '15:00~15:30 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:00~15:30 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '15:00~15:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '15:00~15:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '15:00~15:30 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:00~15:30 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '15:00~15:30 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '15:00~15:30 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '15:00~15:30 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:00~15:30 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '15:00~15:30 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '15:00~15:30 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
    
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0
            print '\t'
            continue 
        elif i == data_trade_time_series_1530_1600 - 1:
            print 'Spread 5 and Category One = %d'%(N_spr5_category_one)
            print 'Spread 10 and Category One = %d'%(N_spr10_category_one)
            print 'Spread 5 and Category Two= %d'%(N_spr5_category_two)
            print 'Spread 10 and Category Two = %d'%(N_spr10_category_two)        
            print 'Spread 5 and Category Three = %d'%(N_spr5_category_three)
            print 'Spread 10 and Category Three = %d'%(N_spr10_category_three)
            print 'Spread 5 and Category Four = %d'%(N_spr5_category_four)
            print 'Spread 10 and Category Four = %d'%(N_spr10_category_four)
            print 'Spread 5 and Category Five = %d'%(N_spr5_category_five)
            print 'Spread 10 and Category Five = %d'%(N_spr10_category_five)
            print 'Spread 5 and Category One traded = %d'%(N_spr5_category_one_traded)
            print 'Spread 10 and Category One traded = %d'%(N_spr10_category_one_traded)
            print 'Spread 5 and Category two traded = %d'%(N_spr5_category_two_traded)
            print 'Spread 10 and Category two traded = %d'%(N_spr10_category_two_traded)
            print 'Spread 5 and Category three traded = %d'%(N_spr5_category_three_traded)
            print 'Spread 10 and Category three traded = %d'%(N_spr10_category_three_traded)
            print 'Spread 5 and Category four traded = %d'%(N_spr5_category_four_traded)
            print 'Spread 10 and Category four traded = %d'%(N_spr10_category_four_traded)
            print 'Spread 5 and Category five traded = %d'%(N_spr5_category_five_traded)
            print 'Spread 10 and Category five traded = %d'%(N_spr10_category_five_traded)
            
            print '15:30~16:00 bid1 spread 5 category one traded probability = %f'%(Bid1_traded_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 5 category one traded expectation = %f'%(Bid1_traded_expected_spr5_category_one*(1.0)/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded probability = %f'%(Bid1_traded_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded expectation = %f'%(Bid1_traded_expected_spr10_category_one*(1.0)/(N_spr10_category_one+0.000001))
            print '15:30~16:00 bid1 spread 5 category one MDD = %f'%(MDD_traded_spr5_category_one/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one MDD = %f'%(MDD_traded_spr10_category_one/(N_spr10_category_one+0.000001))
            print '15:30~16:00 bid1 spread 5 category one traded time = %f'%(traded_time_spr5_category_one/(N_spr5_category_one+0.000001))
            print '15:30~16:00 bid1 spread 10 category one traded time = %f'%(traded_time_spr10_category_one/(N_spr10_category_one+0.000001))
            print 'bid1 spread 5 category one traded time in market = %f'%(traded_time_spr5_category_one_traded/(N_spr5_category_one_traded+0.000001))
            print 'bid1 spread 10 category one traded time in market = %f'%(traded_time_spr10_category_one_traded/(N_spr10_category_one_traded+0.000001))
            
            print '15:30~16:00 bid1 spread 5 category two traded probability = %f'%(Bid1_traded_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 5 category two traded expectation = %f'%(Bid1_traded_expected_spr5_category_two*(1.0)/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded probability = %f'%(Bid1_traded_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded expectation = %f'%(Bid1_traded_expected_spr10_category_two*(1.0)/(N_spr10_category_two+0.000001))
            print '15:30~16:00 bid1 spread 5 category two MDD = %f'%(MDD_traded_spr5_category_two/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two MDD = %f'%(MDD_traded_spr10_category_two/(N_spr10_category_two+0.000001))
            print '15:30~16:00 bid1 spread 5 category two traded time = %f'%(traded_time_spr5_category_two/(N_spr5_category_two+0.000001))
            print '15:30~16:00 bid1 spread 10 category two traded time = %f'%(traded_time_spr10_category_two/(N_spr10_category_two+0.000001))
            print 'bid1 spread 5 category two traded time in market = %f'%(traded_time_spr5_category_two_traded/(N_spr5_category_two_traded+0.000001))
            print 'bid1 spread 10 category two traded time in market = %f'%(traded_time_spr10_category_two_traded/(N_spr10_category_two_traded+0.000001))
    
            print '15:30~16:00 bid1 spread 5 category three traded probability = %f'%(Bid1_traded_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 5 category three traded expectation = %f'%(Bid1_traded_expected_spr5_category_three*(1.0)/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three traded probability = %f'%(Bid1_traded_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three traded expectation = %f'%(Bid1_traded_expected_spr10_category_three*(1.0)/(N_spr10_category_three+0.000001))
            print '15:30~16:00 bid1 spread 5 category three MDD = %f'%(MDD_traded_spr5_category_three/(N_spr5_category_three+0.000001))
            print '15:30~16:00 bid1 spread 10 category three MDD = %f'%(MDD_traded_spr10_category_three/(N_spr10_category_three+0.000001))
            print '15:30~16:30 bid1 spread 5 category three traded time = %f'%(traded_time_spr5_category_three/(N_spr5_category_three+0.000001))
            print '15:30~16:30 bid1 spread 10 category three traded time = %f'%(traded_time_spr10_category_three/(N_spr10_category_three+0.000001))
            print 'bid1 spread 5 category three traded time in market = %f'%(traded_time_spr5_category_three_traded/(N_spr5_category_three_traded+0.000001))
            print 'bid1 spread 10 category three traded time in market = %f'%(traded_time_spr10_category_three_traded/(N_spr10_category_three_traded+0.000001))
          
            print '15:30~16:00 bid1 spread 5 category four traded probability = %f'%(Bid1_traded_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 5 category four traded expectation = %f'%(Bid1_traded_expected_spr5_category_four*(1.0)/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded probability = %f'%(Bid1_traded_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded expectation = %f'%(Bid1_traded_expected_spr10_category_four*(1.0)/(N_spr10_category_four+0.000001))
            print '15:30~16:00 bid1 spread 5 category four MDD = %f'%(MDD_traded_spr5_category_four/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four MDD = %f'%(MDD_traded_spr10_category_four/(N_spr10_category_four+0.000001))
            print '15:30~16:00 bid1 spread 5 category four traded time = %f'%(traded_time_spr5_category_four/(N_spr5_category_four+0.000001))
            print '15:30~16:00 bid1 spread 10 category four traded time = %f'%(traded_time_spr10_category_four/(N_spr10_category_four+0.000001))
            print 'bid1 spread 5 category four traded time in market = %f'%(traded_time_spr5_category_four_traded/(N_spr5_category_four_traded+0.000001))
            print 'bid1 spread 10 category four traded time in market = %f'%(traded_time_spr10_category_four_traded/(N_spr10_category_four_traded+0.000001))
    
            print '15:30~16:00 bid1 spread 5 category five traded probability = %f'%(Bid1_traded_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 5 category five traded expectation = %f'%(Bid1_traded_expected_spr5_category_five*(1.0)/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded probability = %f'%(Bid1_traded_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded expectation = %f'%(Bid1_traded_expected_spr10_category_five*(1.0)/(N_spr10_category_five+0.000001))
            print '15:30~16:00 bid1 spread 5 category five MDD = %f'%(MDD_traded_spr5_category_five/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five MDD = %f'%(MDD_traded_spr10_category_five/(N_spr10_category_five+0.000001))
            print '15:30~16:00 bid1 spread 5 category five traded time = %f'%(traded_time_spr5_category_five/(N_spr5_category_five+0.000001))
            print '15:30~16:00 bid1 spread 10 category five traded time = %f'%(traded_time_spr10_category_five/(N_spr10_category_five+0.000001))
            print 'bid1 spread 5 category five traded time in market = %f'%(traded_time_spr5_category_five_traded/(N_spr5_category_five_traded+0.000001))
            print 'bid1 spread 10 category five traded time in market = %f'%(traded_time_spr10_category_five_traded/(N_spr10_category_five_traded+0.000001))
            
            Bid1_traded_spr5_category_one = 0
            Bid1_traded_expected_spr5_category_one = 0
            Bid1_traded_spr10_category_one = 0
            Bid1_traded_expected_spr10_category_one = 0
            N_spr5_category_one = 0
            N_spr10_category_one = 0
            MDD_traded_spr5_category_one = 0
            MDD_traded_spr10_category_one = 0
            traded_time_spr5_category_one = 0
            traded_time_spr10_category_one = 0
            N_spr5_category_one_traded = 0
            N_spr10_category_one_traded = 0
            traded_time_spr5_category_one_traded = 0
            traded_time_spr10_category_one_traded = 0

            Bid1_traded_spr5_category_two = 0
            Bid1_traded_expected_spr5_category_two = 0
            Bid1_traded_spr10_category_two = 0
            Bid1_traded_expected_spr10_category_two = 0
            N_spr5_category_two = 0
            N_spr10_category_two = 0
            MDD_traded_spr5_category_two = 0
            MDD_traded_spr10_category_two = 0
            traded_time_spr5_category_two = 0
            traded_time_spr10_category_two = 0
            N_spr5_category_two_traded = 0
            N_spr10_category_two_traded = 0
            traded_time_spr5_category_two_traded = 0
            traded_time_spr10_category_two_traded = 0

            Bid1_traded_spr5_category_three = 0
            Bid1_traded_expected_spr5_category_three = 0
            Bid1_traded_spr10_category_three = 0
            Bid1_traded_expected_spr10_category_three = 0
            N_spr5_category_three = 0
            N_spr10_category_three = 0
            MDD_traded_spr5_category_three = 0
            MDD_traded_spr10_category_three = 0
            traded_time_spr5_category_three = 0
            traded_time_spr10_category_three = 0
            N_spr5_category_three_traded = 0
            N_spr10_category_three_traded = 0
            traded_time_spr5_category_three_traded = 0
            traded_time_spr10_category_three_traded = 0

            Bid1_traded_spr5_category_four = 0
            Bid1_traded_expected_spr5_category_four = 0
            Bid1_traded_spr10_category_four = 0
            Bid1_traded_expected_spr10_category_four = 0
            N_spr5_category_four = 0
            N_spr10_category_four = 0
            MDD_traded_spr5_category_four = 0
            MDD_traded_spr10_category_four = 0
            traded_time_spr5_category_four = 0
            traded_time_spr10_category_four = 0
            N_spr5_category_four_traded = 0
            N_spr10_category_four_traded = 0
            traded_time_spr5_category_four_traded = 0
            traded_time_spr10_category_four_traded = 0

            Bid1_traded_spr5_category_five = 0
            Bid1_traded_expected_spr5_category_five = 0
            Bid1_traded_spr10_category_five = 0
            Bid1_traded_expected_spr10_category_five = 0
            N_spr5_category_five = 0
            N_spr10_category_five = 0
            MDD_traded_spr5_category_five = 0
            MDD_traded_spr10_category_five = 0    
            traded_time_spr5_category_five = 0
            traded_time_spr10_category_five = 0    
            N_spr5_category_five_traded = 0
            N_spr10_category_five_traded = 0
            traded_time_spr5_category_five_traded = 0
            traded_time_spr10_category_five_traded = 0
            print '\t'
            continue

# %%
bid_stat_time_spread_divid_category(Bid1,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price,data_trade_timestamp)
# Out:
# Spread 5 and Category One = 849
# Spread 10 and Category One = 284
# Spread 5 and Category Two= 691
# Spread 10 and Category Two = 411
# Spread 5 and Category Three = 559
# Spread 10 and Category Three = 235
# Spread 5 and Category Four = 460
# Spread 10 and Category Four = 219
# Spread 5 and Category Five = 1234
# Spread 10 and Category Five = 356
# Spread 5 and Category One traded = 849
# Spread 10 and Category One traded = 284
# Spread 5 and Category two traded = 691
# Spread 10 and Category two traded = 411
# Spread 5 and Category three traded = 559
# Spread 10 and Category three traded = 235
# Spread 5 and Category four traded = 460
# Spread 10 and Category four traded = 219
# Spread 5 and Category five traded = 1234
# Spread 10 and Category five traded = 356
# 09:00~09:30 bid1 spread 5 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category one traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category one traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category one MDD = 2.738516
# 09:00~09:30 bid1 spread 10 category one MDD = 4.000000
# 09:00~09:30 bid1 spread 5 category one traded time = 459.421672
# 09:00~09:30 bid1 spread 10 category one traded time = 744.999997
# bid1 spread 5 category one traded time in market = 459.421672
# bid1 spread 10 category one traded time in market = 744.999997
# 09:00~09:30 bid1 spread 5 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category two traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category two traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category two MDD = 3.214182
# 09:00~09:30 bid1 spread 10 category two MDD = 3.586375
# 09:00~09:30 bid1 spread 5 category two traded time = 571.787264
# 09:00~09:30 bid1 spread 10 category two traded time = 641.087590
# bid1 spread 5 category two traded time in market = 571.787264
# bid1 spread 10 category two traded time in market = 641.087590
# 09:00~09:30 bid1 spread 5 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category three traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category three traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category three MDD = 3.228980
# 09:00~09:30 bid1 spread 10 category three MDD = 4.451064
# 09:00~09:30 bid1 spread 5 category three traded time = 595.860464
# 09:00~09:30 bid1 spread 10 category three traded time = 889.736166
# bid1 spread 5 category three traded time in market = 595.860464
# bid1 spread 10 category three traded time in market = 889.736166
# 09:00~09:30 bid1 spread 5 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category four traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category four traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category four MDD = 3.478261
# 09:00~09:30 bid1 spread 10 category four MDD = 5.625571
# 09:00~09:30 bid1 spread 5 category four traded time = 657.365216
# 09:00~09:30 bid1 spread 10 category four traded time = 1231.520542
# bid1 spread 5 category four traded time in market = 657.365216
# bid1 spread 10 category four traded time in market = 1231.520542
# 09:00~09:30 bid1 spread 5 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 5 category five traded expectation = 1.000000
# 09:00~09:30 bid1 spread 10 category five traded probability = 1.000000
# 09:00~09:30 bid1 spread 10 category five traded expectation = 2.000000
# 09:00~09:30 bid1 spread 5 category five MDD = 3.505673
# 09:00~09:30 bid1 spread 10 category five MDD = 4.036517
# 09:00~09:30 bid1 spread 5 category five traded time = 667.431928
# 09:00~09:30 bid1 spread 10 category five traded time = 732.870784
# bid1 spread 5 category five traded time in market = 667.431928
# bid1 spread 10 category five traded time in market = 732.870784
#
# Spread 5 and Category One = 1170
# Spread 10 and Category One = 91
# Spread 5 and Category Two= 1405
# Spread 10 and Category Two = 348
# Spread 5 and Category Three = 1461
# Spread 10 and Category Three = 271
# Spread 5 and Category Four = 902
# Spread 10 and Category Four = 189
# Spread 5 and Category Five = 2018
# Spread 10 and Category Five = 89
# Spread 5 and Category One traded = 1170
# Spread 10 and Category One traded = 91
# Spread 5 and Category two traded = 1405
# Spread 10 and Category two traded = 348
# Spread 5 and Category three traded = 1461
# Spread 10 and Category three traded = 271
# Spread 5 and Category four traded = 902
# Spread 10 and Category four traded = 189
# Spread 5 and Category five traded = 2018
# Spread 10 and Category five traded = 89
# 09:30~10:00 bid1 spread 5 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category one traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category one traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category one traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category one MDD = 1.470085
# 09:30~10:00 bid1 spread 10 category one MDD = 2.395604
# 09:30~10:00 bid1 spread 5 category one traded time = 179.951282
# 09:30~10:00 bid1 spread 10 category one traded time = 305.593403
# bid1 spread 5 category one traded time in market = 179.951282
# bid1 spread 10 category one traded time in market = 305.593403
# 09:30~10:00 bid1 spread 5 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category two traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category two traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category two traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category two MDD = 1.747331
# 09:30~10:00 bid1 spread 10 category two MDD = 2.660920
# 09:30~10:00 bid1 spread 5 category two traded time = 261.179359
# 09:30~10:00 bid1 spread 10 category two traded time = 524.520113
# bid1 spread 5 category two traded time in market = 261.179359
# bid1 spread 10 category two traded time in market = 524.520113
# 09:30~10:00 bid1 spread 5 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category three traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category three traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category three traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category three MDD = 1.865161
# 09:30~10:00 bid1 spread 10 category three MDD = 2.295203
# 09:30~10:00 bid1 spread 5 category three traded time = 246.380561
# 09:30~10:00 bid1 spread 10 category three traded time = 283.594095
# bid1 spread 5 category three traded time in market = 246.380561
# bid1 spread 10 category three traded time in market = 283.594095
# 09:30~10:00 bid1 spread 5 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category four traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category four traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category four traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category four MDD = 2.004435
# 09:30~10:00 bid1 spread 10 category four MDD = 2.343915
# 09:30~10:00 bid1 spread 5 category four traded time = 292.259423
# 09:30~10:00 bid1 spread 10 category four traded time = 211.984126
# bid1 spread 5 category four traded time in market = 292.259423
# bid1 spread 10 category four traded time in market = 211.984126
# 09:30~10:00 bid1 spread 5 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 5 category five traded expectation = 1.000000
# 09:30~10:00 bid1 spread 10 category five traded probability = 1.000000
# 09:30~10:00 bid1 spread 10 category five traded expectation = 2.000000
# 09:30~10:00 bid1 spread 5 category five MDD = 2.217542
# 09:30~10:00 bid1 spread 10 category five MDD = 2.157303
# 09:30~10:00 bid1 spread 5 category five traded time = 317.411794
# 09:30~10:00 bid1 spread 10 category five traded time = 133.808987
# bid1 spread 5 category five traded time in market = 317.411794
# bid1 spread 10 category five traded time in market = 133.808987
#
# Spread 5 and Category One = 1289
# Spread 10 and Category One = 20
# Spread 5 and Category Two= 1099
# Spread 10 and Category Two = 122
# Spread 5 and Category Three = 1327
# Spread 10 and Category Three = 326
# Spread 5 and Category Four = 826
# Spread 10 and Category Four = 348
# Spread 5 and Category Five = 2264
# Spread 10 and Category Five = 89
# Spread 5 and Category One traded = 1289
# Spread 10 and Category One traded = 20
# Spread 5 and Category two traded = 1099
# Spread 10 and Category two traded = 122
# Spread 5 and Category three traded = 1327
# Spread 10 and Category three traded = 326
# Spread 5 and Category four traded = 826
# Spread 10 and Category four traded = 348
# Spread 5 and Category five traded = 2264
# Spread 10 and Category five traded = 89
# 10:00~10:30 bid1 spread 5 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category one traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category one traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category one MDD = 2.595811
# 10:00~10:30 bid1 spread 10 category one MDD = 3.050000
# 10:00~10:30 bid1 spread 5 category one traded time = 611.067494
# 10:00~10:30 bid1 spread 10 category one traded time = 737.199963
# bid1 spread 5 category one traded time in market = 611.067494
# bid1 spread 10 category one traded time in market = 737.199963
# 10:00~10:30 bid1 spread 5 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category two traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category two traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category two traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category two MDD = 2.822566
# 10:00~10:30 bid1 spread 10 category two MDD = 3.639344
# 10:00~10:30 bid1 spread 5 category two traded time = 654.947224
# 10:00~10:30 bid1 spread 10 category two traded time = 802.385239
# bid1 spread 5 category two traded time in market = 654.947224
# bid1 spread 10 category two traded time in market = 802.385239
# 10:00~10:30 bid1 spread 5 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category three traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category three traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category three traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category three MDD = 2.731726
# 10:00~10:30 bid1 spread 10 category three MDD = 4.315951
# 10:00~10:30 bid1 spread 5 category three traded time = 571.822908
# 10:00~10:30 bid1 spread 10 category three traded time = 1163.711653
# bid1 spread 5 category three traded time in market = 571.822908
# bid1 spread 10 category three traded time in market = 1163.711653
# 10:00~10:30 bid1 spread 5 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category four traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category four traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category four traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category four MDD = 3.262712
# 10:00~10:30 bid1 spread 10 category four MDD = 3.778736
# 10:00~10:30 bid1 spread 5 category four traded time = 730.520580
# 10:00~10:30 bid1 spread 10 category four traded time = 942.554595
# bid1 spread 5 category four traded time in market = 730.520580
# bid1 spread 10 category four traded time in market = 942.554595
# 10:00~10:30 bid1 spread 5 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 5 category five traded expectation = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded probability = 1.000000
# 10:00~10:30 bid1 spread 10 category five traded expectation = 2.000000
# 10:00~10:30 bid1 spread 5 category five MDD = 3.517226
# 10:00~10:30 bid1 spread 10 category five MDD = 2.741573
# 10:00~10:30 bid1 spread 5 category five traded time = 786.328180
# 10:00~10:30 bid1 spread 10 category five traded time = 468.595500
# bid1 spread 5 category five traded time in market = 786.328180
# bid1 spread 10 category five traded time in market = 468.595500
#
# Spread 5 and Category One = 1505
# Spread 10 and Category One = 90
# Spread 5 and Category Two= 1505
# Spread 10 and Category Two = 157
# Spread 5 and Category Three = 1582
# Spread 10 and Category Three = 147
# Spread 5 and Category Four = 1189
# Spread 10 and Category Four = 202
# Spread 5 and Category Five = 1806
# Spread 10 and Category Five = 187
# Spread 5 and Category One traded = 1346
# Spread 10 and Category One traded = 90
# Spread 5 and Category two traded = 1341
# Spread 10 and Category two traded = 111
# Spread 5 and Category three traded = 1463
# Spread 10 and Category three traded = 113
# Spread 5 and Category four traded = 1103
# Spread 10 and Category four traded = 108
# Spread 5 and Category five traded = 1356
# Spread 10 and Category five traded = 181
# 10:30~11:00 bid1 spread 5 category one traded probability = 0.894352
# 10:30~11:00 bid1 spread 5 category one traded expectation = 0.424585
# 10:30~11:00 bid1 spread 10 category one traded probability = 1.000000
# 10:30~11:00 bid1 spread 10 category one traded expectation = 2.000000
# 10:30~11:00 bid1 spread 5 category one MDD = 4.217276
# 10:30~11:00 bid1 spread 10 category one MDD = 4.500000
# 10:30~11:00 bid1 spread 5 category one traded time = 3597.240529
# 10:30~11:00 bid1 spread 10 category one traded time = 1311.711097
# bid1 spread 5 category one traded time in market = 1805.800890
# bid1 spread 10 category one traded time in market = 1311.711097
# 10:30~11:00 bid1 spread 5 category two traded probability = 0.891030
# 10:30~11:00 bid1 spread 5 category two traded expectation = 0.380731
# 10:30~11:00 bid1 spread 10 category two traded probability = 0.707006
# 10:30~11:00 bid1 spread 10 category two traded expectation = 0.292994
# 10:30~11:00 bid1 spread 5 category two MDD = 3.614618
# 10:30~11:00 bid1 spread 10 category two MDD = 5.248408
# 10:30~11:00 bid1 spread 5 category two traded time = 3068.664450
# 10:30~11:00 bid1 spread 10 category two traded time = 5969.363019
# bid1 spread 5 category two traded time in market = 1149.586129
# bid1 spread 10 category two traded time in market = 678.504498
# 10:30~11:00 bid1 spread 5 category three traded probability = 0.924779
# 10:30~11:00 bid1 spread 5 category three traded expectation = 0.565107
# 10:30~11:00 bid1 spread 10 category three traded probability = 0.768707
# 10:30~11:00 bid1 spread 10 category three traded expectation = 0.714286
# 10:30~11:00 bid1 spread 5 category three MDD = 3.548673
# 10:30~11:00 bid1 spread 10 category three MDD = 4.061224
# 10:30~11:00 bid1 spread 5 category three traded time = 2850.431098
# 10:30~11:00 bid1 spread 10 category three traded time = 4465.999970
# bid1 spread 5 category three traded time in market = 1556.035542
# bid1 spread 10 category three traded time in market = 171.752211
# 10:30~11:00 bid1 spread 5 category four traded probability = 0.927670
# 10:30~11:00 bid1 spread 5 category four traded expectation = 0.585366
# 10:30~11:00 bid1 spread 10 category four traded probability = 0.534653
# 10:30~11:00 bid1 spread 10 category four traded expectation = 0.108911
# 10:30~11:00 bid1 spread 5 category four MDD = 2.803196
# 10:30~11:00 bid1 spread 10 category four MDD = 5.371287
# 10:30~11:00 bid1 spread 5 category four traded time = 1804.594616
# 10:30~11:00 bid1 spread 10 category four traded time = 8863.980154
# bid1 spread 5 category four traded time in market = 484.010879
# bid1 spread 10 category four traded time in market = 368.185182
# 10:30~11:00 bid1 spread 5 category five traded probability = 0.750831
# 10:30~11:00 bid1 spread 5 category five traded expectation = -0.426357
# 10:30~11:00 bid1 spread 10 category five traded probability = 0.967914
# 10:30~11:00 bid1 spread 10 category five traded expectation = 1.871658
# 10:30~11:00 bid1 spread 5 category five MDD = 4.205426
# 10:30~11:00 bid1 spread 10 category five MDD = 2.363636
# 10:30~11:00 bid1 spread 5 category five traded time = 4904.796786
# 10:30~11:00 bid1 spread 10 category five traded time = 744.256681
# bid1 spread 5 category five traded time in market = 318.209439
# bid1 spread 10 category five traded time in market = 153.569060
#
# Spread 5 and Category One = 1963
# Spread 10 and Category One = 50
# Spread 5 and Category Two= 1929
# Spread 10 and Category Two = 167
# Spread 5 and Category Three = 1801
# Spread 10 and Category Three = 58
# Spread 5 and Category Four = 1359
# Spread 10 and Category Four = 85
# Spread 5 and Category Five = 1143
# Spread 10 and Category Five = 69
# Spread 5 and Category One traded = 1956
# Spread 10 and Category One traded = 50
# Spread 5 and Category two traded = 1691
# Spread 10 and Category two traded = 167
# Spread 5 and Category three traded = 1630
# Spread 10 and Category three traded = 58
# Spread 5 and Category four traded = 1281
# Spread 10 and Category four traded = 85
# Spread 5 and Category five traded = 1066
# Spread 10 and Category five traded = 57
# 11:00~11:30 bid1 spread 5 category one traded probability = 0.996434
# 11:00~11:30 bid1 spread 5 category one traded expectation = 0.985736
# 11:00~11:30 bid1 spread 10 category one traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category one traded expectation = 2.000000
# 11:00~11:30 bid1 spread 5 category one MDD = 1.873663
# 11:00~11:30 bid1 spread 10 category one MDD = 3.220000
# 11:00~11:30 bid1 spread 5 category one traded time = 751.644931
# 11:00~11:30 bid1 spread 10 category one traded time = 472.739991
# bid1 spread 5 category one traded time in market = 695.395705
# bid1 spread 10 category one traded time in market = 472.739991
# 11:00~11:30 bid1 spread 5 category two traded probability = 0.876620
# 11:00~11:30 bid1 spread 5 category two traded expectation = 0.506480
# 11:00~11:30 bid1 spread 10 category two traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category two traded expectation = 2.000000
# 11:00~11:30 bid1 spread 5 category two MDD = 2.587351
# 11:00~11:30 bid1 spread 10 category two MDD = 3.000000
# 11:00~11:30 bid1 spread 5 category two traded time = 2554.216173
# 11:00~11:30 bid1 spread 10 category two traded time = 608.077841
# bid1 spread 5 category two traded time in market = 598.244825
# bid1 spread 10 category two traded time in market = 608.077841
# 11:00~11:30 bid1 spread 5 category three traded probability = 0.905053
# 11:00~11:30 bid1 spread 5 category three traded expectation = 0.620211
# 11:00~11:30 bid1 spread 10 category three traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category three traded expectation = 2.000000
# 11:00~11:30 bid1 spread 5 category three MDD = 2.863964
# 11:00~11:30 bid1 spread 10 category three MDD = 2.758621
# 11:00~11:30 bid1 spread 5 category three traded time = 4005.949470
# 11:00~11:30 bid1 spread 10 category three traded time = 680.482747
# bid1 spread 5 category three traded time in market = 2702.131287
# bid1 spread 10 category three traded time in market = 680.482747
# 11:00~11:30 bid1 spread 5 category four traded probability = 0.942605
# 11:00~11:30 bid1 spread 5 category four traded expectation = 0.770419
# 11:00~11:30 bid1 spread 10 category four traded probability = 1.000000
# 11:00~11:30 bid1 spread 10 category four traded expectation = 2.000000
# 11:00~11:30 bid1 spread 5 category four MDD = 2.713760
# 11:00~11:30 bid1 spread 10 category four MDD = 2.117647
# 11:00~11:30 bid1 spread 5 category four traded time = 3620.088298
# 11:00~11:30 bid1 spread 10 category four traded time = 369.164702
# bid1 spread 5 category four traded time in market = 2840.584697
# bid1 spread 10 category four traded time in market = 369.164702
# 11:00~11:30 bid1 spread 5 category five traded probability = 0.932633
# 11:00~11:30 bid1 spread 5 category five traded expectation = 0.730534
# 11:00~11:30 bid1 spread 10 category five traded probability = 0.826087
# 11:00~11:30 bid1 spread 10 category five traded expectation = 1.304348
# 11:00~11:30 bid1 spread 5 category five MDD = 2.503062
# 11:00~11:30 bid1 spread 10 category five MDD = 2.927536
# 11:00~11:30 bid1 spread 5 category five traded time = 1911.818896
# 11:00~11:30 bid1 spread 10 category five traded time = 3326.159372
# bid1 spread 5 category five traded time in market = 868.205440
# bid1 spread 10 category five traded time in market = 609.631568
#
# Spread 5 and Category One = 243
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 91
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 93
# Spread 10 and Category Three = 108
# Spread 5 and Category Four = 50
# Spread 10 and Category Four = 39
# Spread 5 and Category Five = 142
# Spread 10 and Category Five = 6
# Spread 5 and Category One traded = 243
# Spread 10 and Category One traded = 0
# Spread 5 and Category two traded = 91
# Spread 10 and Category two traded = 0
# Spread 5 and Category three traded = 24
# Spread 10 and Category three traded = 10
# Spread 5 and Category four traded = 0
# Spread 10 and Category four traded = 0
# Spread 5 and Category five traded = 6
# Spread 10 and Category five traded = 0
# 11:30~12:00 bid1 spread 5 category one traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category one traded expectation = 1.000000
# 11:30~12:00 bid1 spread 10 category one traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category one traded expectation = 0.000000
# 11:30~12:00 bid1 spread 5 category one MDD = 2.666667
# 11:30~12:00 bid1 spread 10 category one MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category one traded time = 5363.534957
# 11:30~12:00 bid1 spread 10 category one traded time = 0.000000
# bid1 spread 5 category one traded time in market = 5363.534957
# bid1 spread 10 category one traded time in market = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded probability = 1.000000
# 11:30~12:00 bid1 spread 5 category two traded expectation = 1.000000
# 11:30~12:00 bid1 spread 10 category two traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category two traded expectation = 0.000000
# 11:30~12:00 bid1 spread 5 category two MDD = 3.000000
# 11:30~12:00 bid1 spread 10 category two MDD = 0.000000
# 11:30~12:00 bid1 spread 5 category two traded time = 6368.230699
# 11:30~12:00 bid1 spread 10 category two traded time = 0.000000
# bid1 spread 5 category two traded time in market = 6368.230699
# bid1 spread 10 category two traded time in market = 0.000000
# 11:30~12:00 bid1 spread 5 category three traded probability = 0.258065
# 11:30~12:00 bid1 spread 5 category three traded expectation = -1.967742
# 11:30~12:00 bid1 spread 10 category three traded probability = 0.092593
# 11:30~12:00 bid1 spread 10 category three traded expectation = -1.629630
# 11:30~12:00 bid1 spread 5 category three MDD = 5.967742
# 11:30~12:00 bid1 spread 10 category three MDD = 6.629630
# 11:30~12:00 bid1 spread 5 category three traded time = 13022.376204
# 11:30~12:00 bid1 spread 10 category three traded time = 14148.286906
# bid1 spread 5 category three traded time in market = 6221.124741
# bid1 spread 10 category three traded time in market = 4831.299517
# 11:30~12:00 bid1 spread 5 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 5 category four traded expectation = -3.000000
# 11:30~12:00 bid1 spread 10 category four traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category four traded expectation = -2.000000
# 11:30~12:00 bid1 spread 5 category four MDD = 7.000000
# 11:30~12:00 bid1 spread 10 category four MDD = 7.000000
# 11:30~12:00 bid1 spread 5 category four traded time = 15190.159696
# 11:30~12:00 bid1 spread 10 category four traded time = 16139.897022
# bid1 spread 5 category four traded time in market = 0.000000
# bid1 spread 10 category four traded time in market = 0.000000
# 11:30~12:00 bid1 spread 5 category five traded probability = 0.042254
# 11:30~12:00 bid1 spread 5 category five traded expectation = -2.830986
# 11:30~12:00 bid1 spread 10 category five traded probability = 0.000000
# 11:30~12:00 bid1 spread 10 category five traded expectation = -2.000000
# 11:30~12:00 bid1 spread 5 category five MDD = 6.830986
# 11:30~12:00 bid1 spread 10 category five MDD = 6.999999
# 11:30~12:00 bid1 spread 5 category five traded time = 14806.535107
# 11:30~12:00 bid1 spread 10 category five traded time = 14601.997566
# bid1 spread 5 category five traded time in market = 4833.999194
# bid1 spread 10 category five traded time in market = 0.000000
#
# Spread 5 and Category One = 154
# Spread 10 and Category One = 83
# Spread 5 and Category Two= 78
# Spread 10 and Category Two = 0
# Spread 5 and Category Three = 37
# Spread 10 and Category Three = 0
# Spread 5 and Category Four = 20
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 0
# Spread 10 and Category Five = 0
# Spread 5 and Category One traded = 154
# Spread 10 and Category One traded = 83
# Spread 5 and Category two traded = 78
# Spread 10 and Category two traded = 0
# Spread 5 and Category three traded = 37
# Spread 10 and Category three traded = 0
# Spread 5 and Category four traded = 20
# Spread 10 and Category four traded = 0
# Spread 5 and Category five traded = 0
# Spread 10 and Category five traded = 0
# 12:00~12:30 bid1 spread 5 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category one traded expectation = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded probability = 1.000000
# 12:00~12:30 bid1 spread 10 category one traded expectation = 2.000000
# 12:00~12:30 bid1 spread 5 category one MDD = 1.181818
# 12:00~12:30 bid1 spread 10 category one MDD = 2.000000
# 12:00~12:30 bid1 spread 5 category one traded time = 1778.487001
# 12:00~12:30 bid1 spread 10 category one traded time = 3977.915615
# bid1 spread 5 category one traded time in market = 1778.487001
# bid1 spread 10 category one traded time in market = 3977.915615
# 12:00~12:30 bid1 spread 5 category two traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category two traded expectation = 1.000000
# 12:00~12:30 bid1 spread 10 category two traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category two traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category two MDD = 2.000000
# 12:00~12:30 bid1 spread 10 category two MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category two traded time = 3150.140985
# 12:00~12:30 bid1 spread 10 category two traded time = 0.000000
# bid1 spread 5 category two traded time in market = 3150.140985
# bid1 spread 10 category two traded time in market = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category three traded expectation = 1.000000
# 12:00~12:30 bid1 spread 10 category three traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category three traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category three MDD = 2.000000
# 12:00~12:30 bid1 spread 10 category three MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category three traded time = 3689.405306
# 12:00~12:30 bid1 spread 10 category three traded time = 0.000000
# bid1 spread 5 category three traded time in market = 3689.405306
# bid1 spread 10 category three traded time in market = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded probability = 1.000000
# 12:00~12:30 bid1 spread 5 category four traded expectation = 1.000000
# 12:00~12:30 bid1 spread 10 category four traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category four traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category four MDD = 2.000000
# 12:00~12:30 bid1 spread 10 category four MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category four traded time = 3888.999806
# 12:00~12:30 bid1 spread 10 category four traded time = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded probability = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded expectation = 0.000000
# 12:00~12:30 bid1 spread 5 category five MDD = 0.000000
# 12:00~12:30 bid1 spread 10 category five MDD = 0.000000
# 12:00~12:30 bid1 spread 5 category five traded time = 0.000000
# 12:00~12:30 bid1 spread 10 category five traded time = 0.000000
# bid1 spread 5 category five traded time in market = 0.000000
# bid1 spread 10 category five traded time in market = 0.000000
#
# Spread 5 and Category One = 152
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 28
# Spread 10 and Category Two = 6
# Spread 5 and Category Three = 2
# Spread 10 and Category Three = 11
# Spread 5 and Category Four = 0
# Spread 10 and Category Four = 66
# Spread 5 and Category Five = 228
# Spread 10 and Category Five = 0
# Spread 5 and Category One traded = 152
# Spread 10 and Category One traded = 0
# Spread 5 and Category two traded = 28
# Spread 10 and Category two traded = 6
# Spread 5 and Category three traded = 2
# Spread 10 and Category three traded = 11
# Spread 5 and Category four traded = 0
# Spread 10 and Category four traded = 66
# Spread 5 and Category five traded = 228
# Spread 10 and Category five traded = 0
# 12:30~13:00 bid1 spread 5 category one traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category one traded expectation = 1.000000
# 12:30~13:00 bid1 spread 10 category one traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category one traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category one MDD = 2.000000
# 12:30~13:00 bid1 spread 10 category one MDD = 0.000000
# 12:30~13:00 bid1 spread 5 category one traded time = 1969.447355
# 12:30~13:00 bid1 spread 10 category one traded time = 0.000000
# bid1 spread 5 category one traded time in market = 1969.447355
# bid1 spread 10 category one traded time in market = 0.000000
# 12:30~13:00 bid1 spread 5 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category two traded expectation = 1.000000
# 12:30~13:00 bid1 spread 10 category two traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category two traded expectation = 2.000000
# 12:30~13:00 bid1 spread 5 category two MDD = 2.000000
# 12:30~13:00 bid1 spread 10 category two MDD = 3.000000
# 12:30~13:00 bid1 spread 5 category two traded time = 2054.678498
# 12:30~13:00 bid1 spread 10 category two traded time = 1790.999702
# bid1 spread 5 category two traded time in market = 2054.678498
# bid1 spread 10 category two traded time in market = 1790.999702
# 12:30~13:00 bid1 spread 5 category three traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category three traded expectation = 1.000000
# 12:30~13:00 bid1 spread 10 category three traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category three traded expectation = 2.000000
# 12:30~13:00 bid1 spread 5 category three MDD = 1.999999
# 12:30~13:00 bid1 spread 10 category three MDD = 3.000000
# 12:30~13:00 bid1 spread 5 category three traded time = 1827.499086
# 12:30~13:00 bid1 spread 10 category three traded time = 1490.999864
# bid1 spread 5 category three traded time in market = 1827.499086
# bid1 spread 10 category three traded time in market = 1490.999864
# 12:30~13:00 bid1 spread 5 category four traded probability = 0.000000
# 12:30~13:00 bid1 spread 5 category four traded expectation = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded probability = 1.000000
# 12:30~13:00 bid1 spread 10 category four traded expectation = 2.000000
# 12:30~13:00 bid1 spread 5 category four MDD = 0.000000
# 12:30~13:00 bid1 spread 10 category four MDD = 3.000000
# 12:30~13:00 bid1 spread 5 category four traded time = 0.000000
# 12:30~13:00 bid1 spread 10 category four traded time = 2174.348452
# bid1 spread 5 category four traded time in market = 0.000000
# bid1 spread 10 category four traded time in market = 2174.348452
# 12:30~13:00 bid1 spread 5 category five traded probability = 1.000000
# 12:30~13:00 bid1 spread 5 category five traded expectation = 1.000000
# 12:30~13:00 bid1 spread 10 category five traded probability = 0.000000
# 12:30~13:00 bid1 spread 10 category five traded expectation = 0.000000
# 12:30~13:00 bid1 spread 5 category five MDD = 3.000000
# 12:30~13:00 bid1 spread 10 category five MDD = 0.000000
# 12:00~13:00 bid1 spread 5 category five traded time = 1349.087713
# 12:00~13:00 bid1 spread 10 category five traded time = 0.000000
# bid1 spread 5 category five traded time in market = 1349.087713
# bid1 spread 10 category five traded time in market = 0.000000
#
# Spread 5 and Category One = 993
# Spread 10 and Category One = 6
# Spread 5 and Category Two= 870
# Spread 10 and Category Two = 101
# Spread 5 and Category Three = 438
# Spread 10 and Category Three = 105
# Spread 5 and Category Four = 535
# Spread 10 and Category Four = 134
# Spread 5 and Category Five = 615
# Spread 10 and Category Five = 18
# Spread 5 and Category One traded = 908
# Spread 10 and Category One traded = 6
# Spread 5 and Category two traded = 789
# Spread 10 and Category two traded = 61
# Spread 5 and Category three traded = 401
# Spread 10 and Category three traded = 75
# Spread 5 and Category four traded = 403
# Spread 10 and Category four traded = 131
# Spread 5 and Category five traded = 367
# Spread 10 and Category five traded = 18
# 13:00~13:30 bid1 spread 5 category one traded probability = 0.914401
# 13:00~13:30 bid1 spread 5 category one traded expectation = 0.657603
# 13:00~13:30 bid1 spread 10 category one traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category one traded expectation = 2.000000
# 13:00~13:30 bid1 spread 5 category one MDD = 1.809668
# 13:00~13:30 bid1 spread 10 category one MDD = 2.000000
# 13:00~13:30 bid1 spread 5 category one traded time = 1241.259817
# 13:00~13:30 bid1 spread 10 category one traded time = 499.833250
# bid1 spread 5 category one traded time in market = 449.744493
# bid1 spread 10 category one traded time in market = 499.833250
# 13:00~13:30 bid1 spread 5 category two traded probability = 0.906897
# 13:00~13:30 bid1 spread 5 category two traded expectation = 0.627586
# 13:00~13:30 bid1 spread 10 category two traded probability = 0.603960
# 13:00~13:30 bid1 spread 10 category two traded expectation = 0.415842
# 13:00~13:30 bid1 spread 5 category two MDD = 2.021839
# 13:00~13:30 bid1 spread 10 category two MDD = 3.970297
# 13:30~13:30 bid1 spread 5 category two traded time = 1379.867815
# 13:30~13:30 bid1 spread 10 category two traded time = 4120.346494
# bid1 spread 5 category two traded time in market = 525.994930
# bid1 spread 10 category two traded time in market = 699.065562
# 13:00~13:30 bid1 spread 5 category three traded probability = 0.915525
# 13:00~13:30 bid1 spread 5 category three traded expectation = 0.662100
# 13:00~13:30 bid1 spread 10 category three traded probability = 0.714286
# 13:00~13:30 bid1 spread 10 category three traded expectation = 0.857143
# 13:00~13:30 bid1 spread 5 category three MDD = 2.130137
# 13:00~13:30 bid1 spread 10 category three MDD = 3.428571
# 13:00~13:30 bid1 spread 5 category three traded time = 1342.002280
# 13:00~13:30 bid1 spread 10 category three traded time = 3405.914253
# bid1 spread 5 category three traded time in market = 573.902742
# bid1 spread 10 category three traded time in market = 747.666657
# 13:00~13:30 bid1 spread 5 category four traded probability = 0.753271
# 13:00~13:30 bid1 spread 5 category four traded expectation = -0.061682
# 13:00~13:30 bid1 spread 10 category four traded probability = 0.977612
# 13:00~13:30 bid1 spread 10 category four traded expectation = 1.910448
# 13:00~13:30 bid1 spread 5 category four MDD = 3.054206
# 13:00~13:30 bid1 spread 10 category four MDD = 2.111940
# 13:00~13:30 bid1 spread 5 category four traded time = 2809.672892
# 13:00~13:30 bid1 spread 10 category four traded time = 1056.335813
# bid1 spread 5 category four traded time in market = 619.106698
# bid1 spread 10 category four traded time in market = 848.992360
# 13:00~13:30 bid1 spread 5 category five traded probability = 0.596748
# 13:00~13:30 bid1 spread 5 category five traded expectation = -0.647154
# 13:00~13:30 bid1 spread 10 category five traded probability = 1.000000
# 13:00~13:30 bid1 spread 10 category five traded expectation = 2.000000
# 13:00~13:30 bid1 spread 5 category five MDD = 4.026016
# 13:00~13:30 bid1 spread 10 category five MDD = 2.500000
# 13:00~13:30 bid1 spread 5 category five traded time = 4284.809749
# 13:00~13:30 bid1 spread 10 category five traded time = 1080.833273
# bid1 spread 5 category five traded time in market = 683.280652
# bid1 spread 10 category five traded time in market = 1080.833273
#
# Spread 5 and Category One = 773
# Spread 10 and Category One = 43
# Spread 5 and Category Two= 882
# Spread 10 and Category Two = 119
# Spread 5 and Category Three = 1128
# Spread 10 and Category Three = 221
# Spread 5 and Category Four = 614
# Spread 10 and Category Four = 34
# Spread 5 and Category Five = 955
# Spread 10 and Category Five = 2
# Spread 5 and Category One traded = 317
# Spread 10 and Category One traded = 0
# Spread 5 and Category two traded = 216
# Spread 10 and Category two traded = 21
# Spread 5 and Category three traded = 162
# Spread 10 and Category three traded = 10
# Spread 5 and Category four traded = 91
# Spread 10 and Category four traded = 0
# Spread 5 and Category five traded = 56
# Spread 10 and Category five traded = 0
# 13:30~14:00 bid1 spread 5 category one traded probability = 0.410091
# 13:30~14:00 bid1 spread 5 category one traded expectation = -0.600259
# 13:30~14:00 bid1 spread 10 category one traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category one traded expectation = -1.000000
# 13:30~14:00 bid1 spread 5 category one MDD = 3.781371
# 13:30~14:00 bid1 spread 10 category one MDD = 6.000000
# 13:30~14:00 bid1 spread 5 category one traded time = 4706.133241
# 13:30~14:00 bid1 spread 10 category one traded time = 8242.906785
# bid1 spread 5 category one traded time in market = 161.533123
# bid1 spread 10 category one traded time in market = 0.000000
# 13:30~14:00 bid1 spread 5 category two traded probability = 0.244898
# 13:30~14:00 bid1 spread 5 category two traded expectation = -1.488662
# 13:30~14:00 bid1 spread 10 category two traded probability = 0.176471
# 13:30~14:00 bid1 spread 10 category two traded expectation = -0.462185
# 13:30~14:00 bid1 spread 5 category two MDD = 5.043084
# 13:30~14:00 bid1 spread 10 category two MDD = 5.277311
# 13:30~14:00 bid1 spread 5 category two traded time = 6108.363939
# 13:30~14:00 bid1 spread 10 category two traded time = 6666.924314
# bid1 spread 5 category two traded time in market = 196.240740
# bid1 spread 10 category two traded time in market = 252.476178
# 13:30~14:00 bid1 spread 5 category three traded probability = 0.143617
# 13:30~14:00 bid1 spread 5 category three traded expectation = -1.960106
# 13:30~14:00 bid1 spread 10 category three traded probability = 0.045249
# 13:30~14:00 bid1 spread 10 category three traded expectation = -1.520362
# 13:30~14:00 bid1 spread 5 category three MDD = 5.675532
# 13:30~14:00 bid1 spread 10 category three MDD = 6.475113
# 13:30~14:00 bid1 spread 5 category three traded time = 6934.854604
# 13:30~14:00 bid1 spread 10 category three traded time = 7572.013540
# bid1 spread 5 category three traded time in market = 218.234567
# bid1 spread 10 category three traded time in market = 285.199971
# 13:30~14:00 bid1 spread 5 category four traded probability = 0.148208
# 13:30~14:00 bid1 spread 5 category four traded expectation = -1.649837
# 13:30~14:00 bid1 spread 10 category four traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category four traded expectation = -2.205882
# 13:30~14:00 bid1 spread 5 category four MDD = 5.355049
# 13:30~14:00 bid1 spread 10 category four MDD = 7.205882
# 13:30~14:00 bid1 spread 5 category four traded time = 6824.897383
# 13:30~14:00 bid1 spread 10 category four traded time = 8218.352699
# bid1 spread 5 category four traded time in market = 189.670328
# bid1 spread 10 category four traded time in market = 0.000000
# 13:30~14:00 bid1 spread 5 category five traded probability = 0.058639
# 13:30~14:00 bid1 spread 5 category five traded expectation = -2.300524
# 13:30~14:00 bid1 spread 10 category five traded probability = 0.000000
# 13:30~14:00 bid1 spread 10 category five traded expectation = 0.000000
# 13:30~14:00 bid1 spread 5 category five MDD = 6.217801
# 13:30~14:00 bid1 spread 10 category five MDD = 4.999998
# 13:30~14:00 bid1 spread 5 category five traded time = 7554.278526
# 13:30~14:00 bid1 spread 10 category five traded time = 7321.996339
# bid1 spread 5 category five traded time in market = 243.089281
# bid1 spread 10 category five traded time in market = 0.000000
#
# Spread 5 and Category One = 843
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 618
# Spread 10 and Category Two = 112
# Spread 5 and Category Three = 828
# Spread 10 and Category Three = 253
# Spread 5 and Category Four = 608
# Spread 10 and Category Four = 33
# Spread 5 and Category Five = 1242
# Spread 10 and Category Five = 0
# Spread 5 and Category One traded = 721
# Spread 10 and Category One traded = 0
# Spread 5 and Category two traded = 437
# Spread 10 and Category two traded = 99
# Spread 5 and Category three traded = 458
# Spread 10 and Category three traded = 167
# Spread 5 and Category four traded = 301
# Spread 10 and Category four traded = 2
# Spread 5 and Category five traded = 606
# Spread 10 and Category five traded = 0
# 14:00~14:30 bid1 spread 5 category one traded probability = 0.855279
# 14:00~14:30 bid1 spread 5 category one traded expectation = 0.855279
# 14:00~14:30 bid1 spread 10 category one traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category one traded expectation = 0.000000
# 14:00~14:30 bid1 spread 5 category one MDD = 1.655991
# 14:00~14:30 bid1 spread 10 category one MDD = 0.000000
# 14:00~14:30 bid1 spread 5 category one traded time = 1812.355870
# 14:00~14:30 bid1 spread 10 category one traded time = 0.000000
# bid1 spread 5 category one traded time in market = 916.101247
# bid1 spread 10 category one traded time in market = 0.000000
# 14:00~14:30 bid1 spread 5 category two traded probability = 0.707120
# 14:00~14:30 bid1 spread 5 category two traded expectation = 0.707120
# 14:00~14:30 bid1 spread 10 category two traded probability = 0.883929
# 14:00~14:30 bid1 spread 10 category two traded expectation = 1.883929
# 14:00~14:30 bid1 spread 5 category two MDD = 2.273463
# 14:00~14:30 bid1 spread 10 category two MDD = 2.276786
# 14:00~14:30 bid1 spread 5 category two traded time = 2874.663426
# 14:00~14:30 bid1 spread 10 category two traded time = 1502.767844
# bid1 spread 5 category two traded time in market = 1138.606405
# bid1 spread 10 category two traded time in market = 810.868679
# 14:00~14:30 bid1 spread 5 category three traded probability = 0.553140
# 14:00~14:30 bid1 spread 5 category three traded expectation = 0.536232
# 14:00~14:30 bid1 spread 10 category three traded probability = 0.660079
# 14:00~14:30 bid1 spread 10 category three traded expectation = 1.438735
# 14:00~14:30 bid1 spread 5 category three MDD = 2.946860
# 14:00~14:30 bid1 spread 10 category three MDD = 2.909091
# 14:00~14:30 bid1 spread 5 category three traded time = 3672.487918
# 14:00~14:30 bid1 spread 10 category three traded time = 3032.209474
# bid1 spread 5 category three traded time in market = 1134.600434
# bid1 spread 10 category three traded time in market = 978.730533
# 14:00~14:30 bid1 spread 5 category four traded probability = 0.495066
# 14:00~14:30 bid1 spread 5 category four traded expectation = 0.361842
# 14:00~14:30 bid1 spread 10 category four traded probability = 0.060606
# 14:00~14:30 bid1 spread 10 category four traded expectation = 0.363636
# 14:00~14:30 bid1 spread 5 category four MDD = 3.151316
# 14:00~14:30 bid1 spread 10 category four MDD = 4.575757
# 14:00~14:30 bid1 spread 5 category four traded time = 3967.332230
# 14:00~14:30 bid1 spread 10 category four traded time = 6695.272524
# bid1 spread 5 category four traded time in market = 1063.392023
# bid1 spread 10 category four traded time in market = 1254.999373
# 14:00~14:30 bid1 spread 5 category five traded probability = 0.487923
# 14:00~14:30 bid1 spread 5 category five traded expectation = 0.254428
# 14:00~14:30 bid1 spread 10 category five traded probability = 0.000000
# 14:00~14:30 bid1 spread 10 category five traded expectation = 0.000000
# 14:00~14:30 bid1 spread 5 category five MDD = 3.265700
# 14:00~14:30 bid1 spread 10 category five MDD = 0.000000
# 14:00~14:30 bid1 spread 5 category five traded time = 3996.213362
# 14:00~14:30 bid1 spread 10 category five traded time = 0.000000
# bid1 spread 5 category five traded time in market = 962.834982
# bid1 spread 10 category five traded time in market = 0.000000
#
# Spread 5 and Category One = 804
# Spread 10 and Category One = 14
# Spread 5 and Category Two= 654
# Spread 10 and Category Two = 65
# Spread 5 and Category Three = 1007
# Spread 10 and Category Three = 135
# Spread 5 and Category Four = 365
# Spread 10 and Category Four = 18
# Spread 5 and Category Five = 705
# Spread 10 and Category Five = 0
# Spread 5 and Category One traded = 766
# Spread 10 and Category One traded = 0
# Spread 5 and Category two traded = 545
# Spread 10 and Category two traded = 46
# Spread 5 and Category three traded = 645
# Spread 10 and Category three traded = 82
# Spread 5 and Category four traded = 177
# Spread 10 and Category four traded = 5
# Spread 5 and Category five traded = 535
# Spread 10 and Category five traded = 0
# 14:30~15:00 bid1 spread 5 category one traded probability = 0.952736
# 14:30~15:00 bid1 spread 5 category one traded expectation = 0.952736
# 14:30~15:00 bid1 spread 10 category one traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category one traded expectation = 1.000000
# 14:30~15:00 bid1 spread 5 category one MDD = 1.248756
# 14:30~15:00 bid1 spread 10 category one MDD = 3.000000
# 14:30~15:00 bid1 spread 5 category one traded time = 1200.909202
# 14:30~15:00 bid1 spread 10 category one traded time = 4721.213948
# bid1 spread 5 category one traded time in market = 1018.864228
# bid1 spread 10 category one traded time in market = 0.000000
# 14:30~15:00 bid1 spread 5 category two traded probability = 0.833333
# 14:30~15:00 bid1 spread 5 category two traded expectation = 0.833333
# 14:30~15:00 bid1 spread 10 category two traded probability = 0.707692
# 14:30~15:00 bid1 spread 10 category two traded expectation = 1.707692
# 14:30~15:00 bid1 spread 5 category two MDD = 1.418960
# 14:30~15:00 bid1 spread 10 category two MDD = 2.292308
# 14:30~15:00 bid1 spread 5 category two traded time = 1468.842505
# 14:30~15:00 bid1 spread 10 category two traded time = 3758.569173
# bid1 spread 5 category two traded time in market = 817.658714
# bid1 spread 10 category two traded time in market = 3369.326014
# 14:30~15:00 bid1 spread 5 category three traded probability = 0.640516
# 14:30~15:00 bid1 spread 5 category three traded expectation = 0.636544
# 14:30~15:00 bid1 spread 10 category three traded probability = 0.607407
# 14:30~15:00 bid1 spread 10 category three traded expectation = 1.511111
# 14:30~15:00 bid1 spread 5 category three MDD = 1.792453
# 14:30~15:00 bid1 spread 10 category three MDD = 2.481481
# 14:30~15:00 bid1 spread 5 category three traded time = 2213.945380
# 14:30~15:00 bid1 spread 10 category three traded time = 3157.837014
# bid1 spread 5 category three traded time in market = 791.620154
# bid1 spread 10 category three traded time in market = 2036.304853
# 14:30~15:00 bid1 spread 5 category four traded probability = 0.484932
# 14:30~15:00 bid1 spread 5 category four traded expectation = 0.432877
# 14:30~15:00 bid1 spread 10 category four traded probability = 0.277778
# 14:30~15:00 bid1 spread 10 category four traded expectation = 0.555556
# 14:30~15:00 bid1 spread 5 category four MDD = 2.243836
# 14:30~15:00 bid1 spread 10 category four MDD = 3.444444
# 14:00~15:00 bid1 spread 5 category four traded time = 3185.536978
# 14:00~15:00 bid1 spread 10 category four traded time = 4608.555300
# bid1 spread 5 category four traded time in market = 1535.548014
# bid1 spread 10 category four traded time in market = 3774.999245
# 14:30~15:00 bid1 spread 5 category five traded probability = 0.758865
# 14:30~15:00 bid1 spread 5 category five traded expectation = 0.595745
# 14:30~15:00 bid1 spread 10 category five traded probability = 0.000000
# 14:30~15:00 bid1 spread 10 category five traded expectation = 0.000000
# 14:30~15:00 bid1 spread 5 category five MDD = 2.306383
# 14:30~15:00 bid1 spread 10 category five MDD = 0.000000
# 14:30~15:00 bid1 spread 5 category five traded time = 3376.687938
# 14:30~15:00 bid1 spread 10 category five traded time = 0.000000
# bid1 spread 5 category five traded time in market = 2925.708406
# bid1 spread 10 category five traded time in market = 0.000000
#
# Spread 5 and Category One = 90
# Spread 10 and Category One = 0
# Spread 5 and Category Two= 390
# Spread 10 and Category Two = 19
# Spread 5 and Category Three = 374
# Spread 10 and Category Three = 55
# Spread 5 and Category Four = 204
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 288
# Spread 10 and Category Five = 7
# Spread 5 and Category One traded = 84
# Spread 10 and Category One traded = 0
# Spread 5 and Category two traded = 140
# Spread 10 and Category two traded = 19
# Spread 5 and Category three traded = 262
# Spread 10 and Category three traded = 20
# Spread 5 and Category four traded = 147
# Spread 10 and Category four traded = 0
# Spread 5 and Category five traded = 223
# Spread 10 and Category five traded = 0
# 15:00~15:30 bid1 spread 5 category one traded probability = 0.933333
# 15:00~15:30 bid1 spread 5 category one traded expectation = 0.933333
# 15:00~15:30 bid1 spread 10 category one traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category one traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category one MDD = 1.300000
# 15:00~15:30 bid1 spread 10 category one MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category one traded time = 919.899990
# 15:00~15:30 bid1 spread 10 category one traded time = 0.000000
# bid1 spread 5 category one traded time in market = 792.095229
# bid1 spread 10 category one traded time in market = 0.000000
# 15:00~15:30 bid1 spread 5 category two traded probability = 0.358974
# 15:00~15:30 bid1 spread 5 category two traded expectation = 0.358974
# 15:00~15:30 bid1 spread 10 category two traded probability = 1.000000
# 15:00~15:30 bid1 spread 10 category two traded expectation = 2.000000
# 15:00~15:30 bid1 spread 5 category two MDD = 2.351282
# 15:00~15:30 bid1 spread 10 category two MDD = 2.000000
# 15:00~15:30 bid1 spread 5 category two traded time = 2045.525636
# 15:00~15:30 bid1 spread 10 category two traded time = 2961.999844
# bid1 spread 5 category two traded time in market = 747.835709
# bid1 spread 10 category two traded time in market = 2961.999844
# 15:00~15:30 bid1 spread 5 category three traded probability = 0.700535
# 15:00~15:30 bid1 spread 5 category three traded expectation = 0.700535
# 15:00~15:30 bid1 spread 10 category three traded probability = 0.363636
# 15:00~15:30 bid1 spread 10 category three traded expectation = 1.363636
# 15:00~15:30 bid1 spread 5 category three MDD = 2.122995
# 15:00~15:30 bid1 spread 10 category three MDD = 2.636364
# 15:00~15:30 bid1 spread 5 category three traded time = 2277.695181
# 15:00~15:30 bid1 spread 10 category three traded time = 2925.109038
# bid1 spread 5 category three traded time in market = 2177.580144
# bid1 spread 10 category three traded time in market = 2997.449850
# 15:00~15:30 bid1 spread 5 category four traded probability = 0.720588
# 15:00~15:30 bid1 spread 5 category four traded expectation = 0.720588
# 15:00~15:30 bid1 spread 10 category four traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category four traded expectation = 0.000000
# 15:00~15:30 bid1 spread 5 category four MDD = 2.240196
# 15:00~15:30 bid1 spread 10 category four MDD = 0.000000
# 15:00~15:30 bid1 spread 5 category four traded time = 2551.142144
# 15:00~15:30 bid1 spread 10 category four traded time = 0.000000
# bid1 spread 5 category four traded time in market = 2743.333315
# bid1 spread 10 category four traded time in market = 0.000000
# 15:00~15:30 bid1 spread 5 category five traded probability = 0.774306
# 15:00~15:30 bid1 spread 5 category five traded expectation = 0.774306
# 15:00~15:30 bid1 spread 10 category five traded probability = 0.000000
# 15:00~15:30 bid1 spread 10 category five traded expectation = 1.000000
# 15:00~15:30 bid1 spread 5 category five MDD = 2.180556
# 15:00~15:30 bid1 spread 10 category five MDD = 3.000000
# 15:00~15:30 bid1 spread 5 category five traded time = 2783.406240
# 15:00~15:30 bid1 spread 10 category five traded time = 3536.285209
# bid1 spread 5 category five traded time in market = 2814.663665
# bid1 spread 10 category five traded time in market = 0.000000
#
# Spread 5 and Category One = 105
# Spread 10 and Category One = 31
# Spread 5 and Category Two= 10
# Spread 10 and Category Two = 51
# Spread 5 and Category Three = 13
# Spread 10 and Category Three = 19
# Spread 5 and Category Four = 7
# Spread 10 and Category Four = 0
# Spread 5 and Category Five = 74
# Spread 10 and Category Five = 0
# Spread 5 and Category One traded = 105
# Spread 10 and Category One traded = 31
# Spread 5 and Category two traded = 10
# Spread 10 and Category two traded = 6
# Spread 5 and Category three traded = 13
# Spread 10 and Category three traded = 0
# Spread 5 and Category four traded = 7
# Spread 10 and Category four traded = 0
# Spread 5 and Category five traded = 15
# Spread 10 and Category five traded = 0
# 15:30~16:00 bid1 spread 5 category one traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category one traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category one traded probability = 1.000000
# 15:30~16:00 bid1 spread 10 category one traded expectation = 2.000000
# 15:30~16:00 bid1 spread 5 category one MDD = 1.609524
# 15:30~16:00 bid1 spread 10 category one MDD = 1.903226
# 15:30~16:00 bid1 spread 5 category one traded time = 640.314280
# 15:30~16:00 bid1 spread 10 category one traded time = 34.483870
# bid1 spread 5 category one traded time in market = 640.314280
# bid1 spread 10 category one traded time in market = 34.483870
# 15:30~16:00 bid1 spread 5 category two traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category two traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category two traded probability = 0.117647
# 15:30~16:00 bid1 spread 10 category two traded expectation = 1.117647
# 15:30~16:00 bid1 spread 5 category two MDD = 2.000000
# 15:30~16:00 bid1 spread 10 category two MDD = 2.882353
# 15:30~16:00 bid1 spread 5 category two traded time = 489.899951
# 15:30~16:00 bid1 spread 10 category two traded time = 1138.039193
# bid1 spread 5 category two traded time in market = 489.899951
# bid1 spread 10 category two traded time in market = 377.999937
# 15:30~16:00 bid1 spread 5 category three traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category three traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category three traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category three traded expectation = 1.000000
# 15:30~16:00 bid1 spread 5 category three MDD = 2.000000
# 15:30~16:00 bid1 spread 10 category three MDD = 3.000000
# 15:30~16:30 bid1 spread 5 category three traded time = 488.999962
# 15:30~16:30 bid1 spread 10 category three traded time = 1485.999922
# bid1 spread 5 category three traded time in market = 488.999962
# bid1 spread 10 category three traded time in market = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded probability = 1.000000
# 15:30~16:00 bid1 spread 5 category four traded expectation = 1.000000
# 15:30~16:00 bid1 spread 10 category four traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category four traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category four MDD = 2.000000
# 15:30~16:00 bid1 spread 10 category four MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category four traded time = 461.428506
# 15:30~16:00 bid1 spread 10 category four traded time = 0.000000
# bid1 spread 5 category four traded time in market = 461.428506
# bid1 spread 10 category four traded time in market = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded probability = 0.202703
# 15:30~16:00 bid1 spread 5 category five traded expectation = 0.202703
# 15:30~16:00 bid1 spread 10 category five traded probability = 0.000000
# 15:30~16:00 bid1 spread 10 category five traded expectation = 0.000000
# 15:30~16:00 bid1 spread 5 category five MDD = 2.797297
# 15:30~16:00 bid1 spread 10 category five MDD = 0.000000
# 15:30~16:00 bid1 spread 5 category five traded time = 1122.486471
# 15:30~16:00 bid1 spread 10 category five traded time = 0.000000
# bid1 spread 5 category five traded time in market = 279.599981
# bid1 spread 10 category five traded time in market = 0.000000

# %%
211580./284
# Out:
# 745.0

# %%
bid_stat_time_spread_divid(Bid1,Ask1,min_Ask1_time_series\
                           ,Bid1_Quantity,Bid2_Quantity,Bid3_Quantity\
                           ,Ask1_Quantity,Ask2_Quantity,Ask3_Quantity\
                           ,weight1,weight2,weight3\
                           ,data_trade_time_series_0900_0930\
                           ,data_trade_time_series_0930_1000\
                           ,data_trade_time_series_1000_1030\
                           ,data_trade_time_series_1030_1100\
                           ,data_trade_time_series_1100_1130\
                           ,data_trade_time_series_1130_1200\
                           ,data_trade_time_series_1200_1230\
                           ,data_trade_time_series_1230_1300\
                           ,data_trade_time_series_1300_1330\
                           ,data_trade_time_series_1330_1400\
                           ,data_trade_time_series_1400_1430\
                           ,data_trade_time_series_1430_1500\
                           ,data_trade_time_series_1500_1530\
                           ,data_trade_time_series_1530_1600\
                           ,Close_Price)

# %%
2221./691
# Out:
# 3.2141823444283646
