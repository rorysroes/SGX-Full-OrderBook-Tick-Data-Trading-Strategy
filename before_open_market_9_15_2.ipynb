# %%
import pandas as pd

## read file
def read_file(year,month,day):
    data = []
    if len(str(month)) == 1:
        month_ = '0'+str(month)
    else:
        month_ = str(month)
    if len(str(day)) == 1:
        day_ = '0'+str(day)
    else:
        day_ = str(day)
    datapath = '/home/bigdatas16/SGX-OrderBook-Tick-Data-Trading-Strategy-/CN_Futures_'+str(year)+'.'+str(month_)+'.'+str(day_)+'.csv'
    data = pd.read_csv(datapath)
    data_CN14 = data[data.Series == data['Series'][0]]
    data = data_CN14
    return data

# %%
data = read_file(2014,1,30)

# %%
BestPrice 	BestQuantity
# Out:
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 0  CNG14               1  2014-01-30D04:27:08.581903900  BFC92EA46AE44FA4
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 0                  1  700000                   1              A     682000
#
#    BestQuantity  QuantityDifference_
# 0             1                    1

# %%
import time 
data['QuantityDifference_'] = data['QuantityDifference']
data_ask = data[(data.BidOrAsk == 'A')].reset_index(drop=True)
data_bid = data[(data.BidOrAsk == 'B')].reset_index(drop=True)
def insert(order_book_data,data_to_insert,ob_position):
    top = order_book_data[0:ob_position]
    bottom = order_book_data[ob_position:]
    return pd.concat((top,data_to_insert,bottom)).reset_index(drop = True)

start  =  time.time()
order_book_bid = []
order_book_ask = []
timestamp = data.TimeStamp[0]
temp_ask = 0
temp_bid = 0
bid = []
ask = []
timestamp_ = []
x1 = data[(data.BidOrAsk == 'A')].TimeStamp.unique()
x2 = data[(data.BidOrAsk == 'B')].TimeStamp.unique()
y = data[data['TimeStamp'].str.contains(timestamp)]
bid.append(y[(y.BidOrAsk == 'B')][["Price","OrderNumber","QuantityDifference","QuantityDifference_"]]) # bid
ask.append(y[(y.BidOrAsk == 'A')][["Price","OrderNumber","QuantityDifference","QuantityDifference_"]]) # ask
a = bid[0].sort(['Price'],ascending = [False])
b = ask[0].sort(['Price'],ascending = [True])    
order_book_bid.append(a[a.QuantityDifference != 0].reset_index(drop = True))
order_book_ask.append(b[b.QuantityDifference != 0].reset_index(drop = True))
order_book_bid.append(0)
order_book_ask.append(0)

for i in range(len(y),5000,1):
    print i,temp_bid,temp_ask
    if data.BidOrAsk[i] == 'A':
        time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                      int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                      int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
        if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            if order_book_bid[temp_bid].Price[0] >= data[i:i+1].Price.iloc[0] & time_second < 32400:
                for k in range(0,len(order_book_bid[temp_bid])):
                    diff = order_book_bid[temp_bid].QuantityDifference_[k] - data[i:i+1].QuantityDifference_.iloc[0]
                    if order_book_bid[temp_bid].Price[k] >= data[i:i+1].Price.iloc[0] and diff >= 0:
                        order_book_bid[temp_bid].QuantityDifference_[k] = diff
                        data[i:i+1].QuantityDifference_.iloc[0] = 0
                        break
                    elif order_book_bid[temp_bid].Price[k] >= data[i:i+1].Price.iloc[0] and diff < 0:
                        order_book_bid[temp_bid].QuantityDifference_[k] = 0
                        data[i:i+1].QuantityDifference_.iloc[0] = -diff
                        pass
                    else:
                        break
            if data.TimeStamp[i] == x1[temp_ask]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 
                order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)
                if time_second > 32400:
                    if position_ == 0 and len(order_book_ask[0]) > 1:
                        if order_book_ask[temp_ask][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error1(Ask & Q>0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< (len(order_book_ask[temp_ask])-1):
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]:#or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error1(Ask & Q>0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'   
                            pass
                    elif position_ == len(order_book_ask[temp_ask])-1:
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error1(Ask & Q>0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'                
                            pass
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True' 
                        pass
                else:
                    print 'before open market'
            elif data.TimeStamp[i] != x1[temp_ask]:
                if temp_ask == 0:
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = order_book_ask[temp_ask - 1]
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)                  
                    if time_second > 32400:
                        if position_ == 0 and len(order_book_ask[0]) > 1:
                            if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error2(Ask & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                                break
                            else:
                                print 'position and Best Price is True'                     
                                pass
                        elif 0 < position_< len(order_book_ask[temp_ask])-1:
                            if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error2(Ask & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                                break
                            else:
                                print 'position and Best Price is True'  
                                pass
                        elif position_ == len(order_book_ask[temp_ask])-1:   
                            if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error2(Ask & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                                break
                            else:
                                print 'position and Best Price is True'
                                pass
                        elif position_ == 0 and len(order_book_ask[0]) == 1:
                            print 'position and Best Price is True'
                            pass
                    else:
                        print 'before open market'
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 
                    order_book_ask.append(order_book_ask[temp_ask])
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)#int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    if time_second > 32400:
                        if position_ == 0:
                            if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                                print 'Some error3(Ask & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                                break
                            else:
                                print 'position and Best Price is True'                     
                                pass
                        elif 0 < position_< len(order_book_ask[temp_ask])-1:
                            if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                                print 'Some error3(Ask & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                                break
                            else:
                                print 'position and Best Price is True'  
                                continue
                        elif position_ == len(order_book_ask[temp_ask])-1:    
                            if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                                print 'Some error3(Ask & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                                break
                            else:
                                print 'position and Best Price is True'                        
                                pass
                        elif position_ == 0 and len(order_book_ask[0]) == 1:
                            print 'position and Best Price is True'
                            pass
                    else:
                        print 'before open market'
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    
            if data.TimeStamp[i] == x1[temp_ask]: 
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_ask[temp_ask][order_book_ask[temp_ask].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                if time_second > 32400:
                    if position_ == 0 and len(order_book_ask[0]) > 1:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error4(Ask & Q<0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass       
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error4(Ask & Q<0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_ask[temp_ask])-1:       
                        if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error4(Ask & Q<0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])   
                            break
                        elif position_ == 0:
                            print 'position and Best Price is True'
                            pass                        
                        else:
                            print 'position and Best Price is True'                        
                            pass
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        pass
                else:
                    print 'before open market'                   
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
            elif data.TimeStamp[i] != x1[temp_ask]:
                order_book_ask.append(order_book_ask[temp_ask])
                order_number_ =  data['OrderNumber'][i : i + 1].iloc[0]
                position_ = order_book_ask[temp_ask][order_book_ask[temp_ask].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_ask = temp_ask + 1
                if time_second > 32400:
                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error5(Ask & Q<0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error5(Ask & Q<0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_ask[temp_ask])-1:

                        if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error5(Ask & Q<0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            break
                        elif position_ == 0:
                            print 'position and Best Price is True'
                            pass                       
                        else:
                            print 'position and Best Price is True'                        
                            pass
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        pass      
                else:
                    print 'before open market'
                    
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                    
    elif data.BidOrAsk[i] == 'B':
        time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                      int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                      int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
        if int(data[['QuantityDifference']][i:i+1].values) > 0: 
            if order_book_ask[temp_ask].Price[0] <= data[i:i+1].Price.iloc[0] & time_second < 32400:
                for k in range(0,len(order_book_ask[temp_ask])):
                    diff = order_book_ask[temp_ask].QuantityDifference_[k] - data[i:i+1].QuantityDifference_.iloc[0]
                    if order_book_ask[temp_ask].Price[k] <= data[i:i+1].Price.iloc[0] and diff >= 0:
                        order_book_ask[temp_ask].QuantityDifference_[k] = diff
                        data[i:i+1].QuantityDifference_.iloc[0] = 0
                        break
                    elif order_book_ask[temp_ask].Price[k] <= data[i:i+1].Price.iloc[0] and diff < 0:
                        order_book_ask[temp_ask].QuantityDifference_[k] = 0
                        data[i:i+1].QuantityDifference_.iloc[0] = -diff
                        pass
                    else:
                        break
            if data.TimeStamp[i] == x2[temp_bid] :               
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 
                order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)
                best_price = order_book_bid[temp_bid].Price[0]
                best_quantity = sum(order_book_bid[temp_bid][order_book_bid[temp_bid].Price == best_price].QuantityDifference)             
                if time_second > 32400:
                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_+1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]:
                            print 'Some error1(Bid & Q>0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass     
                    elif 0 < position_< len(order_book_bid[temp_bid])-1: 
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                            print 'Some error1(Bid & Q>0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'   
                            pass
                    elif position_ == len(order_book_bid[temp_bid])-1 and len(order_book_bid[0]) > 1:      
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                            print 'Some error1(Bid & Q>0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'                
                            pass
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        pass 
                else:
                    print 'before open market'
                    pass
            elif data.TimeStamp[i] != x2[temp_bid]:
                if temp_bid == 0:
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 
                    temp_bid = temp_bid + 1
                    order_book_bid[temp_bid] = order_book_bid[temp_bid - 1]
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)#int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    best_price = order_book_bid[temp_bid].Price[0]
                    best_quantity = sum(order_book_bid[temp_bid][order_book_bid[temp_bid].Price == best_price].QuantityDifference)            
                    if time_second > 32400:
                        if position_ == 0  and len(order_book_bid[0]) > 1:
                            if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                                print 'Some error2(Bid & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'                     
                                pass       
                        elif 0 < position_< len(order_book_bid[temp_bid])-1:
                            if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or \
                                best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                                print 'Some error2(Bid & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                                break
                            else:
                                print 'position and Best Price is True'  
                                pass
                        elif position_ == len(order_book_bid[temp_bid])-1:    
                            if order_book_bid[temp_bid][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                                print 'Some error2(Bid & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])                                        
                                pass
                            else:
                                print 'position and Best Price is True'
                                pass
                        elif position_ == 0 and len(order_book_bid[0]) == 1:
                                print 'position and Best Price is True'
                                pass
                    else:
                        print 'before open market'
                        pass
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 
                    order_book_bid.append(order_book_bid[temp_bid])
                    temp_bid = temp_bid + 1 
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)   
                    best_price = order_book_bid[temp_bid].Price[0]
                    best_quantity = sum(order_book_bid[temp_bid][order_book_bid[temp_bid].Price == best_price].QuantityDifference) 
                    if time_second > 32400:
                        if position_ == 0 and len(order_book_bid[0]) > 1:
                            if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or \
                                order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i] or \
                                best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                                print 'Some error3(Bid & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                                break
                            else:
                                print 'position and Best Price is True'                     
                                pass
                        elif 0 < position_< len(order_book_bid[temp_bid])-1:
                            if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or \
                                order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                                print 'Some error3(Bid & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                                break
                            else:
                                print 'position and Best Price is True'  
                                pass
                        elif position_ == len(order_book_bid[temp_bid])-1:
                            if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or \
                                order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i] or \
                                best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                                print 'Some error3(Bid & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                                break
                            else:
                                print 'position and Best Price is True'                        
                                pass
                        elif position_ == 0 and len(order_book_bid[0]) == 1:
                            print 'position and Best Price is True'
                            pass
                    else:
                        print 'before open market'
                        pass
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    
            if data.TimeStamp[i] == x2[temp_bid]: 
                order_number_ =  data['OrderNumber'][i : i + 1].iloc[0]
                position_ = order_book_bid[temp_bid][order_book_bid[temp_bid].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                best_price = order_book_bid[temp_bid].Price[0]
                best_quantity = sum(order_book_bid[temp_bid][order_book_bid[temp_bid].Price == best_price].QuantityDifference) 
                if time_second > 32400:
                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                            print 'Some error4(Bid & Q<0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass               
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or \
                            order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]:
                            print 'Some error4(Bid & Q<0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_bid[temp_bid])-1:
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]:
                            print 'Some error4(Bid & Q<0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            break
                        elif position_ == 0:
                            print 'position and Best Price is True'
                            pass
                        else:
                            print 'position and Best Price is True'                        
                            pass
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        pass
                else:
                    print 'before open market'
                    pass
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]                
            elif data.TimeStamp[i] != x2[temp_bid]:
                order_book_bid.append(order_book_bid[temp_bid])
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_bid[temp_bid][order_book_bid[temp_bid].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_bid = temp_bid + 1
                best_price = order_book_bid[temp_bid].Price[0]
                best_quantity = sum(order_book_bid[temp_bid][order_book_bid[temp_bid].Price == best_price].QuantityDifference) 

                if time_second > 32400:
                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]:  
                            print 'Some error5(Bid & Q<0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or \
                            order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]:
                            print 'Some error5(Bid & Q<0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_bid[temp_bid])-1: 
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or \
                            best_price != data['BestPrice'][i:i+1].iloc[0] or best_quantity != data['BestQuantity'][i:i+1].iloc[0]: 
                            print 'Some error5(Bid & Q<0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        elif position_ == 0:
                            print 'position and Best Price is True'
                            pass
                        else:
                            print 'position and Best Price is True'                        
                            pass    
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        pass  
                else:
                    print 'before open market'
                    pass
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
end = time.time()            
print "Total time = %f"%(end - start)
# Out:
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:24: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# 13 0 0
# before open market
# 14 1 0
# before open market
# 15 2 0
# before open market
# 16 3 0
# before open market
# 17 4 0
# before open market
# 18 5 0
# before open market
# 19 6 0
# before open market
# 20 7 0
# before open market
# 21 7 1
# before open market
# 22 8 1
# before open market
# 23 9 1
# before open market
# 24 10 1
# before open market
# 25 11 1
# before open market
# 26 11 1
# before open market
# 27 12 1
# before open market
# 28 13 1
# before open market
# 29 14 1
# before open market
# 30 14 2
# before open market
# 31 15 2
# before open market
# 32 15 2
# before open market
# 33 15 3
# before open market
# 34 15 3
# before open market
# 35 15 4
# before open market
# 36 16 4
# before open market
# 37 16 5
# before open market
# 38 16 6
# before open market
# 39 16 6
# before open market
# 40 16 7
# before open market
# 41 16 7
# before open market
# 42 16 8
# before open market
# 43 16 9
# before open market
# 44 16 10
# before open market
# 45 17 10
# before open market
# 46 17 11
# before open market
# 47 17 12
# before open market
# 48 18 12
# before open market
# 49 18 13
# before open market
# 50 18 14
# before open market
# 51 19 14
# before open market
# 52 19 15
# before open market
# 53 19 16
# before open market
# 54 19 17
# before open market
# 55 19 18
# before open market
# 56 19 18
# before open market
# 57 19 19
# before open market
# 58 20 19
# before open market
# 59 21 19
# before open market
# 60 21 20
# before open market
# 61 22 20
# before open market
# 62 22 21
# before open market
# 63 22 22
# before open market
# 64 22 23
# before open market
# 65 22 24
# before open market
# 66 22 25
# before open market
# 67 23 25
# before open market
# 68 23 26
# before open market
# 69 23 27
# before open market
# 70 23 28
# before open market
# 71 24 28
# before open market
# 72 24 29
# before open market
# 73 25 29
# before open market
# 74 26 29
# before open market
# 75 27 29
# before open market
# 76 28 29
# before open market
# 77 29 29
# before open market
# 78 30 29
# before open market
# 79 31 29
# before open market
# 80 32 29
# before open market
# 81 33 29
# before open market
# 82 34 29
# before open market
# 83 35 29
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# before open market
# 84 35 30
# before open market
# 85 36 30
# before open market
# 86 37 30
# before open market
# 87 37 31
# before open market
# 88 37 32
# before open market
# 89 38 32
# before open market
# 90 38 33
# before open market
# 91 39 33
# before open market
# 92 39 34
# before open market
# 93 40 34
# before open market
# 94 40 35
# before open market
# 95 41 35
# before open market
# 96 42 35
# before open market
# 97 43 35
# before open market
# 98 44 35
# before open market
# 99 44 36
# before open market
# 100 44 37
# before open market
# 101 44 38
# before open market
# 102 45 38
# before open market
# 103 45 39
# before open market
# 104 45 40
# before open market
# 105 46 40
# before open market
# 106 46 41
# before open market
# 107 46 42
# before open market
# 108 47 42
# before open market
# 109 47 42
# before open market
# 110 47 42
# before open market
# 111 47 42
# before open market
# 112 47 42
# before open market
# 113 47 42
# before open market
# 114 47 42
# before open market
# 115 47 42
# before open market
# 116 47 42
# before open market
# 117 47 42
# before open market
# 118 47 42
# before open market
# 119 47 42
# before open market
# 120 47 42
# before open market
# 121 47 42
# before open market
# 122 47 42
# before open market
# 123 47 42
# before open market
# 124 47 42
# before open market
# 125 47 42
# before open market
# 126 47 42
# before open market
# 127 47 42
# before open market
# 128 47 42
# before open market
# 129 47 42
# before open market
# 130 47 42
# before open market
# 131 47 42
# before open market
# 132 47 42
# before open market
# 133 47 42
# before open market
# 134 47 43
# before open market
# 135 48 43
# before open market
# 136 49 43
# before open market
# 137 50 43
# before open market
# 138 50 44
# before open market
# 139 50 45
# before open market
# 140 50 46
# before open market
# 141 50 47
# before open market
# 142 50 47
# before open market
# 143 51 47
# before open market
# 144 52 47
# before open market
# 145 53 47
# before open market
# 146 54 47
# before open market
# 147 55 47
# before open market
# 148 56 47
# before open market
# 149 57 47
# before open market
# 150 58 47
# before open market
# 151 59 47
# before open market
# 152 60 47
# before open market
# 153 61 47
# before open market
# 154 62 47
# before open market
# 155 63 47
# before open market
# 156 64 47
# before open market
# 157 65 47
# before open market
# 158 66 47
# before open market
# 159 67 47
# before open market
# 160 68 47
# before open market
# 161 69 47
# before open market
# 162 70 47
# before open market
# 163 71 47
# before open market
# 164 71 48
# before open market
# 165 71 49
# before open market
# 166 72 49
# before open market
# 167 72 49
# before open market
# 168 72 49
# before open market
# 169 72 49
# before open market
# 170 72 49
# before open market
# 171 72 49
# before open market
# 172 72 49
# before open market
# 173 72 49
# before open market
# 174 72 49
# before open market
# 175 72 49
# before open market
# 176 72 49
# before open market
# 177 72 49
# before open market
# 178 72 49
# before open market
# 179 72 49
# before open market
# 180 72 49
# before open market
# 181 72 49
# before open market
# 182 72 49
# before open market
# 183 72 49
# before open market
# 184 72 49
# before open market
# 185 72 49
# before open market
# 186 72 49
# before open market
# 187 72 49
# before open market
# 188 72 49
# before open market
# 189 72 49
# before open market
# 190 72 49
# before open market
# 191 72 49
# before open market
# 192 72 49
# before open market
# 193 72 49
# before open market
# 194 72 50
# before open market
# 195 73 50
# before open market
# 196 73 50
# before open market
# 197 73 50
# before open market
# 198 73 50
# before open market
# 199 73 50
# before open market
# 200 73 50
# before open market
# 201 73 50
# before open market
# 202 73 50
# before open market
# 203 73 50
# before open market
# 204 73 50
# before open market
# 205 73 50
# before open market
# 206 73 50
# before open market
# 207 73 50
# before open market
# 208 73 50
# before open market
# 209 73 50
# before open market
# 210 73 50
# before open market
# 211 73 50
# before open market
# 212 73 50
# before open market
# 213 73 50
# before open market
# 214 73 50
# before open market
# 215 73 50
# before open market
# 216 73 50
# before open market
# 217 73 50
# before open market
# 218 73 50
# before open market
# 219 73 50
# before open market
# 220 73 50
# before open market
# 221 74 50
# before open market
# 222 74 51
# before open market
# 223 74 52
# before open market
# 224 74 53
# before open market
# 225 74 54
# before open market
# 226 74 55
# before open market
# 227 74 56
# before open market
# 228 74 57
# before open market
# 229 74 58
# before open market
# 230 74 59
# before open market
# 231 74 60
# before open market
# 232 74 61
# before open market
# 233 74 62
# before open market
# 234 74 63
# before open market
# 235 74 64
# before open market
# 236 74 65
# before open market
# 237 74 66
# before open market
# 238 74 67
# before open market
# 239 74 68
# before open market
# 240 74 69
# before open market
# 241 74 70
# before open market
# 242 74 71
# before open market
# 243 74 72
# before open market
# 244 74 73
# before open market
# 245 75 73
# before open market
# 246 75 74
# before open market
# 247 75 75
# before open market
# 248 75 76
# before open market
# 249 76 76
# before open market
# 250 77 76
# before open market
# 251 77 77
# before open market
# 252 77 78
# before open market
# 253 77 79
# before open market
# 254 77 80
# before open market
# 255 77 81
# before open market
# 256 77 82
# before open market
# 257 77 83
# before open market
# 258 77 84
# before open market
# 259 77 85
# before open market
# 260 77 86
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:225: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# before open market
# 261 77 87
# before open market
# 262 77 88
# before open market
# 263 77 89
# before open market
# 264 77 89
# before open market
# 265 77 90
# before open market
# 266 77 91
# before open market
# 267 77 92
# before open market
# 268 77 92
# before open market
# 269 77 93
# before open market
# 270 77 94
# before open market
# 271 77 95
# before open market
# 272 77 95
# before open market
# 273 77 96
# before open market
# 274 77 97
# before open market
# 275 77 98
# before open market
# 276 77 98
# before open market
# 277 77 99
# before open market
# 278 77 100
# before open market
# 279 77 101
# before open market
# 280 77 101
# before open market
# 281 77 102
# before open market
# 282 77 103
# before open market
# 283 77 104
# before open market
# 284 77 104
# before open market
# 285 77 105
# before open market
# 286 78 105
# before open market
# 287 78 105
# before open market
# 288 78 105
# before open market
# 289 78 105
# before open market
# 290 78 105
# before open market
# 291 78 105
# before open market
# 292 78 105
# before open market
# 293 78 105
# before open market
# 294 78 105
# before open market
# 295 78 105
# before open market
# 296 78 105
# before open market
# 297 78 105
# before open market
# 298 78 105
# before open market
# 299 78 105
# before open market
# 300 78 105
# before open market
# 301 79 105
# before open market
# 302 79 105
# before open market
# 303 79 105
# before open market
# 304 79 105
# before open market
# 305 79 105
# before open market
# 306 79 106
# before open market
# 307 79 106
# before open market
# 308 79 106
# before open market
# 309 79 106
# before open market
# 310 79 106
# before open market
# 311 79 106
# before open market
# 312 79 106
# before open market
# 313 79 106
# before open market
# 314 79 106
# before open market
# 315 79 106
# before open market
# 316 79 107
# before open market
# 317 79 108
# before open market
# 318 79 108
# before open market
# 319 79 109
# before open market
# 320 79 110
# before open market
# 321 79 111
# before open market
# 322 79 111
# before open market
# 323 79 112
# before open market
# 324 80 112
# before open market
# 325 80 112
# before open market
# 326 80 112
# before open market
# 327 80 112
# before open market
# 328 80 112
# before open market
# 329 80 112
# before open market
# 330 80 112
# before open market
# 331 80 112
# before open market
# 332 80 112
# before open market
# 333 80 112
# before open market
# 334 80 112
# before open market
# 335 80 112
# before open market
# 336 80 112
# before open market
# 337 80 112
# before open market
# 338 80 112
# before open market
# 339 80 112
# before open market
# 340 80 112
# before open market
# 341 80 112
# before open market
# 342 80 112
# before open market
# 343 80 112
# before open market
# 344 80 112
# before open market
# 345 80 112
# before open market
# 346 80 112
# before open market
# 347 80 112
# before open market
# 348 80 112
# before open market
# 349 80 112
# before open market
# 350 80 112
# before open market
# 351 80 112
# before open market
# 352 80 113
# before open market
# 353 80 114
# before open market
# 354 80 114
# before open market
# 355 80 115
# before open market
# 356 81 115
# before open market
# 357 81 115
# before open market
# 358 81 115
# before open market
# 359 81 115
# before open market
# 360 81 115
# before open market
# 361 81 115
# before open market
# 362 81 115
# before open market
# 363 81 115
# before open market
# 364 81 115
# before open market
# 365 81 115
# before open market
# 366 81 115
# before open market
# 367 81 115
# before open market
# 368 81 115
# before open market
# 369 81 115
# before open market
# 370 81 115
# before open market
# 371 81 115
# before open market
# 372 81 115
# before open market
# 373 81 115
# before open market
# 374 81 115
# before open market
# 375 81 115
# before open market
# 376 81 115
# before open market
# 377 81 115
# before open market
# 378 81 115
# before open market
# 379 81 115
# before open market
# 380 81 115
# before open market
# 381 81 115
# before open market
# 382 81 116
# before open market
# 383 81 117
# before open market
# 384 81 117
# before open market
# 385 81 118
# before open market
# 386 81 119
# before open market
# 387 81 120
# before open market
# 388 81 120
# before open market
# 389 81 121
# before open market
# 390 82 121
# before open market
# 391 82 121
# before open market
# 392 82 121
# before open market
# 393 82 121
# before open market
# 394 82 121
# before open market
# 395 82 121
# before open market
# 396 82 121
# before open market
# 397 82 121
# before open market
# 398 82 121
# before open market
# 399 82 121
# before open market
# 400 82 121
# before open market
# 401 82 121
# before open market
# 402 82 121
# before open market
# 403 82 121
# before open market
# 404 82 121
# before open market
# 405 82 121
# before open market
# 406 82 121
# before open market
# 407 82 121
# before open market
# 408 82 121
# before open market
# 409 82 121
# before open market
# 410 82 121
# before open market
# 411 82 121
# before open market
# 412 82 121
# before open market
# 413 82 121
# before open market
# 414 82 121
# before open market
# 415 82 121
# before open market
# 416 82 121
# before open market
# 417 82 121
# before open market
# 418 82 121
# before open market
# 419 82 121
# before open market
# 420 82 122
# before open market
# 421 82 123
# before open market
# 422 82 123
# before open market
# 423 82 124
# before open market
# 424 83 124
# before open market
# 425 83 124
# before open market
# 426 83 124
# before open market
# 427 83 124
# before open market
# 428 83 124
# before open market
# 429 83 124
# before open market
# 430 83 124
# before open market
# 431 83 124
# before open market
# 432 83 124
# before open market
# 433 84 124
# before open market
# 434 84 124
# before open market
# 435 84 124
# before open market
# 436 84 124
# before open market
# 437 84 124
# before open market
# 438 84 124
# before open market
# 439 84 124
# before open market
# 440 84 124
# before open market
# 441 84 124
# before open market
# 442 84 124
# before open market
# 443 84 124
# before open market
# 444 84 125
# before open market
# 445 84 125
# before open market
# 446 84 125
# before open market
# 447 84 125
# before open market
# 448 84 125
# before open market
# 449 84 125
# before open market
# 450 84 125
# before open market
# 451 84 125
# before open market
# 452 84 126
# before open market
# 453 84 127
# before open market
# 454 84 127
# before open market
# 455 85 127
# before open market
# 456 85 128
# before open market
# 457 85 129
# before open market
# 458 86 129
# before open market
# 459 87 129
# before open market
# 460 87 130
# before open market
# 461 87 131
# before open market
# 462 87 132
# before open market
# 463 88 132
# before open market
# 464 88 132
# before open market
# 465 88 132
# before open market
# 466 88 132
# before open market
# 467 88 132
# before open market
# 468 88 132
# before open market
# 469 88 132
# before open market
# 470 88 132
# before open market
# 471 88 132
# before open market
# 472 88 132
# before open market
# 473 88 132
# before open market
# 474 88 132
# before open market
# 475 88 132
# before open market
# 476 88 132
# before open market
# 477 88 132
# before open market
# 478 88 132
# before open market
# 479 88 132
# before open market
# 480 88 132
# before open market
# 481 88 132
# before open market
# 482 88 132
# before open market
# 483 88 132
# before open market
# 484 88 132
# before open market
# 485 88 132
# before open market
# 486 88 132
# before open market
# 487 88 132
# before open market
# 488 88 132
# before open market
# 489 88 132
# before open market
# 490 88 132
# before open market
# 491 88 132
# before open market
# 492 88 132
# before open market
# 493 88 133
# before open market
# 494 88 134
# before open market
# 495 88 134
# before open market
# 496 88 135
# before open market
# 497 88 136
# before open market
# 498 88 137
# before open market
# 499 88 138
# before open market
# 500 89 138
# before open market
# 501 89 138
# before open market
# 502 89 138
# before open market
# 503 89 138
# before open market
# 504 89 138
# before open market
# 505 89 138
# before open market
# 506 89 138
# before open market
# 507 89 138
# before open market
# 508 89 138
# before open market
# 509 89 138
# before open market
# 510 89 138
# before open market
# 511 89 138
# before open market
# 512 89 138
# before open market
# 513 89 138
# before open market
# 514 89 138
# before open market
# 515 89 138
# before open market
# 516 89 138
# before open market
# 517 89 138
# before open market
# 518 89 138
# before open market
# 519 89 138
# before open market
# 520 89 138
# before open market
# 521 89 138
# before open market
# 522 89 138
# before open market
# 523 89 138
# before open market
# 524 89 138
# before open market
# 525 89 138
# before open market
# 526 89 138
# before open market
# 527 89 138
# before open market
# 528 89 139
# before open market
# 529 89 140
# before open market
# 530 89 141
# before open market
# 531 89 142
# before open market
# 532 89 143
# before open market
# 533 89 144
# before open market
# 534 90 144
# before open market
# 535 90 144
# before open market
# 536 90 144
# before open market
# 537 90 144
# before open market
# 538 90 144
# before open market
# 539 90 144
# before open market
# 540 90 144
# before open market
# 541 90 144
# before open market
# 542 90 144
# before open market
# 543 90 144
# before open market
# 544 90 144
# before open market
# 545 90 144
# before open market
# 546 90 144
# before open market
# 547 90 144
# before open market
# 548 90 144
# before open market
# 549 90 144
# before open market
# 550 90 144
# before open market
# 551 90 144
# before open market
# 552 90 144
# before open market
# 553 90 144
# before open market
# 554 90 144
# before open market
# 555 90 144
# before open market
# 556 90 144
# before open market
# 557 90 144
# before open market
# 558 90 144
# before open market
# 559 90 144
# before open market
# 560 90 145
# before open market
# 561 90 146
# before open market
# 562 90 147
# before open market
# 563 90 148
# before open market
# 564 90 148
# before open market
# 565 90 149
# before open market
# 566 90 150
# before open market
# 567 91 150
# before open market
# 568 91 150
# before open market
# 569 91 150
# before open market
# 570 91 150
# before open market
# 571 91 150
# before open market
# 572 91 150
# before open market
# 573 91 150
# before open market
# 574 91 150
# before open market
# 575 91 150
# before open market
# 576 91 150
# before open market
# 577 91 150
# before open market
# 578 91 150
# before open market
# 579 91 150
# before open market
# 580 91 150
# before open market
# 581 91 150
# before open market
# 582 91 150
# before open market
# 583 91 150
# before open market
# 584 91 150
# before open market
# 585 91 150
# before open market
# 586 91 150
# before open market
# 587 91 150
# before open market
# 588 91 150
# before open market
# 589 91 150
# before open market
# 590 91 150
# before open market
# 591 91 150
# before open market
# 592 91 150
# before open market
# 593 91 150
# before open market
# 594 91 150
# before open market
# 595 91 150
# before open market
# 596 91 150
# before open market
# 597 91 151
# before open market
# 598 91 152
# before open market
# 599 91 152
# before open market
# 600 91 153
# before open market
# 601 92 153
# before open market
# 602 92 153
# before open market
# 603 92 153
# before open market
# 604 92 153
# before open market
# 605 92 153
# before open market
# 606 92 153
# before open market
# 607 92 153
# before open market
# 608 92 153
# before open market
# 609 92 153
# before open market
# 610 92 153
# before open market
# 611 92 153
# before open market
# 612 92 153
# before open market
# 613 92 153
# before open market
# 614 92 153
# before open market
# 615 92 153
# before open market
# 616 92 153
# before open market
# 617 92 153
# before open market
# 618 92 153
# before open market
# 619 92 153
# before open market
# 620 92 153
# before open market
# 621 92 153
# before open market
# 622 92 153
# before open market
# 623 92 153
# before open market
# 624 92 153
# before open market
# 625 92 154
# before open market
# 626 92 154
# before open market
# 627 92 154
# before open market
# 628 92 154
# before open market
# 629 92 155
# before open market
# 630 92 156
# before open market
# 631 92 157
# before open market
# 632 92 157
# before open market
# 633 93 157
# before open market
# 634 94 157
# before open market
# 635 95 157
# before open market
# 636 96 157
# before open market
# 637 97 157
# before open market
# 638 98 157
# before open market
# 639 99 157
# before open market
# 640 100 157
# before open market
# 641 101 157
# before open market
# 642 102 157
# before open market
# 643 103 157
# before open market
# 644 104 157
# before open market
# 645 105 157
# before open market
# 646 106 157
# before open market
# 647 107 157
# before open market
# 648 107 158
# before open market
# 649 108 158
# before open market
# 650 109 158
# before open market
# 651 110 158
# before open market
# 652 110 159
# before open market
# 653 111 159
# before open market
# 654 111 159
# before open market
# 655 112 159
# before open market
# 656 112 159
# before open market
# 657 112 159
# before open market
# 658 112 159
# before open market
# 659 112 159
# before open market
# 660 112 159
# before open market
# 661 112 159
# before open market
# 662 112 159
# before open market
# 663 112 159
# before open market
# 664 112 159
# before open market
# 665 112 159
# before open market
# 666 112 159
# before open market
# 667 112 159
# before open market
# 668 112 159
# before open market
# 669 112 159
# before open market
# 670 112 159
# before open market
# 671 112 159
# before open market
# 672 112 159
# before open market
# 673 112 160
# before open market
# 674 112 160
# before open market
# 675 112 160
# before open market
# 676 112 160
# before open market
# 677 112 160
# before open market
# 678 112 160
# before open market
# 679 112 160
# before open market
# 680 112 160
# before open market
# 681 112 161
# before open market
# 682 112 162
# before open market
# 683 112 163
# before open market
# 684 112 164
# before open market
# 685 112 165
# before open market
# 686 112 166
# before open market
# 687 112 166
# before open market
# 688 113 166
# before open market
# 689 113 166
# before open market
# 690 113 166
# before open market
# 691 113 166
# before open market
# 692 113 166
# before open market
# 693 113 166
# before open market
# 694 113 166
# before open market
# 695 113 166
# before open market
# 696 113 166
# before open market
# 697 113 166
# before open market
# 698 113 166
# before open market
# 699 113 166
# before open market
# 700 113 166
# before open market
# 701 113 166
# before open market
# 702 113 166
# before open market
# 703 113 166
# before open market
# 704 113 166
# before open market
# 705 113 166
# before open market
# 706 113 166
# before open market
# 707 113 166
# before open market
# 708 113 166
# before open market
# 709 113 166
# before open market
# 710 113 166
# before open market
# 711 113 166
# before open market
# 712 113 166
# before open market
# 713 113 166
# before open market
# 714 113 167
# before open market
# 715 113 168
# before open market
# 716 114 168
# before open market
# 717 114 168
# before open market
# 718 114 168
# before open market
# 719 114 168
# before open market
# 720 114 168
# before open market
# 721 114 168
# before open market
# 722 114 168
# before open market
# 723 114 168
# before open market
# 724 114 168
# before open market
# 725 114 168
# before open market
# 726 114 168
# before open market
# 727 114 168
# before open market
# 728 114 168
# before open market
# 729 114 168
# before open market
# 730 114 168
# before open market
# 731 114 168
# before open market
# 732 114 168
# before open market
# 733 114 168
# before open market
# 734 114 168
# before open market
# 735 114 168
# before open market
# 736 114 168
# before open market
# 737 114 168
# before open market
# 738 114 168
# before open market
# 739 114 168
# before open market
# 740 114 168
# before open market
# 741 114 168
# before open market
# 742 114 169
# before open market
# 743 114 170
# before open market
# 744 114 171
# before open market
# 745 114 172
# before open market
# 746 114 172
# before open market
# 747 114 173
# before open market
# 748 114 173
# before open market
# 749 114 174
# before open market
# 750 115 174
# before open market
# 751 115 174
# before open market
# 752 115 174
# before open market
# 753 115 174
# before open market
# 754 115 174
# before open market
# 755 115 174
# before open market
# 756 115 174
# before open market
# 757 115 174
# before open market
# 758 115 174
# before open market
# 759 115 174
# before open market
# 760 115 174
# before open market
# 761 115 174
# before open market
# 762 115 174
# before open market
# 763 115 174
# before open market
# 764 115 174
# before open market
# 765 115 174
# before open market
# 766 115 174
# before open market
# 767 115 174
# before open market
# 768 115 174
# before open market
# 769 115 174
# before open market
# 770 115 174
# before open market
# 771 115 174
# before open market
# 772 115 174
# before open market
# 773 115 174
# before open market
# 774 115 174
# before open market
# 775 115 174
# before open market
# 776 115 174
# before open market
# 777 115 174
# before open market
# 778 115 175
# before open market
# 779 115 176
# before open market
# 780 115 177
# before open market
# 781 115 177
# before open market
# 782 115 178
# before open market
# 783 115 179
# before open market
# 784 115 180
# before open market
# 785 116 180
# before open market
# 786 117 180
# before open market
# 787 117 181
# before open market
# 788 117 182
# before open market
# 789 117 183
# before open market
# 790 117 184
# before open market
# 791 117 185
# before open market
# 792 118 185
# before open market
# 793 118 186
# before open market
# 794 119 186
# before open market
# 795 119 186
# before open market
# 796 119 186
# before open market
# 797 119 186
# before open market
# 798 119 186
# before open market
# 799 119 186
# before open market
# 800 119 186
# before open market
# 801 119 186
# before open market
# 802 119 186
# before open market
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 803 119 186
# before open market
# 804 119 186
# before open market
# 805 119 186
# before open market
# 806 119 186
# before open market
# 807 119 186
# before open market
# 808 119 186
# before open market
# 809 119 186
# before open market
# 810 119 186
# before open market
# 811 119 187
# before open market
# 812 119 188
# before open market
# 813 120 188
# before open market
# 814 120 188
# before open market
# 815 120 188
# before open market
# 816 120 189
# before open market
# 817 121 189
# before open market
# 818 121 190
# before open market
# 819 121 191
# before open market
# 820 121 192
# before open market
# 821 121 193
# before open market
# 822 121 193
# before open market
# 823 121 194
# before open market
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:433: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 824 121 195
# before open market
# 825 121 196
# before open market
# 826 121 196
# before open market
# 827 121 197
# before open market
# 828 122 197
# before open market
# 829 123 197
# before open market
# 830 124 197
# position and Best Price is True
# 831 124 198
# position and Best Price is True
# 832 124 199
# position and Best Price is True
# 833 124 199
# position and Best Price is True
# 834 124 199
# position and Best Price is True
# 835 124 199
# position and Best Price is True
# 836 124 200
# position and Best Price is True
# 837 124 200
# position and Best Price is True
# 838 124 201
# position and Best Price is True
# 839 124 202
# position and Best Price is True
# 840 124 203
# position and Best Price is True
# 841 124 204
# position and Best Price is True
# 842 124 205
# position and Best Price is True
# 843 124 206
# position and Best Price is True
# 844 124 207
# position and Best Price is True
# 845 124 208
# position and Best Price is True
# 846 124 209
# position and Best Price is True
# 847 125 209
# position and Best Price is True
# 848 126 209
# position and Best Price is True
# 849 127 209
# position and Best Price is True
# 850 128 209
# position and Best Price is True
# 851 128 209
# position and Best Price is True
# 852 128 209
# position and Best Price is True
# 853 129 209
# position and Best Price is True
# 854 130 209
# position and Best Price is True
# 855 130 209
# position and Best Price is True
# 856 131 209
# position and Best Price is True
# 857 132 209
# position and Best Price is True
# 858 133 209
# position and Best Price is True
# 859 134 209
# position and Best Price is True
# 860 135 209
# position and Best Price is True
# 861 136 209
# position and Best Price is True
# 862 137 209
# position and Best Price is True
# 863 138 209
# position and Best Price is True
# 864 139 209
# position and Best Price is True
# 865 140 209
# position and Best Price is True
# 866 141 209
# position and Best Price is True
# 867 142 209
# Some error5(Bid & Q<0 & timestamp change & 2),position = 20,index = 867,price = 668000,OrderNumber = A3A4E12BAF8091C0
# Total time = 76.090098

# %%
data[865:868]
# Out:
#     Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 865  CNG14             866  2014-01-30D09:00:03.508037600  015A453E967E789E
# 866  CNG14             867  2014-01-30D09:00:03.531037600  2BA4612B6D044F44
# 867  CNG14             868  2014-01-30D09:00:03.547037600  A3A4E12BAF8091C0
#
#      OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 865                 28  667000                   1              B     672000
# 866                 29  667000                   1              B     672000
# 867                 21  668000                  -1              B     672000
#
#      BestQuantity  QuantityDifference_
# 865            46                    1
# 866            46                    1
# 867            47                   -1

# %%
temp_ask,temp_bid,best_price,best_quantity
# Out:
# (209, 143, 672000, 46)

# %%
order_book_bid[143]
# Out:
#      Price       OrderNumber  QuantityDifference  QuantityDifference_
# 0   672000  AD19452667B04C70                  15                   15
# 1   672000  AD91452E50DD359D                  15                   15
# 2   672000  AB2C6123BF3DA17D                   1                    1
# 3   672000  AD19452E2CD01190                  15                   15
# 4   671500  F00DAF85379C189C                  10                   10
# 5   671000  7CA2E30920EE052E                  48                   50
# 6   671000  D4A2621D51303010                  20                   20
# 7   670500  74A2E7010AE6EF27                  22                   22
# 8   670500  A158C53E826F674F                  30                   30
# 9   670000  7071660D57A33AC3                   1                    1
# 10  670000  A71E496E02E4E7E5                  30                   30
# 11  669500  7071E605384E1B6E                 130                  130
# 12  669500  D47AEA0571815561                  27                   27
# 13  669500  2BAC61237AF85D38                   1                    1
# 14  669500  8B9EC17E3E8D20ED                   1                    1
# 15  669000  F071660D6D755095                  20                   20
# 16  669000  74A2E309ABEA902A                 130                  130
# 17  668500  F0F1E605ADD890F8                 196                  196
# 18  668500  D0F04B51A9918D91                  27                   27
# 19  668000  2DD0417EFB04DFC4                   1                    1
# 20  668000  A3A4E12BAF8091C0                   1                    1
# 21  667500  F42AEF09E613CA53                   1                    1
# 22  667500  0BA8ED2B3D561F96                   1                    1
# 23  667000  58B96A4592587578                   1                    1
# 24  667000  D6336701B88599E5                 200                  200
# 25  667000  2B24612B579839D8                   1                    1
# 26  667000  831E4976C094A2F4                   2                    2
# 27  667000  015A453E967E789E                   1                    1
# 28  667000  2BA4612B6D044F44                   1                    1
# 29  666500  74AAEF097F526392                   1                    1
# ..     ...               ...                 ...                  ...
# 61  660000  6CB163000307E808                 100                  100
# 62  660000  70F9E60D28000B20                   2                    2
# 63  660000  50B1EA4DA4338753                   1                    1
# 64  657500  83306123592B3B6B                   1                    1
# 65  657500  0B06457E153BF79C                  23                   23
# 66  657000  8BB4E52B9CAC7EEC                  23                   23
# 67  656500  89CAC9361123F344                   1                    1
# 68  656500  AB46453E5DC54025                   1                    1
# 69  656500  291645367CBA5EDA                  23                   23
# 70  656000  8B34E52BCB90ADD0                  50                   50
# 71  655500  01D2C936D78EB9AE                  42                   42
# 72  655500  81D2C936B0BF92DF                  47                   47
# 73  655000  299645363C7A1E9A                  39                   39
# 74  655000  8B06457E107EF2DF                  37                   37
# 75  654500  A9164536E2ECC50C                  44                   44
# 76  654000  0B86457E92C47524                  45                   45
# 77  653500  8152C9368AEA6D0A                  45                   45
# 78  653500  0B3CE52B5BD93E19                  46                   46
# 79  653000  7422E301C4DBA91B                   5                    5
# 80  653000  A996453630C812E8                  41                   41
# 81  653000  8B86457EE898CAF8                  51                   51
# 82  652500  291E4536BEB5A0D5                  49                   49
# 83  652000  8D19C52E1C820142                   1                    1
# 84  651500  74A2EF01357119B1                   5                    5
# 85  650000  F079E60D468F29AF                   2                    2
# 86  650000  8BB8E923A8D28B12                   1                    1
# 87  642500  8F1D456EC3C0A640                   4                    4
# 88  641500  D0B9EA45AFE79307                  10                   10
# 89  632500  8943C12E6C734ED3                  10                   10
# 90  631500  5821EE451C2AFF4B                  20                   20
#
# [91 rows x 4 columns]

# %%
order_book_ask[1561]
# Out:
#       Price       OrderNumber  QuantityDifference  QuantityDifference_
# 0    673000  2364ED2BFD07DF47                  39                   50
# 1    673000  2546C56662A847A8                   1                    1
# 2    673000  703B6205650344C3                  10                   10
# 3    673500  7021EE45C802AB22                   2                    2
# 4    673500  A320652B37571997                   1                    1
# 5    673500  562D86D190FE717E                  10                   10
# 6    673500  583B66051CD2FC93                  10                   10
# 7    673500  5424E24D67034663                  10                   10
# 8    673500  54ABE205282E0B6E                  10                   10
# 9    673500  0B584D3E5A2E3F0E                  45                   45
# 10   673500  F8AAC655F778D678                  10                   10
# 11   673500  52EE42459FD07ED0                  10                   10
# 12   673500  786DC24542E92649                   9                    9
# 13   673500  54AA0AC1A6C58745                  15                   15
# 14   673500  2B91CD76171BF99C                   8                    8
# 15   674000  743AEB017EEF632F                   3                    3
# 16   674000  A145CD2E8BD07090                   1                    1
# 17   674000  D870C351F32DD72D                  50                   50
# 18   674000  D6AAEA45FC02DAE2                   3                    3
# 19   674000  2DDEC5664FFA34FA                  45                   45
# 20   674000  7CFA0A89FC56DCD6                  10                   10
# 21   674000  D42B620DE04AC38A                  10                   10
# 22   674000  DAB94B59358F14CF                  10                   10
# 23   674000  5A72E25D25E005A0                  40                   40
# 24   674000  A340413634B11991                  15                   15
# 25   674000  583B6E0DE833C7F3                  10                   10
# 26   674000  54AB6E0DFD44E084                  10                   10
# 27   674000  D433E60D519034D0                  10                   10
# 28   674000  DA7B4215EEBFD27F                  10                   10
# 29   674000  7E8C2BDD205C015C                  10                   10
# ..      ...               ...                 ...                  ...
# 159  690500  F422E3092A7B0EBB                   1                    1
# 160  691000  6EA6E34859783E78                  10                   10
# 161  691500  F42AE301BE7FA2BF                   1                    1
# 162  692000  03A0E9239C0F7E4F                   1                    1
# 163  694000  2B38E5235FD34213                   2                    2
# 164  696000  0FC64D6E08BCEADD                  10                   10
# 165  696500  F0F9660DC98CACAC                   1                    1
# 166  697500  85914D2EB9369DF6                   1                    1
# 167  698000  70F1660D31FB151B                   3                    3
# 168  698500  D8316A4D6CA64FC6                  10                   10
# 169  699000  662E6B4847A22CA2                  10                   10
# 170  700000  BFC92EA46AE44FA4                   1                    1
# 171  700000  7CAA630160DC451C                   2                    2
# 172  700000  03A8ED2B0B99EDDA                   1                    1
# 173  701500  7422E309B47598B5                   1                    1
# 174  702000  0328E923CB03AD43                   1                    1
# 175  706500  F071E605F211D531                   1                    1
# 176  708000  74A2E301A7F98C39                   8                    8
# 177  708500  FC226F01E629CA69                  20                   20
# 178  710000  8F9D456E75BE583E                   4                    4
# 179  710000  0BA06D2321B203F2                   1                    1
# 180  712000  8328E92390437283                   1                    1
# 181  713500  8943C126D460B6C0                  10                   10
# 182  717500  2BD5C16638561AB6                  10                   10
# 183  718500  F021624DB2EB960B                   1                   20
# 184  718500  FCE26301BBFFA03F                  19                   19
# 185  721000  83A0E92BE5DDC81D                   1                    1
# 186  725000  7A666A457D4F5C2F                   4                    4
# 187  737000  74AAE301440E284E                  19                   19
# 188  737000  F079660DC063A383                   1                    1
#
# [189 rows x 4 columns]

# %%
position_
# Out:
# 0

# %%
data[108:109]
# Out:
#     Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 108  CNG14             109  2014-01-30D08:50:29.121495300  FA6ACA4D2D540C54
#
#      OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 108                  1  674500                   1              B     674500
#
#      BestQuantity  QuantityDifference_
# 108            10                    1

# %%
#order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] #> data['Price'][i:i+1].iloc[0]

# %%
#data['Price'][i:i+1].iloc[0]

# %%
import time 
data['QuantityDifference_'] = data['QuantityDifference']
data_ask = data[(data.BidOrAsk == 'A')].reset_index(drop=True)
data_bid = data[(data.BidOrAsk == 'B')].reset_index(drop=True)
def insert(order_book_data,data_to_insert,ob_position):
    top = order_book_data[0:ob_position]
    bottom = order_book_data[ob_position:]
    return pd.concat((top,data_to_insert,bottom)).reset_index(drop = True)

start  =  time.time()
order_book_bid = []
order_book_ask = []
timestamp = data.TimeStamp[0]
temp_ask = 0
temp_bid = 0
bid = []
ask = []
timestamp_ = []
x1 = data[(data.BidOrAsk == 'A')].TimeStamp.unique()
x2 = data[(data.BidOrAsk == 'B')].TimeStamp.unique()
y = data[data['TimeStamp'].str.contains(timestamp)]
bid.append(y[(y.BidOrAsk == 'B')][["Price","OrderNumber","QuantityDifference","QuantityDifference_"]]) # bid
ask.append(y[(y.BidOrAsk == 'A')][["Price","OrderNumber","QuantityDifference","QuantityDifference_"]]) # ask
a = bid[0].sort(['Price'],ascending = [False])
b = ask[0].sort(['Price'],ascending = [True])    
order_book_bid.append(a[a.QuantityDifference != 0].reset_index(drop = True))
order_book_ask.append(b[b.QuantityDifference != 0].reset_index(drop = True))
order_book_bid.append(0)
order_book_ask.append(0)

for i in range(len(y),1000,1):
    print i,temp_bid,temp_ask
    if data.BidOrAsk[i] == 'A':
        if order_book_bid[temp_bid].Price[0] >= data[i:i+1].Price.iloc[0]:
            for k in range(0,len(order_book_bid[temp_bid])):
                diff = order_book_bid[temp_bid].QuantityDifference_[k] - data[i:i+1].QuantityDifference_.iloc[0]
                print 'diff_ask = %d'%(diff)
                if order_book_bid[temp_bid].Price[k] >= data[i:i+1].Price.iloc[0] and diff >= 0:
                    order_book_bid[temp_bid].QuantityDifference_[k] = diff
                    data[i:i+1].QuantityDifference_.iloc[0] = 0
                    print 'hello1 + %d'%(k)
                    break
                elif order_book_bid[temp_bid].Price[k] >= data[i:i+1].Price.iloc[0] and diff < 0:
                    order_book_bid[temp_bid].QuantityDifference_[k] = 0
                    data[i:i+1].QuantityDifference_.iloc[0] = -diff
                    print 'hello2 + %d'%(k)
                    pass
                else:
                    break
        if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            if data.TimeStamp[i] == x1[temp_ask]:
                #time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                #              int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                #              int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                #if 31500 <= time_second < 31800 :
                #    length_order_book_zero = len(order_book_ask[temp_ask][(order_book_ask[temp_ask].Price <= data['Price'][i:i+1].iloc[0]) & (order_book_ask[temp_ask].QuantityDifference_ == 0)])
                #else:
                #    length_order_book_zero = 0
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 #+ length_order_book_zero
                order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)
                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Ask & Q>0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass
                elif 0 < position_< (len(order_book_ask[temp_ask])-1):
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]:#or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Ask & Q>0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'   
                        pass
                elif position_ == len(order_book_ask[temp_ask])-1:
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Ask & Q>0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                
                        pass
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True' 
                    pass
                
            elif data.TimeStamp[i] != x1[temp_ask]:
                if temp_ask == 0:
                    #time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                    #              int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                    #              int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                    #if 31500 < time_second < 31800 :
                    #    length_order_book_zero = len(order_book_ask[temp_ask][(order_book_ask[temp_ask].Price <= data['Price'][i:i+1].iloc[0]) & (order_book_ask[temp_ask].QuantityDifference_ == 0)])
                    #else:
                    #    length_order_book_zero = 0
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = order_book_ask[temp_ask - 1]
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 #+ length_order_book_zero
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)                  
                   
                    if position_ == 0 and len(order_book_ask[0]) > 1:
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Ask & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Ask & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_ask[temp_ask])-1:   
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Ask & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            break
                        else:
                            print 'position and Best Price is True'
                            pass
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        pass
                else:
                    #time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                    #              int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                    #              int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                    #if 31500 < time_second < 31800 :
                    #    length_order_book_zero = len(order_book_ask[temp_ask][(order_book_ask[temp_ask].Price <= data['Price'][i:i+1].iloc[0]) & (order_book_ask[temp_ask].QuantityDifference_ == 0)])
                    #else:
                    #    length_order_book_zero = 0
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 #+ length_order_book_zero
                    order_book_ask.append(order_book_ask[temp_ask])
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)#int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    if position_ == 0:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3(Ask & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3(Ask & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:    
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3(Ask & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            break
                        else:
                            print 'position and Best Price is True'                        
                            pass
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        pass
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x1[temp_ask]: 
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_ask[temp_ask][order_book_ask[temp_ask].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error4(Ask & Q<0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass       
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error4(Ask & Q<0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_ask[temp_ask])-1:       
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error4(Ask & Q<0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])   
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass                        
                    else:
                        print 'position and Best Price is True'                        
                        pass
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    pass
    
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]

            elif data.TimeStamp[i] != x1[temp_ask]:
                order_book_ask.append(order_book_ask[temp_ask])
                order_number_ =  data['OrderNumber'][i : i + 1].iloc[0]
                position_ = order_book_ask[temp_ask][order_book_ask[temp_ask].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_ask = temp_ask + 1

                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Ask & Q<0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Ask & Q<0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Ask & Q<0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass                       
                    else:
                        print 'position and Best Price is True'                        
                        pass
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    pass      
                    
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                    
    elif data.BidOrAsk[i] == 'B':
        if order_book_ask[temp_ask].Price[0] <= data[i:i+1].Price.iloc[0]:
            for k in range(0,len(order_book_ask[temp_ask])):
                diff = order_book_ask[temp_ask].QuantityDifference_[k] - data[i:i+1].QuantityDifference_.iloc[0]
                print 'diff_bid = %d'%(diff)
                if order_book_ask[temp_ask].Price[k] <= data[i:i+1].Price.iloc[0] and diff >= 0:
                    order_book_ask[temp_ask].QuantityDifference_[k] = diff
                    data[i:i+1].QuantityDifference_.iloc[0] = 0
                    print 'hello3 + %d'%(k)
                    break
                elif order_book_ask[temp_ask].Price[k] <= data[i:i+1].Price.iloc[0] and diff < 0:
                    order_book_ask[temp_ask].QuantityDifference_[k] = 0
                    data[i:i+1].QuantityDifference_.iloc[0] = -diff
                    print 'hello4 + %d'%(k)
                    pass
                else:
                    break
        if int(data[['QuantityDifference']][i:i+1].values) > 0: 
            if data.TimeStamp[i] == x2[temp_bid] :               
                #time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                #              int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                #              int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                #if 31500 <= time_second < 31800 :
                #    length_order_book_zero = len(order_book_bid[temp_bid][(order_book_bid[temp_bid].Price > data['Price'][i:i+1].iloc[0]) & (order_book_bid[temp_bid].QuantityDifference_ == 0)])
                #else:
                #    length_order_book_zero = 0
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 #+ length_order_book_zero
                order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Bid & Q>0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass     
                elif 0 < position_< len(order_book_bid[temp_bid])-1: 
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Bid & Q>0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'   
                        pass
                elif position_ == len(order_book_bid[temp_bid])-1 and len(order_book_bid[0]) > 1:      
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Bid & Q>0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                
                        pass
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    pass  
            elif data.TimeStamp[i] != x2[temp_bid]:
                if temp_bid == 0:
                    #time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                    #              int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                    #              int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                    #if 31500 <= time_second < 31800 :
                    #    length_order_book_zero = len(order_book_bid[temp_bid][(order_book_bid[temp_bid].Price > data['Price'][i:i+1].iloc[0]) & (order_book_bid[temp_bid].QuantityDifference_ == 0)])
                    #else:
                    #    length_order_book_zero = 0
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 #+ length_order_book_zero
                    temp_bid = temp_bid + 1
                    order_book_bid[temp_bid] = order_book_bid[temp_bid - 1]
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)#int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    if position_ == 0  and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Bid & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass       
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Bid & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_bid[temp_bid])-1:    
                        if order_book_bid[temp_bid][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Bid & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])                                        
                            pass
                        else:
                            print 'position and Best Price is True'
                            pass
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                            print 'position and Best Price is True'
                            pass
                else:
                    #time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                    #              int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                    #              int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                    #if 31500 <= time_second < 31800 :
                    #    length_order_book_zero = len(order_book_bid[temp_bid][(order_book_bid[temp_bid].Price > data['Price'][i:i+1].iloc[0]) & (order_book_bid[temp_bid].QuantityDifference_ == 0)])
                    #else:
                    #    length_order_book_zero = 0                    
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 #+ length_order_book_zero
                    order_book_bid.append(order_book_bid[temp_bid])
                    temp_bid = temp_bid + 1 
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)   
                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3(Bid & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3(Bid & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_bid[temp_bid])-1:
                        
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3(Bid & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            break
                        else:
                            print 'position and Best Price is True'                        
                            pass
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        pass
                        
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x2[temp_bid]: 
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_bid[temp_bid][order_book_bid[temp_bid].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error4(Bid & Q<0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass               
                elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error4(Bid & Q<0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_bid[temp_bid])-1:
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]:
                        print 'Some error4(Bid & Q<0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass
                    else:
                        #print 'position and Best Price is True'                        
                        pass
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    pass
                    
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]                
            elif data.TimeStamp[i] != x2[temp_bid]:
                order_book_bid.append(order_book_bid[temp_bid])
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_bid[temp_bid][order_book_bid[temp_bid].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_bid = temp_bid + 1
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error5(Bid & Q<0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass
                elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error5(Bid & Q<0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_bid[temp_bid])-1: 
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Bid & Q<0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass
                    else:
                        print 'position and Best Price is True'                        
                        pass    
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    pass  
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
end = time.time()            
print "Total time = %f"%(end - start)
# Out:
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:24: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# 13 0 0
# position and Best Price is True
# 14 1 0
# position and Best Price is True
# 15 2 0
# position and Best Price is True
# 16 3 0
# position and Best Price is True
# 17 4 0
# position and Best Price is True
# 18 5 0
# position and Best Price is True
# 19 6 0
# position and Best Price is True
# 20 7 0
# position and Best Price is True
# 21 7 1
# position and Best Price is True
# 22 8 1
# position and Best Price is True
# 23 9 1
# position and Best Price is True
# 24 10 1
# position and Best Price is True
# 25 11 1
# 26 11 1
# position and Best Price is True
# 27 12 1
# position and Best Price is True
# 28 13 1
# position and Best Price is True
# 29 14 1
# position and Best Price is True
# 30 14 2
# position and Best Price is True
# 31 15 2
# position and Best Price is True
# 32 15 2
# position and Best Price is True
# 33 15 3
# position and Best Price is True
# 34 15 3
# position and Best Price is True
# 35 15 4
# position and Best Price is True
# 36 16 4
# position and Best Price is True
# 37 16 5
# position and Best Price is True
# 38 16 6
# position and Best Price is True
# 39 16 6
# position and Best Price is True
# 40 16 7
# position and Best Price is True
# 41 16 7
# position and Best Price is True
# 42 16 8
# position and Best Price is True
# 43 16 9
# position and Best Price is True
# 44 16 10
# position and Best Price is True
# 45 17 10
# position and Best Price is True
# 46 17 11
# position and Best Price is True
# 47 17 12
# position and Best Price is True
# 48 18 12
# position and Best Price is True
# 49 18 13
# position and Best Price is True
# 50 18 14
# position and Best Price is True
# 51 19 14
# position and Best Price is True
# 52 19 15
# position and Best Price is True
# 53 19 16
# position and Best Price is True
# 54 19 17
# position and Best Price is True
# 55 19 18
# position and Best Price is True
# 56 19 18
# position and Best Price is True
# 57 19 19
# position and Best Price is True
# 58 20 19
# position and Best Price is True
# 59 21 19
# position and Best Price is True
# 60 21 20
# position and Best Price is True
# 61 22 20
# position and Best Price is True
# 62 22 21
# position and Best Price is True
# 63 22 22
# position and Best Price is True
# 64 22 23
# position and Best Price is True
# 65 22 24
# position and Best Price is True
# 66 22 25
# diff_bid = 19
# hello3 + 0
# position and Best Price is True
# 67 23 25
# position and Best Price is True
# 68 23 26
# position and Best Price is True
# 69 23 27
# position and Best Price is True
# 70 23 28
# position and Best Price is True
# 71 24 28
# position and Best Price is True
# 72 24 29
# diff_bid = 18
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:247: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:248: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# hello3 + 0
# position and Best Price is True
# 73 25 29
# diff_bid = 16
# hello3 + 0
# position and Best Price is True
# 74 26 29
# diff_bid = 15
# hello3 + 0
# position and Best Price is True
# 75 27 29
# diff_bid = 17
# hello3 + 0
# position and Best Price is True
# 76 28 29
# diff_bid = 18
# hello3 + 0
# position and Best Price is True
# 77 29 29
# diff_bid = 17
# hello3 + 0
# position and Best Price is True
# 78 30 29
# diff_bid = 16
# hello3 + 0
# position and Best Price is True
# 79 31 29
# diff_bid = 15
# hello3 + 0
# position and Best Price is True
# 80 32 29
# diff_bid = 14
# hello3 + 0
# position and Best Price is True
# 81 33 29
# diff_bid = 13
# hello3 + 0
# position and Best Price is True
# 82 34 29
# diff_bid = 12
# hello3 + 0
# position and Best Price is True
# 83 35 29
# diff_ask = -3
# hello2 + 0
# diff_ask = -3
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# hello2 + 1
# diff_ask = -3
# hello2 + 2
# diff_ask = -3
# hello2 + 3
# diff_ask = -3
# hello2 + 4
# diff_ask = -3
# hello2 + 5
# diff_ask = -3
# hello2 + 6
# diff_ask = -3
# hello2 + 7
# diff_ask = 47
# position and Best Price is True
# 84 35 30
# position and Best Price is True
# 85 36 30
# diff_bid = 2
# hello3 + 0
# position and Best Price is True
# 86 37 30
# position and Best Price is True
# 87 37 31
# diff_ask = 3
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# hello1 + 0
# position and Best Price is True
# 88 37 32
# diff_bid = 11
# hello3 + 0
# position and Best Price is True
# 89 38 32
# diff_ask = 0
# hello1 + 0
# position and Best Price is True
# 90 38 33
# position and Best Price is True
# 91 39 33
# position and Best Price is True
# 92 39 34
# position and Best Price is True
# 93 40 34
# diff_ask = 3
# hello1 + 0
# position and Best Price is True
# 94 40 35
# position and Best Price is True
# 95 41 35
# position and Best Price is True
# 96 42 35
# position and Best Price is True
# 97 43 35
# position and Best Price is True
# 98 44 35
# position and Best Price is True
# 99 44 36
# diff_ask = 2
# hello1 + 0
# position and Best Price is True
# 100 44 37
# diff_ask = 0
# hello1 + 0
# position and Best Price is True
# 101 44 38
# position and Best Price is True
# 102 45 38
# diff_ask = -6
# hello2 + 0
# diff_ask = -6
# hello2 + 1
# diff_ask = -6
# hello2 + 2
# diff_ask = -6
# hello2 + 3
# diff_ask = -6
# hello2 + 4
# diff_ask = -6
# hello2 + 5
# diff_ask = -6
# hello2 + 6
# diff_ask = -6
# hello2 + 7
# diff_ask = -6
# hello2 + 8
# diff_ask = -6
# hello2 + 9
# diff_ask = 44
# position and Best Price is True
# 103 45 39
# diff_ask = -1
# hello2 + 0
# diff_ask = -1
# hello2 + 1
# diff_ask = -1
# hello2 + 2
# diff_ask = -1
# hello2 + 3
# diff_ask = -1
# hello2 + 4
# diff_ask = -1
# hello2 + 5
# diff_ask = -1
# hello2 + 6
# diff_ask = -1
# hello2 + 7
# diff_ask = -1
# hello2 + 8
# diff_ask = -1
# hello2 + 9
# diff_ask = 49
# position and Best Price is True
# 104 45 40
# position and Best Price is True
# 105 46 40
# diff_ask = -1
# hello2 + 0
# diff_ask = -1
# hello2 + 1
# diff_ask = -1
# hello2 + 2
# diff_ask = -1
# hello2 + 3
# diff_ask = -1
# hello2 + 4
# diff_ask = -1
# hello2 + 5
# diff_ask = -1
# hello2 + 6
# diff_ask = -1
# hello2 + 7
# diff_ask = -1
# hello2 + 8
# diff_ask = -1
# hello2 + 9
# diff_ask = 49
# position and Best Price is True
# 106 46 41
# diff_ask = -70
# hello2 + 0
# diff_ask = -70
# hello2 + 1
# diff_ask = -70
# hello2 + 2
# diff_ask = -70
# hello2 + 3
# diff_ask = -70
# hello2 + 4
# diff_ask = -70
# hello2 + 5
# diff_ask = -70
# hello2 + 6
# diff_ask = -70
# hello2 + 7
# diff_ask = -70
# hello2 + 8
# diff_ask = -70
# hello2 + 9
# diff_ask = -20
# position and Best Price is True
# 107 46 42
# diff_bid = 1
# hello3 + 0
# position and Best Price is True
# 108 47 42
# Some error1(Bid & Q>0 & timestamp not change & 1),position = 0,index = 108,price = 674500,OrderNumber = FA6ACA4D2D540C54
# Total time = 6.936419

# %%
len(order_book_bid),len(order_book_ask)
# Out:
# (358, 286)

# %%
#order_book_bid[357]

# %%
#order_book_ask[285]

# %%
len(data[0:len(data)][(data[0:len(data)].BidOrAsk == 'A')].TimeStamp.unique()),len(data[0:len(data)][(data[0:len(data)].BidOrAsk == 'B')].TimeStamp.unique())
# Out:
# (18184, 18315)

# %%
import time
start = time.time()
order_book_bid_merge = []
order_book_ask_merge = []
for i in range(0,len(order_book_bid)):
    a = order_book_bid[i][['Price','QuantityDifference']].groupby(by = ['Price'],as_index = False).sum()#.sort(['Price'],ascending = [False])
    order_book_bid_merge.append(pd.DataFrame(a.values))
for i in range(0,len(order_book_ask)):
    a = order_book_ask[i][['Price','QuantityDifference']].groupby(by = ['Price'],as_index = False).sum()#.sort(['Price'],ascending = [True])
    order_book_ask_merge.append(pd.DataFrame(a.values))
end = time.time()            
print ("Total time = %f"%(end - start))
# Out:
# Total time = 226.436287

# %%
import time 
data['QuantityDifference_'] = data['QuantityDifference']
data_ask = data[(data.BidOrAsk == 'A')].reset_index(drop=True)
data_bid = data[(data.BidOrAsk == 'B')].reset_index(drop=True)
def insert(order_book_data,data_to_insert,ob_position):
    top = order_book_data[0:ob_position]
    bottom = order_book_data[ob_position:]
    return pd.concat((top,data_to_insert,bottom)).reset_index(drop = True)

start  =  time.time()
order_book_bid = []
order_book_ask = []
timestamp = data.TimeStamp[0]
temp_ask = 0
temp_bid = 0
bid = []
ask = []
timestamp_ = []
x1 = data[(data.BidOrAsk == 'A')].TimeStamp.unique()
x2 = data[(data.BidOrAsk == 'B')].TimeStamp.unique()
y = data[data['TimeStamp'].str.contains(timestamp)]
bid.append(y[(y.BidOrAsk == 'B')][["Price","OrderNumber","QuantityDifference","QuantityDifference_"]]) # bid
ask.append(y[(y.BidOrAsk == 'A')][["Price","OrderNumber","QuantityDifference","QuantityDifference_"]]) # ask
a = bid[0].sort(['Price'],ascending = [False])
b = ask[0].sort(['Price'],ascending = [True])    
order_book_bid.append(a[a.QuantityDifference != 0].reset_index(drop = True))
order_book_ask.append(b[b.QuantityDifference != 0].reset_index(drop = True))
order_book_bid.append(0)
order_book_ask.append(0)

for i in range(len(y),1000,1):
    print i,temp_bid,temp_ask
    if data.BidOrAsk[i] == 'A':
        if order_book_bid[temp_bid].Price[0] >= data[i:i+1].Price.iloc[0]:
            for k in range(0,len(order_book_bid[temp_bid])):
                diff = order_book_bid[temp_bid].QuantityDifference_[k] - data[i:i+1].QuantityDifference_.iloc[0]
                print 'diff_ask = %d'%(diff)
                if order_book_bid[temp_bid].Price[k] >= data[i:i+1].Price.iloc[0] and diff >= 0:
                    order_book_bid[temp_bid].QuantityDifference_[k] = diff
                    data[i:i+1].QuantityDifference_.iloc[0] = 0
                    print 'hello1 + %d'%(k)
                    break
                elif order_book_bid[temp_bid].Price[k] >= data[i:i+1].Price.iloc[0] and diff < 0:
                    order_book_bid[temp_bid].QuantityDifference_[k] = 0
                    data[i:i+1].QuantityDifference_.iloc[0] = -diff
                    print 'hello2 + %d'%(k)
                    pass
                else:
                    break
        if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            if data.TimeStamp[i] == x1[temp_ask]:
                time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                              int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                              int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                print 'time second = %d'%(time_second)
                #if 31800 + 29 == time_second:#31800 + 29 <= time_second < 32400 :
                #    length_order_book_zero = len(order_book_ask[temp_ask][(order_book_ask[temp_ask].Price <= data['Price'][i:i+1].iloc[0]) & (order_book_ask[temp_ask].QuantityDifference_ == 0)])
                #else:
                #    length_order_book_zero = 0
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 #+ length_order_book_zero
                order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)
                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Ask & Q>0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass
                elif 0 < position_< (len(order_book_ask[temp_ask])-1):
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]:#or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Ask & Q>0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'   
                        pass
                elif position_ == len(order_book_ask[temp_ask])-1:
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Ask & Q>0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                
                        pass
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True' 
                    pass
                
            elif data.TimeStamp[i] != x1[temp_ask]:
                if temp_ask == 0:
                    time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                                  int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                                  int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                    print 'time second = %d'%(time_second)
                    #if 31800 + 29 == time_second:#31800 + 29 <= time_second < 32400 :
                    #    length_order_book_zero = len(order_book_ask[temp_ask][(order_book_ask[temp_ask].Price <= data['Price'][i:i+1].iloc[0]) & (order_book_ask[temp_ask].QuantityDifference_ == 0)])
                    #else:
                    #    length_order_book_zero = 0
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = order_book_ask[temp_ask - 1]
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 #+ length_order_book_zero
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)                  
                   
                    if position_ == 0 and len(order_book_ask[0]) > 1:
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Ask & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Ask & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_ask[temp_ask])-1:   
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Ask & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            break
                        else:
                            print 'position and Best Price is True'
                            pass
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        pass
                else:
                    time_second == int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                                  int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                                  int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                    print 'time second = %d'%(time_second)
                    #if 31800 + 29 == time_second:#31800 + 29 <= time_second < 32400 :
                    #    length_order_book_zero = len(order_book_ask[temp_ask][(order_book_ask[temp_ask].Price <= data['Price'][i:i+1].iloc[0]) & (order_book_ask[temp_ask].QuantityDifference_ == 0)])
                    #else:
                    #    length_order_book_zero = 0
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 #+ length_order_book_zero
                    order_book_ask.append(order_book_ask[temp_ask])
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)#int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    if position_ == 0:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3(Ask & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3(Ask & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:    
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3(Ask & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            break
                        else:
                            print 'position and Best Price is True'                        
                            pass
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        pass
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x1[temp_ask]: 
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_ask[temp_ask][order_book_ask[temp_ask].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error4(Ask & Q<0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass       
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error4(Ask & Q<0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_ask[temp_ask])-1:       
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error4(Ask & Q<0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])   
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass                        
                    else:
                        print 'position and Best Price is True'                        
                        pass
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    pass
    
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]

            elif data.TimeStamp[i] != x1[temp_ask]:
                order_book_ask.append(order_book_ask[temp_ask])
                order_number_ =  data['OrderNumber'][i : i + 1].iloc[0]
                position_ = order_book_ask[temp_ask][order_book_ask[temp_ask].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_ask = temp_ask + 1

                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Ask & Q<0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Ask & Q<0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Ask & Q<0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass                       
                    else:
                        print 'position and Best Price is True'                        
                        pass
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    pass      
                    
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                    
    elif data.BidOrAsk[i] == 'B':
        if order_book_ask[temp_ask].Price[0] <= data[i:i+1].Price.iloc[0]:
            for k in range(0,len(order_book_ask[temp_ask])):
                diff = order_book_ask[temp_ask].QuantityDifference_[k] - data[i:i+1].QuantityDifference_.iloc[0]
                print 'diff_bid = %d'%(diff)
                if order_book_ask[temp_ask].Price[k] <= data[i:i+1].Price.iloc[0] and diff >= 0:
                    order_book_ask[temp_ask].QuantityDifference_[k] = diff
                    data[i:i+1].QuantityDifference_.iloc[0] = 0
                    print 'hello3 + %d'%(k)
                    break
                elif order_book_ask[temp_ask].Price[k] <= data[i:i+1].Price.iloc[0] and diff < 0:
                    order_book_ask[temp_ask].QuantityDifference_[k] = 0
                    data[i:i+1].QuantityDifference_.iloc[0] = -diff
                    print 'hello4 + %d'%(k)
                    pass
                else:
                    break
        if int(data[['QuantityDifference']][i:i+1].values) > 0: 
            if data.TimeStamp[i] == x2[temp_bid] :               
                time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                              int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                              int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                print 'time second = %d'%(time_second)
                if 31800 + 29 == time_second or 31942 == time_second:#31800 + 29 <= time_second < 32400 :
                    length_order_book_zero = len(order_book_bid[temp_bid][(order_book_bid[temp_bid].Price >= data['Price'][i:i+1].iloc[0]) & (order_book_bid[temp_bid].QuantityDifference_ == 0)])
                else:
                    length_order_book_zero = 0
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 + length_order_book_zero
                order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Bid & Q>0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass     
                elif 0 < position_< len(order_book_bid[temp_bid])-1: 
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Bid & Q>0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'   
                        pass
                elif position_ == len(order_book_bid[temp_bid])-1 and len(order_book_bid[0]) > 1:      
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Bid & Q>0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                
                        pass
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    pass  
            elif data.TimeStamp[i] != x2[temp_bid]:
                if temp_bid == 0:
                    time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                                  int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                                  int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                    print 'time second = %d'%(time_second)
                    if 31800 + 29 == time_second or 31942 == time_second:#31800 + 29 <= time_second < 32400 :
                        length_order_book_zero = len(order_book_bid[temp_bid][(order_book_bid[temp_bid].Price >= data['Price'][i:i+1].iloc[0]) & (order_book_bid[temp_bid].QuantityDifference_ == 0)])
                    else:
                        length_order_book_zero = 0
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 + length_order_book_zero
                    temp_bid = temp_bid + 1
                    order_book_bid[temp_bid] = order_book_bid[temp_bid - 1]
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)#int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    if position_ == 0  and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Bid & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass       
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Bid & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_bid[temp_bid])-1:    
                        if order_book_bid[temp_bid][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Bid & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])                                        
                            pass
                        else:
                            print 'position and Best Price is True'
                            pass
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                            print 'position and Best Price is True'
                            pass
                else:
                    time_second = int(data[i:i+1].TimeStamp.iloc[0][18]) + int(data[i:i+1].TimeStamp.iloc[0][17])*10 +\
                                  int(data[i:i+1].TimeStamp.iloc[0][15])*60 + int(data[i:i+1].TimeStamp.iloc[0][14])*600 +\
                                  int(data[i:i+1].TimeStamp.iloc[0][12])*3600 + int(data[i:i+1].TimeStamp.iloc[0][11])*36000
                    print 'time second = %d'%(time_second)
                    if 31800 + 29 == time_second or 31942 == time_second:#31800 + 29 <= time_second < 32400 :
                        length_order_book_zero = len(order_book_bid[temp_bid][(order_book_bid[temp_bid].Price >= data['Price'][i:i+1].iloc[0]) & (order_book_bid[temp_bid].QuantityDifference_ == 0)])
                    else:
                        length_order_book_zero = 0                    
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1 + length_order_book_zero
                    order_book_bid.append(order_book_bid[temp_bid])
                    temp_bid = temp_bid + 1 
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference','QuantityDifference_']][i:i+1],position_)   
                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3(Bid & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3(Bid & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_bid[temp_bid])-1:
                        
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3(Bid & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            break
                        else:
                            print 'position and Best Price is True'                        
                            pass
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        pass
                        
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x2[temp_bid]: 
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_bid[temp_bid][order_book_bid[temp_bid].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error4(Bid & Q<0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass               
                elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error4(Bid & Q<0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_bid[temp_bid])-1:
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]:
                        print 'Some error4(Bid & Q<0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass
                    else:
                        #print 'position and Best Price is True'                        
                        pass
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    pass
                    
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]                
            elif data.TimeStamp[i] != x2[temp_bid]:
                order_book_bid.append(order_book_bid[temp_bid])
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_bid[temp_bid][order_book_bid[temp_bid].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_bid = temp_bid + 1
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error5(Bid & Q<0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass
                elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error5(Bid & Q<0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_bid[temp_bid])-1: 
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Bid & Q<0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass
                    else:
                        print 'position and Best Price is True'                        
                        pass    
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    pass  
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
end = time.time()            
print "Total time = %f"%(end - start)
# Out:
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:24: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# 13 0 0
# time second = 31500
# position and Best Price is True
# 14 1 0
# time second = 31501
# position and Best Price is True
# 15 2 0
# time second = 31501
# position and Best Price is True
# 16 3 0
# time second = 31501
# position and Best Price is True
# 17 4 0
# time second = 31501
# position and Best Price is True
# 18 5 0
# time second = 31501
# position and Best Price is True
# 19 6 0
# position and Best Price is True
# 20 7 0
# time second = 31526
# position and Best Price is True
# 21 7 1
# time second = 31530
# position and Best Price is True
# 22 8 1
# time second = 31531
# position and Best Price is True
# 23 9 1
# time second = 31544
# position and Best Price is True
# 24 10 1
# position and Best Price is True
# 25 11 1
# 26 11 1
# position and Best Price is True
# 27 12 1
# time second = 31553
# position and Best Price is True
# 28 13 1
# time second = 31553
# position and Best Price is True
# 29 14 1
# time second = 31553
# position and Best Price is True
# 30 14 2
# time second = 31560
# position and Best Price is True
# 31 15 2
# time second = 31560
# position and Best Price is True
# 32 15 2
# time second = 31560
# position and Best Price is True
# 33 15 3
# time second = 31560
# position and Best Price is True
# 34 15 3
# time second = 31560
# position and Best Price is True
# 35 15 4
# time second = 31560
# position and Best Price is True
# 36 16 4
# time second = 31560
# position and Best Price is True
# 37 16 5
# time second = 31560
# position and Best Price is True
# 38 16 6
# time second = 31560
# position and Best Price is True
# 39 16 6
# time second = 31560
# position and Best Price is True
# 40 16 7
# time second = 31560
# position and Best Price is True
# 41 16 7
# time second = 31560
# position and Best Price is True
# 42 16 8
# time second = 31560
# position and Best Price is True
# 43 16 9
# time second = 31560
# position and Best Price is True
# 44 16 10
# time second = 31560
# position and Best Price is True
# 45 17 10
# time second = 31560
# position and Best Price is True
# 46 17 11
# time second = 31560
# position and Best Price is True
# 47 17 12
# time second = 31560
# position and Best Price is True
# 48 18 12
# time second = 31560
# position and Best Price is True
# 49 18 13
# time second = 31560
# position and Best Price is True
# 50 18 14
# time second = 31560
# position and Best Price is True
# 51 19 14
# time second = 31560
# position and Best Price is True
# 52 19 15
# time second = 31560
# position and Best Price is True
# 53 19 16
# time second = 31560
# position and Best Price is True
# 54 19 17
# time second = 31560
# position and Best Price is True
# 55 19 18
# time second = 31560
# position and Best Price is True
# 56 19 18
# time second = 31560
# position and Best Price is True
# 57 19 19
# time second = 31561
# position and Best Price is True
# 58 20 19
# time second = 31561
# position and Best Price is True
# 59 21 19
# time second = 31561
# position and Best Price is True
# 60 21 20
# time second = 31562
# position and Best Price is True
# 61 22 20
# time second = 31562
# position and Best Price is True
# 62 22 21
# time second = 31562
# position and Best Price is True
# 63 22 22
# time second = 31562
# position and Best Price is True
# 64 22 23
# time second = 31562
# position and Best Price is True
# 65 22 24
# time second = 31562
# position and Best Price is True
# 66 22 25
# diff_bid = 19
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# hello3 + 0
# time second = 31575
# position and Best Price is True
# 67 23 25
# time second = 31575
# position and Best Price is True
# 68 23 26
# time second = 31575
# position and Best Price is True
# 69 23 27
# time second = 31575
# position and Best Price is True
# 70 23 28
# time second = 31586
# position and Best Price is True
# 71 24 28
# time second = 31586
# position and Best Price is True
# 72 24 29
# diff_bid = 18
# hello3 + 0
# time second = 31599
# position and Best Price is True
# 73 25 29
# diff_bid = 16
# hello3 + 0
# time second = 31604
# position and Best Price is True
# 74 26 29
# diff_bid = 15
# hello3 + 0
# time second = 31606
# position and Best Price is True
# 75 27 29
# diff_bid = 17
# hello3 + 0
# position and Best Price is True
# 76 28 29
# diff_bid = 18
# hello3 + 0
# position and Best Price is True
# 77 29 29
# diff_bid = 17
# hello3 + 0
# time second = 31615
# position and Best Price is True
# 78 30 29
# diff_bid = 16
# hello3 + 0
# time second = 31626
# position and Best Price is True
# 79 31 29
# diff_bid = 15
# hello3 + 0
# time second = 31634
# position and Best Price is True
# 80 32 29
# diff_bid = 14
# hello3 + 0
# time second = 31641
# position and Best Price is True
# 81 33 29
# diff_bid = 13
# hello3 + 0
# time second = 31646
# position and Best Price is True
# 82 34 29
# diff_bid = 12
# hello3 + 0
# time second = 31653
# position and Best Price is True
# 83 35 29
# diff_ask = -3
# hello2 + 0
# diff_ask = -3
# hello2 + 1
# diff_ask = -3
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# hello2 + 2
# diff_ask = -3
# hello2 + 3
# diff_ask = -3
# hello2 + 4
# diff_ask = -3
# hello2 + 5
# diff_ask = -3
# hello2 + 6
# diff_ask = -3
# hello2 + 7
# diff_ask = 47
# time second = 31653
# position and Best Price is True
# 84 35 30
# time second = 31655
# position and Best Price is True
# 85 36 30
# diff_bid = 2
# hello3 + 0
# time second = 31659
# position and Best Price is True
# 86 37 30
# time second = 31659
# position and Best Price is True
# 87 37 31
# diff_ask = 3
# hello1 + 0
# position and Best Price is True
# 88 37 32
# diff_bid = 11
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# hello3 + 0
# time second = 31666
# position and Best Price is True
# 89 38 32
# diff_ask = 0
# hello1 + 0
# time second = 31666
# position and Best Price is True
# 90 38 33
# time second = 31686
# position and Best Price is True
# 91 39 33
# time second = 31686
# position and Best Price is True
# 92 39 34
# time second = 31695
# position and Best Price is True
# 93 40 34
# diff_ask = 3
# hello1 + 0
# position and Best Price is True
# 94 40 35
# time second = 31749
# position and Best Price is True
# 95 41 35
# time second = 31759
# position and Best Price is True
# 96 42 35
# time second = 31759
# position and Best Price is True
# 97 43 35
# time second = 31765
# position and Best Price is True
# 98 44 35
# position and Best Price is True
# 99 44 36
# diff_ask = 2
# hello1 + 0
# time second = 31765
# position and Best Price is True
# 100 44 37
# diff_ask = 0
# hello1 + 0
# time second = 31765
# position and Best Price is True
# 101 44 38
# time second = 31779
# position and Best Price is True
# 102 45 38
# diff_ask = -6
# hello2 + 0
# diff_ask = -6
# hello2 + 1
# diff_ask = -6
# hello2 + 2
# diff_ask = -6
# hello2 + 3
# diff_ask = -6
# hello2 + 4
# diff_ask = -6
# hello2 + 5
# diff_ask = -6
# hello2 + 6
# diff_ask = -6
# hello2 + 7
# diff_ask = -6
# hello2 + 8
# diff_ask = -6
# hello2 + 9
# diff_ask = 44
# time second = 31779
# position and Best Price is True
# 103 45 39
# diff_ask = -1
# hello2 + 0
# diff_ask = -1
# hello2 + 1
# diff_ask = -1
# hello2 + 2
# diff_ask = -1
# hello2 + 3
# diff_ask = -1
# hello2 + 4
# diff_ask = -1
# hello2 + 5
# diff_ask = -1
# hello2 + 6
# diff_ask = -1
# hello2 + 7
# diff_ask = -1
# hello2 + 8
# diff_ask = -1
# hello2 + 9
# diff_ask = 49
# time second = 31779
# position and Best Price is True
# 104 45 40
# time second = 31812
# position and Best Price is True
# 105 46 40
# diff_ask = -1
# hello2 + 0
# diff_ask = -1
# hello2 + 1
# diff_ask = -1
# hello2 + 2
# diff_ask = -1
# hello2 + 3
# diff_ask = -1
# hello2 + 4
# diff_ask = -1
# hello2 + 5
# diff_ask = -1
# hello2 + 6
# diff_ask = -1
# hello2 + 7
# diff_ask = -1
# hello2 + 8
# diff_ask = -1
# hello2 + 9
# diff_ask = 49
# time second = 31812
# position and Best Price is True
# 106 46 41
# diff_ask = -70
# hello2 + 0
# diff_ask = -70
# hello2 + 1
# diff_ask = -70
# hello2 + 2
# diff_ask = -70
# hello2 + 3
# diff_ask = -70
# hello2 + 4
# diff_ask = -70
# hello2 + 5
# diff_ask = -70
# hello2 + 6
# diff_ask = -70
# hello2 + 7
# diff_ask = -70
# hello2 + 8
# diff_ask = -70
# hello2 + 9
# diff_ask = -20
# time second = 31812
# position and Best Price is True
# 107 46 42
# diff_bid = 1
# hello3 + 0
# position and Best Price is True
# 108 47 42
# time second = 31829
# position and Best Price is True
# 109 47 42
# diff_bid = 2
# hello3 + 0
# position and Best Price is True
# 110 47 42
# time second = 31829
# position and Best Price is True
# 111 47 42
# diff_bid = 3
# hello3 + 0
# position and Best Price is True
# 112 47 42
# time second = 31829
# position and Best Price is True
# 113 47 42
# diff_bid = 4
# hello3 + 0
# position and Best Price is True
# 114 47 42
# time second = 31829
# position and Best Price is True
# 115 47 42
# diff_bid = 5
# hello3 + 0
# position and Best Price is True
# 116 47 42
# time second = 31829
# position and Best Price is True
# 117 47 42
# diff_bid = 6
# hello3 + 0
# position and Best Price is True
# 118 47 42
# time second = 31829
# position and Best Price is True
# 119 47 42
# diff_bid = 7
# hello3 + 0
# position and Best Price is True
# 120 47 42
# time second = 31829
# position and Best Price is True
# 121 47 42
# diff_bid = 8
# hello3 + 0
# position and Best Price is True
# 122 47 42
# time second = 31829
# position and Best Price is True
# 123 47 42
# diff_bid = 9
# hello3 + 0
# position and Best Price is True
# 124 47 42
# time second = 31829
# position and Best Price is True
# 125 47 42
# diff_bid = 10
# hello3 + 0
# position and Best Price is True
# 126 47 42
# time second = 31829
# position and Best Price is True
# 127 47 42
# position and Best Price is True
# 128 47 42
# diff_ask = 0
# hello1 + 0
# time second = 31829
# position and Best Price is True
# 129 47 42
# position and Best Price is True
# 130 47 42
# diff_ask = -1
# hello2 + 0
# diff_ask = 0
# hello1 + 1
# time second = 31829
# position and Best Price is True
# 131 47 42
# position and Best Price is True
# 132 47 42
# diff_ask = -70
# hello2 + 0
# diff_ask = -70
# hello2 + 1
# diff_ask = -69
# hello2 + 2
# diff_ask = -68
# hello2 + 3
# diff_ask = -67
# hello2 + 4
# diff_ask = -66
# hello2 + 5
# diff_ask = -65
# hello2 + 6
# diff_ask = -64
# hello2 + 7
# diff_ask = -63
# hello2 + 8
# diff_ask = -62
# hello2 + 9
# diff_ask = -12
# time second = 31829
# position and Best Price is True
# 133 47 42
# diff_ask = -2
# hello2 + 0
# diff_ask = -2
# hello2 + 1
# diff_ask = -2
# hello2 + 2
# diff_ask = -2
# hello2 + 3
# diff_ask = -2
# hello2 + 4
# diff_ask = -2
# hello2 + 5
# diff_ask = -2
# hello2 + 6
# diff_ask = -2
# hello2 + 7
# diff_ask = -2
# hello2 + 8
# diff_ask = -2
# hello2 + 9
# diff_ask = 48
# time second = 31829
# position and Best Price is True
# 134 47 43
# time second = 31846
# position and Best Price is True
# 135 48 43
# time second = 31854
# position and Best Price is True
# 136 49 43
# time second = 31855
# position and Best Price is True
# 137 50 43
# time second = 31855
# position and Best Price is True
# 138 50 44
# time second = 31855
# position and Best Price is True
# 139 50 45
# time second = 31855
# position and Best Price is True
# 140 50 46
# position and Best Price is True
# 141 50 47
# time second = 31886
# position and Best Price is True
# 142 50 47
# time second = 31890
# position and Best Price is True
# 143 51 47
# time second = 31897
# position and Best Price is True
# 144 52 47
# time second = 31899
# position and Best Price is True
# 145 53 47
# time second = 31902
# position and Best Price is True
# 146 54 47
# time second = 31904
# position and Best Price is True
# 147 55 47
# time second = 31906
# position and Best Price is True
# 148 56 47
# time second = 31923
# position and Best Price is True
# 149 57 47
# time second = 31925
# position and Best Price is True
# 150 58 47
# time second = 31926
# position and Best Price is True
# 151 59 47
# time second = 31927
# position and Best Price is True
# 152 60 47
# time second = 31927
# position and Best Price is True
# 153 61 47
# time second = 31927
# position and Best Price is True
# 154 62 47
# time second = 31928
# position and Best Price is True
# 155 63 47
# time second = 31928
# position and Best Price is True
# 156 64 47
# time second = 31928
# position and Best Price is True
# 157 65 47
# time second = 31929
# position and Best Price is True
# 158 66 47
# time second = 31929
# position and Best Price is True
# 159 67 47
# time second = 31929
# position and Best Price is True
# 160 68 47
# time second = 31930
# position and Best Price is True
# 161 69 47
# time second = 31933
# position and Best Price is True
# 162 70 47
# time second = 31938
# position and Best Price is True
# 163 71 47
# diff_ask = -5
# hello2 + 0
# diff_ask = -5
# hello2 + 1
# diff_ask = -5
# hello2 + 2
# diff_ask = -5
# hello2 + 3
# diff_ask = -5
# hello2 + 4
# diff_ask = -5
# hello2 + 5
# diff_ask = -5
# hello2 + 6
# diff_ask = -5
# hello2 + 7
# diff_ask = -5
# hello2 + 8
# diff_ask = -5
# hello2 + 9
# diff_ask = 45
# time second = 31938
# position and Best Price is True
# 164 71 48
# diff_ask = -4
# hello2 + 0
# diff_ask = -4
# hello2 + 1
# diff_ask = -4
# hello2 + 2
# diff_ask = -4
# hello2 + 3
# diff_ask = -4
# hello2 + 4
# diff_ask = -4
# hello2 + 5
# diff_ask = -4
# hello2 + 6
# diff_ask = -4
# hello2 + 7
# diff_ask = -4
# hello2 + 8
# diff_ask = -4
# hello2 + 9
# diff_ask = 46
# time second = 31938
# position and Best Price is True
# 165 71 49
# diff_bid = 1
# hello3 + 0
# position and Best Price is True
# 166 72 49
# time second = 31942
# position and Best Price is True
# 167 72 49
# diff_bid = 2
# hello3 + 0
# position and Best Price is True
# 168 72 49
# time second = 31942
# position and Best Price is True
# 169 72 49
# diff_bid = 3
# hello3 + 0
# position and Best Price is True
# 170 72 49
# time second = 31942
# position and Best Price is True
# 171 72 49
# diff_bid = 4
# hello3 + 0
# position and Best Price is True
# 172 72 49
# time second = 31942
# position and Best Price is True
# 173 72 49
# diff_bid = 5
# hello3 + 0
# position and Best Price is True
# 174 72 49
# time second = 31942
# position and Best Price is True
# 175 72 49
# diff_bid = 6
# hello3 + 0
# position and Best Price is True
# 176 72 49
# time second = 31942
# position and Best Price is True
# 177 72 49
# diff_bid = 7
# hello3 + 0
# position and Best Price is True
# 178 72 49
# time second = 31942
# position and Best Price is True
# 179 72 49
# diff_bid = 8
# hello3 + 0
# position and Best Price is True
# 180 72 49
# time second = 31942
# position and Best Price is True
# 181 72 49
# diff_bid = 9
# hello3 + 0
# position and Best Price is True
# 182 72 49
# time second = 31942
# position and Best Price is True
# 183 72 49
# diff_bid = 10
# hello3 + 0
# position and Best Price is True
# 184 72 49
# time second = 31942
# position and Best Price is True
# 185 72 49
# position and Best Price is True
# 186 72 49
# diff_ask = 0
# hello1 + 0
# time second = 31942
# position and Best Price is True
# 187 72 49
# position and Best Price is True
# 188 72 49
# diff_ask = -1
# hello2 + 0
# diff_ask = 0
# hello1 + 1
# time second = 31942
# position and Best Price is True
# 189 72 49
# position and Best Price is True
# 190 72 49
# diff_ask = -5
# hello2 + 0
# diff_ask = -5
# hello2 + 1
# diff_ask = -4
# hello2 + 2
# diff_ask = -3
# hello2 + 3
# diff_ask = -2
# hello2 + 4
# diff_ask = -1
# hello2 + 5
# diff_ask = 0
# hello1 + 6
# time second = 31942
# position and Best Price is True
# 191 72 49
# position and Best Price is True
# 192 72 49
# diff_ask = -4
# hello2 + 0
# diff_ask = -4
# hello2 + 1
# diff_ask = -4
# hello2 + 2
# diff_ask = -4
# hello2 + 3
# diff_ask = -4
# hello2 + 4
# diff_ask = -4
# hello2 + 5
# diff_ask = -4
# hello2 + 6
# diff_ask = -3
# hello2 + 7
# diff_ask = -2
# hello2 + 8
# diff_ask = -1
# hello2 + 9
# diff_ask = 49
# time second = 31942
# position and Best Price is True
# 193 72 49
# diff_ask = 4
# hello1 + 0
# position and Best Price is True
# 194 72 50
# diff_bid = 1
# hello3 + 0
# position and Best Price is True
# 195 73 50
# diff_bid = 0
# hello3 + 0
# time second = 31942
# position and Best Price is True
# 196 73 50
# diff_bid = 1
# hello3 + 0
# position and Best Price is True
# 197 73 50
# diff_bid = 0
# hello3 + 0
# time second = 31942
# Some error1(Bid & Q>0 & timestamp not change & 2),position = 2,index = 197,price = 674500,OrderNumber = 74224A0DC315A215
# Total time = 16.633069

# %%
#data[(data.BidOrAsk == 'B')].TimeStamp.unique()[:]

# %%
#data[(data.BidOrAsk == 'A')].TimeStamp.unique()[0:]

# %%
import time
start = time.time()
time_ = data.TimeStamp.unique()
time_bid = data[(data.BidOrAsk == 'B')].TimeStamp.unique()[1:]
time_ask = data[(data.BidOrAsk == 'A')].TimeStamp.unique()[1:]
bid_index = 0
ask_index = 0
a = 0
b = 0
first = pd.concat([pd.DataFrame(order_book_bid_merge[bid_index].iloc[::-1][0:3].values),pd.DataFrame(order_book_ask_merge[ask_index].iloc[0:3].values)],axis = 1)
first = pd.DataFrame(first.values)
time = pd.DataFrame([['TimeStamp',time_[0][11:29],'','']])
order_book_concat = time.append(first).reset_index(drop=True)
order_book = order_book_concat
#print order_book
time_series = 1
for time in time_[1:]:
    #print 'time' + time
    #print 'time_series = %d'%(time_series)
    time_to_concat = pd.DataFrame([['TimeStamp',time_[time_series][11:29],'','']])
    #print time_to_concat
    #print time_bid[a]
    #print time_ask[b]
    #print order_book_bid_merge[a]
    #print order_book_ask_merge[b]
    if time == time_bid[a] and time == time_ask[b]:
        #print '1 = ' + time
        bid_index = bid_index + 1
        ask_index = ask_index + 1
        order_book_no_time = pd.concat([pd.DataFrame(order_book_bid_merge[bid_index].iloc[::-1][0:3].values),pd.DataFrame(order_book_ask_merge[ask_index].iloc[0:3].values)],axis = 1)
        order_book_no_time = pd.DataFrame(order_book_no_time.values)
        order_book_concat = time_to_concat.append(order_book_no_time).reset_index(drop=True)        
        a = a + 1
        b = b + 1
    elif time == time_bid[a] and time != time_ask[b]: 
        #print '2 = ' +time
        bid_index = bid_index + 1        
        
        order_book_no_time = pd.concat([pd.DataFrame(order_book_bid_merge[bid_index].iloc[::-1][0:3].values),pd.DataFrame(order_book_ask_merge[ask_index].iloc[0:3].values)],axis = 1)
        order_book_no_time = pd.DataFrame(order_book_no_time.values)
        order_book_concat = time_to_concat.append(order_book_no_time).reset_index(drop=True)        
        a = a + 1
    elif time != time_bid[a] and time == time_ask[b]: 
        #print '3 = ' +time
        ask_index = ask_index + 1    
        order_book_no_time = pd.concat([pd.DataFrame(order_book_bid_merge[bid_index].iloc[::-1][0:3].values),pd.DataFrame(order_book_ask_merge[ask_index].iloc[0:3].values)],axis = 1)
        order_book_no_time = pd.DataFrame(order_book_no_time.values)
        order_book_concat = time_to_concat.append(order_book_no_time).reset_index(drop=True)        
        b = b + 1
    else:
        continue
    order_book = pd.concat([order_book,order_book_concat])    
    time_series = time_series + 1    
    
    #print order_book
end = time.time()            
print "Total time = %f"%(end - start)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-f09b03a1e195> in <module>()
#      24     #print order_book_bid_merge[a]
#      25     #print order_book_ask_merge[b]
# ---> 26     if time == time_bid[a] and time == time_ask[b]:
#      27         #print '1 = ' + time
#      28         bid_index = bid_index + 1
#
# IndexError: index 43236 is out of bounds for axis 0 with size 43236

# %%
order_book = pd.DataFrame(order_book.values)
order_book.to_csv('CNF14_01_03_order_book_final.csv',sep = '\t',encoding = 'utf-8')

# %%
import time 
start  =  time.time()
for i in range(len(y),1000,1):
    #print '------------------------------------------------------------------------------'
    #print (i)
    #print data[['TimeStamp']][i:i+1]
    #print data[['Price','OrderNumber','QuantityDifference','BidOrAsk','BestPrice','OrderBookPosition']][i:i+1]
    #print 'data_ask_number = %d'%(data_ask_number)
    #print data.BidOrAsk[i] == 'A'
    if data.BidOrAsk[i] == 'A':
        #data_ask_number = data_ask_number + 1
        if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            
            if data.TimeStamp[i] == x1[temp_ask]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1

                order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)

                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Ask & Q>0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass
                elif 0 < position_< (len(order_book_ask[temp_ask])-1):
                    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]:#or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Ask & Q>0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'   
                        pass
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Ask & Q>0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                
                        pass
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True' 
                    pass
                
            elif data.TimeStamp[i] != x1[temp_ask]:
                ###a.append(x1[temp_ask])
                #print order_book_ask[temp_ask]['Price'][0:1].iloc[0]
                #print data_ask[data_ask_number:data_ask_number+1]['BestPrice'].iloc[0]
                #print data_ask[data_ask_number-2:data_ask_number-1]['BestPrice'].iloc[0]
                #print 'data_ask_number = %d'%(data_ask_number)
                #if data_ask_number == 0:
                    #print 'Best Price is True'
                #    pass
                #elif data_ask_number > 0 and order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data_ask[data_ask_number-2:data_ask_number-1]['BestPrice'].iloc[0]:
                    #print 'Best Price is True'
                #    pass
                #else:
                    #print 'Best Price is False'
                #    break
                #print temp_ask
                
                #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data[(data.BidOrAsk == 'A')][i:i]['BestPrice'].iloc[0]:
                #    print 'Best Price is True'
                #    continue
                #else:
                #    print 'Best Price is False'
                #   break
                    
                if temp_ask == 0:
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = order_book_ask[temp_ask - 1]
                    #print order_book_ask[temp_ask]
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    #print order_book_ask[temp_ask]
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    #print 'position = %d'%(position_)
                    #print 'length-1 = %d'%(len(order_book_ask[temp_ask])-1)
                    #print order_book_ask[temp_ask][position_+1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]
                    #print order_book_ask[temp_ask][position_-1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]
                    #print order_book_ask[temp_ask]['Price'][0:1].iloc[0]# != data['BestPrice'][i]
                    if position_ == 0 and len(order_book_ask[0]) > 1:
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Ask & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Ask & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_ask[temp_ask])-1:   
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Ask & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            pass
                        else:
                            print 'position and Best Price is True'
                            pass
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        pass
                    #print order_book_ask[temp_ask]                        
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    order_book_ask.append(order_book_ask[temp_ask])
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    if position_ == 0:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3(Ask & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3(Ask & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:    
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3(Ask & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            pass
                        else:
                            print 'position and Best Price is True'                        
                            pass
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        pass
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x1[temp_ask]: 
                #print temp_ask
                #print order_book_ask[temp_ask]
                #position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_ask[temp_ask][order_book_ask[temp_ask].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                
                #if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                #    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                #else:
                #    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_ask[temp_ask]

                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error4(Ask & Q<0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass       
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error4(Ask & Q<0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_ask[temp_ask])-1:       
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error4(Ask & Q<0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])   
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass                        
                    else:
                        print 'position and Best Price is True'                        
                        pass
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    pass
    
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]

            elif data.TimeStamp[i] != x1[temp_ask]:
                ###a.append(x1[temp_ask])
                #print temp_ask
                #print order_book_ask[temp_ask]
                #print order_book_ask[temp_ask]['Price'][0:1].iloc[0]
                #print data_ask[data_ask_number-2:data_ask_number-1]['BestPrice'].iloc[0]
                
                #if data_ask_number == 0:
                #    print 'Best Price is True'
                #    pass
                #elif data_ask_number > 0 and order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data_ask[data_ask_number-2:data_ask_number-1]['BestPrice'].iloc[0]:
                #    print 'Best Price is True'
                #    pass
                #else:
                #    print 'Best Price is False'
                #    break
                #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                #    print 'Best Price is True'
                #    continue
                #else:
                #    print 'Best Price is False'
                #    break
                    
                order_book_ask.append(order_book_ask[temp_ask])
                #position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_ask[temp_ask][order_book_ask[temp_ask].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_ask = temp_ask + 1
                #print 'temp_ask2 = %d'%(temp_ask)
                #if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                #    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                #else:
                #    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_ask[temp_ask]
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Ask & Q<0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])    
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Ask & Q<0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Ask & Q<0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass                       
                    else:
                        print 'position and Best Price is True'                        
                        pass
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    pass      
                    
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                
                
                ##if data_ask_number == 0:
                ##    print 'Best Price is True'
                ##    pass
                ##elif data_ask_number > 0 and order_book_ask[temp_ask-1]['Price'][0:1].iloc[0] == data_ask[data_ask_number-2:data_ask_number-1]['BestPrice'].iloc[0]:
                ##    print 'Best Price is True'
                ##    pass
                ##else:
                ##    print 'Best Price is False'
                ##    break
   
                    
    elif data.BidOrAsk[i] == 'B':
        #print i
        #print int(data[['QuantityDifference']][i:i+1].values) > 0
        #data_bid_number = data_bid_number + 1
        #print data_bid_number
        
        if int(data[['QuantityDifference']][i:i+1].values) > 0: #and len(order_book_bid[0]) > 0:
            #print x2[temp_bid]
            #print data.TimeStamp[i] == x2[temp_bid]
            
            if data.TimeStamp[i] == x2[temp_bid]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Bid & Q>0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass     
                elif 0 < position_< len(order_book_bid[temp_bid])-1: 
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Bid & Q>0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'   
                        pass
                elif position_ == len(order_book_bid[temp_bid])-1 and len(order_book_bid[0]) > 1:      
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1(Bid & Q>0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        print 'position and Best Price is True'                
                        pass
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    pass  
            elif data.TimeStamp[i] != x2[temp_bid]:
                
                #print 'order book best price = %d'%(order_book_bid[temp_bid]['Price'][0:1].iloc[0])
                #print ''
                #print 'last data best price = %d'%(data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0])
                #print data_bid_number
                
                #if data_bid_number == 0:
                    #print 'Best Price is True'
                #    pass
                #elif data_bid_number > 0 and order_book_bid[temp_bid]['Price'][0:1].iloc[0] == data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0]:
                    #print 'Best Price is True'
                #    pass
                #else:
                    #print 'Best Price is False'
                #    break
                #data_bid_number = data_bid_number + 1   
                ###b.append(x2[temp_bid])
                #print 'temp bid = %d'%(temp_bid)
                #print order_book_bid[temp_bid]
                    
                if temp_bid == 0:
                    #print temp_bid
                    #print order_book_bid[temp_bid]
                    temp_bid = temp_bid + 1
                    order_book_bid[temp_bid] = order_book_bid[temp_bid - 1]
                    #print order_book_bid[temp_bid]
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    #print order_book_bid[temp_bid]
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    #print position_
                    #print len(order_book_bid[temp_bid]) - 1
                    
                    #print order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]
                    #print order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]
                    #print order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]
                    #print order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0]
                    #print order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0]
                    #print temp_bid
                    #print order_book_bid[temp_bid]
                    #print data['BestPrice'][i]
                    #print order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0]
                    if position_ == 0  and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Bid & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass       
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Bid & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_bid[temp_bid])-1:    
                        if order_book_bid[temp_bid][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2(Bid & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])                                        
                            pass
                        else:
                            print 'position and Best Price is True'
                            pass
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                            print 'position and Best Price is True'
                            pass
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    order_book_bid.append(order_book_bid[temp_bid])
                    temp_bid = temp_bid + 1
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    #print position_    
                    #print len(order_book_bid[temp_bid])-1      
                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3(Bid & Q>0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])     
                            break
                        else:
                            print 'position and Best Price is True'                     
                            pass
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3(Bid & Q>0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                            break
                        else:
                            print 'position and Best Price is True'  
                            pass
                    elif position_ == len(order_book_bid[temp_bid])-1:
                        
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3(Bid & Q>0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                            break
                        else:
                            print 'position and Best Price is True'                        
                            pass
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        pass
                        
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x2[temp_bid]: 
                #print (temp_bid)
                #print (order_book_bid[temp_bid])
                #position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_bid[temp_bid][order_book_bid[temp_bid].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                #print order_book_bid[temp_bid]
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error4(Bid & Q<0 & timestamp not change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        #print 'position and Best Price is True'                     
                        pass
                        
                elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error4(Bid & Q<0 & timestamp not change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])
                        break
                    else:
                        #print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_bid[temp_bid])-1:
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]:
                        print 'Some error4(Bid & Q<0 & timestamp not change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0],data['OrderNumber'][i:i+1].iloc[0])      
                        break
                    elif position_ == 0:
                        #print 'position and Best Price is True'
                        pass
                    else:
                        #print 'position and Best Price is True'                        
                        pass
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    #print 'position and Best Price is True'
                    pass
                    
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                              
                    
            elif data.TimeStamp[i] != x2[temp_bid]:

                #print 'order book best price = %d'%(order_book_bid[temp_bid]['Price'][0:1].iloc[0])
                #print ''
                #print 'last data best price = %d'%(data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0])
                #print data_bid_number
                
                #if data_bid_number == 0:
                #    print 'Best Price is True'
                #    pass
                #elif data_bid_number > 0 and order_book_bid[temp_bid]['Price'][0:1].iloc[0] == data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0]:
                #    print 'Best Price is True'
                #    pass
                #else:
                #    print 'Best Price is False'
                #    break
                
                #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                #    print 'Best Price is True'
                #    continue
                #else:
                #    print 'Best Price is False'
                #    break                
                ###b.append(x2[temp_bid])
                #print temp_bid
                #print order_book_bid[temp_bid]
                order_book_bid.append(order_book_bid[temp_bid])
                #position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                position_ = order_book_bid[temp_bid][order_book_bid[temp_bid].OrderNumber == order_number_].index[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_bid = temp_bid + 1
                #print position_
                #print len(order_book_ask[temp_ask])-1
                #print 'temp_bid2 = %d'%(temp_bid)
                
                #if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                #    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                #else:
                #    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_bid[temp_bid]
                
                
                #print position_
                #print len(order_book_ask[temp_ask])-1
                #print order_book_bid[temp_bid]
                #print order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0]
                #print data['Price'][i:i+1].iloc[0]

                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error5(Bid & Q<0 & timestamp change & 1),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        pass
    
                elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error5(Bid & Q<0 & timestamp change & 2),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        pass
                elif position_ == len(order_book_bid[temp_bid])-1:
                        
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error5(Bid & Q<0 & timestamp change & 3),position = %d,index = %d,price = %d,OrderNumber = %s'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        pass
                    else:
                        print 'position and Best Price is True'                        
                        pass    
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    pass  
                    
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_bid[temp_bid]
                
                ##print 'order book best price = %d'%(order_book_bid[temp_bid]['Price'][0:1].iloc[0])
                ##print ''
                ##print 'last data best price = %d'%(data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0])
                
                ##if data_bid_number == 0:
                ##    print 'Best Price is True'
                ##    pass
                ##elif data_bid_number > 0 and order_book_bid[temp_bid-1]['Price'][0:1].iloc[0] == data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0]:
                ##    print 'Best Price is True'
                ##    pass
                ##else:
                ##    print 'Best Price is False'
                ##    break       
                                    
end = time.time()            
print "Total time = %f"%(end - start)
# Out:
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:24: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# position and Best Price is True
# Some error1(Bid & Q>0 & timestamp not change & 1),position = 0,index = 108,price = 674500,OrderNumber = FA6ACA4D2D540C54
# Total time = 1.075081

# %%
import time
start = time.time()


time_ = data.TimeStamp.unique()
time_bid = data[(data.BidOrAsk == 'B')].TimeStamp.unique()
time_ask = data[(data.BidOrAsk == 'A')].TimeStamp.unique()

bid_index = 0
ask_index = 0
a = 0
b = 0
first = pd.concat([pd.DataFrame(order_book_bid_merge[bid_index].iloc[::-1][0:3].values),pd.DataFrame(order_book_ask_merge[ask_index].iloc[0:3].values)],axis = 1)
first = pd.DataFrame(first.values)
time = pd.DataFrame([['TimeStamp',time_[0][11:29],'','']])
order_book_concat = time.append(first).reset_index(drop=True)
order_book = order_book_concat
#print order_book
a = 1
b = 1
time_series = 1
for time in time_[1:]:
    #print 'time' + time
    #print 'time_series = %d'%(time_series)
    time_to_concat = pd.DataFrame([['TimeStamp',time_[time_series][11:29],'','']])
    #print time_to_concat
    #print time_bid[a-1]
    #print time_ask[b-1]    
    #print time_bid[a]
    #print time_ask[b]
    #print order_book_bid_merge[a]
    #print order_book_ask_merge[b]
    if time == time_bid[a] and time == time_ask[b]:
        #print '1 = ' + time
        #a = a + 1
        #b = b + 1
        order_book_no_time = pd.concat([pd.DataFrame(order_book_bid_merge[a].iloc[::-1][0:3].values),pd.DataFrame(order_book_ask_merge[b].iloc[0:3].values)],axis = 1)
        order_book_no_time = pd.DataFrame(order_book_no_time.values)
        order_book_concat = time_to_concat.append(order_book_no_time).reset_index(drop=True)        
        a = a + 1
        b = b + 1
    elif time == time_bid[a] and time != time_ask[b]: 
        #print '2 = ' +time
        ##a = a + 1
        order_book_no_time = pd.concat([pd.DataFrame(order_book_bid_merge[a].iloc[::-1][0:3].values),pd.DataFrame(order_book_ask_merge[b-1].iloc[0:3].values)],axis = 1)
        order_book_no_time = pd.DataFrame(order_book_no_time.values)
        order_book_concat = time_to_concat.append(order_book_no_time).reset_index(drop=True)        
        a = a + 1
        
    elif time != time_bid[a] and time == time_ask[b]: 
        #print '3 = ' +time
        ##b = b + 1
        order_book_no_time = pd.concat([pd.DataFrame(order_book_bid_merge[a-1].iloc[::-1][0:3].values),pd.DataFrame(order_book_ask_merge[b].iloc[0:3].values)],axis = 1)
        order_book_no_time = pd.DataFrame(order_book_no_time.values)
        order_book_concat = time_to_concat.append(order_book_no_time).reset_index(drop=True)        
        b = b + 1
    else:
        continue
    order_book = pd.concat([order_book,order_book_concat])    
    time_series = time_series + 1    
    #print order_book
end = time.time()            
print "Total time = %f"%(end - start)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-54795ddf2fe5> in <module>()
#      31     #print order_book_bid_merge[a]
#      32     #print order_book_ask_merge[b]
# ---> 33     if time == time_bid[a] and time == time_ask[b]:
#      34         #print '1 = ' + time
#      35         #a = a + 1
#
# IndexError: index 45578 is out of bounds for axis 0 with size 45578

# %%
order_book = pd.DataFrame(order_book.values)
order_book.to_csv('CNF14_01_13_order_book_final.csv',sep = '\t',encoding = 'utf-8')
