# %%
file_name = 'CN_Futures_2014.01.22'
# %pylab inline
import numpy as np
import pandas as pd
data = []

datapath = '/home/bigdatas16/SGX-OrderBook-Tick-Data-Trading-Strategy-/' + file_name + '.csv'
data = pd.read_csv(datapath)
month = 'F'#CNF14
data_CN14 = data[data.Series == 'CN' + month + '14']
data = data_CN14
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data[(data.Trade == 'T')].head(),len(data[(data.Trade == 'T')])
# Out:
# (    Series  SequenceNumber                      TimeStamp       OrderNumber  \
#  400  CNF14             401  2014-01-22D09:00:38.030171400  C228E340C483A6A3
#  402  CNF14             403  2014-01-22D09:00:38.030171400  C944ACF9BDFBA11B
#  412  CNF14             413  2014-01-22D09:00:38.036171400  ED0588BD68524C92
#  420  CNF14             421  2014-01-22D09:00:38.042171400  C90124B9F0E9D0A9
#  454  CNF14             455  2014-01-22D09:00:39.805145400  CB5580F595FE7A3E
#
#       OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
#  400                  1  670000                  -1     T        A     670500
#  402                  1  670500                  -1     T        A     671000
#  412                  1  670500                  -1     T        B     670000
#  420                  1  670500                  -2     T        B     670000
#  454                  1  670000                  -2     T        B     668500
#
#       BestQuantity
# ...

# %%
data[(data.BidOrAsk == 'A')]

# %%
data[0:100]
# Out:
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 0   CNF14               1  2014-01-22D04:21:22.786910500  E3D584F55D4240C2
# 1   CNF14               2  2014-01-22D04:21:22.786910500  B86D00C4CBBFB0BF
# 2   CNF14               3  2014-01-22D04:21:22.786910500  E1C9F25394A679A6
# 3   CNF14               4  2014-01-22D04:21:22.786910500  470284B16BBE4ABE
# 4   CNF14               5  2014-01-22D04:21:22.786910500  C7118CE560A044E0
# 5   CNF14               6  2014-01-22D04:21:22.786910500  6827C7006AEC4FEC
# 6   CNF14               7  2014-01-22D04:21:22.786910500  AF342B8CD518B4B8
# 7   CNF14               8  2014-01-22D04:21:22.786910500  C15D08A5B29C96DC
# 8   CNF14               9  2014-01-22D04:21:22.786910500  48A74F481D750275
# 9   CNF14              10  2014-01-22D04:21:22.786910500  E19E84B960F74517
# 10  CNF14              11  2014-01-22D04:21:22.786910500  166000C4C677AB77
# ...

# %%
data_Trade = data[(data.Trade == 'T')&(data.BidOrAsk == 'A')]
data_Trade
# Out:
#        Series  SequenceNumber                      TimeStamp  \
# 400     CNF14             401  2014-01-22D09:00:38.030171400
# 402     CNF14             403  2014-01-22D09:00:38.030171400
# 485     CNF14             486  2014-01-22D09:00:56.041937400
# 653     CNF14             654  2014-01-22D09:03:23.176026100
# 711     CNF14             712  2014-01-22D09:03:27.061974100
# 738     CNF14             739  2014-01-22D09:03:48.485701100
# 745     CNF14             746  2014-01-22D09:03:54.221623100
# 748     CNF14             749  2014-01-22D09:03:54.392623100
# 756     CNF14             757  2014-01-22D09:04:12.269389100
# 768     CNF14             769  2014-01-22D09:04:35.716090100
# 770     CNF14             771  2014-01-22D09:04:59.233778100
# 777     CNF14             778  2014-01-22D09:05:13.644596100
# 778     CNF14             779  2014-01-22D09:05:18.235533700
# 788     CNF14             789  2014-01-22D09:05:20.287505100
# ...

# %%
data_Trade.TimeStamp.unique(),len(data_Trade.TimeStamp.unique())
# Out:
# (array(['2014-01-22D09:00:38.030171400', '2014-01-22D09:00:38.036171400',
#         '2014-01-22D09:00:38.042171400', ...,
#         '2014-01-23D01:55:35.801010000', '2014-01-23D01:59:55.002643000',
#         '2014-01-23D01:59:55.008643000'], dtype=object), 7087)

# %%
data[(data.TimeStamp == '2014-01-22D09:00:38.030171400')]
# Out:
# Empty DataFrame
# Columns: [Series, SequenceNumber, TimeStamp, OrderNumber, OrderBookPosition, Price, QuantityDifference, Trade, BidOrAsk, BestPrice, BestQuantity]
# Index: []

# %%
data[data['TimeStamp'].str.contains('09:01:00')]
# Out:
#     Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 493  CNF14             494  2014-01-22D09:01:00.126885400  E7D0ACE988FB685B
# 494  CNF14             495  2014-01-22D09:01:00.126885400  4989A4B970E450A4
# 495  CNF14             496  2014-01-22D09:01:00.126885400  4B9524A1CFF8AFB8
# 496  CNF14             497  2014-01-22D09:01:00.128885400  4BC920A19A377977
# 497  CNF14             498  2014-01-22D09:01:00.128885400  4FC784B9A3EB838B
# 498  CNF14             499  2014-01-22D09:01:00.128885400  E51F04F1518A312A
# 499  CNF14             500  2014-01-22D09:01:00.128885400  C500ACB1E712C672
# 500  CNF14             501  2014-01-22D09:01:00.128885400  ED89A0F14E603200
#
#      OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 493                 15  671500                   6              A     670000
# 494                 40  666500                   6              B     669000
# ...

# %%
data[data['TimeStamp'].str.contains('09:00:50')]
# Out:
#     Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 482  CNF14             483  2014-01-22D09:00:50.224015400  E6A74750DBE6C0E6
#
#      OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 482                  3  670500                  50              A     670000
#
#      BestQuantity
# 482            48

# %%
data[data['TimeStamp'].str.contains('09:00:49')]
# Out:
#     Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 480  CNF14             481  2014-01-22D09:00:49.527028400  41D4A4F1946E778E
# 481  CNF14             482  2014-01-22D09:00:49.527028400  41D4A4F1946E778E
#
#      OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 480                 17  667500                 -90              B     668500
# 481                 11  668000                  90              B     668500
#
#      BestQuantity
# 480            10
# 481            10

# %%
data.TimeStamp.unique()
# Out:
# array(['2014-01-22D04:21:22.786910500', '2014-01-22D04:21:22.789910500',
#        '2014-01-22D08:45:02.804303200', ...,
#        '2014-01-23D02:20:00.035007500', '2014-01-23D02:20:00.036007400',
#        '2014-01-23D02:20:00.037007300'], dtype=object)

# %%
data_second = data.TimeStamp[1][0:19]

# %%
data_timestamp_unique = data.TimeStamp.unique()
data_timestamp_unique[0]
# Out:
# '2014-01-22D04:21:22.786910500'

# %%
data.TimeStamp[0]#[0:19]
# Out:
# '2014-01-22D04:21:22.786910500'
