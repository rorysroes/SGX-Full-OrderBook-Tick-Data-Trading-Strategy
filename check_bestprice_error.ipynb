# %%
# %pylab inline
import numpy as np
import pandas as pd
data = []
datapath = '/home/bigdatas16/SGX-OrderBook-Tick-Data-Trading-Strategy-/CN_Futures_2014.01.24.csv'
data = pd.read_csv(datapath)
data_CNF14 = data[data.Series == 'CNF14']
data = data_CNF14
data.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['insert']
# `%matplotlib` prevents importing * from pylab and numpy
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 0  CNF14               1  2014-01-24D04:21:49.419665000  C791DA0F799A5E9A
# 1  CNF14               2  2014-01-24D04:21:49.419665000  E1C9F25394A679A6
# 2  CNF14               3  2014-01-24D04:21:49.419665000  C02B6F481F080128
# 3  CNF14               4  2014-01-24D04:21:49.419665000  C55C20A9615D40FD
# 4  CNF14               5  2014-01-24D04:21:49.419665000  E5D428BDEDEDCCCD
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 0                  1  710000                   2              A     677000
# 1                  2  719500                   1              A     677000
# 2                  1  684000                 100              A     677000
# 3                  2  692500                   1              A     677000
# 4                  1  678500                  20              A     677000
#
#    BestQuantity
# 0            19
# 1            19
# 2            19
# 3            19
# 4            19

# %%
data_CNF = data[data.Series == data.Series[0]]
data = data_CNF
len(data)
# Out:
# 143284

# %%
import time 
def insert(order_book_data,data_to_insert,ob_position):
    top = order_book_data[0:ob_position]
    bottom = order_book_data[ob_position:]
    return pd.concat((top,data_to_insert,bottom)).reset_index(drop = True)

start  =  time.time()

order_book_bid = []
order_book_ask = []
timestamp = data.TimeStamp[0]
temp_ask = 0
temp_bid = 0
bid = []
ask = []
timestamp_ = []
x1 = data[(data.BidOrAsk == 'A')].TimeStamp.unique()
x2 = data[(data.BidOrAsk == 'B')].TimeStamp.unique()
y = data[data['TimeStamp'].str.contains(timestamp)]
bid.append(y[(y.BidOrAsk == 'B')][["Price","OrderNumber","QuantityDifference"]]) # bid
ask.append(y[(y.BidOrAsk == 'A')][["Price","OrderNumber","QuantityDifference"]]) # ask
a = bid[0].sort(['Price'],ascending = [False])
b = ask[0].sort(['Price'],ascending = [True])    
order_book_bid.append(a[a.QuantityDifference != 0].reset_index(drop = True))
order_book_ask.append(b[b.QuantityDifference != 0].reset_index(drop = True))

order_book_bid.append(0)
order_book_ask.append(0)
#a = []
#b = []

for i in range(len(y),3200,1):
    print '------------------------------------------------------------------------------'
    print i
    #print data.BidOrAsk[i] == 'A'
    if data.BidOrAsk[i] == 'A':

        if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            
            if data.TimeStamp[i] == x1[temp_ask]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1

                order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)

                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif 0 < position_< (len(order_book_ask[temp_ask])-1):
                    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]:#or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error2 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'   
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error3 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                
                        continue
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True' 
                
            elif data.TimeStamp[i] != x1[temp_ask]:
                ###a.append(x1[temp_ask])
                print order_book_ask[temp_ask]
                #print temp_ask
                if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                    print 'Best Price is True'
                    continue
                else:
                    print 'Best Price is False'
                    break
                    
                if temp_ask == 0:
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = order_book_ask[temp_ask - 1]
                    #print order_book_ask[temp_ask]
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    #print order_book_ask[temp_ask]
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    #print 'position = %d'%(position_)
                    #print 'length-1 = %d'%(len(order_book_ask[temp_ask])-1)
                    #print order_book_ask[temp_ask][position_+1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]
                    #print order_book_ask[temp_ask][position_-1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]
                    #print order_book_ask[temp_ask]['Price'][0:1].iloc[0]# != data['BestPrice'][i]
                    if position_ == 0 and len(order_book_ask[0]) > 1:
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error11 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            #print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                    
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error22 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:
                        
                        if order_book_ask[temp_ask][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error33 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'
                            continue
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        continue
                        
                    #print order_book_ask[temp_ask]                        
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1

                    order_book_ask.append(order_book_ask[temp_ask])
                    temp_ask = temp_ask + 1

                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)

                        
                    if position_ == 0:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:
                        
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                        
                            continue
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        continue                            
                            
                            
                            
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x1[temp_ask]: 
                #print temp_ask
                #print order_book_ask[temp_ask]
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_ask[temp_ask]

                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error1111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error2222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error3333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        continue                        
                    else:
                        print 'position and Best Price is True'                        
                        continue
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    continue

            elif data.TimeStamp[i] != x1[temp_ask]:
                ###a.append(x1[temp_ask])
                #print temp_ask
                #print order_book_ask[temp_ask]
                if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                    print 'Best Price is True'
                    continue
                else:
                    print 'Best Price is False'
                    break
                    
                order_book_ask.append(order_book_ask[temp_ask])
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_ask = temp_ask + 1
                #print 'temp_ask2 = %d'%(temp_ask)
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_ask[temp_ask]
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error11111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error22222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error33333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        continue                        
                    else:
                        print 'position and Best Price is True'                        
                        continue 
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    continue                          

    elif data.BidOrAsk[i] == 'B':
        #print i
        #print int(data[['QuantityDifference']][i:i+1].values) > 0
        
        if int(data[['QuantityDifference']][i:i+1].values) > 0: #and len(order_book_bid[0]) > 0:
            print data.TimeStamp[i] == x2[temp_bid]
            
            if data.TimeStamp[i] == x2[temp_bid]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                #print position_
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error111111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                        
                elif 0 < position_< len(order_book_bid[temp_bid])-1:
                    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error222222 %d %d %d'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'   
                        continue
                elif position_ == len(order_book_bid[temp_bid])-1 and len(order_book_bid[0]) > 1:
                        
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error333333 %d %d %d'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                
                        continue
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    continue
                
            elif data.TimeStamp[i] != x2[temp_bid]:
                ###b.append(x2[temp_bid])
                #print 'temp bid = %d'%(temp_bid)
                #print order_book_bid[temp_bid]
                if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                    print 'Best Price is True'
                    continue
                else:
                    print 'Best Price is False'
                    break
                    
                if temp_bid == 0:
                    #print temp_bid
                    #print order_book_bid[temp_bid]
                    temp_bid = temp_bid + 1
                    order_book_bid[temp_bid] = order_book_bid[temp_bid - 1]
                    #print order_book_bid[temp_bid]
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    #print order_book_bid[temp_bid]
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    #print position_
                    #print len(order_book_bid[temp_bid]) - 1
                    
                    #print order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]
                    #print order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]
                    #print order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]
                    #print order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0]
                    #print order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0]
                    #print temp_bid
                    #print order_book_bid[temp_bid]
                    print data['BestPrice'][i]
                    print order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0]
                    if position_ == 0  and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error1111111 %d %d %d'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                            
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2222222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_bid[temp_bid])-1:
                        
                        if order_book_bid[temp_bid][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3333333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'
                            continue
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                            print 'position and Best Price is True'
                            continue
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    order_book_bid.append(order_book_bid[temp_bid])
                    temp_bid = temp_bid + 1
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    #print position_    
                    #print len(order_book_bid[temp_bid])-1      
                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error11111111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error22222222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_bid[temp_bid])-1:
                        
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error33333333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                        
                            continue
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        continue
                        
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x2[temp_bid]: 
                #print temp_bid
                #print order_book_bid[temp_bid]
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_bid[temp_bid]

                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error19 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                        
                elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error29 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_bid[temp_bid])-1:
                        
                    if position_ > 0 and order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error39 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        continue
                    else:
                        print 'position and Best Price is True'                        
                        continue
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    continue

            elif data.TimeStamp[i] != x2[temp_bid]:
                if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                    print 'Best Price is True'
                    continue
                else:
                    print 'Best Price is False'
                    break                
                ###b.append(x2[temp_bid])
                #print temp_bid
                #print order_book_bid[temp_bid]
                order_book_bid.append(order_book_bid[temp_bid])
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_bid = temp_bid + 1
                #print position_
                #print len(order_book_ask[temp_ask])-1
                #print 'temp_bid2 = %d'%(temp_bid)
                
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_bid[temp_bid]
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error110 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
    
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error220 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_bid[temp_bid])-1:
                        
                    if position_ > 0 and order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error330 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        continue
                    else:
                        print 'position and Best Price is True'                        
                        continue    
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    continue                    
                                    
end = time.time()            
print "Total time = %f"%(end - start)
# Out:
# ------------------------------------------------------------------------------
# 12
# False
# Best Price is False
# Total time = 0.145939
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:22: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:23: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
def order_book_(data,data_number):
    def insert(order_book_data,data_to_insert,ob_position):
        top = order_book_data[0:ob_position]
        bottom = order_book_data[ob_position:]
        return pd.concat((top,data_to_insert,bottom)).reset_index(drop = True)

    order_book_bid = []
    order_book_ask = []
    timestamp = data.TimeStamp[0]
    temp_ask = 0
    temp_bid = 0
    bid = []
    ask = []
    timestamp_ = []
    x1 = data[(data.BidOrAsk == 'A')].TimeStamp.unique()
    x2 = data[(data.BidOrAsk == 'B')].TimeStamp.unique()
    y = data[data['TimeStamp'].str.contains(timestamp)]
    bid.append(y[(y.BidOrAsk == 'B')][["Price","OrderNumber","QuantityDifference"]]) # bid
    ask.append(y[(y.BidOrAsk == 'A')][["Price","OrderNumber","QuantityDifference"]]) # ask
    a = bid[0].sort(['Price'],ascending = [False])
    b = ask[0].sort(['Price'],ascending = [True])    
    order_book_bid.append(a[a.QuantityDifference != 0].reset_index(drop = True))
    order_book_ask.append(b[b.QuantityDifference != 0].reset_index(drop = True))

    order_book_bid.append(0)
    order_book_ask.append(0)
    #a = []
    #b = []
    
    for i in range(len(y),data_number,1):
        print '------------------------------------------------------------------------------'
        print i
        #print data.BidOrAsk[i] == 'A'
        if data.BidOrAsk[i] == 'A':

            if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            
                if data.TimeStamp[i] == x1[temp_ask]:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1

                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)

                    if position_ == 0 and len(order_book_ask[0]) > 1:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error1 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< (len(order_book_ask[temp_ask])-1):
                    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]:#or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'   
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:
                            
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                
                            continue
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True' 
                
                elif data.TimeStamp[i] != x1[temp_ask]:
                    ###a.append(x1[temp_ask])
                    #print order_book_ask[temp_ask]
                    #print temp_ask
                    #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                    #    print 'Best Price is True'
                    #    continue
                    #else:
                    #    print 'Best Price is False'
                    #    break

                    if temp_ask == 0:
                        temp_ask = temp_ask + 1
                        order_book_ask[temp_ask] = order_book_ask[temp_ask - 1]
                        #print order_book_ask[temp_ask]
                        order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                        #print order_book_ask[temp_ask]
                        best_price = data[i:(i+1)]['BestPrice']
                        position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                        #print 'position = %d'%(position_)
                        #print 'length-1 = %d'%(len(order_book_ask[temp_ask])-1)
                        #print order_book_ask[temp_ask][position_+1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]
                        #print order_book_ask[temp_ask][position_-1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]
                        #print order_book_ask[temp_ask]['Price'][0:1].iloc[0]# != data['BestPrice'][i]
                        if position_ == 0 and len(order_book_ask[0]) > 1:
                            if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error11 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                #print 'position and Best Price is True'                     
                                continue
                        elif 0 < position_< len(order_book_ask[temp_ask])-1:

                            if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error22 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'  
                                continue
                        elif position_ == len(order_book_ask[temp_ask])-1:

                            if order_book_ask[temp_ask][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error33 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                continue
                            else:
                                print 'position and Best Price is True'
                                continue
                        elif position_ == 0 and len(order_book_ask[0]) == 1:
                            print 'position and Best Price is True'
                            continue

                        #print order_book_ask[temp_ask]                        
                    else:
                        position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1

                        order_book_ask.append(order_book_ask[temp_ask])
                        temp_ask = temp_ask + 1

                        order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)


                        if position_ == 0:
                            if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                                print 'Some error111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'                     
                                continue
                        elif 0 < position_< len(order_book_ask[temp_ask])-1:

                            if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                                print 'Some error222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'  
                                continue
                        elif position_ == len(order_book_ask[temp_ask])-1:

                            if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                                print 'Some error333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'                        
                                continue
                        elif position_ == 0 and len(order_book_ask[0]) == 1:
                            print 'position and Best Price is True'
                            continue                            



            elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

                if data.TimeStamp[i] == x1[temp_ask]: 
                    #print temp_ask
                    #print order_book_ask[temp_ask]
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                    price_ = data[i:i+1]['Price'].iloc[0]

                    if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                        order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                    else:
                        order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                    #print order_book_ask[temp_ask]

                    if position_ == 0 and len(order_book_ask[0]) > 1:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error1111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error2222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:

                        if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error3333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        elif position_ == 0:
                            print 'position and Best Price is True'
                            continue                        
                        else:
                            print 'position and Best Price is True'                        
                            continue
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        continue

                elif data.TimeStamp[i] != x1[temp_ask]:
                    ###a.append(x1[temp_ask])
                    #print temp_ask
                    #print order_book_ask[temp_ask]
                    #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                    #    print 'Best Price is True'
                    #    continue
                    #else:
                    #    print 'Best Price is False'
                    #    break

                    order_book_ask.append(order_book_ask[temp_ask])
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                    price_ = data[i:i+1]['Price'].iloc[0]
                    temp_ask = temp_ask + 1
                    #print 'temp_ask2 = %d'%(temp_ask)
                    if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                        order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                    else:
                        order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                    #print order_book_ask[temp_ask]

                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error11111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error22222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:

                        if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error33333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        elif position_ == 0:
                            print 'position and Best Price is True'
                            continue                        
                        else:
                            print 'position and Best Price is True'                        
                            continue 
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        continue                          

        elif data.BidOrAsk[i] == 'B':
            #print i
            #print int(data[['QuantityDifference']][i:i+1].values) > 0

            if int(data[['QuantityDifference']][i:i+1].values) > 0: #and len(order_book_bid[0]) > 0:
                print data.TimeStamp[i] == x2[temp_bid]

                if data.TimeStamp[i] == x2[temp_bid]:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    #print position_

                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error111111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue

                    elif 0 < position_< len(order_book_bid[temp_bid])-1:

                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error222222 %d %d %d'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'   
                            continue
                    elif position_ == len(order_book_bid[temp_bid])-1 and len(order_book_bid[0]) > 1:

                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error333333 %d %d %d'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                
                            continue
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        continue

                elif data.TimeStamp[i] != x2[temp_bid]:
                    ###b.append(x2[temp_bid])
                    #print 'temp bid = %d'%(temp_bid)
                    #print order_book_bid[temp_bid]
                    #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                    #    print 'Best Price is True'
                    #    continue
                    #else:
                    #    print 'Best Price is False'
                    #    break

                    if temp_bid == 0:
                        #print temp_bid
                        #print order_book_bid[temp_bid]
                        temp_bid = temp_bid + 1
                        order_book_bid[temp_bid] = order_book_bid[temp_bid - 1]
                        #print order_book_bid[temp_bid]
                        order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                        #print order_book_bid[temp_bid]
                        best_price = data[i:(i+1)]['BestPrice']
                        position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                        #print position_
                        #print len(order_book_bid[temp_bid]) - 1

                        #print order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]
                        #print order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]
                        #print order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]
                        #print order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0]
                        #print order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0]
                        #print temp_bid
                        #print order_book_bid[temp_bid]
                        print data['BestPrice'][i]
                        print order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0]
                        if position_ == 0  and len(order_book_bid[0]) > 1:
                            if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error1111111 %d %d %d'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'                     
                                continue

                        elif 0 < position_< len(order_book_bid[temp_bid])-1:

                            if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error2222222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'  
                                continue
                        elif position_ == len(order_book_bid[temp_bid])-1:

                            if order_book_bid[temp_bid][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error3333333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                continue
                            else:
                                print 'position and Best Price is True'
                                continue
                        elif position_ == 0 and len(order_book_bid[0]) == 1:
                                print 'position and Best Price is True'
                                continue
                    else:
                        position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                        order_book_bid.append(order_book_bid[temp_bid])
                        temp_bid = temp_bid + 1
                        order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                        #print position_    
                        #print len(order_book_bid[temp_bid])-1      
                        if position_ == 0 and len(order_book_bid[0]) > 1:
                            if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error11111111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'                     
                                continue
                        elif 0 < position_< len(order_book_bid[temp_bid])-1:

                            if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error22222222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'  
                                continue
                        elif position_ == len(order_book_bid[temp_bid])-1:

                            if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                                print 'Some error33333333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                                break
                            else:
                                print 'position and Best Price is True'                        
                                continue
                        elif position_ == 0 and len(order_book_bid[0]) == 1:
                            print 'position and Best Price is True'
                            continue

            elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

                if data.TimeStamp[i] == x2[temp_bid]: 
                    #print temp_bid
                    #print order_book_bid[temp_bid]
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                    price_ = data[i:i+1]['Price'].iloc[0]

                    if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                        order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                    else:
                        order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                    #print order_book_bid[temp_bid]

                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error19 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue

                    elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error29 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_bid[temp_bid])-1:

                        if position_ > 0 and order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error39 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        elif position_ == 0:
                            print 'position and Best Price is True'
                            continue
                        else:
                            print 'position and Best Price is True'                        
                            continue
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        continue

                elif data.TimeStamp[i] != x2[temp_bid]:
                    #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                    #    print 'Best Price is True'
                    #    continue
                    #else:
                    #    print 'Best Price is False'
                    #    break                
                    ###b.append(x2[temp_bid])
                    #print temp_bid
                    #print order_book_bid[temp_bid]
                    order_book_bid.append(order_book_bid[temp_bid])
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                    price_ = data[i:i+1]['Price'].iloc[0]
                    temp_bid = temp_bid + 1
                    #print position_
                    #print len(order_book_ask[temp_ask])-1
                    #print 'temp_bid2 = %d'%(temp_bid)

                    if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                        order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                    else:
                        order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                    #print order_book_bid[temp_bid]

                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error110 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue

                    elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error220 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_bid[temp_bid])-1:

                        if position_ > 0 and order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error330 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        elif position_ == 0:
                            print 'position and Best Price is True'
                            continue
                        else:
                            print 'position and Best Price is True'                        
                            continue    
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        continue                    
    return 
    #return len(data)

# %%
order_book_(data,20)
# Out:
# ------------------------------------------------------------------------------
# 12
# False
# 674500
# 672500
# position and Best Price is True
# ------------------------------------------------------------------------------
# 13
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 14
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 15
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 16
# position and Best Price is True
# ------------------------------------------------------------------------------
# 17
# position and Best Price is True
# ------------------------------------------------------------------------------
# 18
# position and Best Price is True
# ------------------------------------------------------------------------------
# 19
# position and Best Price is True
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:20: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:21: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# 143284

# %%
data.head(30)
# Out:
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 0   CNF14               1  2014-01-24D04:21:49.419665000  C791DA0F799A5E9A
# 1   CNF14               2  2014-01-24D04:21:49.419665000  E1C9F25394A679A6
# 2   CNF14               3  2014-01-24D04:21:49.419665000  C02B6F481F080128
# 3   CNF14               4  2014-01-24D04:21:49.419665000  C55C20A9615D40FD
# 4   CNF14               5  2014-01-24D04:21:49.419665000  E5D428BDEDEDCCCD
# 5   CNF14               6  2014-01-24D04:21:49.419665000  C1442DE9FABCDEFC
# 6   CNF14               7  2014-01-24D04:21:49.419665000  CD0701B13A4F1E8F
# 7   CNF14               8  2014-01-24D04:21:49.419665000  CB1CA0F570654F45
# 8   CNF14               9  2014-01-24D04:21:49.419665000  E94584AD9F7F833F
# 9   CNF14              10  2014-01-24D04:21:49.419665000  9672009CE4FAC9FA
# 10  CNF14              11  2014-01-24D04:21:49.419665000  CFCC80F56C3C4FFC
# 11  CNF14              12  2014-01-24D04:21:49.419665000  C5C820E5C19AA2DA
# 12  CNF14              13  2014-01-24D04:21:49.422665000  61CF08BD2E520E12
# 13  CNF14              14  2014-01-24D04:21:49.422665000  6D92ACE99A8D7EAD
# 14  CNF14              15  2014-01-24D04:21:49.422665000  68C18D29F6F9D7F9
# 15  CNF14              16  2014-01-24D04:21:49.422665000  6D53ACE9F026CF26
# 16  CNF14              17  2014-01-24D04:21:49.422665000  48236F4061CE43EE
# 17  CNF14              18  2014-01-24D04:21:49.422665000  6DD500A560524412
# 18  CNF14              19  2014-01-24D04:21:49.422665000  439B20E9882F672F
# 19  CNF14              20  2014-01-24D04:21:49.422665000  40ABEF40E36DC58D
# 20  CNF14              21  2014-01-24D04:21:49.422665000  C678E758E205C6C5
# 21  CNF14              22  2014-01-24D04:21:49.422665000  C58785B9C5ABA9EB
# 22  CNF14              23  2014-01-24D04:21:49.422665000  4B10A9A1DF87C3C7
# 23  CNF14              24  2014-01-24D04:21:49.422665000  4670E75802D7E798
# 24  CNF14              25  2014-01-24D08:45:00.161957700  E4E04F5426FE093E
# 25  CNF14              26  2014-01-24D08:45:00.161957700  66326B58E3EDC66D
# 26  CNF14              27  2014-01-24D08:45:00.161957700  CEB0CB549A787CB8
# 27  CNF14              28  2014-01-24D08:45:00.897944700  E4684F548D346F74
# 28  CNF14              29  2014-01-24D08:45:01.060944700  4EEE670095C67A86
# 29  CNF14              30  2014-01-24D08:45:02.530918700  64E0CF548D096F49
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 0                   1  710000                   2              A     677000
# 1                   2  719500                   1              A     677000
# 2                   1  684000                 100              A     677000
# 3                   2  692500                   1              A     677000
# 4                   1  678500                  20              A     677000
# 5                   2  679500                  20              A     677000
# 6                   1  674000                  10              B     674000
# 7                   2  672500                  20              B     674000
# 8                   1  677000                  19              A     677000
# 9                   5  689500                   2              A     677000
# 10                  2  677500                  20              A     677000
# 11                  2  674000                  10              B     674000
# 12                  3  673500                   4              B     674500
# 13                  4  673500                   6              B     674500
# 14                  6  672000                  20              B     674500
# 15                  5  673000                  20              B     674500
# 16                  6  684000                 100              A     677000
# 17                  4  679000                  20              A     677000
# 18                  3  678000                  20              A     677000
# 19                  8  684000                 100              A     677000
# 20                 13  710000                 100              A     677000
# 21                  1  674500                  10              B     674500
# 22                  4  673500                  10              B     674500
# 23                 13  710000                 100              A     677000
# 24                 11  690000                  20              A     677000
# 25                 13  707000                  20              A     677000
# 26                 17  716500                  20              A     677000
# 27                 10  662500                   1              B     674500
# 28                 11  650500                   1              B     674500
# 29                 10  672000                   1              B     674500
#
#     BestQuantity
# 0             19
# 1             19
# 2             19
# 3             19
# 4             19
# 5             19
# 6             20
# 7             20
# 8             19
# 9             19
# 10            19
# 11            20
# 12            10
# 13            10
# 14            10
# 15            10
# 16            19
# 17            19
# 18            19
# 19            19
# 20            19
# 21            10
# 22            10
# 23            19
# 24            19
# 25            19
# 26            19
# 27            10
# 28            10
# 29            10

# %%
a = 1
b = 2
if a > b:
    print a
    pass
elif a < b:
    print a
    pass
# Out:
# 1

# %%
order_book_ask[0]#[(order_book_ask[0] == 'A')]
# Out:
#     Price       OrderNumber  QuantityDifference
# 0  677000  E94584AD9F7F833F                  19
# 1  677500  CFCC80F56C3C4FFC                  20
# 2  678500  E5D428BDEDEDCCCD                  20
# 3  679500  C1442DE9FABCDEFC                  20
# 4  684000  C02B6F481F080128                 100
# 5  689500  9672009CE4FAC9FA                   2
# 6  692500  C55C20A9615D40FD                   1
# 7  710000  C791DA0F799A5E9A                   2
# 8  719500  E1C9F25394A679A6                   1

# %%
import time 
data_ask = data[(data.BidOrAsk == 'A')].reindex()
data_bid = data[(data.BidOrAsk == 'B')].reindex()

def insert(order_book_data,data_to_insert,ob_position):
    top = order_book_data[0:ob_position]
    bottom = order_book_data[ob_position:]
    return pd.concat((top,data_to_insert,bottom)).reset_index(drop = True)

start  =  time.time()

order_book_bid = []
order_book_ask = []
timestamp = data.TimeStamp[0]
temp_ask = 0
temp_bid = 0
bid = []
ask = []
timestamp_ = []
x1 = data[(data.BidOrAsk == 'A')].TimeStamp.unique()
x2 = data[(data.BidOrAsk == 'B')].TimeStamp.unique()
y = data[data['TimeStamp'].str.contains(timestamp)]
bid.append(y[(y.BidOrAsk == 'B')][["Price","OrderNumber","QuantityDifference"]]) # bid
ask.append(y[(y.BidOrAsk == 'A')][["Price","OrderNumber","QuantityDifference"]]) # ask
a = bid[0].sort(['Price'],ascending = [False])
b = ask[0].sort(['Price'],ascending = [True])    
order_book_bid.append(a[a.QuantityDifference != 0].reset_index(drop = True))
order_book_ask.append(b[b.QuantityDifference != 0].reset_index(drop = True))

order_book_bid.append(0)
order_book_ask.append(0)
#a = []
#b = []
data_ask_number = len(order_book_ask[0])
data_bid_number = len(order_book_bid[0])

for i in range(len(y),3200,1):
    print '------------------------------------------------------------------------------'
    print i
    print data[['TimeStamp']][i:i+1]
    print data[['Price','OrderNumber','QuantityDifference','BidOrAsk','BestPrice']][i:i+1]
    data_ask_number = data_ask_number + 1
    print 'data_ask_number = %d'%(data_ask_number)
    #print data.BidOrAsk[i] == 'A'
    if data.BidOrAsk[i] == 'A':

        if int(data[['QuantityDifference']][i:i+1].values) > 0 :
            
            if data.TimeStamp[i] == x1[temp_ask]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1

                order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)

                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error1 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif 0 < position_< (len(order_book_ask[temp_ask])-1):
                    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]:#or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error2 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'   
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error3 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                
                        continue
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True' 
                
            elif data.TimeStamp[i] != x1[temp_ask]:
                ###a.append(x1[temp_ask])
                print order_book_ask[temp_ask]['Price'][0:1].iloc[0]
                print data_ask[data_ask_number:data_ask_number+1]['BestPrice'].iloc[0]
                
                if data_ask_number == 0:
                    print 'Best Price is True'
                    pass
                elif data_ask_number > 0 and order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data_ask[data_ask_number-1:data_ask_number]['BestPrice'].iloc[0]:
                    print 'Best Price is True'
                    pass
                else:
                    print 'Best Price is False'
                    pass
                #print temp_ask
                
                #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data[(data.BidOrAsk == 'A')][i:i]['BestPrice'].iloc[0]:
                #    print 'Best Price is True'
                #    continue
                #else:
                #    print 'Best Price is False'
                #   break
                    
                if temp_ask == 0:
                    temp_ask = temp_ask + 1
                    order_book_ask[temp_ask] = order_book_ask[temp_ask - 1]
                    #print order_book_ask[temp_ask]
                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    #print order_book_ask[temp_ask]
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    #print 'position = %d'%(position_)
                    #print 'length-1 = %d'%(len(order_book_ask[temp_ask])-1)
                    #print order_book_ask[temp_ask][position_+1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]
                    #print order_book_ask[temp_ask][position_-1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]
                    #print order_book_ask[temp_ask]['Price'][0:1].iloc[0]# != data['BestPrice'][i]
                    if position_ == 0 and len(order_book_ask[0]) > 1:
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error11 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            #print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                    
                        if order_book_ask[temp_ask][position_+ 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ -  1:position_-1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error22 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:
                        
                        if order_book_ask[temp_ask][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_ask[temp_ask]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error33 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'
                            continue
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        continue
                        
                    #print order_book_ask[temp_ask]                        
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1

                    order_book_ask.append(order_book_ask[temp_ask])
                    temp_ask = temp_ask + 1

                    order_book_ask[temp_ask] = insert(order_book_ask[temp_ask],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)

                        
                    if position_ == 0:
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_ask[temp_ask])-1:
                    
                        if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                            print 'Some error222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_ask[temp_ask])-1:
                        
                        if order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                            print 'Some error333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                        
                            continue
                    elif position_ == 0 and len(order_book_ask[0]) == 1:
                        print 'position and Best Price is True'
                        continue                            
                            
                            
                            
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x1[temp_ask]: 
                #print temp_ask
                #print order_book_ask[temp_ask]
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_ask[temp_ask]

                if position_ == 0 and len(order_book_ask[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error1111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error2222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error3333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        continue                        
                    else:
                        print 'position and Best Price is True'                        
                        continue
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    continue

            elif data.TimeStamp[i] != x1[temp_ask]:
                ###a.append(x1[temp_ask])
                #print temp_ask
                #print order_book_ask[temp_ask]
                print order_book_ask[temp_ask]['Price'][0:1].iloc[0]
                print data_ask[data_ask_number:data_ask_number+1]['BestPrice'].iloc[0]
                
                if data_ask_number == 0:
                    print 'Best Price is True'
                    pass
                elif data_ask_number > 0 and order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data_ask[data_ask_number-1:data_ask_number]['BestPrice'].iloc[0]:
                    print 'Best Price is True'
                    pass
                else:
                    print 'Best Price is False'
                    pass
                #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                #    print 'Best Price is True'
                #    continue
                #else:
                #    print 'Best Price is False'
                #    break
                    
                order_book_ask.append(order_book_ask[temp_ask])
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_ask = temp_ask + 1
                #print 'temp_ask2 = %d'%(temp_ask)
                if order_book_ask[temp_ask][(order_book_ask[temp_ask].OrderNumber == order_number_)&(order_book_ask[temp_ask].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_ask[temp_ask] = order_book_ask[temp_ask].drop(order_book_ask[temp_ask].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] = order_book_ask[temp_ask]['QuantityDifference'][order_book_ask[temp_ask].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_ask[temp_ask]
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error11111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_ask[temp_ask][position_ + 1:position_+1+1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error22222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_ask[temp_ask])-1:
                        
                    if position_ > 0 and order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error33333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        continue                        
                    else:
                        print 'position and Best Price is True'                        
                        continue 
                elif position_ == 0 and len(order_book_ask[0]) == 1:
                    print 'position and Best Price is True'
                    continue                          

    elif data.BidOrAsk[i] == 'B':
        #print i
        #print int(data[['QuantityDifference']][i:i+1].values) > 0
        data_bid_number = data_bid_number + 1
        print data_bid_number
        
        if int(data[['QuantityDifference']][i:i+1].values) > 0: #and len(order_book_bid[0]) > 0:
            print x2[temp_bid]
            print data.TimeStamp[i] == x2[temp_bid]
            
            if data.TimeStamp[i] == x2[temp_bid]:
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                #print position_
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error111111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                        
                elif 0 < position_< len(order_book_bid[temp_bid])-1:
                    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error222222 %d %d %d'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'   
                        continue
                elif position_ == len(order_book_bid[temp_bid])-1 and len(order_book_bid[0]) > 1:
                        
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error333333 %d %d %d'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                
                        continue
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    continue
                
            elif data.TimeStamp[i] != x2[temp_bid]:
                
                print 'order book best price = %d'%(order_book_bid[temp_bid]['Price'][0:1].iloc[0])
                print ''
                print 'last data best price = %d'%(data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0])
                print data_bid_number
                
                if data_bid_number == 0:
                    print 'Best Price is True'
                    pass
                elif data_bid_number > 0 and order_book_bid[temp_bid]['Price'][0:1].iloc[0] == data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0]:
                    print 'Best Price is True'
                    pass
                else:
                    print 'Best Price is False'
                    pass
                #data_bid_number = data_bid_number + 1   
                ###b.append(x2[temp_bid])
                #print 'temp bid = %d'%(temp_bid)
                #print order_book_bid[temp_bid]
                    
                if temp_bid == 0:
                    #print temp_bid
                    #print order_book_bid[temp_bid]
                    temp_bid = temp_bid + 1
                    order_book_bid[temp_bid] = order_book_bid[temp_bid - 1]
                    #print order_book_bid[temp_bid]
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)                  
                    #print order_book_bid[temp_bid]
                    best_price = data[i:(i+1)]['BestPrice']
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    #print position_
                    #print len(order_book_bid[temp_bid]) - 1
                    
                    #print order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]
                    #print order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]
                    #print order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]
                    #print order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0]
                    #print order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0]
                    #print temp_bid
                    #print order_book_bid[temp_bid]
                    #print data['BestPrice'][i]
                    #print order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0]
                    if position_ == 0  and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_ + 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error1111111 %d %d %d'%(position_,i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                            
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error2222222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_bid[temp_bid])-1:
                        
                        if order_book_bid[temp_bid][position_ -  1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error3333333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            continue
                        else:
                            print 'position and Best Price is True'
                            continue
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                            print 'position and Best Price is True'
                            continue
                else:
                    position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                    order_book_bid.append(order_book_bid[temp_bid])
                    temp_bid = temp_bid + 1
                    order_book_bid[temp_bid] = insert(order_book_bid[temp_bid],data[['Price','OrderNumber','QuantityDifference']][i:i+1],int(data[['OrderBookPosition']][i:i+1].iloc[0])-1)
                    #print position_    
                    #print len(order_book_bid[temp_bid])-1      
                    if position_ == 0 and len(order_book_bid[0]) > 1:
                        if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error11111111 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                     
                            continue
                    elif 0 < position_< len(order_book_bid[temp_bid])-1:
                    
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error22222222 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'  
                            continue
                    elif position_ == len(order_book_bid[temp_bid])-1:
                        
                        if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                            print 'Some error33333333 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                            break
                        else:
                            print 'position and Best Price is True'                        
                            continue
                    elif position_ == 0 and len(order_book_bid[0]) == 1:
                        print 'position and Best Price is True'
                        continue
                        
        elif int(data[['QuantityDifference']][i:i+1].values) < 0:    

            if data.TimeStamp[i] == x2[temp_bid]: 
                #print temp_bid
                #print order_book_bid[temp_bid]
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_bid[temp_bid]

                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error19 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
                        
                elif 0 < position_< len(order_book_bid[temp_bid])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error29 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_bid[temp_bid])-1:
                        
                    if position_ > 0 and order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_ask[temp_ask][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: 
                        print 'Some error39 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        continue
                    else:
                        print 'position and Best Price is True'                        
                        continue
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    continue

            elif data.TimeStamp[i] != x2[temp_bid]:

                print 'order book best price = %d'%(order_book_bid[temp_bid]['Price'][0:1].iloc[0])
                print ''
                print 'last data best price = %d'%(data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0])
                print data_bid_number
                
                if data_bid_number == 0:
                    print 'Best Price is True'
                    pass
                elif data_bid_number > 0 and order_book_bid[temp_bid]['Price'][0:1].iloc[0] == data_bid[data_bid_number-2:data_bid_number-1]['BestPrice'].iloc[0]:
                    print 'Best Price is True'
                    pass
                else:
                    print 'Best Price is False'
                    pass
                
                #if order_book_ask[temp_ask]['Price'][0:1].iloc[0] == data['BestPrice'][i-1]:
                #    print 'Best Price is True'
                #    continue
                #else:
                #    print 'Best Price is False'
                #    break                
                ###b.append(x2[temp_bid])
                #print temp_bid
                #print order_book_bid[temp_bid]
                order_book_bid.append(order_book_bid[temp_bid])
                position_ = int(data[['OrderBookPosition']][i:i+1].iloc[0]) - 1
                order_number_ =  data['OrderNumber'][i:i + 1].iloc[0]
                price_ = data[i:i+1]['Price'].iloc[0]
                temp_bid = temp_bid + 1
                #print position_
                #print len(order_book_ask[temp_ask])-1
                #print 'temp_bid2 = %d'%(temp_bid)
                
                if order_book_bid[temp_bid][(order_book_bid[temp_bid].OrderNumber == order_number_)&(order_book_bid[temp_bid].Price == price_)]['QuantityDifference'].iloc[0] == abs(data[i:i+1]['QuantityDifference'].iloc[0]):
                    order_book_bid[temp_bid] = order_book_bid[temp_bid].drop(order_book_bid[temp_bid].index[[position_]]).reset_index(drop = True)
                else:
                    order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] = order_book_bid[temp_bid]['QuantityDifference'][order_book_bid[temp_bid].OrderNumber == order_number_] + data[i:i+1]['QuantityDifference'].iloc[0]
                #print order_book_bid[temp_bid]
                
                if position_ == 0 and len(order_book_bid[0]) > 1:
                    if order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error110 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'                     
                        continue
    
                elif 0 < position_< len(order_book_ask[temp_ask])-1:    
                    if order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0] or order_book_bid[temp_bid][position_ + 1:position_+1+1]["Price"].iloc[0] > data['Price'][i:i+1].iloc[0]: #or order_book_bid[temp_bid]['Price'][0:1].iloc[0] != data['BestPrice'][i]: 
                        print 'Some error220 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    else:
                        print 'position and Best Price is True'  
                        continue
                elif position_ == len(order_book_bid[temp_bid])-1:
                        
                    if position_ > 0 and order_book_bid[temp_bid][position_ - 1:position_ - 1 + 1]["Price"].iloc[0] < data['Price'][i:i+1].iloc[0]: 
                        print 'Some error330 %d %d'%(i,data['Price'][i:i+1].iloc[0]) + data['OrderNumber'][i:i+1].iloc[0]
                        break
                    elif position_ == 0:
                        print 'position and Best Price is True'
                        continue
                    else:
                        print 'position and Best Price is True'                        
                        continue    
                elif position_ == 0 and len(order_book_bid[0]) == 1:
                    print 'position and Best Price is True'
                    continue                    
                                    
end = time.time()            
print "Total time = %f"%(end - start)
# Out:
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/bigdatas16/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:26: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# ------------------------------------------------------------------------------
# 12
#                         TimeStamp
# 12  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 12  673500  61CF08BD2E520E12                   4        B     674500
# data_ask_number = 10
# 4
# 2014-01-24D04:21:49.419665000
# False
# order book best price = 674000
#
# last data best price = 674000
# 4
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 13
#                         TimeStamp
# 13  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 13  673500  6D92ACE99A8D7EAD                   6        B     674500
# data_ask_number = 11
# 5
# 2014-01-24D04:21:49.422665000
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 14
#                         TimeStamp
# 14  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 14  672000  68C18D29F6F9D7F9                  20        B     674500
# data_ask_number = 12
# 6
# 2014-01-24D04:21:49.422665000
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 15
#                         TimeStamp
# 15  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 15  673000  6D53ACE9F026CF26                  20        B     674500
# data_ask_number = 13
# 7
# 2014-01-24D04:21:49.422665000
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 16
#                         TimeStamp
# 16  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 16  684000  48236F4061CE43EE                 100        A     677000
# data_ask_number = 14
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 17
#                         TimeStamp
# 17  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 17  679000  6DD500A560524412                  20        A     677000
# data_ask_number = 15
# position and Best Price is True
# ------------------------------------------------------------------------------
# 18
#                         TimeStamp
# 18  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 18  678000  439B20E9882F672F                  20        A     677000
# data_ask_number = 16
# position and Best Price is True
# ------------------------------------------------------------------------------
# 19
#                         TimeStamp
# 19  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 19  684000  40ABEF40E36DC58D                 100        A     677000
# data_ask_number = 17
# position and Best Price is True
# ------------------------------------------------------------------------------
# 20
#                         TimeStamp
# 20  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 20  710000  C678E758E205C6C5                 100        A     677000
# data_ask_number = 18
# position and Best Price is True
# ------------------------------------------------------------------------------
# 21
#                         TimeStamp
# 21  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 21  674500  C58785B9C5ABA9EB                  10        B     674500
# data_ask_number = 19
# 8
# 2014-01-24D04:21:49.422665000
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 22
#                         TimeStamp
# 22  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 22  673500  4B10A9A1DF87C3C7                  10        B     674500
# data_ask_number = 20
# 9
# 2014-01-24D04:21:49.422665000
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 23
#                         TimeStamp
# 23  2014-01-24D04:21:49.422665000
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 23  710000  4670E75802D7E798                 100        A     677000
# data_ask_number = 21
# position and Best Price is True
# ------------------------------------------------------------------------------
# 24
#                         TimeStamp
# 24  2014-01-24D08:45:00.161957700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 24  690000  E4E04F5426FE093E                  20        A     677000
# data_ask_number = 22
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 25
#                         TimeStamp
# 25  2014-01-24D08:45:00.161957700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 25  707000  66326B58E3EDC66D                  20        A     677000
# data_ask_number = 23
# position and Best Price is True
# ------------------------------------------------------------------------------
# 26
#                         TimeStamp
# 26  2014-01-24D08:45:00.161957700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 26  716500  CEB0CB549A787CB8                  20        A     677000
# data_ask_number = 24
# position and Best Price is True
# ------------------------------------------------------------------------------
# 27
#                         TimeStamp
# 27  2014-01-24D08:45:00.897944700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 27  662500  E4684F548D346F74                   1        B     674500
# data_ask_number = 25
# 10
# 2014-01-24D04:21:49.422665000
# False
# order book best price = 674500
#
# last data best price = 674500
# 10
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 28
#                         TimeStamp
# 28  2014-01-24D08:45:01.060944700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 28  650500  4EEE670095C67A86                   1        B     674500
# data_ask_number = 26
# 11
# 2014-01-24D08:45:00.897944700
# False
# order book best price = 674500
#
# last data best price = 674500
# 11
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 29
#                         TimeStamp
# 29  2014-01-24D08:45:02.530918700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 29  672000  64E0CF548D096F49                   1        B     674500
# data_ask_number = 27
# 12
# 2014-01-24D08:45:01.060944700
# False
# order book best price = 674500
#
# last data best price = 674500
# 12
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 30
#                         TimeStamp
# 30  2014-01-24D08:45:02.983918700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 30  653000  48E4C344EEFCD11C                   1        B     674500
# data_ask_number = 28
# 13
# 2014-01-24D08:45:02.530918700
# False
# order book best price = 674500
#
# last data best price = 674500
# 13
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 31
#                         TimeStamp
# 31  2014-01-24D08:45:02.985918700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 31  665000  E460CF54AED29112                   1        B     674500
# data_ask_number = 29
# 14
# 2014-01-24D08:45:02.983918700
# False
# order book best price = 674500
#
# last data best price = 674500
# 14
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 32
#                         TimeStamp
# 32  2014-01-24D08:45:02.987918700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 32  663500  EE304F0C961D787D                   1        B     674500
# data_ask_number = 30
# 15
# 2014-01-24D08:45:02.985918700
# False
# order book best price = 674500
#
# last data best price = 674500
# 15
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 33
#                         TimeStamp
# 33  2014-01-24D08:45:04.367897500
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 33  653000  E4E0CF5400FCE33D                   1        B     674500
# data_ask_number = 31
# 16
# 2014-01-24D08:45:02.987918700
# False
# order book best price = 674500
#
# last data best price = 674500
# 16
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 34
#                         TimeStamp
# 34  2014-01-24D08:45:05.194892700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 34  653500  6468CF5486486888                   1        B     674500
# data_ask_number = 32
# 17
# 2014-01-24D08:45:04.367897500
# False
# order book best price = 674500
#
# last data best price = 674500
# 17
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 35
#                         TimeStamp
# 35  2014-01-24D08:45:07.100866700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 35  692500  4C2CC35461D84418                   1        A     677000
# data_ask_number = 33
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 36
#                         TimeStamp
# 36  2014-01-24D08:45:14.335772700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 36  706000  C4A44B5472F85538                   1        A     677000
# data_ask_number = 34
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 37
#                         TimeStamp
# 37  2014-01-24D08:45:15.752749700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 37  727000  44AC4B544AAD2CED                   7        A     677000
# data_ask_number = 35
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 38
#                         TimeStamp
# 38  2014-01-24D08:45:16.592736700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 38  719000  C42C4B54338915C9                   6        A     677000
# data_ask_number = 36
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 39
#                         TimeStamp
# 39  2014-01-24D08:45:17.272736700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 39  707000  C4AC4B54CDF7B037                   4        A     677000
# data_ask_number = 37
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 40
#                         TimeStamp
# 40  2014-01-24D08:45:17.792723700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 40  635500  44244B5C1316F557                   2        B     674500
# data_ask_number = 38
# 18
# 2014-01-24D08:45:05.194892700
# False
# order book best price = 674500
#
# last data best price = 674500
# 18
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 41
#                         TimeStamp
# 41  2014-01-24D08:45:18.382716800
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 41  625500  44A44B5CB56C97AC                   4        B     674500
# data_ask_number = 39
# 19
# 2014-01-24D08:45:17.792723700
# False
# order book best price = 674500
#
# last data best price = 674500
# 19
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 42
#                         TimeStamp
# 42  2014-01-24D08:45:30.037567700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 42  725000  6548ACF505E6E4C7                   4        A     677000
# data_ask_number = 40
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 43
#                         TimeStamp
# 43  2014-01-24D08:45:30.039567700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 43  671000  4B8900E59CAE7C4E                   1        B     674500
# data_ask_number = 41
# 20
# 2014-01-24D08:45:18.382716800
# False
# order book best price = 674500
#
# last data best price = 674500
# 20
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 44
#                         TimeStamp
# 44  2014-01-24D08:45:47.570333700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 44  673000  EE34C70CFD8BDFEB                  50        B     674500
# data_ask_number = 42
# 21
# 2014-01-24D08:45:30.039567700
# False
# order book best price = 674500
#
# last data best price = 674500
# 21
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 45
#                         TimeStamp
# 45  2014-01-24D08:46:00.052177700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 45  699500  67CE08ED5A903DB0                   5        A     677000
# data_ask_number = 43
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 46
#                         TimeStamp
# 46  2014-01-24D08:46:00.053177700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 46  685500  4B1C21B9197DFDBE                   1        A     677000
# data_ask_number = 44
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 47
#                         TimeStamp
# 47  2014-01-24D08:46:00.055177700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 47  691500  E74E08ED98757B95                   1        A     677000
# data_ask_number = 45
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 48
#                         TimeStamp
# 48  2014-01-24D08:46:00.091177700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 48  673500  67C688ED19A3FCC4                  65        B     674500
# data_ask_number = 46
# 22
# 2014-01-24D08:45:47.570333700
# False
# order book best price = 674500
#
# last data best price = 674500
# 22
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 49
#                         TimeStamp
# 49  2014-01-24D08:46:00.095177700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 49  673000  E74688ED54B737D7                  65        B     674500
# data_ask_number = 47
# 23
# 2014-01-24D08:46:00.091177700
# False
# order book best price = 674500
#
# last data best price = 674500
# 23
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 50
#                         TimeStamp
# 50  2014-01-24D08:46:00.096177700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 50  672000  4B94A1B90467E8A8                 130        B     674500
# data_ask_number = 48
# 24
# 2014-01-24D08:46:00.095177700
# False
# order book best price = 674500
#
# last data best price = 674500
# 24
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 51
#                         TimeStamp
# 51  2014-01-24D08:46:01.024164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 51  697000  E7C688ED838366A3                  10        A     677000
# data_ask_number = 49
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 52
#                         TimeStamp
# 52  2014-01-24D08:46:01.030164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 52  737500  674E88EDB4329752                   5        A     677000
# data_ask_number = 50
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 53
#                         TimeStamp
# 53  2014-01-24D08:46:01.032164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 53  672500  CB94A1B9E628CA68                 130        B     674500
# data_ask_number = 51
# 25
# 2014-01-24D08:46:00.096177700
# False
# order book best price = 674500
#
# last data best price = 674500
# 25
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 54
#                         TimeStamp
# 54  2014-01-24D08:46:01.034164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 54  671500  67CE88EDEB26CE46                 196        B     674500
# data_ask_number = 52
# 26
# 2014-01-24D08:46:01.032164700
# False
# order book best price = 674500
#
# last data best price = 674500
# 26
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 55
#                         TimeStamp
# 55  2014-01-24D08:46:01.036164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 55  727500  4B1CA1B99EE28322                  10        A     677000
# data_ask_number = 53
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 56
#                         TimeStamp
# 56  2014-01-24D08:46:01.037164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 56  682500  E74E88EDD6AEB9CE                  65        A     677000
# data_ask_number = 54
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 57
#                         TimeStamp
# 57  2014-01-24D08:46:01.039164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 57  737500  4B9CA1B941D12611                   6        A     677000
# data_ask_number = 55
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 58
#                         TimeStamp
# 58  2014-01-24D08:46:01.039164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 58  731500  E7CE88ED32F41614                   6        A     677000
# data_ask_number = 56
# position and Best Price is True
# ------------------------------------------------------------------------------
# 59
#                         TimeStamp
# 59  2014-01-24D08:46:01.042164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 59  683500  6F4608E53C571F77                 130        A     677000
# data_ask_number = 57
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 60
#                         TimeStamp
# 60  2014-01-24D08:46:01.042164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 60  683000  CB1CA1B90450E891                  65        A     677000
# data_ask_number = 58
# position and Best Price is True
# ------------------------------------------------------------------------------
# 61
#                         TimeStamp
# 61  2014-01-24D08:46:01.044164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 61  684000  6FC608E5ADAB90CB                 130        A     677000
# data_ask_number = 59
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 62
#                         TimeStamp
# 62  2014-01-24D08:46:01.045164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 62  684500  CB9CA1B98A1C6E5C                 196        A     677000
# data_ask_number = 60
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 63
#                         TimeStamp
# 63  2014-01-24D08:46:01.047164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 63  670000  EF4608E5CE04B124                  15        B     674500
# data_ask_number = 61
# 27
# 2014-01-24D08:46:01.034164700
# False
# order book best price = 674500
#
# last data best price = 674500
# 27
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 64
#                         TimeStamp
# 64  2014-01-24D08:46:01.047164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 64  672000  431429B1819C65DC                  15        B     674500
# data_ask_number = 62
# 28
# 2014-01-24D08:46:01.047164700
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 65
#                         TimeStamp
# 65  2014-01-24D08:46:01.050164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 65  671000  EFC608E547852AA5                  15        B     674500
# data_ask_number = 63
# 29
# 2014-01-24D08:46:01.047164700
# False
# order book best price = 674500
#
# last data best price = 674500
# 29
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 66
#                         TimeStamp
# 66  2014-01-24D08:46:01.050164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 66  669500  439429B1F2D4D714                  15        B     674500
# data_ask_number = 64
# 30
# 2014-01-24D08:46:01.050164700
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 67
#                         TimeStamp
# 67  2014-01-24D08:46:01.053164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 67  666000  6F4E08E57A005D20                  15        B     674500
# data_ask_number = 65
# 31
# 2014-01-24D08:46:01.050164700
# False
# order book best price = 674500
#
# last data best price = 674500
# 31
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 68
#                         TimeStamp
# 68  2014-01-24D08:46:01.054164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 68  667500  C31429B161D14611                  15        B     674500
# data_ask_number = 66
# 32
# 2014-01-24D08:46:01.053164700
# False
# order book best price = 674500
#
# last data best price = 674500
# 32
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 69
#                         TimeStamp
# 69  2014-01-24D08:46:01.056164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 69  667000  6FCE08E507D8EAF9                  15        B     674500
# data_ask_number = 67
# 33
# 2014-01-24D08:46:01.054164700
# False
# order book best price = 674500
#
# last data best price = 674500
# 33
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 70
#                         TimeStamp
# 70  2014-01-24D08:46:01.057164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 70  682000  C39429B14A7E2EBE                  15        A     677000
# data_ask_number = 68
# 677000
# 677000
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 71
#                         TimeStamp
# 71  2014-01-24D08:46:01.059164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 71  682500  EF4E08E515E2F903                  15        A     677000
# data_ask_number = 69
# 677000
# 676500
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 72
#                         TimeStamp
# 72  2014-01-24D08:46:01.060164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 72  681500  431C29B1029DE6DE                  15        A     677000
# data_ask_number = 70
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 73
#                         TimeStamp
# 73  2014-01-24D08:46:01.062164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 73  681000  EFCE08E558C43BE4                  15        A     677000
# data_ask_number = 71
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 74
#                         TimeStamp
# 74  2014-01-24D08:46:01.064164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 74  686500  439C29B12C5B109B                  15        A     677000
# data_ask_number = 72
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 75
#                         TimeStamp
# 75  2014-01-24D08:46:01.068164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 75  684000  6F4608ED2EBF11DF                   5        A     677000
# data_ask_number = 73
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 76
#                         TimeStamp
# 76  2014-01-24D08:46:01.070164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 76  704500  C31C29B160ED452D                   1        A     677000
# data_ask_number = 74
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 77
#                         TimeStamp
# 77  2014-01-24D08:46:01.071164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 77  655000  6FC608EDDE8FC1AF                  50        B     674500
# data_ask_number = 75
# 34
# 2014-01-24D08:46:01.056164700
# False
# order book best price = 674500
#
# last data best price = 674500
# 34
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 78
#                         TimeStamp
# 78  2014-01-24D08:46:01.073164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 78  677000  C39C29B18C6670A6                  10        A     677000
# data_ask_number = 76
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 79
#                         TimeStamp
# 79  2014-01-24D08:46:01.074164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 79  677500  EF4608ED832B664B                  20        A     677000
# data_ask_number = 77
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 80
#                         TimeStamp
# 80  2014-01-24D08:46:01.076164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 80  678000  431429B9069EEADF                  10        A     677000
# data_ask_number = 78
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 81
#                         TimeStamp
# 81  2014-01-24D08:46:01.077164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 81  678000  EFC608ED00EAE40B                  10        A     677000
# data_ask_number = 79
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 82
#                         TimeStamp
# 82  2014-01-24D08:46:01.079164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 82  699000  439429B96FB653F6                   1        A     677000
# data_ask_number = 80
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 83
#                         TimeStamp
# 83  2014-01-24D08:46:01.241164700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 83  685000  4E7E6B00E2CEC78E                   7        A     677000
# data_ask_number = 81
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 84
#                         TimeStamp
# 84  2014-01-24D08:46:02.084151700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 84  700000  67C604E52DC210E2                   2        A     677000
# data_ask_number = 82
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 85
#                         TimeStamp
# 85  2014-01-24D08:46:02.085151700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 85  690000  C31CA9B1D195B5D5                   2        A     677000
# data_ask_number = 83
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 86
#                         TimeStamp
# 86  2014-01-24D08:46:03.042138700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 86  678500  EF4E04E5135AF67B                  10        A     677000
# data_ask_number = 84
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 87
#                         TimeStamp
# 87  2014-01-24D08:46:03.048138700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 87  678000  EFCE04E552D435F4                  50        A     677000
# data_ask_number = 85
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 88
#                         TimeStamp
# 88  2014-01-24D08:46:07.898073700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 88  665500  44ACC754EF3DD17D                   1        B     674500
# data_ask_number = 86
# 35
# 2014-01-24D08:46:01.071164700
# False
# order book best price = 674500
#
# last data best price = 674500
# 35
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 89
#                         TimeStamp
# 89  2014-01-24D08:46:40.895644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 89  667000  6FCE08E507D8EAF9                 -15        B     674500
# data_ask_number = 87
# 36
# order book best price = 674500
#
# last data best price = 674500
# 36
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 90
#                         TimeStamp
# 90  2014-01-24D08:46:40.904644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 90  681000  EFCE08E558C43BE4                 -15        A     677000
# data_ask_number = 88
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 91
#                         TimeStamp
# 91  2014-01-24D08:46:40.904644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 91  682500  EF4E08E515E2F903                 -15        A     677000
# data_ask_number = 89
# position and Best Price is True
# ------------------------------------------------------------------------------
# 92
#                         TimeStamp
# 92  2014-01-24D08:46:40.907644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 92  671000  EFC608E547852AA5                 -15        B     674500
# data_ask_number = 90
# 37
# order book best price = 674500
#
# last data best price = 674500
# 37
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 93
#                         TimeStamp
# 93  2014-01-24D08:46:40.908644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 93  667500  C31429B161D14611                 -15        B     674500
# data_ask_number = 91
# 38
# order book best price = 674500
#
# last data best price = 674500
# 38
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 94
#                         TimeStamp
# 94  2014-01-24D08:46:40.911644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 94  666000  6F4E08E57A005D20                 -15        B     674500
# data_ask_number = 92
# 39
# order book best price = 674500
#
# last data best price = 674500
# 39
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 95
#                         TimeStamp
# 95  2014-01-24D08:46:40.912644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 95  670000  EF4608E5CE04B124                 -15        B     674500
# data_ask_number = 93
# 40
# order book best price = 674500
#
# last data best price = 674500
# 40
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 96
#                         TimeStamp
# 96  2014-01-24D08:46:40.915644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 96  686500  439C29B12C5B109B                 -15        A     677000
# data_ask_number = 94
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 97
#                         TimeStamp
# 97  2014-01-24D08:46:40.916644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 97  681500  431C29B1029DE6DE                 -15        A     677000
# data_ask_number = 95
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 98
#                         TimeStamp
# 98  2014-01-24D08:46:40.918644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 98  669500  439429B1F2D4D714                 -15        B     674500
# data_ask_number = 96
# 41
# order book best price = 674500
#
# last data best price = 674500
# 41
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 99
#                         TimeStamp
# 99  2014-01-24D08:46:40.919644700
#      Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 99  682000  C39429B14A7E2EBE                 -15        A     677000
# data_ask_number = 97
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 100
#                          TimeStamp
# 100  2014-01-24D08:46:40.925644700
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 100  672000  431429B1819C65DC                 -15        B     674500
# data_ask_number = 98
# 42
# order book best price = 674500
#
# last data best price = 674500
# 42
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 101
#                          TimeStamp
# 101  2014-01-24D08:46:51.683501300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 101  677000  4513A8B9DA30B930                   6        A     677000
# data_ask_number = 99
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 102
#                          TimeStamp
# 102  2014-01-24D08:46:59.024410300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 102  680000  CD592CA52AF809D8                   6        A     677000
# data_ask_number = 100
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 103
#                          TimeStamp
# 103  2014-01-24D08:47:10.894254300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 103  693000  48FBE308308D130D                   1        A     677000
# data_ask_number = 101
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 104
#                          TimeStamp
# 104  2014-01-24D08:47:18.394163300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 104  703000  C8FBE30868FA4B7A                   1        A     677000
# data_ask_number = 102
# 677000
# 674500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 105
#                          TimeStamp
# 105  2014-01-24D08:47:25.411072300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 105  713000  40F36B00D042B2C2                   1        A     677000
# data_ask_number = 103
# 677000
# 674500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 106
#                          TimeStamp
# 106  2014-01-24D08:47:31.716981300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 106  723000  C0F36B004FE43264                   1        A     677000
# data_ask_number = 104
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 107
#                          TimeStamp
# 107  2014-01-24D08:47:36.023929300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 107  653000  C864CF4C483E2A5E                   1        B     674500
# data_ask_number = 105
# 43
# 2014-01-24D08:46:40.925644700
# False
# order book best price = 674500
#
# last data best price = 674500
# 43
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 108
#                          TimeStamp
# 108  2014-01-24D08:47:36.025929300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 108  663500  64704F5CF414D654                   1        B     674500
# data_ask_number = 106
# 44
# 2014-01-24D08:47:36.023929300
# False
# order book best price = 674500
#
# last data best price = 674500
# 44
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 109
#                          TimeStamp
# 109  2014-01-24D08:47:36.509929300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 109  653500  64F04F5C5F204160                   1        B     674500
# data_ask_number = 107
# 45
# 2014-01-24D08:47:36.025929300
# False
# order book best price = 674500
#
# last data best price = 674500
# 45
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 110
#                          TimeStamp
# 110  2014-01-24D08:47:37.185916300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 110  733000  40FB6B00266108E1                   1        A     677000
# data_ask_number = 108
# 677000
# 676500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 111
#                          TimeStamp
# 111  2014-01-24D08:47:54.358695300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 111  743000  407B6B08FEE5E165                   1        A     677000
# data_ask_number = 109
# 677000
# 676000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 112
#                          TimeStamp
# 112  2014-01-24D08:48:03.515578300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 112  709000  4A384F4CDB07BD27                  10        A     677000
# data_ask_number = 110
# 677000
# 675500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 113
#                          TimeStamp
# 113  2014-01-24D08:48:16.235409300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 113  662500  6CF84F5CC9D1AC11                   1        B     674500
# data_ask_number = 111
# 46
# 2014-01-24D08:47:36.509929300
# False
# order book best price = 674500
#
# last data best price = 674500
# 46
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 114
#                          TimeStamp
# 114  2014-01-24D08:48:18.891370300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 114  632500  4AB8CF4C1922FB43                  10        B     674500
# data_ask_number = 112
# 47
# 2014-01-24D08:48:16.235409300
# False
# order book best price = 674500
#
# last data best price = 674500
# 47
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 115
#                          TimeStamp
# 115  2014-01-24D08:49:17.448616300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 115  700000  C59B24B924C803C8                   1        A     677000
# data_ask_number = 113
# 677000
# 675500
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 116
#                          TimeStamp
# 116  2014-01-24D08:49:19.861584000
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 116  665000  C0FCC3449F1A813A                   1        B     674500
# data_ask_number = 114
# 48
# 2014-01-24D08:48:18.891370300
# False
# order book best price = 674500
#
# last data best price = 674500
# 48
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 117
#                          TimeStamp
# 117  2014-01-24D08:49:23.695538300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 117  647000  487B6B008EBE713E                   1        B     674500
# data_ask_number = 115
# 49
# 2014-01-24D08:49:19.861584000
# False
# order book best price = 674500
#
# last data best price = 674500
# 49
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 118
#                          TimeStamp
# 118  2014-01-24D08:49:28.944460500
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 118  647000  487B6B008EBE713E                  -1        B     674500
# data_ask_number = 116
# 50
# order book best price = 674500
#
# last data best price = 674500
# 50
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 119
#                          TimeStamp
# 119  2014-01-24D08:50:11.679914300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 119  663500  C8A14B0446FA293A                   1        B     674500
# data_ask_number = 117
# 51
# 2014-01-24D08:49:28.944460500
# False
# order book best price = 674500
#
# last data best price = 674500
# 51
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 120
#                          TimeStamp
# 120  2014-01-24D08:50:11.703914300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 120  653000  487CCB441A55FC76                   1        B     674500
# data_ask_number = 118
# 52
# 2014-01-24D08:50:11.679914300
# False
# order book best price = 674500
#
# last data best price = 674500
# 52
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 121
#                          TimeStamp
# 121  2014-01-24D08:50:11.891914300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 121  653500  48FCCB4467F74A17                   1        B     674500
# data_ask_number = 119
# 53
# 2014-01-24D08:50:11.703914300
# False
# order book best price = 674500
#
# last data best price = 674500
# 53
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 122
#                          TimeStamp
# 122  2014-01-24D08:50:13.162888300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 122  676500  CE704B0CC2C4A524                   5        A     676500
# data_ask_number = 120
# 677000
# 675000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 123
#                          TimeStamp
# 123  2014-01-24D08:50:59.982290300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 123  682000  4C3CC354347416B4                   1        A     676500
# data_ask_number = 121
# 676500
# 675000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 124
#                          TimeStamp
# 124  2014-01-24D08:51:00.517277300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 124  673500  EC77EB18943A793A                  30        B     674500
# data_ask_number = 122
# 54
# 2014-01-24D08:50:11.891914300
# False
# order book best price = 674500
#
# last data best price = 674500
# 54
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 125
#                          TimeStamp
# 125  2014-01-24D08:51:01.142264300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 125  673000  6C2567505DC642A6                  30        B     674500
# data_ask_number = 123
# 55
# 2014-01-24D08:51:00.517277300
# False
# order book best price = 674500
#
# last data best price = 674500
# 55
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 126
#                          TimeStamp
# 126  2014-01-24D08:51:01.583264300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 126  672500  EEEFEB1092057705                  30        B     674500
# data_ask_number = 124
# 56
# 2014-01-24D08:51:01.142264300
# False
# order book best price = 674500
#
# last data best price = 674500
# 56
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 127
#                          TimeStamp
# 127  2014-01-24D08:51:02.007264100
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 127  672000  42F5EF50024AE72B                  30        B     674500
# data_ask_number = 125
# 57
# 2014-01-24D08:51:01.583264300
# False
# order book best price = 674500
#
# last data best price = 674500
# 57
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 128
#                          TimeStamp
# 128  2014-01-24D08:51:02.344251300
#       Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 128  671500  C428CB0429C50EC5                  30        B     674500
# data_ask_number = 126
# 58
# 2014-01-24D08:51:02.007264100
# False
# order book best price = 674500
#
# last data best price = 674500
# 58
# Best Price is True
# ...
# 3160
#                           TimeStamp
# 3160  2014-01-24D09:17:24.012736600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3160  672500  6DCBACB9EE3CD19C                  20        B     673500
# data_ask_number = 3158
# 1529
# 2014-01-24D09:17:24.009736600
# False
# order book best price = 673500
#
# last data best price = 673500
# 1529
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3161
#                           TimeStamp
# 3161  2014-01-24D09:17:24.012736600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3161  675000  CF4504E55AA53E65                  20        A     674500
# data_ask_number = 3159
# 674500
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3162
#                           TimeStamp
# 3162  2014-01-24D09:17:24.027736600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3162  666500  6B942DF113E6F827                  20        B     673500
# data_ask_number = 3160
# 1530
# 2014-01-24D09:17:24.012736600
# False
# order book best price = 673500
#
# last data best price = 673500
# 1530
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3163
#                           TimeStamp
# 3163  2014-01-24D09:17:24.360723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3163  672000  EE12256964E04560                  10        B     673500
# data_ask_number = 3161
# 1531
# 2014-01-24D09:17:24.027736600
# False
# order book best price = 673500
#
# last data best price = 673500
# 1531
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3164
#                           TimeStamp
# 3164  2014-01-24D09:17:24.371723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3164  676000  E05EA13569744A14                  -7        A     674500
# data_ask_number = 3162
# 674500
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3165
#                           TimeStamp
# 3165  2014-01-24D09:17:24.372723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3165  676000  604A2D3D42A32343                 -10        A     674000
# data_ask_number = 3163
# 674500
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3166
#                           TimeStamp
# 3166  2014-01-24D09:17:24.372723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3166  674000  604A2D3D42A32343                  10        A     674000
# data_ask_number = 3164
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3167
#                           TimeStamp
# 3167  2014-01-24D09:17:24.372723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3167  674000  E25AA9651E6DFF0E                   8        A     674000
# data_ask_number = 3165
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3168
#                           TimeStamp
# 3168  2014-01-24D09:17:24.375723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3168  675000  618980B5D954B8F4                 -10        A     674000
# data_ask_number = 3166
# 674000
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3169
#                           TimeStamp
# 3169  2014-01-24D09:17:24.377723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3169  673500  CD0424A57F935F53                  10        B     673500
# data_ask_number = 3167
# 1532
# 2014-01-24D09:17:24.360723600
# False
# order book best price = 673500
#
# last data best price = 673500
# 1532
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3170
#                           TimeStamp
# 3170  2014-01-24D09:17:24.381723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3170  674500  6D1F00E5AC198FB9                   5        A     674000
# data_ask_number = 3168
# 674000
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3171
#                           TimeStamp
# 3171  2014-01-24D09:17:24.382723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3171  674000  E25AA9651E6DFF0E                  -8        A     674000
# data_ask_number = 3169
# 674000
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3172
#                           TimeStamp
# 3172  2014-01-24D09:17:24.382723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3172  674000  604A2D3D42A32343                 -10        A     674500
# data_ask_number = 3170
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3173
#                           TimeStamp
# 3173  2014-01-24D09:17:24.382723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3173  676000  604A2D3D42A32343                  10        A     674500
# data_ask_number = 3171
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3174
#                           TimeStamp
# 3174  2014-01-24D09:17:24.385723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3174  676000  CC8EA925AB6B8C0B                  10        A     674500
# data_ask_number = 3172
# 674500
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3175
#                           TimeStamp
# 3175  2014-01-24D09:17:24.386723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3175  673500  CD0424A57F935F53                 -10        B     673500
# data_ask_number = 3173
# 1533
# order book best price = 673500
#
# last data best price = 673500
# 1533
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3176
#                           TimeStamp
# 3176  2014-01-24D09:17:24.566723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3176  673500  6252A96D218C022C                   5        B     673500
# data_ask_number = 3174
# 1534
# 2014-01-24D09:17:24.386723600
# False
# order book best price = 673500
#
# last data best price = 673500
# 1534
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3177
#                           TimeStamp
# 3177  2014-01-24D09:17:24.897723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3177  666500  6B942DF113E6F827                 -20        B     673500
# data_ask_number = 3175
# 1535
# order book best price = 673500
#
# last data best price = 673500
# 1535
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3178
#                           TimeStamp
# 3178  2014-01-24D09:17:24.897723600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3178  669500  6B942DF113E6F827                  20        B     673500
# data_ask_number = 3176
# 1536
# 2014-01-24D09:17:24.897723600
# True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3179
#                           TimeStamp
# 3179  2014-01-24D09:17:26.915697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3179  673000  C58C20AD13B7F378                 -10        B     673500
# data_ask_number = 3177
# 1537
# order book best price = 673500
#
# last data best price = 673500
# 1537
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3180
#                           TimeStamp
# 3180  2014-01-24D09:17:26.915697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3180  673500  68862979C846A8C6                 -10        B     673500
# data_ask_number = 3178
# 1538
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3181
#                           TimeStamp
# 3181  2014-01-24D09:17:26.915697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3181  674500  C8C22971AD488DC8                  10        A     674500
# data_ask_number = 3179
# 674500
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3182
#                           TimeStamp
# 3182  2014-01-24D09:17:26.918697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3182  676000  CC8EA925AB6B8C0B                 -10        A     674500
# data_ask_number = 3180
# 674500
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3183
#                           TimeStamp
# 3183  2014-01-24D09:17:26.918697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3183  676000  604A2D3D42A32343                 -10        A     674000
# data_ask_number = 3181
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3184
#                           TimeStamp
# 3184  2014-01-24D09:17:26.918697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3184  674000  604A2D3D42A32343                  10        A     674000
# data_ask_number = 3182
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3185
#                           TimeStamp
# 3185  2014-01-24D09:17:26.918697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3185  674000  4C86A92DFFEEE08E                   5        A     674000
# data_ask_number = 3183
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3186
#                           TimeStamp
# 3186  2014-01-24D09:17:26.921697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3186  673500  4D8C24A573C55385                  10        B     673500
# data_ask_number = 3184
# 1539
# 2014-01-24D09:17:26.915697600
# False
# order book best price = 673500
#
# last data best price = 673500
# 1539
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3187
#                           TimeStamp
# 3187  2014-01-24D09:17:26.921697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3187  674000  6E9A2569BCDA9D5A                  10        A     674000
# data_ask_number = 3185
# 674000
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3188
#                           TimeStamp
# 3188  2014-01-24D09:17:26.923697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3188  673500  690900BD395218F2                  10        B     673500
# data_ask_number = 3186
# 1540
# 2014-01-24D09:17:26.921697600
# False
# order book best price = 673500
#
# last data best price = 673500
# 1540
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3189
#                           TimeStamp
# 3189  2014-01-24D09:17:26.926697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3189  674000  4C86A92DFFEEE08E                  -5        A     674000
# data_ask_number = 3187
# 674000
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3190
#                           TimeStamp
# 3190  2014-01-24D09:17:26.926697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3190  674000  604A2D3D42A32343                 -10        A     674000
# data_ask_number = 3188
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3191
#                           TimeStamp
# 3191  2014-01-24D09:17:26.926697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3191  676000  604A2D3D42A32343                  10        A     674000
# data_ask_number = 3189
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3192
#                           TimeStamp
# 3192  2014-01-24D09:17:26.929697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3192  676000  CACE256DB00690A6                  10        A     674000
# data_ask_number = 3190
# 674000
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3193
#                           TimeStamp
# 3193  2014-01-24D09:17:26.929697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3193  673500  4D8C24A573C55385                 -10        B     673500
# data_ask_number = 3191
# 1541
# order book best price = 673500
#
# last data best price = 673500
# 1541
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3194
#                           TimeStamp
# 3194  2014-01-24D09:17:26.929697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3194  674000  6E9A2569BCDA9D5A                 -10        A     674500
# data_ask_number = 3192
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3195
#                           TimeStamp
# 3195  2014-01-24D09:17:26.930697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3195  673500  690900BD395218F2                 -10        B     673500
# data_ask_number = 3193
# 1542
# order book best price = 673500
#
# last data best price = 673500
# 1542
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3196
#                           TimeStamp
# 3196  2014-01-24D09:17:27.070697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3196  673500  659980F558B13C71                 -40        B     673500
# data_ask_number = 3194
# 1543
# order book best price = 673500
#
# last data best price = 673500
# 1543
# Best Price is True
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3197
#                           TimeStamp
# 3197  2014-01-24D09:17:27.073697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3197  676000  CACE256DB00690A6                 -10        A     674500
# data_ask_number = 3195
# 674500
# 673000
# Best Price is False
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3198
#                           TimeStamp
# 3198  2014-01-24D09:17:27.073697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3198  676000  604A2D3D42A32343                 -10        A     674000
# data_ask_number = 3196
# position and Best Price is True
# ------------------------------------------------------------------------------
# 3199
#                           TimeStamp
# 3199  2014-01-24D09:17:27.073697600
#        Price       OrderNumber  QuantityDifference BidOrAsk  BestPrice
# 3199  674000  604A2D3D42A32343                  10        A     674000
# data_ask_number = 3197
# position and Best Price is True
# Total time = 125.504662

# %%
len(order_book_ask)
# Out:
# 1157

# %%
len(data[0:3200][(data[0:3200].BidOrAsk == 'A')].TimeStamp.unique())
# Out:
# 1157

# %%
len(order_book_bid)
# Out:
# 1121

# %%
len(data[0:3200][(data[0:3200].BidOrAsk == 'B')].TimeStamp.unique())
# Out:
# 1121

# %%
a = data[(data.BidOrAsk == 'A')].index.tolist()[9]  
#data[(data.BidOrAsk == 'A')].head(20) #['BestPrice'].iloc[0]
data[(data.BidOrAsk == 'A')][16:17]
# Out:
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 25  CNF14              26  2014-01-24D08:45:00.161957700  66326B58E3EDC66D
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 25                 13  707000                  20              A     677000
#
#     BestQuantity
# 25            19

# %%
data[(data.BidOrAsk == 'A')].reindex()[0:1]#.head()   #.tolist()
# Out:
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 0  CNF14               1  2014-01-24D04:21:49.419665000  C791DA0F799A5E9A
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 0                  1  710000                   2              A     677000
#
#    BestQuantity
# 0            19

# %%
data_ask = data[(data.BidOrAsk == 'A')].reindex()

j = 0

for i in range(0,20,1):
    print '------------------------------------------------------------------------------'
    print i
    print data[i:i+1]
    #print data_ask[j:j+1]
    #print data.BidOrAsk[i] == 'A'
    if data.BidOrAsk[i] == 'A':
        print data_ask[j:j+1]['BestPrice'].iloc[0]
        j = j + 1 
    else:
        print data_ask[j-1:j]
# Out:
# ------------------------------------------------------------------------------
# 0
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 0  CNF14               1  2014-01-24D04:21:49.419665000  C791DA0F799A5E9A
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 0                  1  710000                   2              A     677000
#
#    BestQuantity
# 0            19
# 677000
# ------------------------------------------------------------------------------
# 1
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 1  CNF14               2  2014-01-24D04:21:49.419665000  E1C9F25394A679A6
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 1                  2  719500                   1              A     677000
#
#    BestQuantity
# 1            19
# 677000
# ------------------------------------------------------------------------------
# 2
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 2  CNF14               3  2014-01-24D04:21:49.419665000  C02B6F481F080128
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 2                  1  684000                 100              A     677000
#
#    BestQuantity
# 2            19
# 677000
# ------------------------------------------------------------------------------
# 3
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 3  CNF14               4  2014-01-24D04:21:49.419665000  C55C20A9615D40FD
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 3                  2  692500                   1              A     677000
#
#    BestQuantity
# 3            19
# 677000
# ------------------------------------------------------------------------------
# 4
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 4  CNF14               5  2014-01-24D04:21:49.419665000  E5D428BDEDEDCCCD
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 4                  1  678500                  20              A     677000
#
#    BestQuantity
# 4            19
# 677000
# ------------------------------------------------------------------------------
# 5
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 5  CNF14               6  2014-01-24D04:21:49.419665000  C1442DE9FABCDEFC
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 5                  2  679500                  20              A     677000
#
#    BestQuantity
# 5            19
# 677000
# ------------------------------------------------------------------------------
# 6
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 6  CNF14               7  2014-01-24D04:21:49.419665000  CD0701B13A4F1E8F
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 6                  1  674000                  10              B     674000
#
#    BestQuantity
# 6            20
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 5  CNF14               6  2014-01-24D04:21:49.419665000  C1442DE9FABCDEFC
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 5                  2  679500                  20              A     677000
#
#    BestQuantity
# 5            19
# ------------------------------------------------------------------------------
# 7
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 7  CNF14               8  2014-01-24D04:21:49.419665000  CB1CA0F570654F45
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 7                  2  672500                  20              B     674000
#
#    BestQuantity
# 7            20
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 5  CNF14               6  2014-01-24D04:21:49.419665000  C1442DE9FABCDEFC
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 5                  2  679500                  20              A     677000
#
#    BestQuantity
# 5            19
# ------------------------------------------------------------------------------
# 8
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 8  CNF14               9  2014-01-24D04:21:49.419665000  E94584AD9F7F833F
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 8                  1  677000                  19              A     677000
#
#    BestQuantity
# 8            19
# 677000
# ------------------------------------------------------------------------------
# 9
#   Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 9  CNF14              10  2014-01-24D04:21:49.419665000  9672009CE4FAC9FA
#
#    OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 9                  5  689500                   2              A     677000
#
#    BestQuantity
# 9            19
# 677000
# ------------------------------------------------------------------------------
# 10
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 10  CNF14              11  2014-01-24D04:21:49.419665000  CFCC80F56C3C4FFC
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 10                  2  677500                  20              A     677000
#
#     BestQuantity
# 10            19
# 677000
# ------------------------------------------------------------------------------
# 11
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 11  CNF14              12  2014-01-24D04:21:49.419665000  C5C820E5C19AA2DA
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 11                  2  674000                  10              B     674000
#
#     BestQuantity
# 11            20
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 10  CNF14              11  2014-01-24D04:21:49.419665000  CFCC80F56C3C4FFC
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 10                  2  677500                  20              A     677000
#
#     BestQuantity
# 10            19
# ------------------------------------------------------------------------------
# 12
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 12  CNF14              13  2014-01-24D04:21:49.422665000  61CF08BD2E520E12
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 12                  3  673500                   4              B     674500
#
#     BestQuantity
# 12            10
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 10  CNF14              11  2014-01-24D04:21:49.419665000  CFCC80F56C3C4FFC
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 10                  2  677500                  20              A     677000
#
#     BestQuantity
# 10            19
# ------------------------------------------------------------------------------
# 13
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 13  CNF14              14  2014-01-24D04:21:49.422665000  6D92ACE99A8D7EAD
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 13                  4  673500                   6              B     674500
#
#     BestQuantity
# 13            10
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 10  CNF14              11  2014-01-24D04:21:49.419665000  CFCC80F56C3C4FFC
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 10                  2  677500                  20              A     677000
#
#     BestQuantity
# 10            19
# ------------------------------------------------------------------------------
# 14
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 14  CNF14              15  2014-01-24D04:21:49.422665000  68C18D29F6F9D7F9
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 14                  6  672000                  20              B     674500
#
#     BestQuantity
# 14            10
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 10  CNF14              11  2014-01-24D04:21:49.419665000  CFCC80F56C3C4FFC
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 10                  2  677500                  20              A     677000
#
#     BestQuantity
# 10            19
# ------------------------------------------------------------------------------
# 15
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 15  CNF14              16  2014-01-24D04:21:49.422665000  6D53ACE9F026CF26
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 15                  5  673000                  20              B     674500
#
#     BestQuantity
# 15            10
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 10  CNF14              11  2014-01-24D04:21:49.419665000  CFCC80F56C3C4FFC
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 10                  2  677500                  20              A     677000
#
#     BestQuantity
# 10            19
# ------------------------------------------------------------------------------
# 16
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 16  CNF14              17  2014-01-24D04:21:49.422665000  48236F4061CE43EE
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 16                  6  684000                 100              A     677000
#
#     BestQuantity
# 16            19
# 677000
# ------------------------------------------------------------------------------
# 17
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 17  CNF14              18  2014-01-24D04:21:49.422665000  6DD500A560524412
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 17                  4  679000                  20              A     677000
#
#     BestQuantity
# 17            19
# 677000
# ------------------------------------------------------------------------------
# 18
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 18  CNF14              19  2014-01-24D04:21:49.422665000  439B20E9882F672F
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 18                  3  678000                  20              A     677000
#
#     BestQuantity
# 18            19
# 677000
# ------------------------------------------------------------------------------
# 19
#    Series  SequenceNumber                      TimeStamp       OrderNumber  \
# 19  CNF14              20  2014-01-24D04:21:49.422665000  40ABEF40E36DC58D
#
#     OrderBookPosition   Price  QuantityDifference Trade BidOrAsk  BestPrice  \
# 19                  8  684000                 100              A     677000
#
#     BestQuantity
# 19            19
# 677000
